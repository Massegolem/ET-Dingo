# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # use GPU 1

from dingo.core.posterior_models.build_model import build_model_from_kwargs

main_pm = build_model_from_kwargs(
    filename="/scratch/tpausch/models/imbh_T2/model_latest.pt",
    device="cuda",
    load_training_info=False,
)
# Out:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Putting posterior model to device cuda.

# %%
import os
import pickle
import numpy as np

import dingo.gw.injection as injection
from dingo.gw.noise.asd_dataset import ASDDataset

# ============================================================
# Setup
# ============================================================

num_injections = 1000
out_dir = "/scratch/tpausch/test_data/imbh_T2/injections"
os.makedirs(out_dir, exist_ok=True)

np.random.seed(42)  # optional, for reproducibility

injection_generator = injection.Injection.from_posterior_model_metadata(
    main_pm.metadata
)

asd_fname = main_pm.metadata["train_settings"]["training"]["stage_0"]["asd_dataset_path"]
asd_dataset = ASDDataset(file_name=asd_fname)

injection_generator.asd = {
    k: v[0] for k, v in asd_dataset.asds.items()
}

# This is the combined intrinsic + extrinsic bilby PriorDict
# that the network was trained on
prior = injection_generator.prior
print(prior)

# ============================================================
# Draw and run injections
# ============================================================

for idx in range(num_injections):

    print(f"Running injection {idx}")

    theta = prior.sample()
    theta = {k: float(v) for k, v in theta.items()}  # cast numpy -> float

    strain_data = injection_generator.injection(theta)

    payload = {
        "theta_true": theta,
        "strain_data": strain_data,
    }

    fname = os.path.join(out_dir, f"inj_{idx:04d}.pkl")

    with open(fname, "wb") as f:
        pickle.dump(payload, f)
# Out:
# Setting spin_conversion_phase = 0.0. Using this value for the phase parameter for conversion to cartesian spins.
# Loading dataset from training_data/asds_ET_T2.hdf5.
# {'mass_1': Constraint(minimum=50.0, maximum=1500.0, name='mass_1', latex_label='$m_1$', unit=None), 'mass_2': Constraint(minimum=50.0, maximum=1500.0, name='mass_2', latex_label='$m_2$', unit=None), 'chirp_mass': bilby.gw.prior.UniformInComponentsChirpMass(minimum=100.0, maximum=700.0, name='chirp_mass', latex_label='$\\mathcal{M}$', unit=None, boundary=None), 'mass_ratio': bilby.gw.prior.UniformInComponentsMassRatio(minimum=0.2, maximum=1.0, name='mass_ratio', latex_label='$q$', unit=None, boundary=None, equal_mass=False), 'phase': Uniform(minimum=0.0, maximum=6.283185307179586, name='phase', latex_label='$\\phi$', unit=None, boundary='periodic'), 'chi_1': bilby.gw.prior.AlignedSpin(a_prior=Uniform(minimum=0, maximum=0.9, name=None, latex_label=None, unit=None, boundary=None), z_prior=Uniform(minimum=-1, maximum=1, name=None, latex_label=None, unit=None, boundary=None), name='chi_1', latex_label='$\\chi_1$', unit=None, boundary=None, minimum=-0.9, maximum=0.9, num_interp=100000), 'chi_2': bilby.gw.prior.AlignedSpin(a_prior=Uniform(minimum=0, maximum=0.9, name=None, latex_label=None, unit=None, boundary=None), z_prior=Uniform(minimum=-1, maximum=1, name=None, latex_label=None, unit=None, boundary=None), name='chi_2', latex_label='$\\chi_2$', unit=None, boundary=None, minimum=-0.9, maximum=0.9, num_interp=100000), 'theta_jn': Sine(minimum=0.0, maximum=3.141592653589793, name='theta_jn', latex_label='$\\theta_{JN}$', unit=None, boundary=None), 'luminosity_distance': LogUniform(minimum=500.0, maximum=100000.0, name='luminosity_distance', latex_label='$d_L$', unit=None, boundary=None), 'geocent_time': Uniform(minimum=-0.1, maximum=0.1, name='geocent_time', latex_label='$t_c$', unit=None, boundary=None), 'dec': Cosine(minimum=-1.5707963267948966, maximum=1.5707963267948966, name='dec', latex_label='$\\mathrm{DEC}$', unit=None, boundary=None), 'ra': Uniform(minimum=0.0, maximum=6.283185307179586, name='ra', latex_label='$\\mathrm{RA}$', unit=None, boundary='periodic'), 'psi': Uniform(minimum=0.0, maximum=3.141592653589793, name='psi', latex_label='$\\psi$', unit=None, boundary='periodic')}
# Running injection 0
# Running injection 1
# Generation with parameters (1.1478051085988936e+33, 9.426137108369361e+32, 0.0, 0.0, 0.11518859019035141, 0.0, 0.0, -0.1419079173876521, 3.085677581491367e+24, 0.48646360878271866, 4.318571436173966, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1478051085988936e+33, 9.426137108369361e+32, 0.0, 0.0, 0.11518859019035141, 0.0, 0.0, -0.1419079173876521, 3.085677581491367e+24, 0.48646360878271866, 4.318571436173966, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 2
# Running injection 3
# Generation with parameters (2.3215462468679838e+33, 9.926996134381559e+32, 0.0, 0.0, 0.605864757593729, 0.0, 0.0, 0.061294816453774104, 3.085677581491367e+24, 0.9559351591334634, 4.616414564167109, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3215462468679838e+33, 9.926996134381559e+32, 0.0, 0.0, 0.605864757593729, 0.0, 0.0, 0.061294816453774104, 3.085677581491367e+24, 0.9559351591334634, 4.616414564167109, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 4
# Generation with parameters (1.6014699385254052e+33, 3.723899947868738e+32, 0.0, 0.0, -0.2209602469335554, 0.0, 0.0, 0.1032718128252517, 3.085677581491367e+24, 0.4439690812347069, 2.272168290587968, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6014699385254052e+33, 3.723899947868738e+32, 0.0, 0.0, -0.2209602469335554, 0.0, 0.0, 0.1032718128252517, 3.085677581491367e+24, 0.4439690812347069, 2.272168290587968, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 5
# Generation with parameters (1.6449493980002097e+33, 1.1600908847621057e+33, 0.0, 0.0, -0.39443967300548366, 0.0, 0.0, -0.3657074020297144, 3.085677581491367e+24, 1.6295899080543979, 4.3004827079825745, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6449493980002097e+33, 1.1600908847621057e+33, 0.0, 0.0, -0.39443967300548366, 0.0, 0.0, -0.3657074020297144, 3.085677581491367e+24, 1.6295899080543979, 4.3004827079825745, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 6
# Generation with parameters (2.916518731958005e+33, 6.620871368061785e+32, 0.0, 0.0, -0.8056469464320344, 0.0, 0.0, -0.11390698377137569, 3.085677581491367e+24, 1.8577725772150404, 4.759342555927832, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.916518731958005e+33, 6.620871368061785e+32, 0.0, 0.0, -0.8056469464320344, 0.0, 0.0, -0.11390698377137569, 3.085677581491367e+24, 1.8577725772150404, 4.759342555927832, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 7
# Generation with parameters (1.1597431557368091e+33, 4.652445189738185e+32, 0.0, 0.0, 0.23490130868930098, 0.0, 0.0, 0.34240003781435097, 3.085677581491367e+24, 0.3922268768759775, 5.680292091419456, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1597431557368091e+33, 4.652445189738185e+32, 0.0, 0.0, 0.23490130868930098, 0.0, 0.0, 0.34240003781435097, 3.085677581491367e+24, 0.3922268768759775, 5.680292091419456, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 8
# Generation with parameters (1.799170426541875e+33, 1.0096656403329288e+33, 0.0, 0.0, 0.39384213105991367, 0.0, 0.0, -0.02246522999964398, 3.085677581491367e+24, 1.5697810772490186, 3.117411390577669, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.799170426541875e+33, 1.0096656403329288e+33, 0.0, 0.0, 0.39384213105991367, 0.0, 0.0, -0.02246522999964398, 3.085677581491367e+24, 1.5697810772490186, 3.117411390577669, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 9
# Generation with parameters (1.8954595007510207e+33, 1.1274716200241103e+33, 0.0, 0.0, 0.32228475912793275, 0.0, 0.0, 0.01559866045864956, 3.085677581491367e+24, 1.1441382135173486, 3.532995786327385, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8954595007510207e+33, 1.1274716200241103e+33, 0.0, 0.0, 0.32228475912793275, 0.0, 0.0, 0.01559866045864956, 3.085677581491367e+24, 1.1441382135173486, 3.532995786327385, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 10
# Running injection 11
# Generation with parameters (1.585407771967218e+33, 9.208624645622168e+32, 0.0, 0.0, 0.002549395451018383, 0.0, 0.0, -0.02312308320490316, 3.085677581491367e+24, 1.298702091975582, 3.3990134110274672, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.585407771967218e+33, 9.208624645622168e+32, 0.0, 0.0, 0.002549395451018383, 0.0, 0.0, -0.02312308320490316, 3.085677581491367e+24, 1.298702091975582, 3.3990134110274672, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 12
# Running injection 13
# Generation with parameters (1.4660974140122417e+33, 1.2967595651464266e+33, 0.0, 0.0, -0.046985739544540765, 0.0, 0.0, 0.20624480515656626, 3.085677581491367e+24, 1.297216099526955, 4.3496414412443345, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4660974140122417e+33, 1.2967595651464266e+33, 0.0, 0.0, -0.046985739544540765, 0.0, 0.0, 0.20624480515656626, 3.085677581491367e+24, 1.297216099526955, 4.3496414412443345, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 14
# Generation with parameters (1.7067356784341078e+33, 1.3292400850118892e+33, 0.0, 0.0, 0.045982604056188425, 0.0, 0.0, 0.19807302858800968, 3.085677581491367e+24, 0.615059011035451, 5.526624896785293, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7067356784341078e+33, 1.3292400850118892e+33, 0.0, 0.0, 0.045982604056188425, 0.0, 0.0, 0.19807302858800968, 3.085677581491367e+24, 0.615059011035451, 5.526624896785293, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 15
# Generation with parameters (1.3320777474941728e+33, 7.83735826013814e+32, 0.0, 0.0, -0.32187452321096005, 0.0, 0.0, -0.22373416823231113, 3.085677581491367e+24, 0.5537863738566687, 5.549648431615594, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3320777474941728e+33, 7.83735826013814e+32, 0.0, 0.0, -0.32187452321096005, 0.0, 0.0, -0.22373416823231113, 3.085677581491367e+24, 0.5537863738566687, 5.549648431615594, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 16
# Generation with parameters (2.672953555919681e+33, 9.94021283472921e+32, 0.0, 0.0, -0.32007923679042927, 0.0, 0.0, -0.6263639457178815, 3.085677581491367e+24, 2.1629397777029506, 5.938912774807278, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.672953555919681e+33, 9.94021283472921e+32, 0.0, 0.0, -0.32007923679042927, 0.0, 0.0, -0.6263639457178815, 3.085677581491367e+24, 2.1629397777029506, 5.938912774807278, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 17
# Generation with parameters (1.362653405968076e+33, 8.089613081858347e+32, 0.0, 0.0, -0.09131577310659107, 0.0, 0.0, -0.18327489883556136, 3.085677581491367e+24, 0.4750687698822634, 5.4948464403481765, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.362653405968076e+33, 8.089613081858347e+32, 0.0, 0.0, -0.09131577310659107, 0.0, 0.0, -0.18327489883556136, 3.085677581491367e+24, 0.4750687698822634, 5.4948464403481765, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 18
# Generation with parameters (1.2398109545062197e+33, 1.0297330548492498e+33, 0.0, 0.0, 0.6992787438174198, 0.0, 0.0, -0.6111563134724808, 3.085677581491367e+24, 2.6641941878190303, 0.013991539874288255, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2398109545062197e+33, 1.0297330548492498e+33, 0.0, 0.0, 0.6992787438174198, 0.0, 0.0, -0.6111563134724808, 3.085677581491367e+24, 2.6641941878190303, 0.013991539874288255, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 19
# Generation with parameters (2.4382649430638866e+33, 9.832376277406719e+32, 0.0, 0.0, -0.10052795007578666, 0.0, 0.0, -0.032324777613883526, 3.085677581491367e+24, 1.7930173446631827, 4.026194312269564, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.4382649430638866e+33, 9.832376277406719e+32, 0.0, 0.0, -0.10052795007578666, 0.0, 0.0, -0.032324777613883526, 3.085677581491367e+24, 1.7930173446631827, 4.026194312269564, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 20
# Generation with parameters (2.891037940795063e+33, 8.852119331145395e+32, 0.0, 0.0, 0.05114564555842811, 0.0, 0.0, -0.0020747245605640006, 3.085677581491367e+24, 1.5709325616116179, 3.8835651979785135, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.891037940795063e+33, 8.852119331145395e+32, 0.0, 0.0, 0.05114564555842811, 0.0, 0.0, -0.0020747245605640006, 3.085677581491367e+24, 1.5709325616116179, 3.8835651979785135, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 21
# Running injection 22
# Generation with parameters (2.4916778719157835e+33, 1.0539864240674111e+33, 0.0, 0.0, -0.4691377767161338, 0.0, 0.0, 0.4005263630468624, 3.085677581491367e+24, 0.8377547324750578, 5.324249620464344, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.4916778719157835e+33, 1.0539864240674111e+33, 0.0, 0.0, -0.4691377767161338, 0.0, 0.0, 0.4005263630468624, 3.085677581491367e+24, 0.8377547324750578, 5.324249620464344, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 23
# Running injection 24
# Running injection 25
# Generation with parameters (1.6166028342402393e+33, 1.3929926806816466e+33, 0.0, 0.0, 0.04606537465861118, 0.0, 0.0, 0.20323264607213773, 3.085677581491367e+24, 1.5163795396717727, 5.137371192007173, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6166028342402393e+33, 1.3929926806816466e+33, 0.0, 0.0, 0.04606537465861118, 0.0, 0.0, 0.20323264607213773, 3.085677581491367e+24, 1.5163795396717727, 5.137371192007173, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 26
# Generation with parameters (2.607893406577275e+33, 9.73851425876018e+32, 0.0, 0.0, 0.22016614910874063, 0.0, 0.0, 0.3136582069973522, 3.085677581491367e+24, 2.185301537518506, 1.8894067662099572, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.607893406577275e+33, 9.73851425876018e+32, 0.0, 0.0, 0.22016614910874063, 0.0, 0.0, 0.3136582069973522, 3.085677581491367e+24, 2.185301537518506, 1.8894067662099572, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 27
# Generation with parameters (8.575870954229541e+32, 8.382868862380772e+32, 0.0, 0.0, -0.33855188016400123, 0.0, 0.0, 0.25649872034322496, 3.085677581491367e+24, 1.7958670627235471, 1.8171404863819682, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.575870954229541e+32, 8.382868862380772e+32, 0.0, 0.0, -0.33855188016400123, 0.0, 0.0, 0.25649872034322496, 3.085677581491367e+24, 1.7958670627235471, 1.8171404863819682, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 28
# Generation with parameters (1.8579503375503502e+33, 1.3477293521980677e+33, 0.0, 0.0, 0.11970507896281168, 0.0, 0.0, -0.29801825340926086, 3.085677581491367e+24, 1.6306688096549555, 2.0651309157737012, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8579503375503502e+33, 1.3477293521980677e+33, 0.0, 0.0, 0.11970507896281168, 0.0, 0.0, -0.29801825340926086, 3.085677581491367e+24, 1.6306688096549555, 2.0651309157737012, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 29
# Running injection 30
# Generation with parameters (1.4876668551123927e+33, 1.1298612153843246e+33, 0.0, 0.0, 0.0492297826342675, 0.0, 0.0, 0.050064498800744005, 3.085677581491367e+24, 1.6744851856609397, 0.9012440462025052, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4876668551123927e+33, 1.1298612153843246e+33, 0.0, 0.0, 0.0492297826342675, 0.0, 0.0, 0.050064498800744005, 3.085677581491367e+24, 1.6744851856609397, 0.9012440462025052, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 31
# Generation with parameters (2.9285192511091064e+33, 7.98594700040613e+32, 0.0, 0.0, -0.016605428118920847, 0.0, 0.0, 0.02889534592156374, 3.085677581491367e+24, 2.192209311321558, 3.707457286689161, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.9285192511091064e+33, 7.98594700040613e+32, 0.0, 0.0, -0.016605428118920847, 0.0, 0.0, 0.02889534592156374, 3.085677581491367e+24, 2.192209311321558, 3.707457286689161, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 32
# Generation with parameters (1.5808175749399766e+33, 1.1117479311911652e+33, 0.0, 0.0, -0.04766706435571257, 0.0, 0.0, -0.04096958174433918, 3.085677581491367e+24, 1.2373462272779157, 0.34780423210782013, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5808175749399766e+33, 1.1117479311911652e+33, 0.0, 0.0, -0.04766706435571257, 0.0, 0.0, -0.04096958174433918, 3.085677581491367e+24, 1.2373462272779157, 0.34780423210782013, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 33
# Generation with parameters (1.4424085995662237e+33, 8.314683126544992e+32, 0.0, 0.0, -0.085627414754435, 0.0, 0.0, 0.18537430791020781, 3.085677581491367e+24, 1.0839596767001278, 0.3390073526039131, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4424085995662237e+33, 8.314683126544992e+32, 0.0, 0.0, -0.085627414754435, 0.0, 0.0, 0.18537430791020781, 3.085677581491367e+24, 1.0839596767001278, 0.3390073526039131, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 34
# Generation with parameters (1.4278940960596146e+33, 7.080070887029849e+32, 0.0, 0.0, 0.010376260952957147, 0.0, 0.0, -0.012361811364995928, 3.085677581491367e+24, 0.30606154559959464, 0.47268463861442744, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4278940960596146e+33, 7.080070887029849e+32, 0.0, 0.0, 0.010376260952957147, 0.0, 0.0, -0.012361811364995928, 3.085677581491367e+24, 0.30606154559959464, 0.47268463861442744, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 35
# Generation with parameters (1.5463536031728168e+33, 8.539794198999397e+32, 0.0, 0.0, -0.7832329219392986, 0.0, 0.0, 0.1412438128216351, 3.085677581491367e+24, 1.6724035447710113, 5.576473440925386, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5463536031728168e+33, 8.539794198999397e+32, 0.0, 0.0, -0.7832329219392986, 0.0, 0.0, 0.1412438128216351, 3.085677581491367e+24, 1.6724035447710113, 5.576473440925386, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 36
# Generation with parameters (1.7128152172179574e+33, 1.2522365367213541e+33, 0.0, 0.0, 0.2868288763215716, 0.0, 0.0, 0.08969251769542635, 3.085677581491367e+24, 2.0841729428855094, 4.2238314605840745, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7128152172179574e+33, 1.2522365367213541e+33, 0.0, 0.0, 0.2868288763215716, 0.0, 0.0, 0.08969251769542635, 3.085677581491367e+24, 2.0841729428855094, 4.2238314605840745, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 37
# Generation with parameters (1.4091373010531273e+33, 1.1216781015421271e+33, 0.0, 0.0, -0.07357542927572096, 0.0, 0.0, -0.1246257580034522, 3.085677581491367e+24, 0.7322727001200584, 1.0085225336499006, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4091373010531273e+33, 1.1216781015421271e+33, 0.0, 0.0, -0.07357542927572096, 0.0, 0.0, -0.1246257580034522, 3.085677581491367e+24, 0.7322727001200584, 1.0085225336499006, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 38
# Generation with parameters (1.848816242402844e+33, 9.792888938763228e+32, 0.0, 0.0, 0.3355030241409217, 0.0, 0.0, 0.23622932636319274, 3.085677581491367e+24, 1.6121780860456547, 2.1714539045606203, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.848816242402844e+33, 9.792888938763228e+32, 0.0, 0.0, 0.3355030241409217, 0.0, 0.0, 0.23622932636319274, 3.085677581491367e+24, 1.6121780860456547, 2.1714539045606203, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 39
# Generation with parameters (1.7313588432242426e+33, 1.2503699105916488e+33, 0.0, 0.0, -0.03707955167646513, 0.0, 0.0, -0.21602809976323795, 3.085677581491367e+24, 2.968063662188437, 5.771944097703066, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7313588432242426e+33, 1.2503699105916488e+33, 0.0, 0.0, -0.03707955167646513, 0.0, 0.0, -0.21602809976323795, 3.085677581491367e+24, 2.968063662188437, 5.771944097703066, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 40
# Generation with parameters (1.3394016215083735e+33, 1.1485267046893967e+33, 0.0, 0.0, -0.410906880766579, 0.0, 0.0, 0.06692714211401433, 3.085677581491367e+24, 2.298410860522636, 1.0049763586536575, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3394016215083735e+33, 1.1485267046893967e+33, 0.0, 0.0, -0.410906880766579, 0.0, 0.0, 0.06692714211401433, 3.085677581491367e+24, 2.298410860522636, 1.0049763586536575, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 41
# Generation with parameters (1.822743392359647e+33, 4.6812341689250334e+32, 0.0, 0.0, 0.11562786157174611, 0.0, 0.0, 0.08547608345901922, 3.085677581491367e+24, 1.677957354298127, 2.598048697508127, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.822743392359647e+33, 4.6812341689250334e+32, 0.0, 0.0, 0.11562786157174611, 0.0, 0.0, 0.08547608345901922, 3.085677581491367e+24, 1.677957354298127, 2.598048697508127, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 42
# Generation with parameters (1.7397643269081355e+33, 4.695258659763835e+32, 0.0, 0.0, -0.17481979532664824, 0.0, 0.0, 0.012293425366191517, 3.085677581491367e+24, 2.85470216710516, 4.786398113528354, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7397643269081355e+33, 4.695258659763835e+32, 0.0, 0.0, -0.17481979532664824, 0.0, 0.0, 0.012293425366191517, 3.085677581491367e+24, 2.85470216710516, 4.786398113528354, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 43
# Running injection 44
# Running injection 45
# Generation with parameters (1.9786960755109578e+33, 5.6509461061187076e+32, 0.0, 0.0, -0.4044027679295546, 0.0, 0.0, 0.2470726096823966, 3.085677581491367e+24, 2.2573082129332995, 0.9235121953298557, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.9786960755109578e+33, 5.6509461061187076e+32, 0.0, 0.0, -0.4044027679295546, 0.0, 0.0, 0.2470726096823966, 3.085677581491367e+24, 2.2573082129332995, 0.9235121953298557, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 46
# Generation with parameters (1.8224895127433448e+33, 3.906481875545046e+32, 0.0, 0.0, 0.679389252319296, 0.0, 0.0, 0.37260350213141324, 3.085677581491367e+24, 1.4500315809419808, 2.604046310601448, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8224895127433448e+33, 3.906481875545046e+32, 0.0, 0.0, 0.679389252319296, 0.0, 0.0, 0.37260350213141324, 3.085677581491367e+24, 1.4500315809419808, 2.604046310601448, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 47
# Generation with parameters (2.4928570573230471e+33, 5.023232912600024e+32, 0.0, 0.0, 0.45666143862240405, 0.0, 0.0, 0.3058277432553178, 3.085677581491367e+24, 2.1904962640055823, 1.6059828556392177, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.4928570573230471e+33, 5.023232912600024e+32, 0.0, 0.0, 0.45666143862240405, 0.0, 0.0, 0.3058277432553178, 3.085677581491367e+24, 2.1904962640055823, 1.6059828556392177, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 48
# Generation with parameters (1.5151377716003683e+33, 8.252104893513825e+32, 0.0, 0.0, -0.5438570817316222, 0.0, 0.0, 0.5015722879889866, 3.085677581491367e+24, 2.5613695305372093, 3.613004593475424, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5151377716003683e+33, 8.252104893513825e+32, 0.0, 0.0, -0.5438570817316222, 0.0, 0.0, 0.5015722879889866, 3.085677581491367e+24, 2.5613695305372093, 3.613004593475424, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 49
# Generation with parameters (2.182861044498142e+33, 9.72834685624526e+32, 0.0, 0.0, -0.201005213721661, 0.0, 0.0, -0.09183529721331078, 3.085677581491367e+24, 2.154209138064443, 0.5182804718976071, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.182861044498142e+33, 9.72834685624526e+32, 0.0, 0.0, -0.201005213721661, 0.0, 0.0, -0.09183529721331078, 3.085677581491367e+24, 2.154209138064443, 0.5182804718976071, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 50
# Generation with parameters (1.020593809767808e+33, 9.8114647199258e+32, 0.0, 0.0, 0.5017998506122554, 0.0, 0.0, -0.07170601288819643, 3.085677581491367e+24, 2.417732574342769, 1.4867866766899613, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.020593809767808e+33, 9.8114647199258e+32, 0.0, 0.0, 0.5017998506122554, 0.0, 0.0, -0.07170601288819643, 3.085677581491367e+24, 2.417732574342769, 1.4867866766899613, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 51
# Generation with parameters (2.256210899489374e+33, 1.0688248296744652e+33, 0.0, 0.0, -0.37609438813491475, 0.0, 0.0, -0.22652783329876464, 3.085677581491367e+24, 1.4624742650596652, 0.6047246531461509, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.256210899489374e+33, 1.0688248296744652e+33, 0.0, 0.0, -0.37609438813491475, 0.0, 0.0, -0.22652783329876464, 3.085677581491367e+24, 1.4624742650596652, 0.6047246531461509, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 52
# Generation with parameters (9.666551882936814e+32, 3.534327154441265e+32, 0.0, 0.0, 0.0728675874522959, 0.0, 0.0, 0.08727138175344384, 3.085677581491367e+24, 2.139526181770745, 1.2605763066694722, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.666551882936814e+32, 3.534327154441265e+32, 0.0, 0.0, 0.0728675874522959, 0.0, 0.0, 0.08727138175344384, 3.085677581491367e+24, 2.139526181770745, 1.2605763066694722, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 53
# Generation with parameters (1.680818029400042e+33, 1.3661551334298866e+33, 0.0, 0.0, 0.7725880939085993, 0.0, 0.0, -0.09616892132339415, 3.085677581491367e+24, 1.7667642688773606, 1.4847746800639448, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.680818029400042e+33, 1.3661551334298866e+33, 0.0, 0.0, 0.7725880939085993, 0.0, 0.0, -0.09616892132339415, 3.085677581491367e+24, 1.7667642688773606, 1.4847746800639448, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 54
# Running injection 55
# Running injection 56
# Generation with parameters (2.7626206699325174e+33, 5.5253419033960005e+32, 0.0, 0.0, 0.7114245755682906, 0.0, 0.0, -0.054276596418570695, 3.085677581491367e+24, 2.368418445296788, 5.196625215769115, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.7626206699325174e+33, 5.5253419033960005e+32, 0.0, 0.0, 0.7114245755682906, 0.0, 0.0, -0.054276596418570695, 3.085677581491367e+24, 2.368418445296788, 5.196625215769115, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 57
# Generation with parameters (8.164121706464817e+32, 5.089656005213795e+32, 0.0, 0.0, 0.5133637786915606, 0.0, 0.0, -0.2682579150680791, 3.085677581491367e+24, 2.170322071100564, 1.1434008670121518, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.164121706464817e+32, 5.089656005213795e+32, 0.0, 0.0, 0.5133637786915606, 0.0, 0.0, -0.2682579150680791, 3.085677581491367e+24, 2.170322071100564, 1.1434008670121518, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 58
# Generation with parameters (2.31106952590598e+33, 9.87137399756238e+32, 0.0, 0.0, -0.20384545071829355, 0.0, 0.0, 0.20476605254372754, 3.085677581491367e+24, 2.8045595740958746, 1.4790142222944063, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.31106952590598e+33, 9.87137399756238e+32, 0.0, 0.0, -0.20384545071829355, 0.0, 0.0, 0.20476605254372754, 3.085677581491367e+24, 2.8045595740958746, 1.4790142222944063, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 59
# Generation with parameters (2.0125702419300596e+33, 1.0845288633471398e+33, 0.0, 0.0, 0.14933782284466818, 0.0, 0.0, -0.7664485108459054, 3.085677581491367e+24, 2.5200586608845486, 0.327970127876449, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0125702419300596e+33, 1.0845288633471398e+33, 0.0, 0.0, 0.14933782284466818, 0.0, 0.0, -0.7664485108459054, 3.085677581491367e+24, 2.5200586608845486, 0.327970127876449, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 60
# Generation with parameters (1.8921746682941463e+33, 8.93371823813724e+32, 0.0, 0.0, -0.19786068884231728, 0.0, 0.0, 0.015313553465555553, 3.085677581491367e+24, 1.6883580536189653, 4.016387179667345, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8921746682941463e+33, 8.93371823813724e+32, 0.0, 0.0, -0.19786068884231728, 0.0, 0.0, 0.015313553465555553, 3.085677581491367e+24, 1.6883580536189653, 4.016387179667345, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 61
# Generation with parameters (1.3156980065393566e+33, 6.2315243582744285e+32, 0.0, 0.0, 0.0678282414745362, 0.0, 0.0, 0.1867289511486364, 3.085677581491367e+24, 1.9240790202682123, 2.9107886637175806, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3156980065393566e+33, 6.2315243582744285e+32, 0.0, 0.0, 0.0678282414745362, 0.0, 0.0, 0.1867289511486364, 3.085677581491367e+24, 1.9240790202682123, 2.9107886637175806, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 62
# Generation with parameters (2.083915361477986e+33, 9.263851120415183e+32, 0.0, 0.0, -0.7539332191154872, 0.0, 0.0, -0.09355806797185776, 3.085677581491367e+24, 2.2517894148463027, 5.114684868904505, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.083915361477986e+33, 9.263851120415183e+32, 0.0, 0.0, -0.7539332191154872, 0.0, 0.0, -0.09355806797185776, 3.085677581491367e+24, 2.2517894148463027, 5.114684868904505, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 63
# Generation with parameters (2.161698217867213e+33, 8.238884949828817e+32, 0.0, 0.0, -0.23951994351392505, 0.0, 0.0, 0.1260711200098094, 3.085677581491367e+24, 2.14679930143681, 3.310924684667741, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.161698217867213e+33, 8.238884949828817e+32, 0.0, 0.0, -0.23951994351392505, 0.0, 0.0, 0.1260711200098094, 3.085677581491367e+24, 2.14679930143681, 3.310924684667741, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 64
# Generation with parameters (1.4079414489978498e+33, 7.098062464892884e+32, 0.0, 0.0, 0.14788968557940702, 0.0, 0.0, -0.34859486353588914, 3.085677581491367e+24, 0.9821779875056221, 2.783627126170469, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4079414489978498e+33, 7.098062464892884e+32, 0.0, 0.0, 0.14788968557940702, 0.0, 0.0, -0.34859486353588914, 3.085677581491367e+24, 0.9821779875056221, 2.783627126170469, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 65
# Generation with parameters (1.3593215058027886e+33, 1.0349859176042053e+33, 0.0, 0.0, 0.24675448166629002, 0.0, 0.0, 0.16854058854947165, 3.085677581491367e+24, 1.520874883044249, 0.8108523745129201, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3593215058027886e+33, 1.0349859176042053e+33, 0.0, 0.0, 0.24675448166629002, 0.0, 0.0, 0.16854058854947165, 3.085677581491367e+24, 1.520874883044249, 0.8108523745129201, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 66
# Generation with parameters (1.3130095576720102e+33, 1.0938431428149636e+33, 0.0, 0.0, -0.009973945439809555, 0.0, 0.0, 0.11874570508961109, 3.085677581491367e+24, 1.2016341826087982, 3.1491796636517457, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3130095576720102e+33, 1.0938431428149636e+33, 0.0, 0.0, -0.009973945439809555, 0.0, 0.0, 0.11874570508961109, 3.085677581491367e+24, 1.2016341826087982, 3.1491796636517457, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 67
# Generation with parameters (1.6239448153428276e+33, 1.3520131737355367e+33, 0.0, 0.0, -0.023007921564271536, 0.0, 0.0, -0.2747240786401681, 3.085677581491367e+24, 2.6278347913581634, 5.0747488935245935, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6239448153428276e+33, 1.3520131737355367e+33, 0.0, 0.0, -0.023007921564271536, 0.0, 0.0, -0.2747240786401681, 3.085677581491367e+24, 2.6278347913581634, 5.0747488935245935, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 68
# Generation with parameters (2.2496348870677306e+33, 1.1591553348906651e+33, 0.0, 0.0, 0.057008928548772785, 0.0, 0.0, 0.6159217045686921, 3.085677581491367e+24, 0.8423392288979326, 4.873460948386931, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2496348870677306e+33, 1.1591553348906651e+33, 0.0, 0.0, 0.057008928548772785, 0.0, 0.0, 0.6159217045686921, 3.085677581491367e+24, 0.8423392288979326, 4.873460948386931, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 69
# Running injection 70
# Generation with parameters (2.3198751154262904e+33, 6.198843849345727e+32, 0.0, 0.0, -0.1384729439775066, 0.0, 0.0, -0.47451394126622815, 3.085677581491367e+24, 1.0030849404692164, 1.7907018401759296, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3198751154262904e+33, 6.198843849345727e+32, 0.0, 0.0, -0.1384729439775066, 0.0, 0.0, -0.47451394126622815, 3.085677581491367e+24, 1.0030849404692164, 1.7907018401759296, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 71
# Generation with parameters (7.804493571470541e+32, 6.626474060637525e+32, 0.0, 0.0, 0.07937202312883858, 0.0, 0.0, -0.41219688688586603, 3.085677581491367e+24, 2.3240428866787015, 4.926688170857067, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.804493571470541e+32, 6.626474060637525e+32, 0.0, 0.0, 0.07937202312883858, 0.0, 0.0, -0.41219688688586603, 3.085677581491367e+24, 2.3240428866787015, 4.926688170857067, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 72
# Generation with parameters (1.7566157848210273e+33, 6.4485034525094986e+32, 0.0, 0.0, 0.021679097573605068, 0.0, 0.0, -0.03721897299363968, 3.085677581491367e+24, 0.662436208404368, 5.767270160373631, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7566157848210273e+33, 6.4485034525094986e+32, 0.0, 0.0, 0.021679097573605068, 0.0, 0.0, -0.03721897299363968, 3.085677581491367e+24, 0.662436208404368, 5.767270160373631, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 73
# Generation with parameters (1.4054007934231838e+33, 6.368224971579424e+32, 0.0, 0.0, 0.7619624123467805, 0.0, 0.0, -0.00416182938355648, 3.085677581491367e+24, 2.6766065492822735, 2.4665021250282346, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4054007934231838e+33, 6.368224971579424e+32, 0.0, 0.0, 0.7619624123467805, 0.0, 0.0, -0.00416182938355648, 3.085677581491367e+24, 2.6766065492822735, 2.4665021250282346, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 74
# Generation with parameters (2.2227387869189292e+33, 8.197111297853735e+32, 0.0, 0.0, -0.01318156067653333, 0.0, 0.0, -0.19160158937487534, 3.085677581491367e+24, 1.6226903750720372, 1.9779088192317864, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2227387869189292e+33, 8.197111297853735e+32, 0.0, 0.0, -0.01318156067653333, 0.0, 0.0, -0.19160158937487534, 3.085677581491367e+24, 1.6226903750720372, 1.9779088192317864, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 75
# Generation with parameters (1.7388296093069265e+33, 8.933116095001017e+32, 0.0, 0.0, -0.3141017979988396, 0.0, 0.0, -0.5408005247123426, 3.085677581491367e+24, 2.451783446409021, 2.306630776619242, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7388296093069265e+33, 8.933116095001017e+32, 0.0, 0.0, -0.3141017979988396, 0.0, 0.0, -0.5408005247123426, 3.085677581491367e+24, 2.451783446409021, 2.306630776619242, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 76
# Generation with parameters (1.3831677718687763e+33, 6.135950924311121e+32, 0.0, 0.0, 0.21789440096947915, 0.0, 0.0, 0.5293988546790342, 3.085677581491367e+24, 0.6872254042167806, 2.3727758393172858, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3831677718687763e+33, 6.135950924311121e+32, 0.0, 0.0, 0.21789440096947915, 0.0, 0.0, 0.5293988546790342, 3.085677581491367e+24, 0.6872254042167806, 2.3727758393172858, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 77
# Generation with parameters (1.8973505093734493e+33, 8.415809239647897e+32, 0.0, 0.0, -0.08635023689593699, 0.0, 0.0, 0.040635099029050235, 3.085677581491367e+24, 1.3731816056798116, 4.258071594771072, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8973505093734493e+33, 8.415809239647897e+32, 0.0, 0.0, -0.08635023689593699, 0.0, 0.0, 0.040635099029050235, 3.085677581491367e+24, 1.3731816056798116, 4.258071594771072, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 78
# Generation with parameters (1.4132546448049167e+33, 3.013926268619868e+32, 0.0, 0.0, -0.011975523411340236, 0.0, 0.0, 0.020244361279822886, 3.085677581491367e+24, 0.636680134377591, 1.532349893334071, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4132546448049167e+33, 3.013926268619868e+32, 0.0, 0.0, -0.011975523411340236, 0.0, 0.0, 0.020244361279822886, 3.085677581491367e+24, 0.636680134377591, 1.532349893334071, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 79
# Generation with parameters (2.6663669694787637e+33, 8.164655905093651e+32, 0.0, 0.0, 0.11226718537305466, 0.0, 0.0, 0.0360734452110889, 3.085677581491367e+24, 0.8125934449319869, 2.764375024389679, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.6663669694787637e+33, 8.164655905093651e+32, 0.0, 0.0, 0.11226718537305466, 0.0, 0.0, 0.0360734452110889, 3.085677581491367e+24, 0.8125934449319869, 2.764375024389679, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 80
# Running injection 81
# Generation with parameters (1.4789041546918764e+33, 1.3235925196889175e+33, 0.0, 0.0, 0.2465735173613057, 0.0, 0.0, -0.04102978636772014, 3.085677581491367e+24, 1.5896955882896124, 3.6394517715010988, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# ...
# Warning: turning off multibanding for parameters (2.2210641329639808e+33, 1.1043746016726575e+33, 0.0, 0.0, -0.4181247690300772, 0.0, 0.0, -0.2523757866193499, 3.085677581491367e+24, 0.7081542309718729, 0.30184284994451044, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 975
# Generation with parameters (1.7311685194188315e+33, 7.905392790927778e+32, 0.0, 0.0, 0.011782576872329371, 0.0, 0.0, -0.05188789336655348, 3.085677581491367e+24, 1.551611737537983, 6.115577108910808, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7311685194188315e+33, 7.905392790927778e+32, 0.0, 0.0, 0.011782576872329371, 0.0, 0.0, -0.05188789336655348, 3.085677581491367e+24, 1.551611737537983, 6.115577108910808, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 976
# Running injection 977
# Generation with parameters (2.3701327277000238e+33, 6.680224533006835e+32, 0.0, 0.0, -0.08585012681682185, 0.0, 0.0, 0.0676969018275972, 3.085677581491367e+24, 1.441476467284836, 4.32558107539901, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3701327277000238e+33, 6.680224533006835e+32, 0.0, 0.0, -0.08585012681682185, 0.0, 0.0, 0.0676969018275972, 3.085677581491367e+24, 1.441476467284836, 4.32558107539901, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 978
# Generation with parameters (1.9580873024989547e+33, 6.2023894283193346e+32, 0.0, 0.0, -0.09916190790004002, 0.0, 0.0, 0.07511983842463892, 3.085677581491367e+24, 2.861558269940095, 3.4441485160584464, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.9580873024989547e+33, 6.2023894283193346e+32, 0.0, 0.0, -0.09916190790004002, 0.0, 0.0, 0.07511983842463892, 3.085677581491367e+24, 2.861558269940095, 3.4441485160584464, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 979
# Generation with parameters (1.642205934538357e+33, 4.322961545716844e+32, 0.0, 0.0, -0.49837761641655254, 0.0, 0.0, 0.04844035628892662, 3.085677581491367e+24, 1.9029081501926062, 1.981115458889092, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.642205934538357e+33, 4.322961545716844e+32, 0.0, 0.0, -0.49837761641655254, 0.0, 0.0, 0.04844035628892662, 3.085677581491367e+24, 1.9029081501926062, 1.981115458889092, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 980
# Generation with parameters (1.812227151282586e+33, 9.789093470784689e+32, 0.0, 0.0, 0.16973474130202826, 0.0, 0.0, -0.4241747868176055, 3.085677581491367e+24, 1.786334808483197, 6.02749973856153, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.812227151282586e+33, 9.789093470784689e+32, 0.0, 0.0, 0.16973474130202826, 0.0, 0.0, -0.4241747868176055, 3.085677581491367e+24, 1.786334808483197, 6.02749973856153, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 981
# Generation with parameters (2.3584851297552418e+33, 7.441701221545259e+32, 0.0, 0.0, -0.006328006383146652, 0.0, 0.0, 0.05580193084636252, 3.085677581491367e+24, 2.399464746980588, 3.8950035323173893, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3584851297552418e+33, 7.441701221545259e+32, 0.0, 0.0, -0.006328006383146652, 0.0, 0.0, 0.05580193084636252, 3.085677581491367e+24, 2.399464746980588, 3.8950035323173893, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 982
# Generation with parameters (1.4525200913290797e+33, 5.788039361627809e+32, 0.0, 0.0, 0.0980356458910478, 0.0, 0.0, 0.5306284611135111, 3.085677581491367e+24, 2.436501149706036, 4.476096142838086, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4525200913290797e+33, 5.788039361627809e+32, 0.0, 0.0, 0.0980356458910478, 0.0, 0.0, 0.5306284611135111, 3.085677581491367e+24, 2.436501149706036, 4.476096142838086, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 983
# Generation with parameters (2.0475867282068442e+33, 4.6324662488696716e+32, 0.0, 0.0, 0.06888482002391005, 0.0, 0.0, 0.4367575140806274, 3.085677581491367e+24, 2.7626272411213186, 3.1953514474936484, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0475867282068442e+33, 4.6324662488696716e+32, 0.0, 0.0, 0.06888482002391005, 0.0, 0.0, 0.4367575140806274, 3.085677581491367e+24, 2.7626272411213186, 3.1953514474936484, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 984
# Generation with parameters (2.2715475578519004e+33, 1.0211088058155176e+33, 0.0, 0.0, -0.08328318721585351, 0.0, 0.0, 0.015000161907200086, 3.085677581491367e+24, 2.657273470752684, 3.6402050785668245, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2715475578519004e+33, 1.0211088058155176e+33, 0.0, 0.0, -0.08328318721585351, 0.0, 0.0, 0.015000161907200086, 3.085677581491367e+24, 2.657273470752684, 3.6402050785668245, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 985
# Generation with parameters (1.7415383216275254e+33, 1.1514897764736465e+33, 0.0, 0.0, 0.1681858971213445, 0.0, 0.0, -0.1826855627753791, 3.085677581491367e+24, 1.6898654061971186, 0.2860984090110164, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7415383216275254e+33, 1.1514897764736465e+33, 0.0, 0.0, 0.1681858971213445, 0.0, 0.0, -0.1826855627753791, 3.085677581491367e+24, 1.6898654061971186, 0.2860984090110164, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 986
# Generation with parameters (1.2647856044183445e+33, 8.49053231533585e+32, 0.0, 0.0, 0.06269513571155945, 0.0, 0.0, -0.018948672517107565, 3.085677581491367e+24, 1.8557213210600112, 0.43737252007318295, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2647856044183445e+33, 8.49053231533585e+32, 0.0, 0.0, 0.06269513571155945, 0.0, 0.0, -0.018948672517107565, 3.085677581491367e+24, 1.8557213210600112, 0.43737252007318295, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 987
# Generation with parameters (1.5462626281873802e+33, 4.896512085831255e+32, 0.0, 0.0, 0.03089280761859201, 0.0, 0.0, 0.14881646737191123, 3.085677581491367e+24, 1.5208912823666625, 0.19663370832651828, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5462626281873802e+33, 4.896512085831255e+32, 0.0, 0.0, 0.03089280761859201, 0.0, 0.0, 0.14881646737191123, 3.085677581491367e+24, 1.5208912823666625, 0.19663370832651828, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 988
# Generation with parameters (9.138579697628313e+32, 9.083820343372852e+32, 0.0, 0.0, 0.0023340924792306507, 0.0, 0.0, -0.20518712768284383, 3.085677581491367e+24, 0.3340187529172193, 1.2113084637795617, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.138579697628313e+32, 9.083820343372852e+32, 0.0, 0.0, 0.0023340924792306507, 0.0, 0.0, -0.20518712768284383, 3.085677581491367e+24, 0.3340187529172193, 1.2113084637795617, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 989
# Generation with parameters (1.6294573188842424e+33, 1.283142494941336e+33, 0.0, 0.0, -0.331873796018227, 0.0, 0.0, 0.2577420852940249, 3.085677581491367e+24, 1.1615524420858327, 5.5880435224400316, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6294573188842424e+33, 1.283142494941336e+33, 0.0, 0.0, -0.331873796018227, 0.0, 0.0, 0.2577420852940249, 3.085677581491367e+24, 1.1615524420858327, 5.5880435224400316, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 990
# Generation with parameters (2.4987030975033998e+33, 7.58009299179248e+32, 0.0, 0.0, -0.07053066643881815, 0.0, 0.0, 0.4493772802092419, 3.085677581491367e+24, 1.6347311659334576, 5.674180405254405, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.4987030975033998e+33, 7.58009299179248e+32, 0.0, 0.0, -0.07053066643881815, 0.0, 0.0, 0.4493772802092419, 3.085677581491367e+24, 1.6347311659334576, 5.674180405254405, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 991
# Generation with parameters (1.475270745195291e+33, 1.1888797121701549e+33, 0.0, 0.0, -0.16480550385513806, 0.0, 0.0, 0.17503225846053327, 3.085677581491367e+24, 0.4861628984951574, 0.07251202560864178, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.475270745195291e+33, 1.1888797121701549e+33, 0.0, 0.0, -0.16480550385513806, 0.0, 0.0, 0.17503225846053327, 3.085677581491367e+24, 0.4861628984951574, 0.07251202560864178, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 992
# Generation with parameters (1.1538410184627473e+33, 1.0703537512199566e+33, 0.0, 0.0, -0.4670594940408198, 0.0, 0.0, -0.2681692066274101, 3.085677581491367e+24, 1.8842102167891503, 5.261938860343375, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1538410184627473e+33, 1.0703537512199566e+33, 0.0, 0.0, -0.4670594940408198, 0.0, 0.0, -0.2681692066274101, 3.085677581491367e+24, 1.8842102167891503, 5.261938860343375, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 993
# Running injection 994
# Generation with parameters (1.778898444015133e+33, 9.6404227409526e+32, 0.0, 0.0, -0.061026431218786696, 0.0, 0.0, 0.4193762470638345, 3.085677581491367e+24, 0.9091130403892081, 6.067766940591919, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.778898444015133e+33, 9.6404227409526e+32, 0.0, 0.0, -0.061026431218786696, 0.0, 0.0, 0.4193762470638345, 3.085677581491367e+24, 0.9091130403892081, 6.067766940591919, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 995
# Generation with parameters (1.4719612310718542e+33, 4.504689824801927e+32, 0.0, 0.0, 0.3903208565323373, 0.0, 0.0, 0.14404548284980856, 3.085677581491367e+24, 1.8181314582401757, 5.479494280942951, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4719612310718542e+33, 4.504689824801927e+32, 0.0, 0.0, 0.3903208565323373, 0.0, 0.0, 0.14404548284980856, 3.085677581491367e+24, 1.8181314582401757, 5.479494280942951, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 996
# Generation with parameters (1.1288363375041879e+33, 4.092067638067113e+32, 0.0, 0.0, -0.2589524661194254, 0.0, 0.0, -0.12332758685456272, 3.085677581491367e+24, 1.1206293486962442, 1.9891436200801855, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1288363375041879e+33, 4.092067638067113e+32, 0.0, 0.0, -0.2589524661194254, 0.0, 0.0, -0.12332758685456272, 3.085677581491367e+24, 1.1206293486962442, 1.9891436200801855, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 997
# Generation with parameters (1.7279617713842333e+33, 7.019373906383617e+32, 0.0, 0.0, 0.3501802103860199, 0.0, 0.0, 0.08646070372862007, 3.085677581491367e+24, 0.45736487045571095, 4.2407563505560155, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7279617713842333e+33, 7.019373906383617e+32, 0.0, 0.0, 0.3501802103860199, 0.0, 0.0, 0.08646070372862007, 3.085677581491367e+24, 0.45736487045571095, 4.2407563505560155, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 998
# Generation with parameters (1.5124789041977583e+33, 5.921505764950349e+32, 0.0, 0.0, -0.24897240268210813, 0.0, 0.0, -0.0008955976561744291, 3.085677581491367e+24, 2.076641182858495, 2.142010902894877, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5124789041977583e+33, 5.921505764950349e+32, 0.0, 0.0, -0.24897240268210813, 0.0, 0.0, -0.0008955976561744291, 3.085677581491367e+24, 2.076641182858495, 2.142010902894877, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 999
# Generation with parameters (2.5529437566856086e+33, 9.611964906439183e+32, 0.0, 0.0, 0.3456634638706283, 0.0, 0.0, 0.08204303432899207, 3.085677581491367e+24, 0.789458168163249, 1.2983626673389446, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5529437566856086e+33, 9.611964906439183e+32, 0.0, 0.0, 0.3456634638706283, 0.0, 0.0, 0.08204303432899207, 3.085677581491367e+24, 0.789458168163249, 1.2983626673389446, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.

# %%
import os
import pickle

from dingo.gw.inference.gw_samplers import GWSampler


os.makedirs("/scratch/tpausch/test_data/imbh_T2/results", exist_ok=True)

injection_files = sorted(os.listdir("/scratch/tpausch/test_data/imbh_T2/injections"))

for fname in injection_files:

    # --------------------------------------------------------
    # Load injection
    # --------------------------------------------------------

    with open(f"/scratch/tpausch/test_data/imbh_T2/injections/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    strain_data = payload["strain_data"]

    # --------------------------------------------------------
    # Run sampler
    # --------------------------------------------------------

    sampler = GWSampler(model=main_pm)

    sampler.context = strain_data

    sampler.run_sampler(
        num_samples=50_000,
        batch_size=10_000,
    )

    result = sampler.to_result()

    # --------------------------------------------------------
    # Store result
    # --------------------------------------------------------

    result_payload = {
        "theta_true": theta_true,
        "result": result,
    }

    outname = fname.replace("inj_", "result_")

    with open(f"/scratch/tpausch/test_data/imbh_T2/results/{outname}", "wb") as f:
        pickle.dump(result_payload, f)

    print(f"Saved /scratch/tpausch/test_data/imbh_T2/results/{outname}")
# Out:
# Running sampler to generate 50000 samples.
# Done. This took 4.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0000.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0001.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0002.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0003.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0004.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0005.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0006.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0007.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0008.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0009.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0010.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0011.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0012.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0013.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0014.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0015.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0016.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0017.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0018.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0019.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0020.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0021.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0022.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0023.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0024.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0025.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0026.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0027.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0028.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0029.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0030.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0031.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0032.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0033.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0034.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0035.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0036.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0037.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0038.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0039.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0040.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0041.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0042.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0043.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0044.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0045.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0046.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0047.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0048.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0049.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0050.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0051.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0052.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0053.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0054.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0055.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0056.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0057.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0058.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0059.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0060.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0061.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0062.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0063.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0064.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0065.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0066.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0067.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0068.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0069.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0070.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0071.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0072.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0073.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0074.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0075.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0076.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0077.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0078.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0079.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0080.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0081.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0082.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# ========
# WARNING!
#
# ...
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1009.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1010.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1011.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1012.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1013.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1014.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1015.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1016.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1017.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1018.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1019.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1020.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1021.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1022.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1023.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1024.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1025.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1026.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1027.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1028.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1029.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1030.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1031.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1032.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1033.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1034.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1035.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1036.pkl

# %%
import os
import pickle
import numpy as np

true_cm = []
true_mr = []
mass_ratio_error = []
mass_ratio_std = []
chirp_mass_error = []
chirp_mass_std = []


result_files = sorted(os.listdir("/scratch/tpausch/test_data/imbh_T2/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/imbh_T2/results/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    result = payload["result"]

    posterior_samples = result.samples

    q_samples = np.array(posterior_samples["mass_ratio"])

    # inference statistics
    q_mean = np.mean(q_samples)
    q_std = np.std(q_samples)

    true_q = theta_true["mass_ratio"]

    cm_samples = np.array(posterior_samples["chirp_mass"])

    cm_mean = np.mean(cm_samples)
    cm_std = np.std(cm_samples)

    true_mr.append(theta_true["mass_ratio"])
    true_cm.append(theta_true["chirp_mass"])
    mass_ratio_error.append(q_mean - true_q)
    mass_ratio_std.append(q_std)
    chirp_mass_error.append(cm_mean - theta_true["chirp_mass"])
    chirp_mass_std.append(cm_std)
# Out:
# /home/tpausch/ET-Dingo/dingo/gw/__init__.py:3: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   import lal

# %%
import matplotlib.pyplot as plt
import numpy as np

true_mr = np.array(true_mr)
true_cm = np.array(true_cm)

chirp_mass_error = np.array(chirp_mass_error)
chirp_mass_std = np.array(chirp_mass_std)

plt.figure(figsize=(8, 5))

# ------------------------------------------------------------
# Error bars
# ------------------------------------------------------------

plt.errorbar(
    true_cm,
    chirp_mass_error,
    yerr=chirp_mass_std,
    fmt="none",
    capsize=4,
    alpha=0.5,
    color="gray",
)

# ------------------------------------------------------------
# Colored scatter points
# ------------------------------------------------------------

sc = plt.scatter(
    true_cm,
    chirp_mass_error,
    c=true_mr,
    cmap="viridis",
    s=70,
    edgecolor="black",
)

# ------------------------------------------------------------
# Reference line
# ------------------------------------------------------------

plt.axhline(0, linestyle="--", color="black")

# ------------------------------------------------------------
# Colorbar
# ------------------------------------------------------------

cbar = plt.colorbar(sc)
cbar.set_label("True mass ratio")

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel("True chirp mass")
plt.ylabel("Chirp mass inference error (inferred − true)")

plt.title("Chirp-mass inference error")

plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm_err = np.asarray(chirp_mass_error)

mean_error = np.mean(cm_err)          # signed average bias (over/under-estimation)
mean_abs_error = np.mean(np.abs(cm_err))  # average magnitude of deviation
rms_error = np.sqrt(np.mean(cm_err**2))   # RMS deviation, penalizes outliers more
std_error = np.std(cm_err)            # spread of the errors around their mean

print(f"Mean error (bias):      {mean_error:.3f}")
print(f"Mean absolute error:    {mean_abs_error:.3f}")
print(f"RMS error:              {rms_error:.3f}")
print(f"Std of error:           {std_error:.3f}")
# Out:
# Mean error (bias):      -0.457
# Mean absolute error:    12.166
# RMS error:              23.577
# Std of error:           23.573

# %%
import matplotlib.pyplot as plt
import numpy as np

true_mr = np.array(true_mr)
true_cm = np.array(true_cm)



mass_ratio_error = np.array(mass_ratio_error)
mass_ratio_std = np.array(mass_ratio_std)


plt.figure(figsize=(8, 5))

# ------------------------------------------------------------
# Error bars
# ------------------------------------------------------------

plt.errorbar(
    true_cm,
    mass_ratio_error,
    yerr=mass_ratio_std,
    fmt="none",
    capsize=4,
    alpha=0.5,
    color="gray",
)

# ------------------------------------------------------------
# Colored scatter points
# ------------------------------------------------------------

sc = plt.scatter(
    true_cm,
    mass_ratio_error,
    c=true_mr,
    cmap="viridis",
    s=70,
    edgecolor="black",
)

# ------------------------------------------------------------
# Reference line
# ------------------------------------------------------------

plt.axhline(0, linestyle="--", color="black")

# ------------------------------------------------------------
# Colorbar
# ------------------------------------------------------------

cbar = plt.colorbar(sc)
cbar.set_label("True mass ratio")

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel("True chirp mass")
plt.ylabel("Mass ratio inference error (inferred − true)")

plt.title("Mass-ratio inference error")

plt.grid(True)

plt.tight_layout()
plt.show()

# %%
pp_values_chirp_mass = []
pp_values_mass_ratio = []

result_files = sorted(os.listdir("/scratch/tpausch/test_data/imbh_T2/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/imbh_T2/results/{fname}", "rb") as f:

        payload = pickle.load(f)

        theta_true = payload["theta_true"]
        result = payload["result"]

        posterior_samples = result.samples


        # ============================================================
        # Chirp mass PP value
        # ============================================================

        cm_samples = posterior_samples["chirp_mass"]

        pp_cm = np.mean(
            cm_samples < theta_true["chirp_mass"]
        )

        pp_values_chirp_mass.append(pp_cm)


        # ============================================================
        # Mass ratio PP value
        # ============================================================

        q_samples = posterior_samples["mass_ratio"]

        pp_q = np.mean(
            q_samples < theta_true["mass_ratio"]
        )

        pp_values_mass_ratio.append(pp_q)

# %%
import matplotlib.pyplot as plt


def plot_pp(pp_values, label):

    pp_values = np.array(pp_values)

    sorted_pp = np.sort(pp_values)

    n = len(sorted_pp)

    empirical_cdf = np.arange(1, n + 1) / n

    x = np.linspace(0, 1, 200)

    sigma = np.sqrt(x * (1 - x) / n)

    plt.figure(figsize=(6, 6))

    # Ideal calibration
    plt.plot(
        [0, 1],
        [0, 1],
        linestyle="--",
        label="Ideal calibration",
    )


    # Empirical PP curve
    plt.plot(
        sorted_pp,
        empirical_cdf,
        marker="o",
        label=label,
    )

    plt.xlabel("Credible level")
    plt.ylabel("Fraction of injections")

    plt.title(f"PP Plot: {label}")

    plt.xlim(0, 1)
    plt.ylim(0, 1)

    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
plot_pp(
    pp_values_chirp_mass,
    "chirp_mass",
)

plot_pp(
    pp_values_mass_ratio,
    "mass_ratio",
)
