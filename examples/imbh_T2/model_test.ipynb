# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # use GPU 1

from dingo.core.posterior_models.build_model import build_model_from_kwargs

main_pm = build_model_from_kwargs(
    filename="/scratch/tpausch/models/imbh_T2/model_latest.pt",
    device="cuda",
    load_training_info=False,
)
# Out:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Putting posterior model to device cuda.

# %%
import numpy as np
import itertools
import os
import pickle

# ============================================================
# Parameter grid
# ============================================================

chirp_masses = np.arange(100, 701, 10)

mass_ratios = np.arange(0.2, 1.01, 0.05)


parameter_grid = list(
    itertools.product(
        chirp_masses,
        mass_ratios
    )
)
print(mass_ratios)
print(f"Total injections: {len(parameter_grid)}")
# Out:
# [0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65 0.7  0.75 0.8  0.85
#  0.9  0.95 1.  ]
# Total injections: 1037

# %%
import os
import pickle
import numpy as np

import dingo.gw.injection as injection
from dingo.gw.noise.asd_dataset import ASDDataset


# ============================================================
# Setup
# ============================================================

os.makedirs("/scratch/tpausch/test_data/imbh_T2/injections", exist_ok=True)

injection_generator = injection.Injection.from_posterior_model_metadata(
    main_pm.metadata
)

asd_fname = main_pm.metadata["train_settings"]["training"]["stage_0"]["asd_dataset_path"]

asd_dataset = ASDDataset(file_name=asd_fname)

injection_generator.asd = {
    k: v[0] for k, v in asd_dataset.asds.items()
}



for idx, (cm, q) in enumerate(parameter_grid):

    print(f"Running injection {idx}")

    intrinsic_parameters = {
        "chirp_mass": float(cm),
        "mass_ratio": float(q),
        "a_1": 0.3,
        "a_2": 0.5,
        "tilt_1": 0.,
        "tilt_2": 0.,
        "phi_jl": 0.,
        "phi_12": 0.
    }

    extrinsic_parameters = {
        'phase': 0.,
        'theta_jn': 2.3,
        'geocent_time': 0.,
        'luminosity_distance': 1000.,
        'ra': 0.,
        'dec': 0.,
        'psi': 0.,
    }

    theta = {
        **intrinsic_parameters,
        **extrinsic_parameters
    }

    strain_data = injection_generator.injection(theta)

    payload = {
        "theta_true": theta,
        "strain_data": strain_data,
    }

    fname = f"/scratch/tpausch/test_data/imbh_T2/injections/inj_{idx:04d}.pkl"

    with open(fname, "wb") as f:
        pickle.dump(payload, f)
# Out:
# /home/tpausch/ET-Dingo/dingo/gw/__init__.py:3: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   import lal
# Setting spin_conversion_phase = 0.0. Using this value for the phase parameter for conversion to cartesian spins.
# Loading dataset from training_data/asds_ET_T2.hdf5.
# Running injection 0
# Running injection 1
# Running injection 2
# Running injection 3
# Running injection 4
# Running injection 5
# Running injection 6
# Running injection 7
# Running injection 8
# Running injection 9
# Running injection 10
# Running injection 11
# Running injection 12
# Running injection 13
# Running injection 14
# Running injection 15
# Running injection 16
# Running injection 17
# Running injection 18
# Running injection 19
# Running injection 20
# Running injection 21
# Running injection 22
# Running injection 23
# Running injection 24
# Running injection 25
# Running injection 26
# Running injection 27
# Running injection 28
# Running injection 29
# Running injection 30
# Running injection 31
# Running injection 32
# Running injection 33
# Running injection 34
# Running injection 35
# Running injection 36
# Running injection 37
# Running injection 38
# Running injection 39
# Running injection 40
# Running injection 41
# Running injection 42
# Running injection 43
# Running injection 44
# Running injection 45
# Running injection 46
# Running injection 47
# Running injection 48
# Running injection 49
# Running injection 50
# Running injection 51
# Running injection 52
# Running injection 53
# Running injection 54
# Running injection 55
# Running injection 56
# Running injection 57
# Running injection 58
# Running injection 59
# Running injection 60
# Running injection 61
# Running injection 62
# Running injection 63
# Running injection 64
# Running injection 65
# Running injection 66
# Running injection 67
# Running injection 68
# Running injection 69
# Running injection 70
# Running injection 71
# Running injection 72
# Running injection 73
# Running injection 74
# Running injection 75
# Running injection 76
# Running injection 77
# Running injection 78
# Running injection 79
# Running injection 80
# Running injection 81
# Running injection 82
# Running injection 83
# Running injection 84
# Running injection 85
# Running injection 86
# Running injection 87
# Running injection 88
# Running injection 89
# Running injection 90
# Running injection 91
# Running injection 92
# Running injection 93
# Running injection 94
# Running injection 95
# Running injection 96
# Running injection 97
# Running injection 98
# Running injection 99
# Running injection 100
# Running injection 101
# Running injection 102
# Running injection 103
# Running injection 104
# Running injection 105
# Running injection 106
# Running injection 107
# Running injection 108
# Running injection 109
# Running injection 110
# Running injection 111
# Running injection 112
# Running injection 113
# Running injection 114
# Running injection 115
# Running injection 116
# Running injection 117
# Running injection 118
# Running injection 119
# Running injection 120
# Running injection 121
# Running injection 122
# Running injection 123
# Running injection 124
# Running injection 125
# Running injection 126
# Running injection 127
# Running injection 128
# Running injection 129
# Running injection 130
# Running injection 131
# Running injection 132
# Running injection 133
# Running injection 134
# Running injection 135
# Running injection 136
# Running injection 137
# Running injection 138
# Running injection 139
# Running injection 140
# Running injection 141
# Running injection 142
# Running injection 143
# Running injection 144
# Running injection 145
# Running injection 146
# Running injection 147
# Running injection 148
# Running injection 149
# Running injection 150
# Running injection 151
# Running injection 152
# Running injection 153
# Running injection 154
# Running injection 155
# Running injection 156
# Running injection 157
# Running injection 158
# Running injection 159
# Running injection 160
# Running injection 161
# Running injection 162
# Running injection 163
# Running injection 164
# Running injection 165
# Running injection 166
# Running injection 167
# Running injection 168
# Running injection 169
# Running injection 170
# Running injection 171
# Running injection 172
# Running injection 173
# Running injection 174
# Running injection 175
# Running injection 176
# Running injection 177
# Running injection 178
# Running injection 179
# Running injection 180
# Running injection 181
# Running injection 182
# Running injection 183
# Running injection 184
# Running injection 185
# Running injection 186
# Running injection 187
# Running injection 188
# Running injection 189
# Running injection 190
# Running injection 191
# Running injection 192
# Running injection 193
# Running injection 194
# Running injection 195
# Running injection 196
# Running injection 197
# Running injection 198
# Running injection 199
# Running injection 200
# Running injection 201
# Running injection 202
# Running injection 203
# Running injection 204
# Running injection 205
# Generation with parameters (1.0508641794047264e+33, 2.627160448511816e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0508641794047264e+33, 2.627160448511816e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 206
# Running injection 207
# Running injection 208
# Running injection 209
# Running injection 210
# Running injection 211
# Running injection 212
# Running injection 213
# Running injection 214
# Running injection 215
# Running injection 216
# Running injection 217
# Running injection 218
# Running injection 219
# Running injection 220
# Running injection 221
# Generation with parameters (1.2458105323983858e+33, 2.491621064796772e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2458105323983858e+33, 2.491621064796772e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 222
# Running injection 223
# Generation with parameters (9.925437614986188e+32, 2.9776312844958563e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.925437614986188e+32, 2.9776312844958563e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 224
# Generation with parameters (9.117162036866342e+32, 3.19100671290322e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.117162036866342e+32, 3.19100671290322e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 225
# Running injection 226
# Running injection 227
# Running injection 228
# Running injection 229
# Running injection 230
# Running injection 231
# Running injection 232
# Running injection 233
# Running injection 234
# Running injection 235
# Running injection 236
# Running injection 237
# Running injection 238
# Generation with parameters (1.2999762077200546e+33, 2.59995241544011e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2999762077200546e+33, 2.59995241544011e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 239
# Generation with parameters (1.1463972866233376e+33, 2.865993216558344e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1463972866233376e+33, 2.865993216558344e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 240
# Generation with parameters (1.0356978380855155e+33, 3.1070935142565465e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0356978380855155e+33, 3.1070935142565465e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 241
# Running injection 242
# Running injection 243
# Running injection 244
# Generation with parameters (7.844285670696077e+32, 3.9221428353480376e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.844285670696077e+32, 3.9221428353480376e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 245
# Generation with parameters (7.457029789275258e+32, 4.101366384101392e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.457029789275258e+32, 4.101366384101392e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 246
# Generation with parameters (7.122794232562352e+32, 4.27367653953741e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.122794232562352e+32, 4.27367653953741e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 247
# Generation with parameters (6.830711247500546e+32, 4.439962310875355e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.830711247500546e+32, 4.439962310875355e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 248
# Running injection 249
# Running injection 250
# Running injection 251
# Running injection 252
# Running injection 253
# Running injection 254
# Running injection 255
# Generation with parameters (1.3541418830417235e+33, 2.708283766083447e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3541418830417235e+33, 2.708283766083447e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 256
# Generation with parameters (1.1941638402326436e+33, 2.985409600581609e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1941638402326436e+33, 2.985409600581609e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 257
# Running injection 258
# Generation with parameters (9.909958735724286e+32, 3.468485557503499e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.909958735724286e+32, 3.468485557503499e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 259
# Generation with parameters (9.213731058103203e+32, 3.6854924232412805e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.213731058103203e+32, 3.6854924232412805e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 260
# Generation with parameters (8.64553774543376e+32, 3.890491985445192e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.64553774543376e+32, 3.890491985445192e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 261
# Running injection 262
# Running injection 263
# Running injection 264
# Running injection 265
# Generation with parameters (6.84663032455121e+32, 4.792641227185846e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.84663032455121e+32, 4.792641227185846e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 266
# Generation with parameters (6.607189618676677e+32, 4.955392214007506e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.607189618676677e+32, 4.955392214007506e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 267
# Generation with parameters (6.392142201505267e+32, 5.113713761204212e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.392142201505267e+32, 5.113713761204212e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 268
# Generation with parameters (6.197676580636682e+32, 5.2680250935411785e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.197676580636682e+32, 5.2680250935411785e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 269
# Generation with parameters (6.020757475320433e+32, 5.41868172778839e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.020757475320433e+32, 5.41868172778839e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 270
# Generation with parameters (5.858934976160926e+32, 5.565988227352877e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.858934976160926e+32, 5.565988227352877e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 271
# Generation with parameters (5.710207868826796e+32, 5.710207868826795e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.710207868826796e+32, 5.710207868826795e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 272
# Generation with parameters (1.4083075583633926e+33, 2.8166151167267854e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4083075583633926e+33, 2.8166151167267854e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 273
# Generation with parameters (1.2419303938419494e+33, 3.1048259846048735e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2419303938419494e+33, 3.1048259846048735e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 274
# Generation with parameters (1.1220059912593083e+33, 3.366017973777925e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1220059912593083e+33, 3.366017973777925e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 275
# Generation with parameters (1.0306357085153258e+33, 3.60722497980364e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0306357085153258e+33, 3.60722497980364e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 276
# Generation with parameters (9.582280300427328e+32, 3.832912120170931e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.582280300427328e+32, 3.832912120170931e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 277
# Generation with parameters (8.99135925525111e+32, 4.046111664862998e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.99135925525111e+32, 4.046111664862998e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 278
# Generation with parameters (8.497976143254082e+32, 4.24898807162704e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.497976143254082e+32, 4.24898807162704e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 279
# Generation with parameters (8.078448938381529e+32, 4.44314691610984e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.078448938381529e+32, 4.44314691610984e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 280
# Generation with parameters (7.716360418609215e+32, 4.629816251165528e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.716360418609215e+32, 4.629816251165528e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 281
# Generation with parameters (7.399937184792257e+32, 4.809959170114967e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.399937184792257e+32, 4.809959170114967e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 282
# Generation with parameters (7.120495537533258e+32, 4.98434687627328e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.120495537533258e+32, 4.98434687627328e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 283
# Generation with parameters (6.871477203423743e+32, 5.153607902567806e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.871477203423743e+32, 5.153607902567806e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 284
# Generation with parameters (6.647827889565476e+32, 5.31826231165238e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.647827889565476e+32, 5.31826231165238e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 285
# Generation with parameters (6.44558364386215e+32, 5.478746097282827e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.44558364386215e+32, 5.478746097282827e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 286
# Generation with parameters (6.261587774333251e+32, 5.635428996899926e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.261587774333251e+32, 5.635428996899926e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 287
# Generation with parameters (6.093292375207363e+32, 5.7886277564469936e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.093292375207363e+32, 5.7886277564469936e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 288
# Generation with parameters (5.9386161835798686e+32, 5.938616183579867e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.9386161835798686e+32, 5.938616183579867e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 289
# Generation with parameters (1.4624732336850617e+33, 2.9249464673701235e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4624732336850617e+33, 2.9249464673701235e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 290
# Generation with parameters (1.2896969474512551e+33, 3.2242423686281377e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2896969474512551e+33, 3.2242423686281377e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 291
# Generation with parameters (1.1651600678462051e+33, 3.4954802035386145e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1651600678462051e+33, 3.4954802035386145e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 292
# Generation with parameters (1.0702755434582226e+33, 3.7459644021037786e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0702755434582226e+33, 3.7459644021037786e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 293
# Generation with parameters (9.950829542751457e+32, 3.980331817100583e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.950829542751457e+32, 3.980331817100583e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 294
# Generation with parameters (9.337180765068459e+32, 4.201731344280806e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.337180765068459e+32, 4.201731344280806e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 295
# Generation with parameters (8.824821379533083e+32, 4.412410689766542e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.824821379533083e+32, 4.412410689766542e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 296
# Generation with parameters (8.389158512934666e+32, 4.6140371821140655e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.389158512934666e+32, 4.6140371821140655e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 297
# Generation with parameters (8.013143511632645e+32, 4.8078861069795866e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.013143511632645e+32, 4.8078861069795866e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 298
# Generation with parameters (7.684550153438113e+32, 4.9949575997347726e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.684550153438113e+32, 4.9949575997347726e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 299
# Generation with parameters (7.394360750515307e+32, 5.176052525360714e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.394360750515307e+32, 5.176052525360714e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 300
# Generation with parameters (7.135764788170809e+32, 5.351823591128105e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.135764788170809e+32, 5.351823591128105e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 301
# Generation with parameters (6.903513577625688e+32, 5.52281086210055e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.903513577625688e+32, 5.52281086210055e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 302
# Generation with parameters (6.693490707087616e+32, 5.689467101024471e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.693490707087616e+32, 5.689467101024471e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 303
# Generation with parameters (6.502418073346069e+32, 5.8521762660114605e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.502418073346069e+32, 5.8521762660114605e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 304
# Generation with parameters (6.327649774253799e+32, 6.011267285541108e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.327649774253799e+32, 6.011267285541108e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 305
# Generation with parameters (6.167024498332939e+32, 6.1670244983329385e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.167024498332939e+32, 6.1670244983329385e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 306
# Generation with parameters (1.5166389090067305e+33, 3.033277818013461e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5166389090067305e+33, 3.033277818013461e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 307
# Generation with parameters (1.3374635010605608e+33, 3.343658752651402e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3374635010605608e+33, 3.343658752651402e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 308
# Generation with parameters (1.2083141444331016e+33, 3.624942433299305e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2083141444331016e+33, 3.624942433299305e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 309
# Generation with parameters (1.10991537840112e+33, 3.88470382440392e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.10991537840112e+33, 3.88470382440392e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 310
# Generation with parameters (1.0319378785075585e+33, 4.1277515140302336e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0319378785075585e+33, 4.1277515140302336e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 311
# Generation with parameters (9.683002274885811e+32, 4.357351023698614e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.683002274885811e+32, 4.357351023698614e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 312
# Generation with parameters (9.151666615812088e+32, 4.575833307906044e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.151666615812088e+32, 4.575833307906044e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 313
# Generation with parameters (8.6998680874878e+32, 4.784927448118289e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.6998680874878e+32, 4.784927448118289e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 314
# Generation with parameters (8.309926604656078e+32, 4.985955962793646e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.309926604656078e+32, 4.985955962793646e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 315
# Generation with parameters (7.969163122083969e+32, 5.17995602935458e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.969163122083969e+32, 5.17995602935458e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 316
# Generation with parameters (7.668225963497355e+32, 5.367758174448148e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.668225963497355e+32, 5.367758174448148e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 317
# Generation with parameters (7.400052372917876e+32, 5.550039279688405e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.400052372917876e+32, 5.550039279688405e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 318
# Generation with parameters (7.159199265685897e+32, 5.7273594125487174e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.159199265685897e+32, 5.7273594125487174e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 319
# Generation with parameters (6.941397770313083e+32, 5.9001881047661195e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.941397770313083e+32, 5.9001881047661195e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 320
# Generation with parameters (6.743248372358887e+32, 6.068923535122997e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.743248372358887e+32, 6.068923535122997e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 321
# Generation with parameters (6.562007173300237e+32, 6.2339068146352234e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.562007173300237e+32, 6.2339068146352234e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 322
# Generation with parameters (6.395432813086012e+32, 6.3954328130860105e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.395432813086012e+32, 6.3954328130860105e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 323
# Generation with parameters (1.5708045843283996e+33, 3.1416091686567992e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5708045843283996e+33, 3.1416091686567992e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 324
# Generation with parameters (1.3852300546698663e+33, 3.463075136674666e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3852300546698663e+33, 3.463075136674666e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 325
# ...
# Generation with parameters (2.3861684177397174e+33, 1.0737757879828727e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3861684177397174e+33, 1.0737757879828727e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1009
# Generation with parameters (2.2552321303251216e+33, 1.1276160651625606e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2552321303251216e+33, 1.1276160651625606e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1010
# Generation with parameters (2.1438960644166363e+33, 1.1791428354291498e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.1438960644166363e+33, 1.1791428354291498e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1011
# Generation with parameters (2.0478033418616764e+33, 1.2286820051170054e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0478033418616764e+33, 1.2286820051170054e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1012
# Generation with parameters (1.9638294836564066e+33, 1.276489164376664e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.9638294836564066e+33, 1.276489164376664e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1013
# Generation with parameters (1.8896699695761337e+33, 1.3227689787032935e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8896699695761337e+33, 1.3227689787032935e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1014
# Generation with parameters (1.8235843347547625e+33, 1.3676882510660714e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8235843347547625e+33, 1.3676882510660714e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1015
# Generation with parameters (1.7642312476154538e+33, 1.4113849980923626e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7642312476154538e+33, 1.4113849980923626e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1016
# Generation with parameters (1.710558736255724e+33, 1.4539749258173652e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.710558736255724e+33, 1.4539749258173652e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1017
# Generation with parameters (1.66172906318844e+33, 1.495556156869596e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.66172906318844e+33, 1.495556156869596e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1018
# Generation with parameters (1.6170660534204153e+33, 1.5362127507493942e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6170660534204153e+33, 1.5362127507493942e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1019
# Generation with parameters (1.5760173717961957e+33, 1.576017371796195e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5760173717961957e+33, 1.576017371796195e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1020
# Generation with parameters (3.7915972725168257e+33, 7.583194545033651e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.7915972725168257e+33, 7.583194545033651e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1021
# Generation with parameters (3.3436587526514025e+33, 8.359146881628506e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.3436587526514025e+33, 8.359146881628506e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1022
# Generation with parameters (3.020785361082753e+33, 9.06235608324826e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.020785361082753e+33, 9.06235608324826e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1023
# Generation with parameters (2.7747884460027994e+33, 9.711759561009798e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.7747884460027994e+33, 9.711759561009798e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1024
# Generation with parameters (2.5798446962688963e+33, 1.0319378785075585e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5798446962688963e+33, 1.0319378785075585e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1025
# Generation with parameters (2.4207505687214527e+33, 1.0893377559246536e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.4207505687214527e+33, 1.0893377559246536e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1026
# Generation with parameters (2.2879166539530217e+33, 1.1439583269765106e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2879166539530217e+33, 1.1439583269765106e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1027
# Generation with parameters (2.1749670218719504e+33, 1.1962318620295726e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.1749670218719504e+33, 1.1962318620295726e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1028
# Generation with parameters (2.0774816511640195e+33, 1.2464889906984114e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0774816511640195e+33, 1.2464889906984114e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1029
# Generation with parameters (1.992290780520992e+33, 1.2949890073386449e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.992290780520992e+33, 1.2949890073386449e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1030
# Generation with parameters (1.9170564908743387e+33, 1.341939543612037e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.9170564908743387e+33, 1.341939543612037e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1031
# Generation with parameters (1.850013093229469e+33, 1.3875098199221015e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.850013093229469e+33, 1.3875098199221015e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1032
# Generation with parameters (1.7897998164214745e+33, 1.4318398531371792e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7897998164214745e+33, 1.4318398531371792e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1033
# Generation with parameters (1.7353494425782708e+33, 1.4750470261915298e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7353494425782708e+33, 1.4750470261915298e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1034
# Generation with parameters (1.6858120930897216e+33, 1.517230883780749e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6858120930897216e+33, 1.517230883780749e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1035
# Generation with parameters (1.6405017933250593e+33, 1.5584767036588056e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6405017933250593e+33, 1.5584767036588056e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1036
# Generation with parameters (1.598858203271503e+33, 1.5988582032715024e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.598858203271503e+33, 1.5988582032715024e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.5, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.

# %%
import os
import pickle

from dingo.gw.inference.gw_samplers import GWSampler


os.makedirs("/scratch/tpausch/test_data/imbh_T2/results", exist_ok=True)

injection_files = sorted(os.listdir("/scratch/tpausch/test_data/imbh_T2/injections"))

for fname in injection_files:

    # --------------------------------------------------------
    # Load injection
    # --------------------------------------------------------

    with open(f"/scratch/tpausch/test_data/imbh_T2/injections/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    strain_data = payload["strain_data"]

    # --------------------------------------------------------
    # Run sampler
    # --------------------------------------------------------

    sampler = GWSampler(model=main_pm)

    sampler.context = strain_data

    sampler.run_sampler(
        num_samples=50_000,
        batch_size=10_000,
    )

    result = sampler.to_result()

    # --------------------------------------------------------
    # Store result
    # --------------------------------------------------------

    result_payload = {
        "theta_true": theta_true,
        "result": result,
    }

    outname = fname.replace("inj_", "result_")

    with open(f"/scratch/tpausch/test_data/imbh_T2/results/{outname}", "wb") as f:
        pickle.dump(result_payload, f)

    print(f"Saved /scratch/tpausch/test_data/imbh_T2/results/{outname}")
# Out:
# Running sampler to generate 50000 samples.
# Done. This took 5.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0000.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0001.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0002.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0003.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0004.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0005.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0006.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0007.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0008.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0009.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0010.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0011.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0012.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0013.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0014.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0015.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0016.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0017.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0018.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0019.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0020.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0021.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0022.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0023.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0024.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0025.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0026.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0027.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0028.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0029.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0030.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0031.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0032.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0033.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0034.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0035.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0036.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0037.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0038.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0039.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0040.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0041.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0042.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0043.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0044.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0045.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0046.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0047.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0048.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0049.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0050.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0051.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0052.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0053.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0054.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0055.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0056.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0057.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0058.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0059.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0060.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0061.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0062.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0063.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0064.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0065.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0066.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0067.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0068.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0069.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0070.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0071.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0072.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0073.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0074.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0075.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0076.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0077.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0078.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0079.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0080.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0081.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_0082.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# ...
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1009.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1010.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1011.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1012.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1013.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1014.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1015.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1016.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1017.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1018.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1019.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1020.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1021.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1022.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1023.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1024.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1025.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1026.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1027.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1028.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1029.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1030.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1031.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1032.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1033.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1034.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1035.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T2/results/result_1036.pkl

# %%
import os
import pickle
import numpy as np

true_cm = []
true_mr = []
mass_ratio_error = []
mass_ratio_std = []
chirp_mass_error = []
chirp_mass_std = []


result_files = sorted(os.listdir("/scratch/tpausch/test_data/imbh_T2/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/imbh_T2/results/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    result = payload["result"]

    posterior_samples = result.samples

    q_samples = np.array(posterior_samples["mass_ratio"])

    # inference statistics
    q_mean = np.mean(q_samples)
    q_std = np.std(q_samples)

    true_q = theta_true["mass_ratio"]

    cm_samples = np.array(posterior_samples["chirp_mass"])

    cm_mean = np.mean(cm_samples)
    cm_std = np.std(cm_samples)

    true_mr.append(theta_true["mass_ratio"])
    true_cm.append(theta_true["chirp_mass"])
    mass_ratio_error.append(q_mean - true_q)
    mass_ratio_std.append(q_std)
    chirp_mass_error.append(cm_mean - theta_true["chirp_mass"])
    chirp_mass_std.append(cm_std)

# %%
import matplotlib.pyplot as plt
import numpy as np


true_mr = np.array(true_mr)
true_cm = np.array(true_cm)
chirp_mass_error = np.array(chirp_mass_error)
chirp_mass_std = np.array(chirp_mass_std)

plt.figure(figsize=(8, 5))

plt.errorbar(
    true_cm,
    chirp_mass_error,
    yerr=chirp_mass_std,
    fmt="o",
    capsize=4,
)

plt.axhline(0, linestyle="--")

plt.xlabel("True chirp mass")
plt.ylabel("Chirp mass inference error (inferred - true)")
plt.title("Chirp-mass inference error across all injections")

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

true_mr = np.array(true_mr)
true_cm = np.array(true_cm)

chirp_mass_error = np.array(chirp_mass_error)
chirp_mass_std = np.array(chirp_mass_std)

plt.figure(figsize=(8, 5))

# ------------------------------------------------------------
# Error bars
# ------------------------------------------------------------

plt.errorbar(
    true_cm,
    chirp_mass_error,
    yerr=chirp_mass_std,
    fmt="none",
    capsize=4,
    alpha=0.5,
    color="gray",
)

# ------------------------------------------------------------
# Colored scatter points
# ------------------------------------------------------------

sc = plt.scatter(
    true_cm,
    chirp_mass_error,
    c=true_mr,
    cmap="viridis",
    s=70,
    edgecolor="black",
)

# ------------------------------------------------------------
# Reference line
# ------------------------------------------------------------

plt.axhline(0, linestyle="--", color="black")

# ------------------------------------------------------------
# Colorbar
# ------------------------------------------------------------

cbar = plt.colorbar(sc)
cbar.set_label("True mass ratio")

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel("True chirp mass")
plt.ylabel("Chirp mass inference error (inferred − true)")

plt.title("Chirp-mass inference error")

plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

true_mr = np.array(true_mr)
chirp_mass_error = np.array(chirp_mass_error)
chirp_mass_std = np.array(chirp_mass_std)

plt.figure(figsize=(8, 5))

plt.errorbar(
    true_mr,
    chirp_mass_error,
    yerr=chirp_mass_std,
    fmt="o",
    capsize=4,
)

plt.axhline(0, linestyle="--")

plt.xlabel("True mass ratio")
plt.ylabel("Chirp mass inference error (inferred - true)")
plt.title("Chirp-mass inference error across all injections")

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

true_cm = np.array(true_cm)
mass_ratio_error = np.array(mass_ratio_error)
mass_ratio_std = np.array(mass_ratio_std)

plt.figure(figsize=(8, 5))

plt.errorbar(
    true_cm,
    mass_ratio_error,
    yerr=mass_ratio_std,
    fmt="o",
    capsize=4,
)

plt.axhline(0, linestyle="--")

plt.xlabel("True chirp mass")
plt.ylabel("Mass ratio inference error (inferred - true)")
plt.title("Mass-ratio inference error across all injections")

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

true_mr = np.array(true_mr)
true_cm = np.array(true_cm)



mass_ratio_error = np.array(mass_ratio_error)
mass_ratio_std = np.array(mass_ratio_std)


plt.figure(figsize=(8, 5))

# ------------------------------------------------------------
# Error bars
# ------------------------------------------------------------

plt.errorbar(
    true_cm,
    mass_ratio_error,
    yerr=mass_ratio_std,
    fmt="none",
    capsize=4,
    alpha=0.5,
    color="gray",
)

# ------------------------------------------------------------
# Colored scatter points
# ------------------------------------------------------------

sc = plt.scatter(
    true_cm,
    mass_ratio_error,
    c=true_mr,
    cmap="viridis",
    s=70,
    edgecolor="black",
)

# ------------------------------------------------------------
# Reference line
# ------------------------------------------------------------

plt.axhline(0, linestyle="--", color="black")

# ------------------------------------------------------------
# Colorbar
# ------------------------------------------------------------

cbar = plt.colorbar(sc)
cbar.set_label("True mass ratio")

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel("True chirp mass")
plt.ylabel("Mass ratio inference error (inferred − true)")

plt.title("Mass-ratio inference error")

plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

true_mr = np.array(true_mr)
mass_ratio_error = np.array(mass_ratio_error)
mass_ratio_std = np.array(mass_ratio_std)

plt.figure(figsize=(8, 5))

plt.errorbar(
    true_mr,
    mass_ratio_error,
    yerr=mass_ratio_std,
    fmt="o",
    capsize=4,
)

plt.axhline(0, linestyle="--")

plt.xlabel("True mass ratio")
plt.ylabel("Mass ratio inference error (inferred - true)")
plt.title("Mass-ratio inference error across all injections")

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
pp_values_chirp_mass = []
pp_values_mass_ratio = []

result_files = sorted(os.listdir("/scratch/tpausch/test_data/imbh_T2/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/imbh_T2/results/{fname}", "rb") as f:

        payload = pickle.load(f)

        theta_true = payload["theta_true"]
        result = payload["result"]

        posterior_samples = result.samples


        # ============================================================
        # Chirp mass PP value
        # ============================================================

        cm_samples = posterior_samples["chirp_mass"]

        pp_cm = np.mean(
            cm_samples < theta_true["chirp_mass"]
        )

        pp_values_chirp_mass.append(pp_cm)


        # ============================================================
        # Mass ratio PP value
        # ============================================================

        q_samples = posterior_samples["mass_ratio"]

        pp_q = np.mean(
            q_samples < theta_true["mass_ratio"]
        )

        pp_values_mass_ratio.append(pp_q)

# %%
import matplotlib.pyplot as plt


def plot_pp(pp_values, label):

    pp_values = np.array(pp_values)

    sorted_pp = np.sort(pp_values)

    n = len(sorted_pp)

    empirical_cdf = np.arange(1, n + 1) / n

    x = np.linspace(0, 1, 200)

    sigma = np.sqrt(x * (1 - x) / n)

    plt.figure(figsize=(6, 6))

    # Ideal calibration
    plt.plot(
        [0, 1],
        [0, 1],
        linestyle="--",
        label="Ideal calibration",
    )


    # Empirical PP curve
    plt.plot(
        sorted_pp,
        empirical_cdf,
        marker="o",
        label=label,
    )

    plt.xlabel("Credible level")
    plt.ylabel("Fraction of injections")

    plt.title(f"PP Plot: {label}")

    plt.xlim(0, 1)
    plt.ylim(0, 1)

    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
plot_pp(
    pp_values_chirp_mass,
    "chirp_mass",
)

plot_pp(
    pp_values_mass_ratio,
    "mass_ratio",
)
