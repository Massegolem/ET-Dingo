# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # use GPU 1

from dingo.core.posterior_models.build_model import build_model_from_kwargs

main_pm = build_model_from_kwargs(
    filename="/scratch/tpausch/models/imbh_T8_mass1/model_latest.pt",
    device="cuda",
    load_training_info=False,
)
# Out:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Putting posterior model to device cuda.

# %%
import os
import pickle
import numpy as np

import dingo.gw.injection as injection
from dingo.gw.noise.asd_dataset import ASDDataset

# ============================================================
# Setup
# ============================================================

num_injections = 1000
out_dir = "/scratch/tpausch/test_data/imbh_T8_mass1/injections"
os.makedirs(out_dir, exist_ok=True)

np.random.seed(42)  # optional, for reproducibility

injection_generator = injection.Injection.from_posterior_model_metadata(
    main_pm.metadata
)

asd_fname = main_pm.metadata["train_settings"]["training"]["stage_0"]["asd_dataset_path"]
asd_dataset = ASDDataset(file_name=asd_fname)

injection_generator.asd = {
    k: v[0] for k, v in asd_dataset.asds.items()
}

# This is the combined intrinsic + extrinsic bilby PriorDict
# that the network was trained on
prior = injection_generator.prior
print(prior)

# ============================================================
# Draw and run injections
# ============================================================

for idx in range(num_injections):

    print(f"Running injection {idx}")

    theta = prior.sample()
    theta = {k: float(v) for k, v in theta.items()}  # cast numpy -> float

    strain_data = injection_generator.injection(theta)

    payload = {
        "theta_true": theta,
        "strain_data": strain_data,
    }

    fname = os.path.join(out_dir, f"inj_{idx:04d}.pkl")

    with open(fname, "wb") as f:
        pickle.dump(payload, f)
# Out:
# /home/tpausch/ET-Dingo/dingo/gw/__init__.py:3: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   import lal
# Setting spin_conversion_phase = 0.0. Using this value for the phase parameter for conversion to cartesian spins.
# Loading dataset from training_data/asds_ET_T8.hdf5.
# {'mass_1': Constraint(minimum=30.0, maximum=3000.0, name='mass_1', latex_label='$m_1$', unit=None), 'mass_2': Constraint(minimum=30.0, maximum=3000.0, name='mass_2', latex_label='$m_2$', unit=None), 'chirp_mass': bilby.gw.prior.UniformInComponentsChirpMass(minimum=50.0, maximum=1000.0, name='chirp_mass', latex_label='$\\mathcal{M}$', unit=None, boundary=None), 'mass_ratio': bilby.gw.prior.UniformInComponentsMassRatio(minimum=0.125, maximum=1.0, name='mass_ratio', latex_label='$q$', unit=None, boundary=None, equal_mass=False), 'phase': Uniform(minimum=0.0, maximum=6.283185307179586, name='phase', latex_label='$\\phi$', unit=None, boundary='periodic'), 'chi_1': bilby.gw.prior.AlignedSpin(a_prior=Uniform(minimum=0, maximum=0.9, name=None, latex_label=None, unit=None, boundary=None), z_prior=Uniform(minimum=-1, maximum=1, name=None, latex_label=None, unit=None, boundary=None), name='chi_1', latex_label='$\\chi_1$', unit=None, boundary=None, minimum=-0.9, maximum=0.9, num_interp=100000), 'chi_2': bilby.gw.prior.AlignedSpin(a_prior=Uniform(minimum=0, maximum=0.9, name=None, latex_label=None, unit=None, boundary=None), z_prior=Uniform(minimum=-1, maximum=1, name=None, latex_label=None, unit=None, boundary=None), name='chi_2', latex_label='$\\chi_2$', unit=None, boundary=None, minimum=-0.9, maximum=0.9, num_interp=100000), 'theta_jn': Sine(minimum=0.0, maximum=3.141592653589793, name='theta_jn', latex_label='$\\theta_{JN}$', unit=None, boundary=None), 'luminosity_distance': LogUniform(minimum=1000.0, maximum=1000000.0, name='luminosity_distance', latex_label='$d_L$', unit=None, boundary=None), 'geocent_time': Uniform(minimum=-0.1, maximum=0.1, name='geocent_time', latex_label='$t_c$', unit=None, boundary=None), 'dec': Cosine(minimum=-1.5707963267948966, maximum=1.5707963267948966, name='dec', latex_label='$\\mathrm{DEC}$', unit=None, boundary=None), 'ra': Uniform(minimum=0.0, maximum=6.283185307179586, name='ra', latex_label='$\\mathrm{RA}$', unit=None, boundary='periodic'), 'psi': Uniform(minimum=0.0, maximum=3.141592653589793, name='psi', latex_label='$\\psi$', unit=None, boundary='periodic')}
# Running injection 0
# Generation with parameters (3.5991625415551043e+33, 8.939944502933366e+32, 0.0, 0.0, 0.0744426248813646, 0.0, 0.0, 0.6248217265008059, 3.085677581491367e+24, 2.848677037626495, 2.4624274898058385, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.5991625415551043e+33, 8.939944502933366e+32, 0.0, 0.0, 0.0744426248813646, 0.0, 0.0, 0.6248217265008059, 3.085677581491367e+24, 2.848677037626495, 2.4624274898058385, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1
# Generation with parameters (2.3521431621922548e+33, 1.2300308044350132e+33, 0.0, 0.0, -0.1009528157865408, 0.0, 0.0, -0.1206862355749499, 3.085677581491367e+24, 2.1191227766336365, 0.26566574441822277, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3521431621922548e+33, 1.2300308044350132e+33, 0.0, 0.0, -0.1009528157865408, 0.0, 0.0, -0.1206862355749499, 3.085677581491367e+24, 2.1191227766336365, 0.26566574441822277, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 2
# Generation with parameters (3.5141606296376326e+33, 7.944599756425082e+32, 0.0, 0.0, 0.10851464228588921, 0.0, 0.0, 0.005335378402762158, 3.085677581491367e+24, 2.5963449988159857, 2.40807196700588, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.5141606296376326e+33, 7.944599756425082e+32, 0.0, 0.0, 0.10851464228588921, 0.0, 0.0, 0.005335378402762158, 3.085677581491367e+24, 2.5963449988159857, 2.40807196700588, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 3
# Generation with parameters (4.848645903149259e+33, 1.1222213993139663e+33, 0.0, 0.0, 0.1338674048638922, 0.0, 0.0, 0.5754605530880165, 3.085677581491367e+24, 1.4798302771767806, 5.436755120248301, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.848645903149259e+33, 1.1222213993139663e+33, 0.0, 0.0, 0.1338674048638922, 0.0, 0.0, 0.5754605530880165, 3.085677581491367e+24, 1.4798302771767806, 5.436755120248301, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 4
# Generation with parameters (2.3189896475003098e+33, 3.4634270156759955e+32, 0.0, 0.0, -0.08200950708623747, 0.0, 0.0, 0.24365643545828145, 3.085677581491367e+24, 1.446605789608957, 5.935340389179686, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3189896475003098e+33, 3.4634270156759955e+32, 0.0, 0.0, -0.08200950708623747, 0.0, 0.0, 0.24365643545828145, 3.085677581491367e+24, 1.446605789608957, 5.935340389179686, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 5
# Generation with parameters (3.5590747028791264e+33, 1.372088520419568e+33, 0.0, 0.0, 0.16423969922045617, 0.0, 0.0, 0.23654758258125355, 3.085677581491367e+24, 2.6780150391138258, 5.163024404567138, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.5590747028791264e+33, 1.372088520419568e+33, 0.0, 0.0, 0.16423969922045617, 0.0, 0.0, 0.23654758258125355, 3.085677581491367e+24, 2.6780150391138258, 5.163024404567138, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 6
# Generation with parameters (4.277060028470973e+33, 6.4776804267130714e+32, 0.0, 0.0, -0.023269788413461317, 0.0, 0.0, -0.652049093875419, 3.085677581491367e+24, 1.9119424514112824, 5.7887404388887855, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.277060028470973e+33, 6.4776804267130714e+32, 0.0, 0.0, -0.023269788413461317, 0.0, 0.0, -0.652049093875419, 3.085677581491367e+24, 1.9119424514112824, 5.7887404388887855, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 7
# Generation with parameters (1.849966348427461e+33, 6.017510497735587e+32, 0.0, 0.0, -0.3236180996889235, 0.0, 0.0, 0.12555306557301835, 3.085677581491367e+24, 2.6268292553257084, 1.7802334530644015, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.849966348427461e+33, 6.017510497735587e+32, 0.0, 0.0, -0.3236180996889235, 0.0, 0.0, 0.12555306557301835, 3.085677581491367e+24, 2.6268292553257084, 1.7802334530644015, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 8
# Generation with parameters (2.239503849461221e+33, 2.063906333510322e+33, 0.0, 0.0, 0.16500269967036812, 0.0, 0.0, -0.10354991246008523, 3.085677581491367e+24, 2.3771700901305746, 3.98636739954509, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.239503849461221e+33, 2.063906333510322e+33, 0.0, 0.0, 0.16500269967036812, 0.0, 0.0, -0.10354991246008523, 3.085677581491367e+24, 2.3771700901305746, 3.98636739954509, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 9
# Generation with parameters (2.8261857762161256e+33, 1.010744647432284e+33, 0.0, 0.0, 0.38835588284669903, 0.0, 0.0, -0.4681405822599198, 3.085677581491367e+24, 2.4114350322989786, 3.93160091989024, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.8261857762161256e+33, 1.010744647432284e+33, 0.0, 0.0, 0.38835588284669903, 0.0, 0.0, -0.4681405822599198, 3.085677581491367e+24, 2.4114350322989786, 3.93160091989024, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 10
# Running injection 11
# Generation with parameters (4.891159775138699e+33, 1.1110770313687355e+33, 0.0, 0.0, -0.2076929450170827, 0.0, 0.0, 0.01433150971114853, 3.085677581491367e+24, 2.09732298761752, 2.413849693355709, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.891159775138699e+33, 1.1110770313687355e+33, 0.0, 0.0, -0.2076929450170827, 0.0, 0.0, 0.01433150971114853, 3.085677581491367e+24, 2.09732298761752, 2.413849693355709, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 12
# Generation with parameters (2.0677160114203005e+33, 1.198867250357991e+33, 0.0, 0.0, 0.5552461060862562, 0.0, 0.0, 0.10109498298184923, 3.085677581491367e+24, 2.510653407582006, 3.962569718527901, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0677160114203005e+33, 1.198867250357991e+33, 0.0, 0.0, 0.5552461060862562, 0.0, 0.0, 0.10109498298184923, 3.085677581491367e+24, 2.510653407582006, 3.962569718527901, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 13
# Generation with parameters (3.270140993363039e+33, 5.810404079882453e+32, 0.0, 0.0, 0.21336414758221792, 0.0, 0.0, 0.0816114789648309, 3.085677581491367e+24, 1.7920743283490554, 0.2199745350563007, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.270140993363039e+33, 5.810404079882453e+32, 0.0, 0.0, 0.21336414758221792, 0.0, 0.0, 0.0816114789648309, 3.085677581491367e+24, 1.7920743283490554, 0.2199745350563007, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 14
# Generation with parameters (2.786534274470852e+33, 1.1242831954265945e+33, 0.0, 0.0, 0.013030226778726164, 0.0, 0.0, -0.2633535485191094, 3.085677581491367e+24, 1.1727959954999752, 0.6647643651245421, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.786534274470852e+33, 1.1242831954265945e+33, 0.0, 0.0, 0.013030226778726164, 0.0, 0.0, -0.2633535485191094, 3.085677581491367e+24, 1.1727959954999752, 0.6647643651245421, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 15
# Generation with parameters (1.2959773635149071e+33, 7.90480855325076e+32, 0.0, 0.0, -0.047056345494346605, 0.0, 0.0, 0.16975562557443993, 3.085677581491367e+24, 1.9720001474151232, 4.054622094435374, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2959773635149071e+33, 7.90480855325076e+32, 0.0, 0.0, -0.047056345494346605, 0.0, 0.0, 0.16975562557443993, 3.085677581491367e+24, 1.9720001474151232, 4.054622094435374, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 16
# Generation with parameters (5.542844957974772e+33, 1.0409168662731596e+33, 0.0, 0.0, -0.06562079641054551, 0.0, 0.0, -0.01384510135719562, 3.085677581491367e+24, 1.3177063911025406, 2.9345891110247857, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.542844957974772e+33, 1.0409168662731596e+33, 0.0, 0.0, -0.06562079641054551, 0.0, 0.0, -0.01384510135719562, 3.085677581491367e+24, 1.3177063911025406, 2.9345891110247857, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 17
# Generation with parameters (3.664692790915665e+33, 1.3472622163685796e+33, 0.0, 0.0, 0.5309124780954128, 0.0, 0.0, 0.20836816858051074, 3.085677581491367e+24, 1.9972298670636177, 3.8548416089198048, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.664692790915665e+33, 1.3472622163685796e+33, 0.0, 0.0, 0.5309124780954128, 0.0, 0.0, 0.20836816858051074, 3.085677581491367e+24, 1.9972298670636177, 3.8548416089198048, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 18
# Generation with parameters (1.2993814427916697e+33, 1.2261564675930077e+33, 0.0, 0.0, -0.6680754932552101, 0.0, 0.0, 0.1907524953058693, 3.085677581491367e+24, 1.940222731381263, 3.600046930518072, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2993814427916697e+33, 1.2261564675930077e+33, 0.0, 0.0, -0.6680754932552101, 0.0, 0.0, 0.1907524953058693, 3.085677581491367e+24, 1.940222731381263, 3.600046930518072, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 19
# Generation with parameters (2.168167499399588e+33, 8.232546352369184e+32, 0.0, 0.0, 0.3653237781042314, 0.0, 0.0, -0.03446754906808824, 3.085677581491367e+24, 2.0785401987701775, 4.808726601392004, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.168167499399588e+33, 8.232546352369184e+32, 0.0, 0.0, 0.3653237781042314, 0.0, 0.0, -0.03446754906808824, 3.085677581491367e+24, 2.0785401987701775, 4.808726601392004, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 20
# Generation with parameters (1.8445409835405757e+33, 2.7034353260156926e+32, 0.0, 0.0, 0.6361362276706535, 0.0, 0.0, -0.26730656795682944, 3.085677581491367e+24, 1.908889418140451, 1.121506912496363, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8445409835405757e+33, 2.7034353260156926e+32, 0.0, 0.0, 0.6361362276706535, 0.0, 0.0, -0.26730656795682944, 3.085677581491367e+24, 1.908889418140451, 1.121506912496363, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 21
# Generation with parameters (3.2808750661821556e+33, 7.424133683333833e+32, 0.0, 0.0, -0.02447616674611585, 0.0, 0.0, 0.006384068822265967, 3.085677581491367e+24, 1.116771576260867, 5.404113467902638, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.2808750661821556e+33, 7.424133683333833e+32, 0.0, 0.0, -0.02447616674611585, 0.0, 0.0, 0.006384068822265967, 3.085677581491367e+24, 1.116771576260867, 5.404113467902638, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 22
# Generation with parameters (1.9905579279867547e+33, 1.9467722055561473e+33, 0.0, 0.0, 0.05763394121633263, 0.0, 0.0, -0.42777443632529455, 3.085677581491367e+24, 0.3388105703014938, 4.7962237119071185, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.9905579279867547e+33, 1.9467722055561473e+33, 0.0, 0.0, 0.05763394121633263, 0.0, 0.0, -0.42777443632529455, 3.085677581491367e+24, 0.3388105703014938, 4.7962237119071185, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 23
# Generation with parameters (2.176283511659623e+33, 8.817295084301013e+32, 0.0, 0.0, -0.017221617273591214, 0.0, 0.0, 0.10261965094926144, 3.085677581491367e+24, 1.9390300421458129, 0.7587961251864288, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.176283511659623e+33, 8.817295084301013e+32, 0.0, 0.0, -0.017221617273591214, 0.0, 0.0, 0.10261965094926144, 3.085677581491367e+24, 1.9390300421458129, 0.7587961251864288, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 24
# Generation with parameters (3.822365955833226e+33, 1.3159098292131586e+33, 0.0, 0.0, -0.03084106157272765, 0.0, 0.0, 0.463647432161536, 3.085677581491367e+24, 0.9956638261636065, 1.6101812195657061, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.822365955833226e+33, 1.3159098292131586e+33, 0.0, 0.0, -0.03084106157272765, 0.0, 0.0, 0.463647432161536, 3.085677581491367e+24, 0.9956638261636065, 1.6101812195657061, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 25
# Generation with parameters (2.9041995720145536e+33, 1.5896988685759748e+33, 0.0, 0.0, 0.0029483295198384804, 0.0, 0.0, 0.5294687563070586, 3.085677581491367e+24, 1.787014225006513, 4.289524885055211, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.9041995720145536e+33, 1.5896988685759748e+33, 0.0, 0.0, 0.0029483295198384804, 0.0, 0.0, 0.5294687563070586, 3.085677581491367e+24, 1.787014225006513, 4.289524885055211, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 26
# Generation with parameters (3.232188180004613e+33, 8.793394458645302e+32, 0.0, 0.0, 0.6297192166131179, 0.0, 0.0, -0.2376087946755225, 3.085677581491367e+24, 2.539240730180714, 6.0168341097335745, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.232188180004613e+33, 8.793394458645302e+32, 0.0, 0.0, 0.6297192166131179, 0.0, 0.0, -0.2376087946755225, 3.085677581491367e+24, 2.539240730180714, 6.0168341097335745, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 27
# Generation with parameters (9.873992875645119e+32, 6.869521951540543e+32, 0.0, 0.0, -0.06616797843988971, 0.0, 0.0, -0.5730266943173266, 3.085677581491367e+24, 0.6719294136563191, 4.605675545178899, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.873992875645119e+32, 6.869521951540543e+32, 0.0, 0.0, -0.06616797843988971, 0.0, 0.0, -0.5730266943173266, 3.085677581491367e+24, 0.6719294136563191, 4.605675545178899, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 28
# Running injection 29
# Generation with parameters (4.272036534383707e+33, 6.755049531989839e+32, 0.0, 0.0, 0.2674013226057172, 0.0, 0.0, 0.48165340851899435, 3.085677581491367e+24, 1.7512862161702638, 1.7881701138345438, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.272036534383707e+33, 6.755049531989839e+32, 0.0, 0.0, 0.2674013226057172, 0.0, 0.0, 0.48165340851899435, 3.085677581491367e+24, 1.7512862161702638, 1.7881701138345438, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 30
# Generation with parameters (1.985228519600715e+33, 2.8193546442141308e+32, 0.0, 0.0, 0.822784182870431, 0.0, 0.0, -0.024334803138789527, 3.085677581491367e+24, 2.3792205310103784, 0.3916884714432555, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.985228519600715e+33, 2.8193546442141308e+32, 0.0, 0.0, 0.822784182870431, 0.0, 0.0, -0.024334803138789527, 3.085677581491367e+24, 2.3792205310103784, 0.3916884714432555, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 31
# Generation with parameters (4.4374235578413967e+33, 8.4234060337498e+32, 0.0, 0.0, -0.09779909541376741, 0.0, 0.0, 0.36276160792299766, 3.085677581491367e+24, 0.9353695460093182, 1.2111945573665512, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.4374235578413967e+33, 8.4234060337498e+32, 0.0, 0.0, -0.09779909541376741, 0.0, 0.0, 0.36276160792299766, 3.085677581491367e+24, 0.9353695460093182, 1.2111945573665512, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 32
# Generation with parameters (3.093638703436001e+33, 8.696063949299946e+32, 0.0, 0.0, 0.029519660767983614, 0.0, 0.0, 0.42494285837452, 3.085677581491367e+24, 1.5450364004981887, 5.756066751464734, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.093638703436001e+33, 8.696063949299946e+32, 0.0, 0.0, 0.029519660767983614, 0.0, 0.0, 0.42494285837452, 3.085677581491367e+24, 1.5450364004981887, 5.756066751464734, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 33
# Generation with parameters (2.5247315238722675e+33, 1.4150717480586641e+33, 0.0, 0.0, 0.4108749872365127, 0.0, 0.0, 0.009841644717875063, 3.085677581491367e+24, 2.108347237105293, 1.6088457554890427, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5247315238722675e+33, 1.4150717480586641e+33, 0.0, 0.0, 0.4108749872365127, 0.0, 0.0, 0.009841644717875063, 3.085677581491367e+24, 2.108347237105293, 1.6088457554890427, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 34
# Generation with parameters (2.3969153860697686e+33, 2.1148806881769912e+33, 0.0, 0.0, -0.37708900505654397, 0.0, 0.0, 0.1874292183192263, 3.085677581491367e+24, 1.0988104006139758, 3.327305422331172, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3969153860697686e+33, 2.1148806881769912e+33, 0.0, 0.0, -0.37708900505654397, 0.0, 0.0, 0.1874292183192263, 3.085677581491367e+24, 1.0988104006139758, 3.327305422331172, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 35
# Generation with parameters (1.923963961759886e+33, 1.5316094160815813e+33, 0.0, 0.0, 0.6985815864071359, 0.0, 0.0, 0.04633099893100462, 3.085677581491367e+24, 0.93168754612947, 4.808976165215395, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.923963961759886e+33, 1.5316094160815813e+33, 0.0, 0.0, 0.6985815864071359, 0.0, 0.0, 0.04633099893100462, 3.085677581491367e+24, 0.93168754612947, 4.808976165215395, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 36
# Generation with parameters (5.1415381590216723e+33, 8.753142299994769e+32, 0.0, 0.0, -0.0549428778764805, 0.0, 0.0, 0.12499955309701825, 3.085677581491367e+24, 1.9004082001846752, 0.47777268981282595, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.1415381590216723e+33, 8.753142299994769e+32, 0.0, 0.0, -0.0549428778764805, 0.0, 0.0, 0.12499955309701825, 3.085677581491367e+24, 1.9004082001846752, 0.47777268981282595, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 37
# Generation with parameters (2.2209440135881617e+33, 2.1613118940239742e+33, 0.0, 0.0, -0.04433401685429025, 0.0, 0.0, 0.0009372892131872893, 3.085677581491367e+24, 2.047708735881253, 3.5088438888913687, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2209440135881617e+33, 2.1613118940239742e+33, 0.0, 0.0, -0.04433401685429025, 0.0, 0.0, 0.0009372892131872893, 3.085677581491367e+24, 2.047708735881253, 3.5088438888913687, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 38
# Generation with parameters (4.15201314373049e+33, 8.09244544938502e+32, 0.0, 0.0, -0.009589740146377285, 0.0, 0.0, 0.15861960696808217, 3.085677581491367e+24, 1.52087829480425, 4.555848031954321, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.15201314373049e+33, 8.09244544938502e+32, 0.0, 0.0, -0.009589740146377285, 0.0, 0.0, 0.15861960696808217, 3.085677581491367e+24, 1.52087829480425, 4.555848031954321, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 39
# Generation with parameters (4.023585043998063e+33, 8.150595780995192e+32, 0.0, 0.0, 0.30082075045324286, 0.0, 0.0, -0.30884076131306876, 3.085677581491367e+24, 1.7833013109289233, 2.6723572016915496, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.023585043998063e+33, 8.150595780995192e+32, 0.0, 0.0, 0.30082075045324286, 0.0, 0.0, -0.30884076131306876, 3.085677581491367e+24, 1.7833013109289233, 2.6723572016915496, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 40
# Generation with parameters (5.936316114990994e+33, 9.39057663173296e+32, 0.0, 0.0, -0.015969981844802354, 0.0, 0.0, 0.561609134810129, 3.085677581491367e+24, 1.4974429789910189, 5.746158353769598, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.936316114990994e+33, 9.39057663173296e+32, 0.0, 0.0, -0.015969981844802354, 0.0, 0.0, 0.561609134810129, 3.085677581491367e+24, 1.4974429789910189, 5.746158353769598, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 41
# Generation with parameters (4.391123693957474e+33, 6.678799615936796e+32, 0.0, 0.0, 0.02700463240504841, 0.0, 0.0, 0.19869421243232038, 3.085677581491367e+24, 1.9144426344861403, 4.394994783905049, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.391123693957474e+33, 6.678799615936796e+32, 0.0, 0.0, 0.02700463240504841, 0.0, 0.0, 0.19869421243232038, 3.085677581491367e+24, 1.9144426344861403, 4.394994783905049, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 42
# Generation with parameters (3.1581470988674575e+33, 9.998987063335513e+32, 0.0, 0.0, -0.14143613769964372, 0.0, 0.0, 0.005529239967453455, 3.085677581491367e+24, 2.436171902052517, 0.9219668615740392, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.1581470988674575e+33, 9.998987063335513e+32, 0.0, 0.0, -0.14143613769964372, 0.0, 0.0, 0.005529239967453455, 3.085677581491367e+24, 2.436171902052517, 0.9219668615740392, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 43
# Generation with parameters (9.222705324143088e+32, 4.60648218804131e+32, 0.0, 0.0, 0.00696540877383598, 0.0, 0.0, 0.04696390596510112, 3.085677581491367e+24, 0.9466104834725111, 4.054322165253685, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.222705324143088e+32, 4.60648218804131e+32, 0.0, 0.0, 0.00696540877383598, 0.0, 0.0, 0.04696390596510112, 3.085677581491367e+24, 0.9466104834725111, 4.054322165253685, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 44
# Generation with parameters (2.7644523156883724e+33, 1.1800503241046758e+33, 0.0, 0.0, 0.5822903795859818, 0.0, 0.0, -0.06129722310143777, 3.085677581491367e+24, 2.1035469563817966, 3.6790150429787345, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.7644523156883724e+33, 1.1800503241046758e+33, 0.0, 0.0, 0.5822903795859818, 0.0, 0.0, -0.06129722310143777, 3.085677581491367e+24, 2.1035469563817966, 3.6790150429787345, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 45
# Generation with parameters (3.902377487437233e+33, 1.2488285221194788e+33, 0.0, 0.0, -0.0013351625095484254, 0.0, 0.0, -0.04811066572591647, 3.085677581491367e+24, 1.3980418210513181, 4.314444235166684, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.902377487437233e+33, 1.2488285221194788e+33, 0.0, 0.0, -0.0013351625095484254, 0.0, 0.0, -0.04811066572591647, 3.085677581491367e+24, 1.3980418210513181, 4.314444235166684, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 46
# Generation with parameters (2.544907345577914e+33, 1.343835936167329e+33, 0.0, 0.0, -0.04322607513547449, 0.0, 0.0, -0.22263844359846074, 3.085677581491367e+24, 1.232647468708737, 2.5397354160145866, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.544907345577914e+33, 1.343835936167329e+33, 0.0, 0.0, -0.04322607513547449, 0.0, 0.0, -0.22263844359846074, 3.085677581491367e+24, 1.232647468708737, 2.5397354160145866, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 47
# Generation with parameters (3.083119103264783e+33, 4.5451014244409495e+32, 0.0, 0.0, 0.2910822485351663, 0.0, 0.0, -0.11336373741918088, 3.085677581491367e+24, 0.33843543251559643, 3.10119822331982, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.083119103264783e+33, 4.5451014244409495e+32, 0.0, 0.0, 0.2910822485351663, 0.0, 0.0, -0.11336373741918088, 3.085677581491367e+24, 0.33843543251559643, 3.10119822331982, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 48
# Generation with parameters (1.871804753433628e+33, 4.368482167420942e+32, 0.0, 0.0, 0.40545568146821076, 0.0, 0.0, 0.017812423863891813, 3.085677581491367e+24, 1.2651078473981232, 0.9730097337084016, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.871804753433628e+33, 4.368482167420942e+32, 0.0, 0.0, 0.40545568146821076, 0.0, 0.0, 0.017812423863891813, 3.085677581491367e+24, 1.2651078473981232, 0.9730097337084016, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 49
# Running injection 50
# Generation with parameters (3.119159034365453e+33, 7.326711939313132e+32, 0.0, 0.0, -0.21550988366624269, 0.0, 0.0, 0.47226348500945775, 3.085677581491367e+24, 1.3972944875626214, 3.0492101524165607, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.119159034365453e+33, 7.326711939313132e+32, 0.0, 0.0, -0.21550988366624269, 0.0, 0.0, 0.47226348500945775, 3.085677581491367e+24, 1.3972944875626214, 3.0492101524165607, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 51
# Generation with parameters (3.8640225697492353e+33, 1.2794737256661075e+33, 0.0, 0.0, -0.034864244541825073, 0.0, 0.0, -0.05661808670614232, 3.085677581491367e+24, 2.431499726465395, 5.150803822393132, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.8640225697492353e+33, 1.2794737256661075e+33, 0.0, 0.0, -0.034864244541825073, 0.0, 0.0, -0.05661808670614232, 3.085677581491367e+24, 2.431499726465395, 5.150803822393132, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 52
# Running injection 53
# Generation with parameters (1.7986388761614616e+33, 1.1441089775760632e+33, 0.0, 0.0, 0.351729511604444, 0.0, 0.0, -0.18544651731906778, 3.085677581491367e+24, 1.965164598688233, 0.6521744747994693, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7986388761614616e+33, 1.1441089775760632e+33, 0.0, 0.0, 0.351729511604444, 0.0, 0.0, -0.18544651731906778, 3.085677581491367e+24, 1.965164598688233, 0.6521744747994693, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 54
# Generation with parameters (4.7400595461891724e+33, 9.59049527792884e+32, 0.0, 0.0, 0.4157717276349565, 0.0, 0.0, -0.10785644924973778, 3.085677581491367e+24, 0.9142236279438891, 1.2385094888420525, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.7400595461891724e+33, 9.59049527792884e+32, 0.0, 0.0, 0.4157717276349565, 0.0, 0.0, -0.10785644924973778, 3.085677581491367e+24, 0.9142236279438891, 1.2385094888420525, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 55
# Generation with parameters (9.169335054953491e+32, 6.150845768062202e+32, 0.0, 0.0, 0.10875242164762365, 0.0, 0.0, 0.039937885271383596, 3.085677581491367e+24, 2.203147764700291, 1.004738022094067, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.169335054953491e+32, 6.150845768062202e+32, 0.0, 0.0, 0.10875242164762365, 0.0, 0.0, 0.039937885271383596, 3.085677581491367e+24, 2.203147764700291, 1.004738022094067, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 56
# Generation with parameters (1.9155727402948285e+33, 1.1457329177983322e+33, 0.0, 0.0, 0.04660628466259362, 0.0, 0.0, 0.6014624161130323, 3.085677581491367e+24, 2.0928984791552985, 4.522721408943411, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.9155727402948285e+33, 1.1457329177983322e+33, 0.0, 0.0, 0.04660628466259362, 0.0, 0.0, 0.6014624161130323, 3.085677581491367e+24, 2.0928984791552985, 4.522721408943411, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 57
# Generation with parameters (3.3641363843027e+33, 6.150249012994375e+32, 0.0, 0.0, 0.5785995300143216, 0.0, 0.0, -0.006694805995234612, 3.085677581491367e+24, 1.5404776861091494, 2.1351923117113416, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.3641363843027e+33, 6.150249012994375e+32, 0.0, 0.0, 0.5785995300143216, 0.0, 0.0, -0.006694805995234612, 3.085677581491367e+24, 1.5404776861091494, 2.1351923117113416, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 58
# Generation with parameters (3.518281853131766e+33, 1.1751942798857479e+33, 0.0, 0.0, 0.14139414283535506, 0.0, 0.0, 0.20994675785319428, 3.085677581491367e+24, 1.7772485040544947, 1.832979409007582, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.518281853131766e+33, 1.1751942798857479e+33, 0.0, 0.0, 0.14139414283535506, 0.0, 0.0, 0.20994675785319428, 3.085677581491367e+24, 1.7772485040544947, 1.832979409007582, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 59
# Generation with parameters (2.4346310573412544e+33, 1.659144847126815e+33, 0.0, 0.0, 0.007065878170507466, 0.0, 0.0, -0.03686205717044026, 3.085677581491367e+24, 2.429647265757456, 0.7170534529508299, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.4346310573412544e+33, 1.659144847126815e+33, 0.0, 0.0, 0.007065878170507466, 0.0, 0.0, -0.03686205717044026, 3.085677581491367e+24, 2.429647265757456, 0.7170534529508299, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 60
# Generation with parameters (1.1503269424546122e+33, 4.051103882438689e+32, 0.0, 0.0, 0.0018589911111028278, 0.0, 0.0, -0.10858605857866, 3.085677581491367e+24, 1.27636260810382, 6.2306868503768955, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1503269424546122e+33, 4.051103882438689e+32, 0.0, 0.0, 0.0018589911111028278, 0.0, 0.0, -0.10858605857866, 3.085677581491367e+24, 1.27636260810382, 6.2306868503768955, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 61
# Generation with parameters (3.0182202581386247e+33, 7.77734947443766e+32, 0.0, 0.0, 0.040192269435981524, 0.0, 0.0, -0.08868231061846665, 3.085677581491367e+24, 1.4699310394960763, 5.01886322433091, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.0182202581386247e+33, 7.77734947443766e+32, 0.0, 0.0, 0.040192269435981524, 0.0, 0.0, -0.08868231061846665, 3.085677581491367e+24, 1.4699310394960763, 5.01886322433091, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 62
# Generation with parameters (2.3668070314676062e+33, 1.096068969912408e+33, 0.0, 0.0, 0.4916289096827174, 0.0, 0.0, 0.09764723873453125, 3.085677581491367e+24, 1.7596959781448562, 3.4018654209844366, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3668070314676062e+33, 1.096068969912408e+33, 0.0, 0.0, 0.4916289096827174, 0.0, 0.0, 0.09764723873453125, 3.085677581491367e+24, 1.7596959781448562, 3.4018654209844366, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 63
# Generation with parameters (2.879792530083029e+33, 4.115663142640172e+32, 0.0, 0.0, -0.08198701167702209, 0.0, 0.0, 0.5918033583540795, 3.085677581491367e+24, 1.589292611625986, 1.7188536201128488, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.879792530083029e+33, 4.115663142640172e+32, 0.0, 0.0, -0.08198701167702209, 0.0, 0.0, 0.5918033583540795, 3.085677581491367e+24, 1.589292611625986, 1.7188536201128488, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 64
# Generation with parameters (1.7063977545956087e+33, 1.2545536077471736e+33, 0.0, 0.0, -0.16976264300331287, 0.0, 0.0, -0.059226492071994395, 3.085677581491367e+24, 0.6115033371002532, 1.1191477497061206, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7063977545956087e+33, 1.2545536077471736e+33, 0.0, 0.0, -0.16976264300331287, 0.0, 0.0, -0.059226492071994395, 3.085677581491367e+24, 0.6115033371002532, 1.1191477497061206, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 65
# Generation with parameters (2.199380408273834e+33, 1.2342454522231793e+33, 0.0, 0.0, 0.2952138819368195, 0.0, 0.0, -0.029356215301931284, 3.085677581491367e+24, 1.5289947074103516, 0.5942556333039931, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.199380408273834e+33, 1.2342454522231793e+33, 0.0, 0.0, 0.2952138819368195, 0.0, 0.0, -0.029356215301931284, 3.085677581491367e+24, 1.5289947074103516, 0.5942556333039931, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 66
# Generation with parameters (2.335944295219279e+33, 1.153851553396879e+33, 0.0, 0.0, 0.5212277911064814, 0.0, 0.0, -0.12892876821348884, 3.085677581491367e+24, 1.964416440663463, 1.6367823448220986, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.335944295219279e+33, 1.153851553396879e+33, 0.0, 0.0, 0.5212277911064814, 0.0, 0.0, -0.12892876821348884, 3.085677581491367e+24, 1.964416440663463, 1.6367823448220986, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 67
# Generation with parameters (3.112744128015556e+33, 1.3883198608971812e+33, 0.0, 0.0, -0.03608987815912585, 0.0, 0.0, 0.5814481539814501, 3.085677581491367e+24, 2.262102309355761, 2.6202739147894305, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.112744128015556e+33, 1.3883198608971812e+33, 0.0, 0.0, -0.03608987815912585, 0.0, 0.0, 0.5814481539814501, 3.085677581491367e+24, 2.262102309355761, 2.6202739147894305, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 68
# Generation with parameters (3.0827730614095837e+33, 1.069840093500858e+33, 0.0, 0.0, -0.11263925921140945, 0.0, 0.0, 0.17076399491149472, 3.085677581491367e+24, 2.045915465220441, 1.6101508321551237, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.0827730614095837e+33, 1.069840093500858e+33, 0.0, 0.0, -0.11263925921140945, 0.0, 0.0, 0.17076399491149472, 3.085677581491367e+24, 2.045915465220441, 1.6101508321551237, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 69
# Generation with parameters (1.4444027372708438e+33, 3.619885864302625e+32, 0.0, 0.0, -0.2020284149247091, 0.0, 0.0, -0.3698742110728509, 3.085677581491367e+24, 1.1496597276595377, 4.976501061939445, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4444027372708438e+33, 3.619885864302625e+32, 0.0, 0.0, -0.2020284149247091, 0.0, 0.0, -0.3698742110728509, 3.085677581491367e+24, 1.1496597276595377, 4.976501061939445, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 70
# Generation with parameters (1.8740720986852043e+33, 1.4937603886834867e+33, 0.0, 0.0, -0.8176983751951531, 0.0, 0.0, 0.42153174345737104, 3.085677581491367e+24, 1.6488034345964513, 3.529406213239464, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# ...
# Warning: turning off multibanding for parameters (3.263357461687642e+33, 4.57879134013998e+32, 0.0, 0.0, 0.04499847663869781, 0.0, 0.0, 0.16344091222999782, 3.085677581491367e+24, 2.36518060276061, 0.30412509286520345, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 976
# Generation with parameters (3.3135847223503896e+33, 1.1075987598773584e+33, 0.0, 0.0, 0.3199113348912173, 0.0, 0.0, 0.06610429285159529, 3.085677581491367e+24, 0.38459156283881807, 4.1955157307365685, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.3135847223503896e+33, 1.1075987598773584e+33, 0.0, 0.0, 0.3199113348912173, 0.0, 0.0, 0.06610429285159529, 3.085677581491367e+24, 0.38459156283881807, 4.1955157307365685, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 977
# Generation with parameters (2.3323183065873948e+33, 3.420007313007077e+32, 0.0, 0.0, 0.08466439240500472, 0.0, 0.0, 0.27037587420050857, 3.085677581491367e+24, 2.6437053348118624, 5.646511291212093, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3323183065873948e+33, 3.420007313007077e+32, 0.0, 0.0, 0.08466439240500472, 0.0, 0.0, 0.27037587420050857, 3.085677581491367e+24, 2.6437053348118624, 5.646511291212093, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 978
# Running injection 979
# Generation with parameters (4.9134442498255227e+33, 1.13220002545054e+33, 0.0, 0.0, -0.21221689544325523, 0.0, 0.0, 0.014794803679749155, 3.085677581491367e+24, 1.6474374265083003, 2.85297775915942, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.9134442498255227e+33, 1.13220002545054e+33, 0.0, 0.0, -0.21221689544325523, 0.0, 0.0, 0.014794803679749155, 3.085677581491367e+24, 1.6474374265083003, 2.85297775915942, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 980
# Generation with parameters (1.3011806778264674e+33, 1.1597748157602299e+33, 0.0, 0.0, 0.37207159463298567, 0.0, 0.0, 0.2216154196898482, 3.085677581491367e+24, 2.2756760593269085, 3.7394096716473775, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3011806778264674e+33, 1.1597748157602299e+33, 0.0, 0.0, 0.37207159463298567, 0.0, 0.0, 0.2216154196898482, 3.085677581491367e+24, 2.2756760593269085, 3.7394096716473775, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 981
# Generation with parameters (2.2020632483347477e+33, 8.77541159783244e+32, 0.0, 0.0, 0.3608847341728629, 0.0, 0.0, 0.2170561470293822, 3.085677581491367e+24, 0.8591970156160803, 1.917752963036653, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2020632483347477e+33, 8.77541159783244e+32, 0.0, 0.0, 0.3608847341728629, 0.0, 0.0, 0.2170561470293822, 3.085677581491367e+24, 0.8591970156160803, 1.917752963036653, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 982
# Generation with parameters (2.59242112684646e+33, 7.380576412809332e+32, 0.0, 0.0, -0.11609235771157228, 0.0, 0.0, -0.5119989711365681, 3.085677581491367e+24, 1.3500893313170126, 0.8034340490302082, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.59242112684646e+33, 7.380576412809332e+32, 0.0, 0.0, -0.11609235771157228, 0.0, 0.0, -0.5119989711365681, 3.085677581491367e+24, 1.3500893313170126, 0.8034340490302082, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 983
# Generation with parameters (1.8986719307741228e+33, 1.6192074828201527e+33, 0.0, 0.0, 0.03746038681989667, 0.0, 0.0, -0.025308961975677426, 3.085677581491367e+24, 2.9287452461483143, 5.218153182810609, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8986719307741228e+33, 1.6192074828201527e+33, 0.0, 0.0, 0.03746038681989667, 0.0, 0.0, -0.025308961975677426, 3.085677581491367e+24, 2.9287452461483143, 5.218153182810609, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 984
# Generation with parameters (3.89164502181391e+33, 1.2406085860033071e+33, 0.0, 0.0, -0.082272610067753, 0.0, 0.0, -0.22156988040042494, 3.085677581491367e+24, 1.979815676823621, 0.42689932808250214, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.89164502181391e+33, 1.2406085860033071e+33, 0.0, 0.0, -0.082272610067753, 0.0, 0.0, -0.22156988040042494, 3.085677581491367e+24, 1.979815676823621, 0.42689932808250214, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 985
# Generation with parameters (1.5056048234673204e+33, 6.785222210702214e+32, 0.0, 0.0, 0.44321346688086133, 0.0, 0.0, -0.02242601682924069, 3.085677581491367e+24, 1.0789506484585099, 4.478699493741304, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5056048234673204e+33, 6.785222210702214e+32, 0.0, 0.0, 0.44321346688086133, 0.0, 0.0, -0.02242601682924069, 3.085677581491367e+24, 1.0789506484585099, 4.478699493741304, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 986
# Generation with parameters (2.602731288855203e+33, 6.55112551288326e+32, 0.0, 0.0, -0.028976475044357047, 0.0, 0.0, -0.3922400737160435, 3.085677581491367e+24, 1.4797194105013456, 5.864868402130324, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.602731288855203e+33, 6.55112551288326e+32, 0.0, 0.0, -0.028976475044357047, 0.0, 0.0, -0.3922400737160435, 3.085677581491367e+24, 1.4797194105013456, 5.864868402130324, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 987
# Generation with parameters (2.361675941927308e+33, 9.410022311110107e+32, 0.0, 0.0, 0.0058474307581788945, 0.0, 0.0, -0.008468841107153301, 3.085677581491367e+24, 0.6112772640520933, 2.0258832046042037, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.361675941927308e+33, 9.410022311110107e+32, 0.0, 0.0, 0.0058474307581788945, 0.0, 0.0, -0.008468841107153301, 3.085677581491367e+24, 0.6112772640520933, 2.0258832046042037, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 988
# Generation with parameters (5.942302964401382e+33, 9.601576968748357e+32, 0.0, 0.0, 0.354743003923221, 0.0, 0.0, -0.1856336431859406, 3.085677581491367e+24, 0.7540754898467344, 3.9404372566155783, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.942302964401382e+33, 9.601576968748357e+32, 0.0, 0.0, 0.354743003923221, 0.0, 0.0, -0.1856336431859406, 3.085677581491367e+24, 0.7540754898467344, 3.9404372566155783, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 989
# Generation with parameters (1.939995052958529e+33, 1.8377942552436373e+33, 0.0, 0.0, -0.16345703448007803, 0.0, 0.0, 0.15551223450587565, 3.085677581491367e+24, 1.8167359255245334, 4.773676203506296, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.939995052958529e+33, 1.8377942552436373e+33, 0.0, 0.0, -0.16345703448007803, 0.0, 0.0, 0.15551223450587565, 3.085677581491367e+24, 1.8167359255245334, 4.773676203506296, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 990
# Generation with parameters (1.4626373249633536e+33, 1.0133957954326381e+33, 0.0, 0.0, -0.12009303768152563, 0.0, 0.0, -0.043809123030354905, 3.085677581491367e+24, 1.6400188005393377, 0.6244452345915613, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4626373249633536e+33, 1.0133957954326381e+33, 0.0, 0.0, -0.12009303768152563, 0.0, 0.0, -0.043809123030354905, 3.085677581491367e+24, 1.6400188005393377, 0.6244452345915613, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 991
# Generation with parameters (4.7529190819413203e+33, 9.034718536270153e+32, 0.0, 0.0, 0.025729839599098414, 0.0, 0.0, -0.3157359285276938, 3.085677581491367e+24, 2.697788560015737, 2.729274238689653, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.7529190819413203e+33, 9.034718536270153e+32, 0.0, 0.0, 0.025729839599098414, 0.0, 0.0, -0.3157359285276938, 3.085677581491367e+24, 2.697788560015737, 2.729274238689653, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 992
# Generation with parameters (2.5045543701570526e+33, 4.040464247282754e+32, 0.0, 0.0, 0.5035632129442186, 0.0, 0.0, 0.1759045145512548, 3.085677581491367e+24, 1.9935389449644967, 5.582443555393572, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5045543701570526e+33, 4.040464247282754e+32, 0.0, 0.0, 0.5035632129442186, 0.0, 0.0, 0.1759045145512548, 3.085677581491367e+24, 1.9935389449644967, 5.582443555393572, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 993
# Generation with parameters (2.771310107084508e+33, 8.114513852706023e+32, 0.0, 0.0, -0.03666827536775571, 0.0, 0.0, -0.038697476007343724, 3.085677581491367e+24, 0.7863271571462925, 4.289945117207527, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.771310107084508e+33, 8.114513852706023e+32, 0.0, 0.0, -0.03666827536775571, 0.0, 0.0, -0.038697476007343724, 3.085677581491367e+24, 0.7863271571462925, 4.289945117207527, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 994
# Generation with parameters (9.237013400937452e+32, 6.275980262363573e+32, 0.0, 0.0, -0.5906600557318442, 0.0, 0.0, 0.2922923289626046, 3.085677581491367e+24, 2.6814835564627595, 3.063761874125204, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.237013400937452e+32, 6.275980262363573e+32, 0.0, 0.0, -0.5906600557318442, 0.0, 0.0, 0.2922923289626046, 3.085677581491367e+24, 2.6814835564627595, 3.063761874125204, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 995
# Generation with parameters (2.3680326462651553e+33, 1.4357665350110075e+33, 0.0, 0.0, -0.037183821843809264, 0.0, 0.0, -0.044493924425692215, 3.085677581491367e+24, 2.1631779420900608, 1.7660679352318154, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3680326462651553e+33, 1.4357665350110075e+33, 0.0, 0.0, -0.037183821843809264, 0.0, 0.0, -0.044493924425692215, 3.085677581491367e+24, 2.1631779420900608, 1.7660679352318154, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 996
# Generation with parameters (4.927390484621288e+33, 1.0263480851741341e+33, 0.0, 0.0, 0.0859857068848326, 0.0, 0.0, 0.0847993483899038, 3.085677581491367e+24, 0.8682070584849836, 3.9743188961959044, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.927390484621288e+33, 1.0263480851741341e+33, 0.0, 0.0, 0.0859857068848326, 0.0, 0.0, 0.0847993483899038, 3.085677581491367e+24, 0.8682070584849836, 3.9743188961959044, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 997
# Generation with parameters (2.7739676689637717e+33, 7.908439696368325e+32, 0.0, 0.0, 0.11927116261428813, 0.0, 0.0, -0.12013269349024824, 3.085677581491367e+24, 0.9342581241241799, 2.78944109454703, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.7739676689637717e+33, 7.908439696368325e+32, 0.0, 0.0, 0.11927116261428813, 0.0, 0.0, -0.12013269349024824, 3.085677581491367e+24, 0.9342581241241799, 2.78944109454703, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 998
# Generation with parameters (4.928399921833871e+33, 1.1585504614882351e+33, 0.0, 0.0, 0.2846422077306756, 0.0, 0.0, 0.02193322786177954, 3.085677581491367e+24, 2.3662357215473797, 1.84527749666201, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.928399921833871e+33, 1.1585504614882351e+33, 0.0, 0.0, 0.2846422077306756, 0.0, 0.0, 0.02193322786177954, 3.085677581491367e+24, 2.3662357215473797, 1.84527749666201, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 999
# Generation with parameters (5.044051097041272e+33, 7.640791832636493e+32, 0.0, 0.0, 0.2194789578811688, 0.0, 0.0, -0.04649237286073186, 3.085677581491367e+24, 2.145831878066769, 0.5535509721478866, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.044051097041272e+33, 7.640791832636493e+32, 0.0, 0.0, 0.2194789578811688, 0.0, 0.0, -0.04649237286073186, 3.085677581491367e+24, 2.145831878066769, 0.5535509721478866, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.

# %%
import os
import pickle

from dingo.gw.inference.gw_samplers import GWSampler


os.makedirs("/scratch/tpausch/test_data/imbh_T8_mass1/results", exist_ok=True)

injection_files = sorted(os.listdir("/scratch/tpausch/test_data/imbh_T8_mass1/injections"))

for fname in injection_files:

    # --------------------------------------------------------
    # Load injection
    # --------------------------------------------------------

    with open(f"/scratch/tpausch/test_data/imbh_T8_mass1/injections/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    strain_data = payload["strain_data"]

    # --------------------------------------------------------
    # Run sampler
    # --------------------------------------------------------

    sampler = GWSampler(model=main_pm)

    sampler.context = strain_data

    sampler.run_sampler(
        num_samples=50_000,
        batch_size=10_000,
    )

    result = sampler.to_result()

    # --------------------------------------------------------
    # Store result
    # --------------------------------------------------------

    result_payload = {
        "theta_true": theta_true,
        "result": result,
    }

    outname = fname.replace("inj_", "result_")

    with open(f"/scratch/tpausch/test_data/imbh_T8_mass1/results/{outname}", "wb") as f:
        pickle.dump(result_payload, f)

    print(f"Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/{outname}")
# Out:
# Running sampler to generate 50000 samples.
# Done. This took 0.6 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0000.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0001.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0002.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0003.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0004.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0005.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0006.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0007.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0008.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0009.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0010.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0011.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0012.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0013.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0014.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0015.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0016.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0017.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0018.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0019.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0020.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0021.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0022.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0023.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0024.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0025.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0026.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0027.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0028.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0029.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0030.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0031.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0032.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0033.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0034.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0035.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0036.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0037.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0038.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0039.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0040.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0041.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0042.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0043.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0044.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0045.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0046.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0047.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0048.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0049.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0050.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0051.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0052.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0053.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0054.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0055.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0056.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0057.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0058.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0059.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0060.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0061.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0062.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0063.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0064.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0065.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0066.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0067.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0068.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0069.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0070.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0071.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0072.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0073.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0074.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0075.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0076.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0077.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0078.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0079.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0080.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0081.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# ...
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0972.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0973.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0974.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0975.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0976.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0977.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0978.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0979.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0980.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0981.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0982.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0983.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0984.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0985.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0986.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0987.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0988.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0989.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0990.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0991.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0992.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0993.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0994.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0995.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0996.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0997.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0998.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass1/results/result_0999.pkl

# %%
import os
import pickle
import numpy as np

true_cm = []
true_mr = []
mass_ratio_error = []
mass_ratio_std = []
chirp_mass_error = []
chirp_mass_std = []


result_files = sorted(os.listdir("/scratch/tpausch/test_data/imbh_T8_mass1/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/imbh_T8_mass1/results/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    result = payload["result"]

    posterior_samples = result.samples

    #q_samples = np.array(posterior_samples["mass_ratio"])

    # inference statistics
    #q_mean = np.mean(q_samples)
    #q_std = np.std(q_samples)
#
    #true_q = theta_true["mass_ratio"]

    cm_samples = np.array(posterior_samples["chirp_mass"])

    cm_mean = np.mean(cm_samples)
    cm_std = np.std(cm_samples)

    true_mr.append(theta_true["mass_ratio"])
    true_cm.append(theta_true["chirp_mass"])
    #mass_ratio_error.append(q_mean - true_q)
    #mass_ratio_std.append(q_std)
    chirp_mass_error.append(cm_mean - theta_true["chirp_mass"])
    chirp_mass_std.append(cm_std)

# %%
import matplotlib.pyplot as plt
import numpy as np

true_mr = np.array(true_mr)
true_cm = np.array(true_cm)




# ------------------------------------------------------------
# Error bars
# ------------------------------------------------------------

plt.errorbar(
    true_cm,
    chirp_mass_error,
    yerr=chirp_mass_std,
    fmt="none",
    capsize=4,
    alpha=0.5,
    color="gray",
)

# ------------------------------------------------------------
# Colored scatter points
# ------------------------------------------------------------

sc = plt.scatter(
    true_cm,
    chirp_mass_error,
    c=true_mr,
    cmap="viridis",
    s=70,
    edgecolor="black",
)

# ------------------------------------------------------------
# Reference line
# ------------------------------------------------------------

plt.axhline(0, linestyle="--", color="black")

# ------------------------------------------------------------
# Colorbar
# ------------------------------------------------------------

cbar = plt.colorbar(sc)
cbar.set_label("True mass ratio")

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel("True chirp mass")
plt.ylabel("Chirp mass inference error (inferred − true)")

plt.title("Chirp-mass inference error")

plt.grid(True)

plt.tight_layout()
plt.show()

# %%
pp_values_chirp_mass = []
pp_values_mass_ratio = []

result_files = sorted(os.listdir("/scratch/tpausch/test_data/imbh_T8_mass1/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/imbh_T8_mass1/results/{fname}", "rb") as f:

        payload = pickle.load(f)

        theta_true = payload["theta_true"]
        result = payload["result"]

        posterior_samples = result.samples


        # ============================================================
        # Chirp mass PP value
        # ============================================================

        cm_samples = posterior_samples["chirp_mass"]

        pp_cm = np.mean(
            cm_samples < theta_true["chirp_mass"]
        )

        pp_values_chirp_mass.append(pp_cm)


        # ============================================================
        # Mass ratio PP value
        # ============================================================

        #q_samples = posterior_samples["mass_ratio"]
#
        #pp_q = np.mean(
        #    q_samples < theta_true["mass_ratio"]
        #)
#
        #pp_values_mass_ratio.append(pp_q)

# %%
import matplotlib.pyplot as plt


def plot_pp(pp_values, label):

    pp_values = np.array(pp_values)

    sorted_pp = np.sort(pp_values)

    n = len(sorted_pp)

    empirical_cdf = np.arange(1, n + 1) / n

    x = np.linspace(0, 1, 200)

    sigma = np.sqrt(x * (1 - x) / n)

    plt.figure(figsize=(6, 6))

    # Ideal calibration
    plt.plot(
        [0, 1],
        [0, 1],
        linestyle="--",
        label="Ideal calibration",
    )


    # Empirical PP curve
    plt.plot(
        sorted_pp,
        empirical_cdf,
        marker="o",
        label=label,
    )

    plt.xlabel("Credible level")
    plt.ylabel("Fraction of injections")

    plt.title(f"PP Plot: {label}")

    plt.xlim(0, 1)
    plt.ylim(0, 1)

    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
plot_pp(
    pp_values_chirp_mass,
    "chirp_mass",
)

#plot_pp(
#    pp_values_mass_ratio,
#    "mass_ratio",
#)
