# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # use GPU 1

from dingo.core.posterior_models.build_model import build_model_from_kwargs

main_pm = build_model_from_kwargs(
    filename="/scratch/tpausch/models/imbh_T8_mass2/model_latest.pt",
    device="cuda",
    load_training_info=False,
)
# Out:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Putting posterior model to device cuda.

# %%
import os
import pickle
import numpy as np

import dingo.gw.injection as injection
from dingo.gw.noise.asd_dataset import ASDDataset

# ============================================================
# Setup
# ============================================================

num_injections = 1000
out_dir = "/scratch/tpausch/test_data/imbh_T8_mass2/injections"
os.makedirs(out_dir, exist_ok=True)

np.random.seed(42)  # optional, for reproducibility

injection_generator = injection.Injection.from_posterior_model_metadata(
    main_pm.metadata
)

asd_fname = main_pm.metadata["train_settings"]["training"]["stage_0"]["asd_dataset_path"]
asd_dataset = ASDDataset(file_name=asd_fname)

injection_generator.asd = {
    k: v[0] for k, v in asd_dataset.asds.items()
}

# This is the combined intrinsic + extrinsic bilby PriorDict
# that the network was trained on
prior = injection_generator.prior
print(prior)

# ============================================================
# Draw and run injections
# ============================================================

for idx in range(num_injections):

    print(f"Running injection {idx}")

    theta = prior.sample()
    theta = {k: float(v) for k, v in theta.items()}  # cast numpy -> float

    strain_data = injection_generator.injection(theta)

    payload = {
        "theta_true": theta,
        "strain_data": strain_data,
    }

    fname = os.path.join(out_dir, f"inj_{idx:04d}.pkl")

    with open(fname, "wb") as f:
        pickle.dump(payload, f)
# Out:
# Setting spin_conversion_phase = 0.0. Using this value for the phase parameter for conversion to cartesian spins.
# Loading dataset from training_data/asds_ET_T8.hdf5.
# {'mass_1': Constraint(minimum=30.0, maximum=3000.0, name='mass_1', latex_label='$m_1$', unit=None), 'mass_2': Constraint(minimum=30.0, maximum=3000.0, name='mass_2', latex_label='$m_2$', unit=None), 'chirp_mass': bilby.gw.prior.UniformInComponentsChirpMass(minimum=50.0, maximum=1000.0, name='chirp_mass', latex_label='$\\mathcal{M}$', unit=None, boundary=None), 'mass_ratio': bilby.gw.prior.UniformInComponentsMassRatio(minimum=0.125, maximum=1.0, name='mass_ratio', latex_label='$q$', unit=None, boundary=None, equal_mass=False), 'phase': Uniform(minimum=0.0, maximum=6.283185307179586, name='phase', latex_label='$\\phi$', unit=None, boundary='periodic'), 'chi_1': bilby.gw.prior.AlignedSpin(a_prior=Uniform(minimum=0, maximum=0.9, name=None, latex_label=None, unit=None, boundary=None), z_prior=Uniform(minimum=-1, maximum=1, name=None, latex_label=None, unit=None, boundary=None), name='chi_1', latex_label='$\\chi_1$', unit=None, boundary=None, minimum=-0.9, maximum=0.9, num_interp=100000), 'chi_2': bilby.gw.prior.AlignedSpin(a_prior=Uniform(minimum=0, maximum=0.9, name=None, latex_label=None, unit=None, boundary=None), z_prior=Uniform(minimum=-1, maximum=1, name=None, latex_label=None, unit=None, boundary=None), name='chi_2', latex_label='$\\chi_2$', unit=None, boundary=None, minimum=-0.9, maximum=0.9, num_interp=100000), 'theta_jn': Sine(minimum=0.0, maximum=3.141592653589793, name='theta_jn', latex_label='$\\theta_{JN}$', unit=None, boundary=None), 'luminosity_distance': LogUniform(minimum=1000.0, maximum=1000000.0, name='luminosity_distance', latex_label='$d_L$', unit=None, boundary=None), 'geocent_time': Uniform(minimum=-0.1, maximum=0.1, name='geocent_time', latex_label='$t_c$', unit=None, boundary=None), 'dec': Cosine(minimum=-1.5707963267948966, maximum=1.5707963267948966, name='dec', latex_label='$\\mathrm{DEC}$', unit=None, boundary=None), 'ra': Uniform(minimum=0.0, maximum=6.283185307179586, name='ra', latex_label='$\\mathrm{RA}$', unit=None, boundary='periodic'), 'psi': Uniform(minimum=0.0, maximum=3.141592653589793, name='psi', latex_label='$\\psi$', unit=None, boundary='periodic')}
# Running injection 0
# Generation with parameters (2.464827609968678e+33, 2.0157424929979802e+33, 0.0, 0.0, -0.0016273810918112084, 0.0, 0.0, -0.12198659084072981, 3.085677581491367e+24, 1.208617280164388, 0.427623426251762, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.464827609968678e+33, 2.0157424929979802e+33, 0.0, 0.0, -0.0016273810918112084, 0.0, 0.0, -0.12198659084072981, 3.085677581491367e+24, 1.208617280164388, 0.427623426251762, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1
# Generation with parameters (1.1827774502126638e+33, 3.204166594900481e+32, 0.0, 0.0, 0.14437299707067466, 0.0, 0.0, -0.4052108577233777, 3.085677581491367e+24, 1.6110885185163375, 0.7502826320284158, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1827774502126638e+33, 3.204166594900481e+32, 0.0, 0.0, 0.14437299707067466, 0.0, 0.0, -0.4052108577233777, 3.085677581491367e+24, 1.6110885185163375, 0.7502826320284158, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 2
# Generation with parameters (2.9059523085947195e+33, 1.6595610621020687e+33, 0.0, 0.0, 0.04000729365152626, 0.0, 0.0, -0.22524427348801138, 3.085677581491367e+24, 0.6519462532386655, 2.901179690646013, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.9059523085947195e+33, 1.6595610621020687e+33, 0.0, 0.0, 0.04000729365152626, 0.0, 0.0, -0.22524427348801138, 3.085677581491367e+24, 0.6519462532386655, 2.901179690646013, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 3
# Generation with parameters (5.341782863184282e+33, 1.0522418964897066e+33, 0.0, 0.0, -0.5922579160289058, 0.0, 0.0, -0.15218461752041515, 3.085677581491367e+24, 1.6307573602446808, 3.5361149373657965, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.341782863184282e+33, 1.0522418964897066e+33, 0.0, 0.0, -0.5922579160289058, 0.0, 0.0, -0.15218461752041515, 3.085677581491367e+24, 1.6307573602446808, 3.5361149373657965, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 4
# Generation with parameters (4.800500403665606e+33, 1.1096415246565658e+33, 0.0, 0.0, -0.2534702175199973, 0.0, 0.0, 0.046287546784905806, 3.085677581491367e+24, 2.4945327499919436, 3.4567525547038707, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.800500403665606e+33, 1.1096415246565658e+33, 0.0, 0.0, -0.2534702175199973, 0.0, 0.0, 0.046287546784905806, 3.085677581491367e+24, 2.4945327499919436, 3.4567525547038707, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 5
# Generation with parameters (3.4293848400592103e+33, 1.1204495207358013e+33, 0.0, 0.0, 0.06640616285480667, 0.0, 0.0, 0.03830949820697294, 3.085677581491367e+24, 2.421237876668826, 0.32681597165310694, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.4293848400592103e+33, 1.1204495207358013e+33, 0.0, 0.0, 0.06640616285480667, 0.0, 0.0, 0.03830949820697294, 3.085677581491367e+24, 2.421237876668826, 0.32681597165310694, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 6
# Generation with parameters (3.653356270454209e+33, 1.2558780294026657e+33, 0.0, 0.0, 0.1633732505887339, 0.0, 0.0, 0.2103729636110866, 3.085677581491367e+24, 1.0262817683921173, 4.274001318909325, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.653356270454209e+33, 1.2558780294026657e+33, 0.0, 0.0, 0.1633732505887339, 0.0, 0.0, 0.2103729636110866, 3.085677581491367e+24, 1.0262817683921173, 4.274001318909325, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 7
# Generation with parameters (2.2736330388339626e+33, 1.2585521645274829e+33, 0.0, 0.0, 0.1148189864239942, 0.0, 0.0, -0.3425469591798027, 3.085677581491367e+24, 1.3447644096512636, 6.0498611619585, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2736330388339626e+33, 1.2585521645274829e+33, 0.0, 0.0, 0.1148189864239942, 0.0, 0.0, -0.3425469591798027, 3.085677581491367e+24, 1.3447644096512636, 6.0498611619585, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 8
# Generation with parameters (3.375092268419158e+33, 8.795917666514747e+32, 0.0, 0.0, 0.09085566534165591, 0.0, 0.0, -0.2523106842027043, 3.085677581491367e+24, 1.9298958889825355, 3.7302917718882633, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.375092268419158e+33, 8.795917666514747e+32, 0.0, 0.0, 0.09085566534165591, 0.0, 0.0, -0.2523106842027043, 3.085677581491367e+24, 1.9298958889825355, 3.7302917718882633, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 9
# Generation with parameters (3.4495552286162444e+33, 1.07274794048638e+33, 0.0, 0.0, 0.2715167385607805, 0.0, 0.0, 0.7352264595199784, 3.085677581491367e+24, 1.3177566408571184, 3.7610583253691146, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.4495552286162444e+33, 1.07274794048638e+33, 0.0, 0.0, 0.2715167385607805, 0.0, 0.0, 0.7352264595199784, 3.085677581491367e+24, 1.3177566408571184, 3.7610583253691146, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 10
# Generation with parameters (1.4664316882180594e+33, 7.964732936341936e+32, 0.0, 0.0, 0.005584130443481128, 0.0, 0.0, -0.27995304475703015, 3.085677581491367e+24, 1.8348564702158474, 2.693306878085497, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4664316882180594e+33, 7.964732936341936e+32, 0.0, 0.0, 0.005584130443481128, 0.0, 0.0, -0.27995304475703015, 3.085677581491367e+24, 1.8348564702158474, 2.693306878085497, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 11
# Generation with parameters (8.981904260155069e+32, 2.980149937051683e+32, 0.0, 0.0, -0.05094057798707286, 0.0, 0.0, -0.18367556791199474, 3.085677581491367e+24, 0.21896079852533248, 3.975783195836823, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.981904260155069e+32, 2.980149937051683e+32, 0.0, 0.0, -0.05094057798707286, 0.0, 0.0, -0.18367556791199474, 3.085677581491367e+24, 0.21896079852533248, 3.975783195836823, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 12
# Generation with parameters (1.9421218827684447e+33, 1.788708025827898e+33, 0.0, 0.0, -0.7396624216485568, 0.0, 0.0, -0.02542121476935335, 3.085677581491367e+24, 0.510318269404202, 2.6677117979705485, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.9421218827684447e+33, 1.788708025827898e+33, 0.0, 0.0, -0.7396624216485568, 0.0, 0.0, -0.02542121476935335, 3.085677581491367e+24, 0.510318269404202, 2.6677117979705485, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 13
# Generation with parameters (1.0898682564458288e+33, 5.367844696138951e+32, 0.0, 0.0, -0.0521076497922639, 0.0, 0.0, 0.06873702589891043, 3.085677581491367e+24, 1.444240888779162, 0.5739638424791713, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0898682564458288e+33, 5.367844696138951e+32, 0.0, 0.0, -0.0521076497922639, 0.0, 0.0, 0.06873702589891043, 3.085677581491367e+24, 1.444240888779162, 0.5739638424791713, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 14
# Generation with parameters (4.495390550402002e+33, 7.514110949853594e+32, 0.0, 0.0, 0.15999753993977361, 0.0, 0.0, 0.10549183425164818, 3.085677581491367e+24, 1.8489726267125257, 6.107887662026541, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.495390550402002e+33, 7.514110949853594e+32, 0.0, 0.0, 0.15999753993977361, 0.0, 0.0, 0.10549183425164818, 3.085677581491367e+24, 1.8489726267125257, 6.107887662026541, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 15
# Generation with parameters (1.6878860348071294e+33, 1.2877924784573766e+33, 0.0, 0.0, 0.5154871321834177, 0.0, 0.0, -0.3428441641612627, 3.085677581491367e+24, 1.3086025723624173, 2.2150633356567164, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6878860348071294e+33, 1.2877924784573766e+33, 0.0, 0.0, 0.5154871321834177, 0.0, 0.0, -0.3428441641612627, 3.085677581491367e+24, 1.3086025723624173, 2.2150633356567164, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 16
# Generation with parameters (1.8186011756858455e+33, 7.127795650310002e+32, 0.0, 0.0, -0.27068815636445165, 0.0, 0.0, 0.1957427012508093, 3.085677581491367e+24, 1.3284034423178017, 2.3943268449652773, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8186011756858455e+33, 7.127795650310002e+32, 0.0, 0.0, -0.27068815636445165, 0.0, 0.0, 0.1957427012508093, 3.085677581491367e+24, 1.3284034423178017, 2.3943268449652773, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 17
# Generation with parameters (1.7898614733621753e+33, 1.0271668473658001e+33, 0.0, 0.0, -0.04463633730447053, 0.0, 0.0, -0.22369195515883872, 3.085677581491367e+24, 2.899964693545905, 1.5068442886211022, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7898614733621753e+33, 1.0271668473658001e+33, 0.0, 0.0, -0.04463633730447053, 0.0, 0.0, -0.22369195515883872, 3.085677581491367e+24, 2.899964693545905, 1.5068442886211022, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 18
# Generation with parameters (3.724325161078021e+33, 7.524549160613992e+32, 0.0, 0.0, 0.20149997187151206, 0.0, 0.0, -2.9319283123149384e-05, 3.085677581491367e+24, 1.8639555752839874, 6.11772883502101, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.724325161078021e+33, 7.524549160613992e+32, 0.0, 0.0, 0.20149997187151206, 0.0, 0.0, -2.9319283123149384e-05, 3.085677581491367e+24, 1.8639555752839874, 6.11772883502101, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 19
# Generation with parameters (2.998952750526277e+33, 8.079281878574153e+32, 0.0, 0.0, 0.17434349444793756, 0.0, 0.0, 0.03888733614161479, 3.085677581491367e+24, 2.007871157963876, 3.219574969990353, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.998952750526277e+33, 8.079281878574153e+32, 0.0, 0.0, 0.17434349444793756, 0.0, 0.0, 0.03888733614161479, 3.085677581491367e+24, 2.007871157963876, 3.219574969990353, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 20
# Generation with parameters (4.7688583709123256e+33, 6.69618497877892e+32, 0.0, 0.0, -0.3213481275291172, 0.0, 0.0, -0.03244633705232974, 3.085677581491367e+24, 0.3242146999222908, 2.841717524301108, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.7688583709123256e+33, 6.69618497877892e+32, 0.0, 0.0, -0.3213481275291172, 0.0, 0.0, -0.03244633705232974, 3.085677581491367e+24, 0.3242146999222908, 2.841717524301108, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 21
# Generation with parameters (3.672855550599034e+33, 1.0505370018205047e+33, 0.0, 0.0, 0.15085761382394822, 0.0, 0.0, -0.14762801413101356, 3.085677581491367e+24, 1.8007672794044474, 0.6109652233441958, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.672855550599034e+33, 1.0505370018205047e+33, 0.0, 0.0, 0.15085761382394822, 0.0, 0.0, -0.14762801413101356, 3.085677581491367e+24, 1.8007672794044474, 0.6109652233441958, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 22
# Generation with parameters (3.3248495733451963e+33, 4.7430385117293046e+32, 0.0, 0.0, 0.1627542146217993, 0.0, 0.0, -0.6537552718005217, 3.085677581491367e+24, 1.1547741013763675, 0.08966264869202933, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.3248495733451963e+33, 4.7430385117293046e+32, 0.0, 0.0, 0.1627542146217993, 0.0, 0.0, -0.6537552718005217, 3.085677581491367e+24, 1.1547741013763675, 0.08966264869202933, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 23
# Generation with parameters (2.0368840712071128e+33, 7.983869851535826e+32, 0.0, 0.0, -0.12273375153948647, 0.0, 0.0, -0.43180471500211975, 3.085677581491367e+24, 1.467449615243846, 4.168583323339842, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0368840712071128e+33, 7.983869851535826e+32, 0.0, 0.0, -0.12273375153948647, 0.0, 0.0, -0.43180471500211975, 3.085677581491367e+24, 1.467449615243846, 4.168583323339842, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 24
# Generation with parameters (4.708459748625644e+33, 6.579067569514683e+32, 0.0, 0.0, -0.16674616296074887, 0.0, 0.0, -0.005421657981387682, 3.085677581491367e+24, 3.023226997045691, 6.161259851018559, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.708459748625644e+33, 6.579067569514683e+32, 0.0, 0.0, -0.16674616296074887, 0.0, 0.0, -0.005421657981387682, 3.085677581491367e+24, 3.023226997045691, 6.161259851018559, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 25
# Generation with parameters (2.960817180161817e+33, 1.62491505670697e+33, 0.0, 0.0, -0.10593519938156862, 0.0, 0.0, -0.22181538724329455, 3.085677581491367e+24, 2.0660225004461314, 0.3964804151607627, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.960817180161817e+33, 1.62491505670697e+33, 0.0, 0.0, -0.10593519938156862, 0.0, 0.0, -0.22181538724329455, 3.085677581491367e+24, 2.0660225004461314, 0.3964804151607627, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 26
# Generation with parameters (2.1232182432231442e+33, 1.5156398032635664e+33, 0.0, 0.0, 0.4043990741183599, 0.0, 0.0, -0.30691358383505324, 3.085677581491367e+24, 1.7927318259623808, 3.693379839113163, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.1232182432231442e+33, 1.5156398032635664e+33, 0.0, 0.0, 0.4043990741183599, 0.0, 0.0, -0.30691358383505324, 3.085677581491367e+24, 1.7927318259623808, 3.693379839113163, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 27
# Generation with parameters (1.8560304044904505e+33, 7.374040044796762e+32, 0.0, 0.0, -0.15160831851846884, 0.0, 0.0, -0.004390819288637266, 3.085677581491367e+24, 1.0427748315820107, 0.33098162444766693, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8560304044904505e+33, 7.374040044796762e+32, 0.0, 0.0, -0.15160831851846884, 0.0, 0.0, -0.004390819288637266, 3.085677581491367e+24, 1.0427748315820107, 0.33098162444766693, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 28
# Generation with parameters (3.8771981522409146e+33, 6.138705191895186e+32, 0.0, 0.0, 0.057668583509551466, 0.0, 0.0, 0.09817106410451641, 3.085677581491367e+24, 2.4358583624590144, 0.022287845091753605, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.8771981522409146e+33, 6.138705191895186e+32, 0.0, 0.0, 0.057668583509551466, 0.0, 0.0, 0.09817106410451641, 3.085677581491367e+24, 2.4358583624590144, 0.022287845091753605, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 29
# Generation with parameters (3.0041560548483504e+33, 1.291647193228735e+33, 0.0, 0.0, 0.6705991500214709, 0.0, 0.0, -0.04336851200961791, 3.085677581491367e+24, 0.5976665160553767, 1.4997176351402355, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.0041560548483504e+33, 1.291647193228735e+33, 0.0, 0.0, 0.6705991500214709, 0.0, 0.0, -0.04336851200961791, 3.085677581491367e+24, 0.5976665160553767, 1.4997176351402355, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 30
# Generation with parameters (4.106306655286214e+33, 6.802172970082067e+32, 0.0, 0.0, 0.3187318515104348, 0.0, 0.0, -0.02028167879508396, 3.085677581491367e+24, 0.5297682271400951, 2.7369288552950333, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.106306655286214e+33, 6.802172970082067e+32, 0.0, 0.0, 0.3187318515104348, 0.0, 0.0, -0.02028167879508396, 3.085677581491367e+24, 0.5297682271400951, 2.7369288552950333, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 31
# Generation with parameters (3.733022200873218e+33, 6.063302153415775e+32, 0.0, 0.0, 0.27159036920491725, 0.0, 0.0, -0.19760128983140088, 3.085677581491367e+24, 1.983851157662268, 2.609182731589101, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.733022200873218e+33, 6.063302153415775e+32, 0.0, 0.0, 0.27159036920491725, 0.0, 0.0, -0.19760128983140088, 3.085677581491367e+24, 1.983851157662268, 2.609182731589101, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 32
# Running injection 33
# Generation with parameters (4.833333349577486e+33, 1.0827273825910317e+33, 0.0, 0.0, -0.5741070018019682, 0.0, 0.0, 0.07368950090162937, 3.085677581491367e+24, 1.6667852001088654, 0.06720546207172085, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.833333349577486e+33, 1.0827273825910317e+33, 0.0, 0.0, -0.5741070018019682, 0.0, 0.0, 0.07368950090162937, 3.085677581491367e+24, 1.6667852001088654, 0.06720546207172085, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 34
# Generation with parameters (2.5438189562238446e+33, 3.490644548945932e+32, 0.0, 0.0, -0.0032982472461165584, 0.0, 0.0, -0.2707085898929041, 3.085677581491367e+24, 1.0462046828557061, 4.958850424520221, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5438189562238446e+33, 3.490644548945932e+32, 0.0, 0.0, -0.0032982472461165584, 0.0, 0.0, -0.2707085898929041, 3.085677581491367e+24, 1.0462046828557061, 4.958850424520221, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 35
# Running injection 36
# Generation with parameters (1.2550930686651189e+33, 5.966978221316731e+32, 0.0, 0.0, 0.46084120502736436, 0.0, 0.0, -0.017985336943262147, 3.085677581491367e+24, 2.4799035014121147, 2.2240252391036033, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2550930686651189e+33, 5.966978221316731e+32, 0.0, 0.0, 0.46084120502736436, 0.0, 0.0, -0.017985336943262147, 3.085677581491367e+24, 2.4799035014121147, 2.2240252391036033, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 37
# Generation with parameters (1.448931560020429e+33, 4.953800763482895e+32, 0.0, 0.0, 0.011761837065025132, 0.0, 0.0, 0.10457584843303828, 3.085677581491367e+24, 1.0938435914057612, 2.485447394894742, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.448931560020429e+33, 4.953800763482895e+32, 0.0, 0.0, 0.011761837065025132, 0.0, 0.0, 0.10457584843303828, 3.085677581491367e+24, 1.0938435914057612, 2.485447394894742, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 38
# Generation with parameters (3.0061614369291994e+33, 6.570098883292973e+32, 0.0, 0.0, 0.6398402723582031, 0.0, 0.0, -0.2625827802712525, 3.085677581491367e+24, 1.8060260023973485, 4.621745580910732, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.0061614369291994e+33, 6.570098883292973e+32, 0.0, 0.0, 0.6398402723582031, 0.0, 0.0, -0.2625827802712525, 3.085677581491367e+24, 1.8060260023973485, 4.621745580910732, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 39
# Generation with parameters (1.803231866094936e+33, 1.2726735345150601e+33, 0.0, 0.0, 0.09894520377170755, 0.0, 0.0, -0.07520680816222146, 3.085677581491367e+24, 0.6585560139304871, 1.9227971983332253, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.803231866094936e+33, 1.2726735345150601e+33, 0.0, 0.0, 0.09894520377170755, 0.0, 0.0, -0.07520680816222146, 3.085677581491367e+24, 0.6585560139304871, 1.9227971983332253, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 40
# Generation with parameters (1.3689244210663984e+33, 7.455957044016912e+32, 0.0, 0.0, 0.21741286210044036, 0.0, 0.0, 0.006098646663489306, 3.085677581491367e+24, 1.337889111635981, 0.028827566336626677, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3689244210663984e+33, 7.455957044016912e+32, 0.0, 0.0, 0.21741286210044036, 0.0, 0.0, 0.006098646663489306, 3.085677581491367e+24, 1.337889111635981, 0.028827566336626677, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 41
# Generation with parameters (2.749172936387284e+33, 6.482015752494147e+32, 0.0, 0.0, 0.38635238283280376, 0.0, 0.0, 0.47953735301629263, 3.085677581491367e+24, 1.3602138565439847, 6.212516921881521, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.749172936387284e+33, 6.482015752494147e+32, 0.0, 0.0, 0.38635238283280376, 0.0, 0.0, 0.47953735301629263, 3.085677581491367e+24, 1.3602138565439847, 6.212516921881521, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 42
# Generation with parameters (3.0455485070543376e+33, 1.2590670615855199e+33, 0.0, 0.0, 0.20632959714314916, 0.0, 0.0, 0.012619310124033683, 3.085677581491367e+24, 2.386538231476883, 4.218438761918334, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.0455485070543376e+33, 1.2590670615855199e+33, 0.0, 0.0, 0.20632959714314916, 0.0, 0.0, 0.012619310124033683, 3.085677581491367e+24, 2.386538231476883, 4.218438761918334, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 43
# Generation with parameters (2.038717011493576e+33, 6.099462734255479e+32, 0.0, 0.0, 0.4149717525544946, 0.0, 0.0, 0.4530301269961799, 3.085677581491367e+24, 1.9529636120225944, 0.7968414538749111, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.038717011493576e+33, 6.099462734255479e+32, 0.0, 0.0, 0.4149717525544946, 0.0, 0.0, 0.4530301269961799, 3.085677581491367e+24, 1.9529636120225944, 0.7968414538749111, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 44
# Generation with parameters (3.025345626602835e+33, 1.1887202781751601e+33, 0.0, 0.0, -0.06873021304406067, 0.0, 0.0, 0.2648823305036001, 3.085677581491367e+24, 1.767929960893538, 2.5743604209039908, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.025345626602835e+33, 1.1887202781751601e+33, 0.0, 0.0, -0.06873021304406067, 0.0, 0.0, 0.2648823305036001, 3.085677581491367e+24, 1.767929960893538, 2.5743604209039908, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 45
# Generation with parameters (3.4784965068816365e+33, 8.475070318387508e+32, 0.0, 0.0, -0.03899983076679445, 0.0, 0.0, 0.14073481320796644, 3.085677581491367e+24, 0.4109883787621669, 3.831068877146848, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.4784965068816365e+33, 8.475070318387508e+32, 0.0, 0.0, -0.03899983076679445, 0.0, 0.0, 0.14073481320796644, 3.085677581491367e+24, 0.4109883787621669, 3.831068877146848, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 46
# Generation with parameters (4.0273027877267794e+33, 1.0178084615649037e+33, 0.0, 0.0, 0.22671540433421733, 0.0, 0.0, 0.25916088889394867, 3.085677581491367e+24, 2.5431990261052113, 3.7609791503768517, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.0273027877267794e+33, 1.0178084615649037e+33, 0.0, 0.0, 0.22671540433421733, 0.0, 0.0, 0.25916088889394867, 3.085677581491367e+24, 2.5431990261052113, 3.7609791503768517, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 47
# Generation with parameters (3.120355408416406e+33, 1.2513542012910541e+33, 0.0, 0.0, -0.16850852608016245, 0.0, 0.0, -0.03244999570484552, 3.085677581491367e+24, 2.212309715819011, 5.442286742991352, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.120355408416406e+33, 1.2513542012910541e+33, 0.0, 0.0, -0.16850852608016245, 0.0, 0.0, -0.03244999570484552, 3.085677581491367e+24, 2.212309715819011, 5.442286742991352, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 48
# Generation with parameters (1.9031956832641234e+33, 1.558252394686996e+33, 0.0, 0.0, -0.14861172846458476, 0.0, 0.0, 0.03872025256665651, 3.085677581491367e+24, 2.346923741532841, 4.096612115129353, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.9031956832641234e+33, 1.558252394686996e+33, 0.0, 0.0, -0.14861172846458476, 0.0, 0.0, 0.03872025256665651, 3.085677581491367e+24, 2.346923741532841, 4.096612115129353, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 49
# Generation with parameters (3.7307562735644174e+33, 5.236712651585502e+32, 0.0, 0.0, 0.46535625226511396, 0.0, 0.0, 0.22067143413569773, 3.085677581491367e+24, 2.4899815849320843, 0.7759098744484726, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.7307562735644174e+33, 5.236712651585502e+32, 0.0, 0.0, 0.46535625226511396, 0.0, 0.0, 0.22067143413569773, 3.085677581491367e+24, 2.4899815849320843, 0.7759098744484726, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 50
# Generation with parameters (2.4516845810581523e+33, 1.6936124552212812e+33, 0.0, 0.0, 0.37449589416077733, 0.0, 0.0, -0.363477460135084, 3.085677581491367e+24, 1.9283819871496257, 6.244813234262173, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.4516845810581523e+33, 1.6936124552212812e+33, 0.0, 0.0, 0.37449589416077733, 0.0, 0.0, -0.363477460135084, 3.085677581491367e+24, 1.9283819871496257, 6.244813234262173, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 51
# Generation with parameters (5.369102485839856e+33, 1.0870070585730994e+33, 0.0, 0.0, 0.006371067332709953, 0.0, 0.0, 0.7146423097704774, 3.085677581491367e+24, 2.386543843632435, 1.3067613434736944, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.369102485839856e+33, 1.0870070585730994e+33, 0.0, 0.0, 0.006371067332709953, 0.0, 0.0, 0.7146423097704774, 3.085677581491367e+24, 2.386543843632435, 1.3067613434736944, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 52
# Generation with parameters (2.2860161119539924e+33, 1.384286353154103e+33, 0.0, 0.0, -0.008721479725611584, 0.0, 0.0, 0.5200866537640838, 3.085677581491367e+24, 2.54385642903462, 1.6392119928518951, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2860161119539924e+33, 1.384286353154103e+33, 0.0, 0.0, -0.008721479725611584, 0.0, 0.0, 0.5200866537640838, 3.085677581491367e+24, 2.54385642903462, 1.6392119928518951, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 53
# Generation with parameters (2.2250458736861467e+33, 3.906016300502407e+32, 0.0, 0.0, 0.007165927971263737, 0.0, 0.0, 0.03687967903252892, 3.085677581491367e+24, 1.2988408141904006, 2.9433942669333804, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2250458736861467e+33, 3.906016300502407e+32, 0.0, 0.0, 0.007165927971263737, 0.0, 0.0, 0.03687967903252892, 3.085677581491367e+24, 1.2988408141904006, 2.9433942669333804, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 54
# Generation with parameters (3.111394571106682e+33, 1.330972383304738e+33, 0.0, 0.0, -0.11236496838607656, 0.0, 0.0, -0.13798458258320834, 3.085677581491367e+24, 1.5463384121643227, 0.04620389605391316, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.111394571106682e+33, 1.330972383304738e+33, 0.0, 0.0, -0.11236496838607656, 0.0, 0.0, -0.13798458258320834, 3.085677581491367e+24, 1.5463384121643227, 0.04620389605391316, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 55
# Generation with parameters (2.2601183264177974e+33, 2.0680308786805397e+33, 0.0, 0.0, -0.07393765754587257, 0.0, 0.0, -0.015706970473707182, 3.085677581491367e+24, 1.311588464672172, 4.092767662661181, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2601183264177974e+33, 2.0680308786805397e+33, 0.0, 0.0, -0.07393765754587257, 0.0, 0.0, -0.015706970473707182, 3.085677581491367e+24, 1.311588464672172, 4.092767662661181, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 56
# Generation with parameters (2.6896616040290735e+33, 1.7270350981019496e+33, 0.0, 0.0, -0.2470160796776843, 0.0, 0.0, 0.3490968649069366, 3.085677581491367e+24, 1.289274602533819, 1.3055197565399583, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.6896616040290735e+33, 1.7270350981019496e+33, 0.0, 0.0, -0.2470160796776843, 0.0, 0.0, 0.3490968649069366, 3.085677581491367e+24, 1.289274602533819, 1.3055197565399583, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 57
# Generation with parameters (2.117663138654482e+33, 1.461700686619159e+33, 0.0, 0.0, 0.7162088845250136, 0.0, 0.0, 0.15484299984340413, 3.085677581491367e+24, 0.8266676021177846, 2.968064391628445, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.117663138654482e+33, 1.461700686619159e+33, 0.0, 0.0, 0.7162088845250136, 0.0, 0.0, 0.15484299984340413, 3.085677581491367e+24, 0.8266676021177846, 2.968064391628445, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 58
# Generation with parameters (3.5975856337741494e+33, 9.70081024793915e+32, 0.0, 0.0, -0.4325083964950602, 0.0, 0.0, 0.22023631182018916, 3.085677581491367e+24, 1.073988059163312, 0.5178535517054857, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.5975856337741494e+33, 9.70081024793915e+32, 0.0, 0.0, -0.4325083964950602, 0.0, 0.0, 0.22023631182018916, 3.085677581491367e+24, 1.073988059163312, 0.5178535517054857, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 59
# Generation with parameters (1.387537104634788e+33, 6.019507183438161e+32, 0.0, 0.0, -0.09434325463772009, 0.0, 0.0, -0.24017764094329871, 3.085677581491367e+24, 1.3333915495992124, 4.8380862101915945, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.387537104634788e+33, 6.019507183438161e+32, 0.0, 0.0, -0.09434325463772009, 0.0, 0.0, -0.24017764094329871, 3.085677581491367e+24, 1.3333915495992124, 4.8380862101915945, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 60
# Generation with parameters (1.8499306336110515e+33, 7.836953924601378e+32, 0.0, 0.0, 0.0013599447212845031, 0.0, 0.0, -0.17237455182500344, 3.085677581491367e+24, 2.576097520396203, 3.805511444876621, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8499306336110515e+33, 7.836953924601378e+32, 0.0, 0.0, 0.0013599447212845031, 0.0, 0.0, -0.17237455182500344, 3.085677581491367e+24, 2.576097520396203, 3.805511444876621, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 61
# Generation with parameters (2.5706223668799696e+33, 1.4298696978985948e+33, 0.0, 0.0, 0.04032438436619516, 0.0, 0.0, 0.3658235903740373, 3.085677581491367e+24, 2.1002405067959176, 3.4070958120664434, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5706223668799696e+33, 1.4298696978985948e+33, 0.0, 0.0, 0.04032438436619516, 0.0, 0.0, 0.3658235903740373, 3.085677581491367e+24, 2.1002405067959176, 3.4070958120664434, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 62
# Generation with parameters (2.702754640308326e+33, 1.324946429220979e+33, 0.0, 0.0, -0.33084449059866855, 0.0, 0.0, 0.05166852457666925, 3.085677581491367e+24, 0.1127880337026141, 0.19066182488830882, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.702754640308326e+33, 1.324946429220979e+33, 0.0, 0.0, -0.33084449059866855, 0.0, 0.0, 0.05166852457666925, 3.085677581491367e+24, 0.1127880337026141, 0.19066182488830882, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 63
# Generation with parameters (1.802029624740105e+33, 8.126933095106807e+32, 0.0, 0.0, -0.529146384310173, 0.0, 0.0, 0.01571937633372371, 3.085677581491367e+24, 1.4893301545609672, 5.372426633381118, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.802029624740105e+33, 8.126933095106807e+32, 0.0, 0.0, -0.529146384310173, 0.0, 0.0, 0.01571937633372371, 3.085677581491367e+24, 1.4893301545609672, 5.372426633381118, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 64
# Generation with parameters (2.3274483775163153e+33, 1.3930437800485045e+33, 0.0, 0.0, -0.13938184572866763, 0.0, 0.0, 0.03138754592090541, 3.085677581491367e+24, 1.8668174128768493, 5.156566646761088, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3274483775163153e+33, 1.3930437800485045e+33, 0.0, 0.0, -0.13938184572866763, 0.0, 0.0, 0.03138754592090541, 3.085677581491367e+24, 1.8668174128768493, 5.156566646761088, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 65
# Generation with parameters (3.3603475140483083e+33, 1.454974994373916e+33, 0.0, 0.0, 0.3605691291311164, 0.0, 0.0, -0.614899139492555, 3.085677581491367e+24, 0.22813713216159887, 4.5974023698305455, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.3603475140483083e+33, 1.454974994373916e+33, 0.0, 0.0, 0.3605691291311164, 0.0, 0.0, -0.614899139492555, 3.085677581491367e+24, 0.22813713216159887, 4.5974023698305455, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 66
# Generation with parameters (1.4875227293904233e+33, 8.363672743904828e+32, 0.0, 0.0, -0.0029434683240558293, 0.0, 0.0, -0.02515958887465037, 3.085677581491367e+24, 0.42457992333815137, 6.0638814200370055, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4875227293904233e+33, 8.363672743904828e+32, 0.0, 0.0, -0.0029434683240558293, 0.0, 0.0, -0.02515958887465037, 3.085677581491367e+24, 0.42457992333815137, 6.0638814200370055, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 67
# Generation with parameters (3.9008267057396083e+33, 1.2536378451183307e+33, 0.0, 0.0, -0.0012454790360357348, 0.0, 0.0, -0.47307960336762894, 3.085677581491367e+24, 2.152795883058513, 1.2050937948739413, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.9008267057396083e+33, 1.2536378451183307e+33, 0.0, 0.0, -0.0012454790360357348, 0.0, 0.0, -0.47307960336762894, 3.085677581491367e+24, 2.152795883058513, 1.2050937948739413, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 68
# Generation with parameters (2.745714823176275e+33, 4.931110103126053e+32, 0.0, 0.0, 0.12318566414418253, 0.0, 0.0, 0.05255047614221502, 3.085677581491367e+24, 0.878610651751514, 1.0681294586408336, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.745714823176275e+33, 4.931110103126053e+32, 0.0, 0.0, 0.12318566414418253, 0.0, 0.0, 0.05255047614221502, 3.085677581491367e+24, 0.878610651751514, 1.0681294586408336, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 69
# ...
# Warning: turning off multibanding for parameters (4.1126817683644964e+33, 8.447859679253724e+32, 0.0, 0.0, 0.039989346201120955, 0.0, 0.0, -0.02658843719177765, 3.085677581491367e+24, 2.0655107699067705, 3.2865505960253882, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 975
# Running injection 976
# Generation with parameters (3.5513915337131635e+33, 7.581834456651996e+32, 0.0, 0.0, 0.7975044128269438, 0.0, 0.0, 0.2565695661237551, 3.085677581491367e+24, 0.9912740447669447, 2.7349947309320193, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.5513915337131635e+33, 7.581834456651996e+32, 0.0, 0.0, 0.7975044128269438, 0.0, 0.0, 0.2565695661237551, 3.085677581491367e+24, 0.9912740447669447, 2.7349947309320193, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 977
# Generation with parameters (1.4262638242069563e+33, 2.3187523168938893e+32, 0.0, 0.0, 0.17347919332597747, 0.0, 0.0, 0.06296548512422734, 3.085677581491367e+24, 1.2402762085185324, 1.777989726845986, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4262638242069563e+33, 2.3187523168938893e+32, 0.0, 0.0, 0.17347919332597747, 0.0, 0.0, 0.06296548512422734, 3.085677581491367e+24, 1.2402762085185324, 1.777989726845986, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 978
# Generation with parameters (1.865136356456969e+33, 1.348053307750854e+33, 0.0, 0.0, -0.03956461866709405, 0.0, 0.0, 0.012947082380520437, 3.085677581491367e+24, 1.6753157128380871, 5.3628423697833885, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.865136356456969e+33, 1.348053307750854e+33, 0.0, 0.0, -0.03956461866709405, 0.0, 0.0, 0.012947082380520437, 3.085677581491367e+24, 1.6753157128380871, 5.3628423697833885, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 979
# Generation with parameters (4.619460839498161e+33, 1.0541455750487971e+33, 0.0, 0.0, 0.014361056731344952, 0.0, 0.0, -0.010803838132376994, 3.085677581491367e+24, 2.5399316345089984, 4.627634798533126, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.619460839498161e+33, 1.0541455750487971e+33, 0.0, 0.0, 0.014361056731344952, 0.0, 0.0, -0.010803838132376994, 3.085677581491367e+24, 2.5399316345089984, 4.627634798533126, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 980
# Generation with parameters (2.148166236866763e+33, 1.948864330917544e+33, 0.0, 0.0, -0.023977775603053076, 0.0, 0.0, 0.01550964713271251, 3.085677581491367e+24, 2.664340250114683, 1.8029040241547916, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.148166236866763e+33, 1.948864330917544e+33, 0.0, 0.0, -0.023977775603053076, 0.0, 0.0, 0.01550964713271251, 3.085677581491367e+24, 2.664340250114683, 1.8029040241547916, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 981
# Generation with parameters (2.365718222707823e+33, 9.166551061638414e+32, 0.0, 0.0, -0.022297647381696865, 0.0, 0.0, -0.2132916690620816, 3.085677581491367e+24, 1.3728651263103535, 0.7518911981559995, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.365718222707823e+33, 9.166551061638414e+32, 0.0, 0.0, -0.022297647381696865, 0.0, 0.0, -0.2132916690620816, 3.085677581491367e+24, 1.3728651263103535, 0.7518911981559995, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 982
# Generation with parameters (2.658965534524593e+33, 1.4820622704438758e+33, 0.0, 0.0, 0.05425432715737454, 0.0, 0.0, 0.5052786014266432, 3.085677581491367e+24, 1.6563996612740088, 5.034223339440733, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.658965534524593e+33, 1.4820622704438758e+33, 0.0, 0.0, 0.05425432715737454, 0.0, 0.0, 0.5052786014266432, 3.085677581491367e+24, 1.6563996612740088, 5.034223339440733, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 983
# Generation with parameters (3.283678011870299e+33, 1.060051814343671e+33, 0.0, 0.0, -0.22325391119937144, 0.0, 0.0, -0.25229300214542255, 3.085677581491367e+24, 1.4179974554009431, 3.1563729463613326, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.283678011870299e+33, 1.060051814343671e+33, 0.0, 0.0, -0.22325391119937144, 0.0, 0.0, -0.25229300214542255, 3.085677581491367e+24, 1.4179974554009431, 3.1563729463613326, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 984
# Generation with parameters (4.3060820763339007e+33, 1.1050390470145343e+33, 0.0, 0.0, -0.1688119693927408, 0.0, 0.0, 0.48119223556601753, 3.085677581491367e+24, 0.3645776997387042, 4.903941634225971, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.3060820763339007e+33, 1.1050390470145343e+33, 0.0, 0.0, -0.1688119693927408, 0.0, 0.0, 0.48119223556601753, 3.085677581491367e+24, 0.3645776997387042, 4.903941634225971, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 985
# Generation with parameters (2.010846893545666e+33, 1.9302648741210377e+33, 0.0, 0.0, 0.1481869748241626, 0.0, 0.0, 0.4749520972815066, 3.085677581491367e+24, 2.3606441111848695, 1.8654685277894463, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.010846893545666e+33, 1.9302648741210377e+33, 0.0, 0.0, 0.1481869748241626, 0.0, 0.0, 0.4749520972815066, 3.085677581491367e+24, 2.3606441111848695, 1.8654685277894463, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 986
# Generation with parameters (2.3148760189337835e+33, 1.7220471150202848e+33, 0.0, 0.0, -0.03013288805429857, 0.0, 0.0, 0.02229811386289684, 3.085677581491367e+24, 1.4224089333663985, 2.026280652129289, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3148760189337835e+33, 1.7220471150202848e+33, 0.0, 0.0, -0.03013288805429857, 0.0, 0.0, 0.02229811386289684, 3.085677581491367e+24, 1.4224089333663985, 2.026280652129289, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 987
# Generation with parameters (3.368415210372987e+33, 1.5647421107242253e+33, 0.0, 0.0, -0.18102429954140403, 0.0, 0.0, -0.10638360787837167, 3.085677581491367e+24, 0.5690204944797379, 4.204713678230521, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.368415210372987e+33, 1.5647421107242253e+33, 0.0, 0.0, -0.18102429954140403, 0.0, 0.0, -0.10638360787837167, 3.085677581491367e+24, 0.5690204944797379, 4.204713678230521, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 988
# Generation with parameters (2.339424157030282e+33, 1.5736506779513714e+33, 0.0, 0.0, -0.4624236424157829, 0.0, 0.0, 0.2245470128582609, 3.085677581491367e+24, 1.1039910871075127, 2.838480140463307, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.339424157030282e+33, 1.5736506779513714e+33, 0.0, 0.0, -0.4624236424157829, 0.0, 0.0, 0.2245470128582609, 3.085677581491367e+24, 1.1039910871075127, 2.838480140463307, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 989
# Running injection 990
# Generation with parameters (2.5687228550835803e+33, 1.110583907426762e+33, 0.0, 0.0, -0.07345984003100522, 0.0, 0.0, -0.3512931200745448, 3.085677581491367e+24, 1.5214788132002632, 3.16817596181721, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5687228550835803e+33, 1.110583907426762e+33, 0.0, 0.0, -0.07345984003100522, 0.0, 0.0, -0.3512931200745448, 3.085677581491367e+24, 1.5214788132002632, 3.16817596181721, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 991
# Generation with parameters (3.6463816164311125e+33, 4.8563695107221895e+32, 0.0, 0.0, 0.020276051863288052, 0.0, 0.0, 0.10582423738878073, 3.085677581491367e+24, 1.2017466691502716, 3.57312565704504, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.6463816164311125e+33, 4.8563695107221895e+32, 0.0, 0.0, 0.020276051863288052, 0.0, 0.0, 0.10582423738878073, 3.085677581491367e+24, 1.2017466691502716, 3.57312565704504, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 992
# Generation with parameters (2.0805965490231814e+33, 1.7445660730969295e+33, 0.0, 0.0, 0.25134531649980557, 0.0, 0.0, -0.06534608686818089, 3.085677581491367e+24, 2.6856820521654856, 3.055895113576591, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0805965490231814e+33, 1.7445660730969295e+33, 0.0, 0.0, 0.25134531649980557, 0.0, 0.0, -0.06534608686818089, 3.085677581491367e+24, 2.6856820521654856, 3.055895113576591, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 993
# Generation with parameters (2.2071907284240458e+33, 9.391469817124551e+32, 0.0, 0.0, 0.08639489377732204, 0.0, 0.0, 0.26234971548531943, 3.085677581491367e+24, 2.7060059649668067, 3.011436243894872, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2071907284240458e+33, 9.391469817124551e+32, 0.0, 0.0, 0.08639489377732204, 0.0, 0.0, 0.26234971548531943, 3.085677581491367e+24, 2.7060059649668067, 3.011436243894872, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 994
# Generation with parameters (2.1128783297775333e+33, 4.888146894127398e+32, 0.0, 0.0, 0.22133322950772114, 0.0, 0.0, 0.5323515384566402, 3.085677581491367e+24, 2.1717650413748046, 3.1101046987388457, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.1128783297775333e+33, 4.888146894127398e+32, 0.0, 0.0, 0.22133322950772114, 0.0, 0.0, 0.5323515384566402, 3.085677581491367e+24, 2.1717650413748046, 3.1101046987388457, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 995
# Generation with parameters (2.130207013150564e+33, 1.1931088670567087e+33, 0.0, 0.0, 0.03183726483649583, 0.0, 0.0, 0.24456033351849996, 3.085677581491367e+24, 2.525111371892984, 4.954567916724903, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.130207013150564e+33, 1.1931088670567087e+33, 0.0, 0.0, 0.03183726483649583, 0.0, 0.0, 0.24456033351849996, 3.085677581491367e+24, 2.525111371892984, 4.954567916724903, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 996
# Generation with parameters (1.3266194339035094e+33, 1.0879101939267704e+33, 0.0, 0.0, -0.38207175054894116, 0.0, 0.0, 0.5436194492252437, 3.085677581491367e+24, 1.257091468024994, 6.160390753128441, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3266194339035094e+33, 1.0879101939267704e+33, 0.0, 0.0, -0.38207175054894116, 0.0, 0.0, 0.5436194492252437, 3.085677581491367e+24, 1.257091468024994, 6.160390753128441, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 997
# Generation with parameters (3.270113416731018e+33, 6.664258953781177e+32, 0.0, 0.0, 0.15483944524185297, 0.0, 0.0, -0.11725375806696414, 3.085677581491367e+24, 2.2196852219594847, 2.406367239644477, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.270113416731018e+33, 6.664258953781177e+32, 0.0, 0.0, 0.15483944524185297, 0.0, 0.0, -0.11725375806696414, 3.085677581491367e+24, 2.2196852219594847, 2.406367239644477, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 998
# Generation with parameters (3.5832369053549954e+33, 7.464594065010124e+32, 0.0, 0.0, 0.7224690088805291, 0.0, 0.0, 0.4456289747494684, 3.085677581491367e+24, 1.8146496847259912, 0.19401192295418845, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.5832369053549954e+33, 7.464594065010124e+32, 0.0, 0.0, 0.7224690088805291, 0.0, 0.0, 0.4456289747494684, 3.085677581491367e+24, 1.8146496847259912, 0.19401192295418845, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 999
# Generation with parameters (1.2720035949162675e+33, 8.312342753750728e+32, 0.0, 0.0, 0.09664222664278477, 0.0, 0.0, -0.32703939300575563, 3.085677581491367e+24, 1.31929127627477, 2.764232629620395, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2720035949162675e+33, 8.312342753750728e+32, 0.0, 0.0, 0.09664222664278477, 0.0, 0.0, -0.32703939300575563, 3.085677581491367e+24, 1.31929127627477, 2.764232629620395, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.

# %%
import os
import pickle

from dingo.gw.inference.gw_samplers import GWSampler


os.makedirs("/scratch/tpausch/test_data/imbh_T8_mass2/results", exist_ok=True)

injection_files = sorted(os.listdir("/scratch/tpausch/test_data/imbh_T8_mass2/injections"))

for fname in injection_files:

    # --------------------------------------------------------
    # Load injection
    # --------------------------------------------------------

    with open(f"/scratch/tpausch/test_data/imbh_T8_mass2/injections/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    strain_data = payload["strain_data"]

    # --------------------------------------------------------
    # Run sampler
    # --------------------------------------------------------

    sampler = GWSampler(model=main_pm)

    sampler.context = strain_data

    sampler.run_sampler(
        num_samples=50_000,
        batch_size=10_000,
    )

    result = sampler.to_result()

    # --------------------------------------------------------
    # Store result
    # --------------------------------------------------------

    result_payload = {
        "theta_true": theta_true,
        "result": result,
    }

    outname = fname.replace("inj_", "result_")

    with open(f"/scratch/tpausch/test_data/imbh_T8_mass2/results/{outname}", "wb") as f:
        pickle.dump(result_payload, f)

    print(f"Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/{outname}")
# Out:
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0000.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0001.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0002.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0003.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0004.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0005.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0006.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0007.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0008.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0009.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0010.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0011.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0012.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0013.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0014.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0015.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0016.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0017.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0018.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0019.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0020.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0021.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0022.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0023.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0024.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0025.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0026.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0027.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0028.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0029.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0030.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0031.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0032.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0033.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0034.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0035.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0036.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0037.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0038.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0039.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0040.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0041.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0042.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0043.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0044.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0045.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0046.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0047.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0048.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0049.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0050.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0051.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0052.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0053.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0054.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0055.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0056.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0057.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0058.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0059.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0060.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0061.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0062.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0063.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0064.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0065.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0066.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0067.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0068.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0069.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0070.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0071.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0072.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0073.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0074.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0075.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0076.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0077.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0078.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0079.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0080.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0081.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# ...
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0972.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0973.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0974.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0975.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0976.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0977.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0978.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0979.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0980.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0981.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0982.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0983.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0984.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0985.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0986.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0987.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0988.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0989.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0990.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0991.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0992.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0993.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0994.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0995.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0996.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0997.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0998.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results/result_0999.pkl

# %%
import os
import pickle
import numpy as np

true_cm = []
true_mr = []
mass_ratio_error = []
mass_ratio_std = []
chirp_mass_error = []
chirp_mass_std = []


result_files = sorted(os.listdir("/scratch/tpausch/test_data/imbh_T8_mass2/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/imbh_T8_mass2/results/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    result = payload["result"]

    posterior_samples = result.samples

    #q_samples = np.array(posterior_samples["mass_ratio"])

    # inference statistics
    #q_mean = np.mean(q_samples)
    #q_std = np.std(q_samples)
#
    #true_q = theta_true["mass_ratio"]

    cm_samples = np.array(posterior_samples["chirp_mass"])

    cm_mean = np.mean(cm_samples)
    cm_std = np.std(cm_samples)

    true_mr.append(theta_true["mass_ratio"])
    true_cm.append(theta_true["chirp_mass"])
    #mass_ratio_error.append(q_mean - true_q)
    #mass_ratio_std.append(q_std)
    chirp_mass_error.append(cm_mean - theta_true["chirp_mass"])
    chirp_mass_std.append(cm_std)
# Out:
# /home/tpausch/ET-Dingo/dingo/gw/__init__.py:3: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   import lal

# %%
import matplotlib.pyplot as plt
import numpy as np

true_mr = np.array(true_mr)
true_cm = np.array(true_cm)




# ------------------------------------------------------------
# Error bars
# ------------------------------------------------------------

#plt.errorbar(
#    true_cm,
#    chirp_mass_error,
#    yerr=chirp_mass_std,
#    fmt="none",
#    capsize=4,
#    alpha=0.5,
#    color="gray",
#)

# ------------------------------------------------------------
# Colored scatter points
# ------------------------------------------------------------

sc = plt.scatter(
    true_cm,
    chirp_mass_error,
    #c=true_mr,
    #cmap="viridis",
    s=20,
    edgecolor="black",
    alpha=0.3
)

# ------------------------------------------------------------
# Reference line
# ------------------------------------------------------------

plt.axhline(0, linestyle="--", color="black")

# ------------------------------------------------------------
# Colorbar
# ------------------------------------------------------------

cbar = plt.colorbar(sc)
cbar.set_label("True mass ratio")

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel("True chirp mass")
plt.ylabel("Chirp mass inference error (inferred − true)")

plt.title("Chirp-mass inference error")

plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm_err = np.asarray(chirp_mass_error)

mean_error = np.mean(cm_err)          # signed average bias (over/under-estimation)
mean_abs_error = np.mean(np.abs(cm_err))  # average magnitude of deviation
rms_error = np.sqrt(np.mean(cm_err**2))   # RMS deviation, penalizes outliers more
std_error = np.std(cm_err)            # spread of the errors around their mean

print(f"Mean error (bias):      {mean_error:.3f}")
print(f"Mean absolute error:    {mean_abs_error:.3f}")
print(f"RMS error:              {rms_error:.3f}")
print(f"Std of error:           {std_error:.3f}")
# Out:
# Mean error (bias):      6.049
# Mean absolute error:    49.418
# RMS error:              101.046
# Std of error:           100.865

# %%
pp_values_chirp_mass = []
pp_values_mass_ratio = []

result_files = sorted(os.listdir("/scratch/tpausch/test_data/imbh_T8_mass2/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/imbh_T8_mass2/results/{fname}", "rb") as f:

        payload = pickle.load(f)

        theta_true = payload["theta_true"]
        result = payload["result"]

        posterior_samples = result.samples


        # ============================================================
        # Chirp mass PP value
        # ============================================================

        cm_samples = posterior_samples["chirp_mass"]

        pp_cm = np.mean(
            cm_samples < theta_true["chirp_mass"]
        )

        pp_values_chirp_mass.append(pp_cm)


        # ============================================================
        # Mass ratio PP value
        # ============================================================

        #q_samples = posterior_samples["mass_ratio"]
#
        #pp_q = np.mean(
        #    q_samples < theta_true["mass_ratio"]
        #)
#
        #pp_values_mass_ratio.append(pp_q)

# %%
import matplotlib.pyplot as plt


def plot_pp(pp_values, label):

    pp_values = np.array(pp_values)

    sorted_pp = np.sort(pp_values)

    n = len(sorted_pp)

    empirical_cdf = np.arange(1, n + 1) / n

    x = np.linspace(0, 1, 200)

    sigma = np.sqrt(x * (1 - x) / n)

    plt.figure(figsize=(6, 6))

    # Ideal calibration
    plt.plot(
        [0, 1],
        [0, 1],
        linestyle="--",
        label="Ideal calibration",
    )


    # Empirical PP curve
    plt.plot(
        sorted_pp,
        empirical_cdf,
        marker="o",
        label=label,
    )

    plt.xlabel("Credible level")
    plt.ylabel("Fraction of injections")

    plt.title(f"PP Plot: {label}")

    plt.xlim(0, 1)
    plt.ylim(0, 1)

    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
plot_pp(
    pp_values_chirp_mass,
    "chirp_mass",
)

#plot_pp(
#    pp_values_mass_ratio,
#    "mass_ratio",
#)
