# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # use GPU 1

from dingo.core.posterior_models.build_model import build_model_from_kwargs

main_pm = build_model_from_kwargs(
    filename="/scratch/tpausch/models/imbh_T8/model_latest.pt",
    device="cuda",
    load_training_info=False,
)
# Out:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Putting posterior model to device cuda.

# %%
import numpy as np
import itertools
import os
import pickle

# ============================================================
# Parameter grid
# ============================================================

chirp_masses = np.arange(50, 1001, 10)

mass_ratios = np.arange(0.2, 1.01, 0.05)


parameter_grid = list(
    itertools.product(
        chirp_masses,
        mass_ratios
    )
)
print(mass_ratios)
print(f"Total injections: {len(parameter_grid)}")
# Out:
# [0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65 0.7  0.75
#  0.8  0.85 0.9  0.95 1.  ]
# Total injections: 1632

# %%
import os
import pickle
import numpy as np

import dingo.gw.injection as injection
from dingo.gw.noise.asd_dataset import ASDDataset


# ============================================================
# Setup
# ============================================================

os.makedirs("/scratch/tpausch/test_data/imbh_T8s/injections", exist_ok=True)

injection_generator = injection.Injection.from_posterior_model_metadata(
    main_pm.metadata
)

asd_fname = main_pm.metadata["train_settings"]["training"]["stage_0"]["asd_dataset_path"]

asd_dataset = ASDDataset(file_name=asd_fname)

injection_generator.asd = {
    k: v[0] for k, v in asd_dataset.asds.items()
}



for idx, (cm, q) in enumerate(parameter_grid):

    print(f"Running injection {idx}")

    intrinsic_parameters = {
        "chirp_mass": float(cm),
        "mass_ratio": float(q),
        "a_1": 0.3,
        "a_2": 0.5,
        "tilt_1": 0.,
        "tilt_2": 0.,
        "phi_jl": 0.,
        "phi_12": 0.
    }

    extrinsic_parameters = {
        'phase': 0.,
        'theta_jn': 2.3,
        'geocent_time': 0.,
        'luminosity_distance': 1000.,
        'ra': 0.,
        'dec': 0.,
        'psi': 0.,
    }

    theta = {
        **intrinsic_parameters,
        **extrinsic_parameters
    }

    strain_data = injection_generator.injection(theta)

    payload = {
        "theta_true": theta,
        "strain_data": strain_data,
    }

    fname = f"/scratch/tpausch/test_data/imbh_T8s/injections/inj_{idx:04d}.pkl"

    with open(fname, "wb") as f:
        pickle.dump(payload, f)
# Out:
# Setting spin_conversion_phase = 0.0. Using this value for the phase parameter for conversion to cartesian spins.
# Loading dataset from training_data/asds_ET_T8.hdf5.
# Running injection 0
# Running injection 1
# Running injection 2
# Running injection 3
# Running injection 4
# Running injection 5
# Running injection 6
# Running injection 7
# Running injection 8
# Running injection 9
# Running injection 10
# Running injection 11
# Running injection 12
# Running injection 13
# Running injection 14
# Running injection 15
# Running injection 16
# Running injection 17
# Running injection 18
# Running injection 19
# Running injection 20
# Running injection 21
# Running injection 22
# Running injection 23
# Running injection 24
# Running injection 25
# Running injection 26
# Running injection 27
# Running injection 28
# Running injection 29
# Running injection 30
# Running injection 31
# Running injection 32
# Running injection 33
# Running injection 34
# Running injection 35
# Running injection 36
# Running injection 37
# Running injection 38
# Running injection 39
# Running injection 40
# Running injection 41
# Running injection 42
# Running injection 43
# Running injection 44
# Running injection 45
# Running injection 46
# Running injection 47
# Running injection 48
# Running injection 49
# Running injection 50
# Running injection 51
# Running injection 52
# Running injection 53
# Running injection 54
# Running injection 55
# Running injection 56
# Running injection 57
# Running injection 58
# Running injection 59
# Running injection 60
# Running injection 61
# Running injection 62
# Running injection 63
# Running injection 64
# Running injection 65
# Running injection 66
# Running injection 67
# Running injection 68
# Running injection 69
# Running injection 70
# Running injection 71
# Running injection 72
# Running injection 73
# Running injection 74
# Running injection 75
# Running injection 76
# Running injection 77
# Running injection 78
# Running injection 79
# Running injection 80
# Running injection 81
# Running injection 82
# Running injection 83
# Running injection 84
# Running injection 85
# Running injection 86
# Running injection 87
# Running injection 88
# Running injection 89
# Running injection 90
# Running injection 91
# Running injection 92
# Running injection 93
# Running injection 94
# Running injection 95
# Running injection 96
# Running injection 97
# Running injection 98
# Running injection 99
# Running injection 100
# Running injection 101
# Running injection 102
# Running injection 103
# Running injection 104
# Running injection 105
# Running injection 106
# Running injection 107
# Running injection 108
# Running injection 109
# Running injection 110
# Running injection 111
# Running injection 112
# Running injection 113
# Running injection 114
# Running injection 115
# Running injection 116
# Running injection 117
# Running injection 118
# Running injection 119
# Running injection 120
# Running injection 121
# Running injection 122
# Running injection 123
# Running injection 124
# Running injection 125
# Running injection 126
# Running injection 127
# Running injection 128
# Running injection 129
# Running injection 130
# Running injection 131
# Running injection 132
# Running injection 133
# Running injection 134
# Running injection 135
# Running injection 136
# Running injection 137
# Running injection 138
# Running injection 139
# Running injection 140
# Running injection 141
# Running injection 142
# Running injection 143
# Running injection 144
# Running injection 145
# Running injection 146
# Running injection 147
# Running injection 148
# Running injection 149
# Running injection 150
# Running injection 151
# Running injection 152
# Running injection 153
# Running injection 154
# Running injection 155
# Running injection 156
# Running injection 157
# Running injection 158
# Running injection 159
# Running injection 160
# Running injection 161
# Running injection 162
# Running injection 163
# Running injection 164
# Running injection 165
# Running injection 166
# Running injection 167
# Running injection 168
# Running injection 169
# Running injection 170
# Running injection 171
# Running injection 172
# Running injection 173
# Running injection 174
# Running injection 175
# Running injection 176
# Running injection 177
# Running injection 178
# Running injection 179
# Running injection 180
# Running injection 181
# Running injection 182
# Running injection 183
# Running injection 184
# Running injection 185
# Running injection 186
# Running injection 187
# Running injection 188
# Running injection 189
# Running injection 190
# Running injection 191
# Running injection 192
# Running injection 193
# Running injection 194
# Running injection 195
# Running injection 196
# Running injection 197
# Running injection 198
# Running injection 199
# Running injection 200
# Running injection 201
# Running injection 202
# Running injection 203
# Running injection 204
# Running injection 205
# Running injection 206
# Running injection 207
# Running injection 208
# Running injection 209
# Running injection 210
# Running injection 211
# Running injection 212
# Running injection 213
# Running injection 214
# Running injection 215
# Running injection 216
# Running injection 217
# Running injection 218
# Running injection 219
# Running injection 220
# Running injection 221
# Running injection 222
# Running injection 223
# Running injection 224
# Running injection 225
# Running injection 226
# Running injection 227
# Running injection 228
# Running injection 229
# Running injection 230
# Running injection 231
# Running injection 232
# Running injection 233
# Running injection 234
# Running injection 235
# Running injection 236
# Running injection 237
# Running injection 238
# Running injection 239
# Running injection 240
# Running injection 241
# Running injection 242
# Running injection 243
# Running injection 244
# Running injection 245
# Running injection 246
# Running injection 247
# Running injection 248
# Running injection 249
# Running injection 250
# Running injection 251
# Running injection 252
# Running injection 253
# Running injection 254
# Running injection 255
# Running injection 256
# Running injection 257
# Running injection 258
# Running injection 259
# Running injection 260
# Running injection 261
# Running injection 262
# Running injection 263
# Running injection 264
# Running injection 265
# Running injection 266
# Running injection 267
# Running injection 268
# Running injection 269
# Running injection 270
# Running injection 271
# Running injection 272
# Generation with parameters (1.137479181755048e+33, 2.274958363510096e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.137479181755048e+33, 2.274958363510096e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 273
# Running injection 274
# Running injection 275
# Running injection 276
# Running injection 277
# Running injection 278
# Running injection 279
# Running injection 280
# Running injection 281
# Running injection 282
# Running injection 283
# Running injection 284
# Running injection 285
# Running injection 286
# Running injection 287
# Running injection 288
# Running injection 289
# Generation with parameters (1.1916448570767169e+33, 2.383289714153434e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1916448570767169e+33, 2.383289714153434e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 290
# Generation with parameters (1.0508641794047264e+33, 2.627160448511816e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0508641794047264e+33, 2.627160448511816e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 291
# Generation with parameters (9.493896849117226e+32, 2.8481690547351676e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.493896849117226e+32, 2.8481690547351676e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 292
# Running injection 293
# Running injection 294
# Running injection 295
# Running injection 296
# Running injection 297
# Running injection 298
# Running injection 299
# Running injection 300
# Running injection 301
# Running injection 302
# Running injection 303
# Running injection 304
# Running injection 305
# Running injection 306
# Generation with parameters (1.2458105323983858e+33, 2.491621064796772e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2458105323983858e+33, 2.491621064796772e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 307
# Generation with parameters (1.098630733014032e+33, 2.74657683253508e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.098630733014032e+33, 2.74657683253508e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 308
# Generation with parameters (9.925437614986188e+32, 2.9776312844958563e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.925437614986188e+32, 2.9776312844958563e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 309
# Generation with parameters (9.117162036866342e+32, 3.19100671290322e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.117162036866342e+32, 3.19100671290322e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 310
# Running injection 311
# Generation with parameters (7.953894725799058e+32, 3.579252626609576e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.953894725799058e+32, 3.579252626609576e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 312
# Running injection 313
# Running injection 314
# Running injection 315
# Running injection 316
# Running injection 317
# Running injection 318
# Running injection 319
# Running injection 320
# Running injection 321
# Running injection 322
# Running injection 323
# Generation with parameters (1.2999762077200546e+33, 2.59995241544011e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2999762077200546e+33, 2.59995241544011e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 324
# Generation with parameters (1.1463972866233376e+33, 2.865993216558344e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1463972866233376e+33, 2.865993216558344e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 325
# Generation with parameters (1.0356978380855155e+33, 3.1070935142565465e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0356978380855155e+33, 3.1070935142565465e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 326
# Generation with parameters (9.513560386295312e+32, 3.3297461352033595e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.513560386295312e+32, 3.3297461352033595e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 327
# Generation with parameters (8.845181815779073e+32, 3.538072726311629e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.845181815779073e+32, 3.538072726311629e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 328
# Generation with parameters (8.299716235616409e+32, 3.734872306027384e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.299716235616409e+32, 3.734872306027384e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 329
# Generation with parameters (7.844285670696077e+32, 3.9221428353480376e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.844285670696077e+32, 3.9221428353480376e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 330
# Generation with parameters (7.457029789275258e+32, 4.101366384101392e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.457029789275258e+32, 4.101366384101392e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 331
# Generation with parameters (7.122794232562352e+32, 4.27367653953741e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.122794232562352e+32, 4.27367653953741e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 332
# Running injection 333
# Running injection 334
# Running injection 335
# Running injection 336
# Running injection 337
# Running injection 338
# Running injection 339
# Running injection 340
# Generation with parameters (1.3541418830417235e+33, 2.708283766083447e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3541418830417235e+33, 2.708283766083447e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 341
# Generation with parameters (1.1941638402326436e+33, 2.985409600581609e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1941638402326436e+33, 2.985409600581609e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 342
# Generation with parameters (1.078851914672412e+33, 3.236555744017236e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.078851914672412e+33, 3.236555744017236e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 343
# Generation with parameters (9.909958735724286e+32, 3.468485557503499e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.909958735724286e+32, 3.468485557503499e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 344
# Generation with parameters (9.213731058103203e+32, 3.6854924232412805e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.213731058103203e+32, 3.6854924232412805e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 345
# Generation with parameters (8.64553774543376e+32, 3.890491985445192e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.64553774543376e+32, 3.890491985445192e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 346
# Generation with parameters (8.171130906975078e+32, 4.085565453487538e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.171130906975078e+32, 4.085565453487538e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 347
# Generation with parameters (7.767739363828393e+32, 4.272256650105616e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.767739363828393e+32, 4.272256650105616e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 348
# Generation with parameters (7.419577325585785e+32, 4.45174639535147e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.419577325585785e+32, 4.45174639535147e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 349
# Generation with parameters (7.115324216146402e+32, 4.6249607404951605e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.115324216146402e+32, 4.6249607404951605e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 350
# Running injection 351
# Running injection 352
# Running injection 353
# Running injection 354
# Running injection 355
# Running injection 356
# Running injection 357
# Generation with parameters (1.4083075583633926e+33, 2.8166151167267854e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4083075583633926e+33, 2.8166151167267854e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 358
# Generation with parameters (1.2419303938419494e+33, 3.1048259846048735e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2419303938419494e+33, 3.1048259846048735e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 359
# Generation with parameters (1.1220059912593083e+33, 3.366017973777925e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1220059912593083e+33, 3.366017973777925e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 360
# Generation with parameters (1.0306357085153258e+33, 3.60722497980364e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0306357085153258e+33, 3.60722497980364e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 361
# Generation with parameters (9.582280300427328e+32, 3.832912120170931e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.582280300427328e+32, 3.832912120170931e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 362
# Generation with parameters (8.99135925525111e+32, 4.046111664862998e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.99135925525111e+32, 4.046111664862998e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 363
# Generation with parameters (8.497976143254082e+32, 4.24898807162704e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.497976143254082e+32, 4.24898807162704e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 364
# Generation with parameters (8.078448938381529e+32, 4.44314691610984e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.078448938381529e+32, 4.44314691610984e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 365
# Generation with parameters (7.716360418609215e+32, 4.629816251165528e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.716360418609215e+32, 4.629816251165528e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 366
# Generation with parameters (7.399937184792257e+32, 4.809959170114967e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.399937184792257e+32, 4.809959170114967e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 367
# Generation with parameters (7.120495537533258e+32, 4.98434687627328e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.120495537533258e+32, 4.98434687627328e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 368
# Generation with parameters (6.871477203423743e+32, 5.153607902567806e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.871477203423743e+32, 5.153607902567806e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 369
# Generation with parameters (6.647827889565476e+32, 5.31826231165238e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.647827889565476e+32, 5.31826231165238e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 370
# Generation with parameters (6.44558364386215e+32, 5.478746097282827e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.44558364386215e+32, 5.478746097282827e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 371
# Generation with parameters (6.261587774333251e+32, 5.635428996899926e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.261587774333251e+32, 5.635428996899926e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 372
# Generation with parameters (6.093292375207363e+32, 5.7886277564469936e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.093292375207363e+32, 5.7886277564469936e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 373
# Generation with parameters (5.9386161835798686e+32, 5.938616183579867e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.9386161835798686e+32, 5.938616183579867e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 374
# Generation with parameters (1.4624732336850617e+33, 2.9249464673701235e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4624732336850617e+33, 2.9249464673701235e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 375
# Generation with parameters (1.2896969474512551e+33, 3.2242423686281377e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2896969474512551e+33, 3.2242423686281377e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 376
# Generation with parameters (1.1651600678462051e+33, 3.4954802035386145e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1651600678462051e+33, 3.4954802035386145e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 377
# Generation with parameters (1.0702755434582226e+33, 3.7459644021037786e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0702755434582226e+33, 3.7459644021037786e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 378
# Generation with parameters (9.950829542751457e+32, 3.980331817100583e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.950829542751457e+32, 3.980331817100583e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 379
# Generation with parameters (9.337180765068459e+32, 4.201731344280806e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.337180765068459e+32, 4.201731344280806e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 380
# Generation with parameters (8.824821379533083e+32, 4.412410689766542e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.824821379533083e+32, 4.412410689766542e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 381
# Generation with parameters (8.389158512934666e+32, 4.6140371821140655e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.389158512934666e+32, 4.6140371821140655e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 382
# Generation with parameters (8.013143511632645e+32, 4.8078861069795866e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.013143511632645e+32, 4.8078861069795866e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 383
# Generation with parameters (7.684550153438113e+32, 4.9949575997347726e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.684550153438113e+32, 4.9949575997347726e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 384
# Generation with parameters (7.394360750515307e+32, 5.176052525360714e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.394360750515307e+32, 5.176052525360714e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 385
# Generation with parameters (7.135764788170809e+32, 5.351823591128105e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.135764788170809e+32, 5.351823591128105e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 386
# Generation with parameters (6.903513577625688e+32, 5.52281086210055e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.903513577625688e+32, 5.52281086210055e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 387
# Generation with parameters (6.693490707087616e+32, 5.689467101024471e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.693490707087616e+32, 5.689467101024471e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 388
# Generation with parameters (6.502418073346069e+32, 5.8521762660114605e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.502418073346069e+32, 5.8521762660114605e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 389
# Generation with parameters (6.327649774253799e+32, 6.011267285541108e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.327649774253799e+32, 6.011267285541108e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 390
# Generation with parameters (6.167024498332939e+32, 6.1670244983329385e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.167024498332939e+32, 6.1670244983329385e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 391
# Generation with parameters (1.5166389090067305e+33, 3.033277818013461e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5166389090067305e+33, 3.033277818013461e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 392
# Generation with parameters (1.3374635010605608e+33, 3.343658752651402e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3374635010605608e+33, 3.343658752651402e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 393
# Generation with parameters (1.2083141444331016e+33, 3.624942433299305e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2083141444331016e+33, 3.624942433299305e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 394
# Generation with parameters (1.10991537840112e+33, 3.88470382440392e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.10991537840112e+33, 3.88470382440392e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 395
# Generation with parameters (1.0319378785075585e+33, 4.1277515140302336e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0319378785075585e+33, 4.1277515140302336e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 396
# Generation with parameters (9.683002274885811e+32, 4.357351023698614e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.683002274885811e+32, 4.357351023698614e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 397
# Generation with parameters (9.151666615812088e+32, 4.575833307906044e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.151666615812088e+32, 4.575833307906044e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 398
# Generation with parameters (8.6998680874878e+32, 4.784927448118289e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.6998680874878e+32, 4.784927448118289e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 399
# Generation with parameters (8.309926604656078e+32, 4.985955962793646e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.309926604656078e+32, 4.985955962793646e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 400
# Generation with parameters (7.969163122083969e+32, 5.17995602935458e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.969163122083969e+32, 5.17995602935458e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 401
# Generation with parameters (7.668225963497355e+32, 5.367758174448148e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.668225963497355e+32, 5.367758174448148e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 402
# Generation with parameters (7.400052372917876e+32, 5.550039279688405e+32, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# ...
# Warning: turning off multibanding for parameters (3.4236329471917684e+33, 1.5406348262362957e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1604
# Generation with parameters (3.2357678391621304e+33, 1.6178839195810652e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.2357678391621304e+33, 1.6178839195810652e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1605
# Generation with parameters (3.076024788076044e+33, 1.691813633441824e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.076024788076044e+33, 1.691813633441824e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1606
# Generation with parameters (2.9381526209319705e+33, 1.762891572559182e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.9381526209319705e+33, 1.762891572559182e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1607
# Generation with parameters (2.8176683895939746e+33, 1.8314844532360833e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.8176683895939746e+33, 1.8314844532360833e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1608
# Generation with parameters (2.711265608522279e+33, 1.8978859259655952e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.711265608522279e+33, 1.8978859259655952e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1609
# Generation with parameters (2.6164470889959634e+33, 1.9623353167469723e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.6164470889959634e+33, 1.9623353167469723e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1610
# Generation with parameters (2.5312883117960856e+33, 2.025030649436868e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5312883117960856e+33, 2.025030649436868e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1611
# Generation with parameters (2.454279925932126e+33, 2.0861379370423068e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.454279925932126e+33, 2.0861379370423068e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1612
# Generation with parameters (2.3842199602268918e+33, 2.1457979642042022e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3842199602268918e+33, 2.1457979642042022e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1613
# Generation with parameters (2.3201382505597268e+33, 2.2041313380317398e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3201382505597268e+33, 2.2041313380317398e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1614
# Generation with parameters (2.2612423160554113e+33, 2.2612423160554108e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2612423160554113e+33, 2.2612423160554108e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1615
# Generation with parameters (5.416567532166894e+33, 1.0833135064333788e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.416567532166894e+33, 1.0833135064333788e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1616
# Generation with parameters (4.7766553609305743e+33, 1.1941638402326436e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.7766553609305743e+33, 1.1941638402326436e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1617
# Generation with parameters (4.315407658689648e+33, 1.2946222976068944e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.315407658689648e+33, 1.2946222976068944e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1618
# Generation with parameters (3.963983494289714e+33, 1.3873942230013997e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.963983494289714e+33, 1.3873942230013997e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1619
# Generation with parameters (3.685492423241281e+33, 1.4741969692965122e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.685492423241281e+33, 1.4741969692965122e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1620
# Generation with parameters (3.458215098173504e+33, 1.5561967941780767e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.458215098173504e+33, 1.5561967941780767e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1621
# Generation with parameters (3.268452362790031e+33, 1.6342261813950153e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.268452362790031e+33, 1.6342261813950153e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1622
# Generation with parameters (3.107095745531357e+33, 1.7089026600422464e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.107095745531357e+33, 1.7089026600422464e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1623
# Generation with parameters (2.967830930234314e+33, 1.780698558140588e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.967830930234314e+33, 1.780698558140588e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1624
# Generation with parameters (2.846129686458561e+33, 1.8499842961980642e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.846129686458561e+33, 1.8499842961980642e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1625
# Generation with parameters (2.738652129820484e+33, 1.9170564908743384e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.738652129820484e+33, 1.9170564908743384e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1626
# Generation with parameters (2.642875847470671e+33, 1.9821568856030023e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.642875847470671e+33, 1.9821568856030023e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1627
# Generation with parameters (2.5568568806021067e+33, 2.0454855044816848e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5568568806021067e+33, 2.0454855044816848e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1628
# Generation with parameters (2.479070632254673e+33, 2.1072100374164714e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.479070632254673e+33, 2.1072100374164714e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1629
# Generation with parameters (2.4083029901281733e+33, 2.167472691115356e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.4083029901281733e+33, 2.167472691115356e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1630
# Generation with parameters (2.3435739904643703e+33, 2.226395290941151e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3435739904643703e+33, 2.226395290941151e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1631
# Generation with parameters (2.2840831475307183e+33, 2.284083147530718e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2840831475307183e+33, 2.284083147530718e+33, 0.0, 0.0, 0.3, 0.0, 0.0, 0.5, 3.085677581491367e+24, 2.3, 0.0, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.

# %%
import os
import pickle

from dingo.gw.inference.gw_samplers import GWSampler


os.makedirs("/scratch/tpausch/test_data/imbh_T8s/results", exist_ok=True)

injection_files = sorted(os.listdir("/scratch/tpausch/test_data/imbh_T8s/injections"))

for fname in injection_files:

    # --------------------------------------------------------
    # Load injection
    # --------------------------------------------------------

    with open(f"/scratch/tpausch/test_data/imbh_T8s/injections/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    strain_data = payload["strain_data"]

    # --------------------------------------------------------
    # Run sampler
    # --------------------------------------------------------

    sampler = GWSampler(model=main_pm)

    sampler.context = strain_data

    sampler.run_sampler(
        num_samples=50_000,
        batch_size=10_000,
    )

    result = sampler.to_result()

    # --------------------------------------------------------
    # Store result
    # --------------------------------------------------------

    result_payload = {
        "theta_true": theta_true,
        "result": result,
    }

    outname = fname.replace("inj_", "result_")

    with open(f"/scratch/tpausch/test_data/imbh_T8s/results/{outname}", "wb") as f:
        pickle.dump(result_payload, f)

    print(f"Saved /scratch/tpausch/test_data/imbh_T8s/results/{outname}")
# Out:
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0000.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0001.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0002.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0003.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0004.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0005.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0006.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0007.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0008.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0009.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0010.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0011.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0012.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0013.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0014.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0015.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0016.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0017.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0018.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0019.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0020.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0021.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0022.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0023.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0024.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0025.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0026.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0027.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0028.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0029.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0030.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0031.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0032.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0033.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0034.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0035.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0036.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0037.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0038.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0039.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0040.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0041.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0042.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0043.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0044.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0045.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0046.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0047.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0048.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0049.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0050.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0051.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0052.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0053.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0054.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0055.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0056.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0057.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0058.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0059.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0060.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0061.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0062.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0063.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0064.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0065.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0066.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0067.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0068.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0069.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0070.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0071.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0072.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0073.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0074.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0075.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0076.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0077.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0078.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0079.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0080.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0081.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_0082.pkl
# ...
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1604.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1605.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1606.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1607.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1608.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1609.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1610.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1611.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1612.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1613.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1614.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1615.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1616.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.1 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1617.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1618.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1619.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1620.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1621.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1622.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1623.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1624.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1625.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1626.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1627.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1628.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1629.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1630.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.2 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8s/results/result_1631.pkl

# %%
import os
import pickle
import numpy as np

true_cm = []
true_mr = []
mass_ratio_error = []
mass_ratio_std = []
chirp_mass_error = []
chirp_mass_std = []


result_files = sorted(os.listdir("/scratch/tpausch/test_data/imbh_T8s/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/imbh_T8s/results/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    result = payload["result"]

    posterior_samples = result.samples

    #q_samples = np.array(posterior_samples["mass_ratio"])

    # inference statistics
    #q_mean = np.mean(q_samples)
    #q_std = np.std(q_samples)
#
    #true_q = theta_true["mass_ratio"]

    cm_samples = np.array(posterior_samples["chirp_mass"])

    cm_mean = np.mean(cm_samples)
    cm_std = np.std(cm_samples)

    true_mr.append(theta_true["mass_ratio"])
    true_cm.append(theta_true["chirp_mass"])
    #mass_ratio_error.append(q_mean - true_q)
    #mass_ratio_std.append(q_std)
    chirp_mass_error.append(cm_mean - theta_true["chirp_mass"])
    chirp_mass_std.append(cm_std)

# %%
import matplotlib.pyplot as plt
import numpy as np

true_mr = np.array(true_mr)
true_cm = np.array(true_cm)

chirp_mass_error = np.array(chirp_mass_error)
chirp_mass_std = np.array(chirp_mass_std)

plt.figure(figsize=(8, 5))

# ------------------------------------------------------------
# Error bars
# ------------------------------------------------------------

plt.errorbar(
    true_cm,
    chirp_mass_error,
    yerr=chirp_mass_std,
    fmt="none",
    capsize=4,
    alpha=0.5,
    color="gray",
)

# ------------------------------------------------------------
# Colored scatter points
# ------------------------------------------------------------

sc = plt.scatter(
    true_cm,
    chirp_mass_error,
    c=true_mr,
    cmap="viridis",
    s=70,
    edgecolor="black",
)

# ------------------------------------------------------------
# Reference line
# ------------------------------------------------------------

plt.axhline(0, linestyle="--", color="black")

# ------------------------------------------------------------
# Colorbar
# ------------------------------------------------------------

cbar = plt.colorbar(sc)
cbar.set_label("True mass ratio")

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel("True chirp mass")
plt.ylabel("Chirp mass inference error (inferred − true)")

plt.title("Chirp-mass inference error")

plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

true_mr = np.array(true_mr)
chirp_mass_error = np.array(chirp_mass_error)
chirp_mass_std = np.array(chirp_mass_std)

plt.figure(figsize=(8, 5))

plt.errorbar(
    true_mr,
    chirp_mass_error,
    yerr=chirp_mass_std,
    fmt="o",
    capsize=4,
)

plt.axhline(0, linestyle="--")

plt.xlabel("True mass ratio")
plt.ylabel("Chirp mass inference error (inferred - true)")
plt.title("Chirp-mass inference error across all injections")

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

true_cm = np.array(true_cm)
mass_ratio_error = np.array(mass_ratio_error)
mass_ratio_std = np.array(mass_ratio_std)

plt.figure(figsize=(8, 5))

plt.errorbar(
    true_cm,
    mass_ratio_error,
    yerr=mass_ratio_std,
    fmt="o",
    capsize=4,
)

plt.axhline(0, linestyle="--")

plt.xlabel("True chirp mass")
plt.ylabel("Mass ratio inference error (inferred - true)")
plt.title("Mass-ratio inference error across all injections")

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

true_mr = np.array(true_mr)
true_cm = np.array(true_cm)



mass_ratio_error = np.array(mass_ratio_error)
mass_ratio_std = np.array(mass_ratio_std)


plt.figure(figsize=(8, 5))

# ------------------------------------------------------------
# Error bars
# ------------------------------------------------------------

plt.errorbar(
    true_cm,
    mass_ratio_error,
    yerr=mass_ratio_std,
    fmt="none",
    capsize=4,
    alpha=0.5,
    color="gray",
)

# ------------------------------------------------------------
# Colored scatter points
# ------------------------------------------------------------

sc = plt.scatter(
    true_cm,
    mass_ratio_error,
    c=true_mr,
    cmap="viridis",
    s=70,
    edgecolor="black",
)

# ------------------------------------------------------------
# Reference line
# ------------------------------------------------------------

plt.axhline(0, linestyle="--", color="black")

# ------------------------------------------------------------
# Colorbar
# ------------------------------------------------------------

cbar = plt.colorbar(sc)
cbar.set_label("True mass ratio")

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel("True chirp mass")
plt.ylabel("Mass ratio inference error (inferred − true)")

plt.title("Mass-ratio inference error")

plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

true_mr = np.array(true_mr)
mass_ratio_error = np.array(mass_ratio_error)
mass_ratio_std = np.array(mass_ratio_std)

plt.figure(figsize=(8, 5))

plt.errorbar(
    true_mr,
    mass_ratio_error,
    yerr=mass_ratio_std,
    fmt="o",
    capsize=4,
)

plt.axhline(0, linestyle="--")

plt.xlabel("True mass ratio")
plt.ylabel("Mass ratio inference error (inferred - true)")
plt.title("Mass-ratio inference error across all injections")

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
pp_values_chirp_mass = []
pp_values_mass_ratio = []

result_files = sorted(os.listdir("/scratch/tpausch/test_data/imbh_T2/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/imbh_T2/results/{fname}", "rb") as f:

        payload = pickle.load(f)

        theta_true = payload["theta_true"]
        result = payload["result"]

        posterior_samples = result.samples


        # ============================================================
        # Chirp mass PP value
        # ============================================================

        cm_samples = posterior_samples["chirp_mass"]

        pp_cm = np.mean(
            cm_samples < theta_true["chirp_mass"]
        )

        pp_values_chirp_mass.append(pp_cm)


        # ============================================================
        # Mass ratio PP value
        # ============================================================

        q_samples = posterior_samples["mass_ratio"]

        pp_q = np.mean(
            q_samples < theta_true["mass_ratio"]
        )

        pp_values_mass_ratio.append(pp_q)

# %%
import matplotlib.pyplot as plt


def plot_pp(pp_values, label):

    pp_values = np.array(pp_values)

    sorted_pp = np.sort(pp_values)

    n = len(sorted_pp)

    empirical_cdf = np.arange(1, n + 1) / n

    x = np.linspace(0, 1, 200)

    sigma = np.sqrt(x * (1 - x) / n)

    plt.figure(figsize=(6, 6))

    # Ideal calibration
    plt.plot(
        [0, 1],
        [0, 1],
        linestyle="--",
        label="Ideal calibration",
    )


    # Empirical PP curve
    plt.plot(
        sorted_pp,
        empirical_cdf,
        marker="o",
        label=label,
    )

    plt.xlabel("Credible level")
    plt.ylabel("Fraction of injections")

    plt.title(f"PP Plot: {label}")

    plt.xlim(0, 1)
    plt.ylim(0, 1)

    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
plot_pp(
    pp_values_chirp_mass,
    "chirp_mass",
)

plot_pp(
    pp_values_mass_ratio,
    "mass_ratio",
)
