# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # use GPU 1

from dingo.core.posterior_models.build_model import build_model_from_kwargs

main_pm = build_model_from_kwargs(
    filename="/scratch/tpausch/models/imbh_T8_mass2/model_100.pt",
    device="cuda",
    load_training_info=False,
)
# Out:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Putting posterior model to device cuda.

# %%
import os
import pickle
import numpy as np

import dingo.gw.injection as injection
from dingo.gw.noise.asd_dataset import ASDDataset

# ============================================================
# Setup
# ============================================================

num_injections = 1000
out_dir = "/scratch/tpausch/test_data/imbh_T8_mass2/injections"
os.makedirs(out_dir, exist_ok=True)

np.random.seed(42)  # optional, for reproducibility

injection_generator = injection.Injection.from_posterior_model_metadata(
    main_pm.metadata
)

asd_fname = main_pm.metadata["train_settings"]["training"]["stage_0"]["asd_dataset_path"]
asd_dataset = ASDDataset(file_name=asd_fname)

injection_generator.asd = {
    k: v[0] for k, v in asd_dataset.asds.items()
}

# This is the combined intrinsic + extrinsic bilby PriorDict
# that the network was trained on
prior = injection_generator.prior
print(prior)

# ============================================================
# Draw and run injections
# ============================================================

for idx in range(num_injections):

    print(f"Running injection {idx}")

    theta = prior.sample()
    theta = {k: float(v) for k, v in theta.items()}  # cast numpy -> float

    strain_data = injection_generator.injection(theta)

    payload = {
        "theta_true": theta,
        "strain_data": strain_data,
    }

    fname = os.path.join(out_dir, f"inj_{idx:04d}.pkl")

    with open(fname, "wb") as f:
        pickle.dump(payload, f)
# Out:
# Setting spin_conversion_phase = 0.0. Using this value for the phase parameter for conversion to cartesian spins.
# Loading dataset from training_data/asds_ET_T8.hdf5.
# {'mass_1': Constraint(minimum=30.0, maximum=3000.0, name='mass_1', latex_label='$m_1$', unit=None), 'mass_2': Constraint(minimum=30.0, maximum=3000.0, name='mass_2', latex_label='$m_2$', unit=None), 'chirp_mass': bilby.gw.prior.UniformInComponentsChirpMass(minimum=50.0, maximum=1000.0, name='chirp_mass', latex_label='$\\mathcal{M}$', unit=None, boundary=None), 'mass_ratio': bilby.gw.prior.UniformInComponentsMassRatio(minimum=0.125, maximum=1.0, name='mass_ratio', latex_label='$q$', unit=None, boundary=None, equal_mass=False), 'phase': Uniform(minimum=0.0, maximum=6.283185307179586, name='phase', latex_label='$\\phi$', unit=None, boundary='periodic'), 'chi_1': bilby.gw.prior.AlignedSpin(a_prior=Uniform(minimum=0, maximum=0.9, name=None, latex_label=None, unit=None, boundary=None), z_prior=Uniform(minimum=-1, maximum=1, name=None, latex_label=None, unit=None, boundary=None), name='chi_1', latex_label='$\\chi_1$', unit=None, boundary=None, minimum=-0.9, maximum=0.9, num_interp=100000), 'chi_2': bilby.gw.prior.AlignedSpin(a_prior=Uniform(minimum=0, maximum=0.9, name=None, latex_label=None, unit=None, boundary=None), z_prior=Uniform(minimum=-1, maximum=1, name=None, latex_label=None, unit=None, boundary=None), name='chi_2', latex_label='$\\chi_2$', unit=None, boundary=None, minimum=-0.9, maximum=0.9, num_interp=100000), 'theta_jn': Sine(minimum=0.0, maximum=3.141592653589793, name='theta_jn', latex_label='$\\theta_{JN}$', unit=None, boundary=None), 'luminosity_distance': LogUniform(minimum=1000.0, maximum=1000000.0, name='luminosity_distance', latex_label='$d_L$', unit=None, boundary=None), 'geocent_time': Uniform(minimum=-0.1, maximum=0.1, name='geocent_time', latex_label='$t_c$', unit=None, boundary=None), 'dec': Cosine(minimum=-1.5707963267948966, maximum=1.5707963267948966, name='dec', latex_label='$\\mathrm{DEC}$', unit=None, boundary=None), 'ra': Uniform(minimum=0.0, maximum=6.283185307179586, name='ra', latex_label='$\\mathrm{RA}$', unit=None, boundary='periodic'), 'psi': Uniform(minimum=0.0, maximum=3.141592653589793, name='psi', latex_label='$\\psi$', unit=None, boundary='periodic')}
# Running injection 0
# Generation with parameters (2.39983046563619e+33, 2.047240075091207e+33, 0.0, 0.0, 0.10802355342509273, 0.0, 0.0, 0.3133252950058395, 3.085677581491367e+24, 2.5286537681941437, 3.886002353903007, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.39983046563619e+33, 2.047240075091207e+33, 0.0, 0.0, 0.10802355342509273, 0.0, 0.0, 0.3133252950058395, 3.085677581491367e+24, 2.5286537681941437, 3.886002353903007, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1
# Generation with parameters (1.3820170105335463e+33, 5.9770676155753415e+32, 0.0, 0.0, -0.3025530384112153, 0.0, 0.0, -0.3721351533256977, 3.085677581491367e+24, 2.686821306347936, 4.72811229480255, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3820170105335463e+33, 5.9770676155753415e+32, 0.0, 0.0, -0.3025530384112153, 0.0, 0.0, -0.3721351533256977, 3.085677581491367e+24, 2.686821306347936, 4.72811229480255, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 2
# Generation with parameters (1.656621956802301e+33, 1.4280683879178718e+33, 0.0, 0.0, 0.03883133817567139, 0.0, 0.0, 0.15871030361867436, 3.085677581491367e+24, 2.28568425365797, 3.2040594826445945, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.656621956802301e+33, 1.4280683879178718e+33, 0.0, 0.0, 0.03883133817567139, 0.0, 0.0, 0.15871030361867436, 3.085677581491367e+24, 2.28568425365797, 3.2040594826445945, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 3
# Generation with parameters (3.1904724893944015e+33, 8.201640896113562e+32, 0.0, 0.0, 0.4527564435161082, 0.0, 0.0, -0.11979648498371984, 3.085677581491367e+24, 2.0462068704057943, 5.076969345330681, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.1904724893944015e+33, 8.201640896113562e+32, 0.0, 0.0, 0.4527564435161082, 0.0, 0.0, -0.11979648498371984, 3.085677581491367e+24, 2.0462068704057943, 5.076969345330681, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 4
# Generation with parameters (2.6950327286361476e+33, 9.070941797633597e+32, 0.0, 0.0, 0.054175912774889076, 0.0, 0.0, -0.4369127374052541, 3.085677581491367e+24, 1.9924684905926104, 4.257143693651343, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.6950327286361476e+33, 9.070941797633597e+32, 0.0, 0.0, 0.054175912774889076, 0.0, 0.0, -0.4369127374052541, 3.085677581491367e+24, 1.9924684905926104, 4.257143693651343, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 5
# Generation with parameters (4.076824448569452e+33, 8.6540962718945e+32, 0.0, 0.0, -0.1408388170055695, 0.0, 0.0, 0.5329278033514931, 3.085677581491367e+24, 1.9517087275671259, 0.7710798998512985, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.076824448569452e+33, 8.6540962718945e+32, 0.0, 0.0, -0.1408388170055695, 0.0, 0.0, 0.5329278033514931, 3.085677581491367e+24, 1.9517087275671259, 0.7710798998512985, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 6
# Generation with parameters (2.8642246915962505e+33, 4.38491593373152e+32, 0.0, 0.0, -0.017865466929993162, 0.0, 0.0, -0.03276392251404329, 3.085677581491367e+24, 1.1504153609630035, 1.2041105743447609, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.8642246915962505e+33, 4.38491593373152e+32, 0.0, 0.0, -0.017865466929993162, 0.0, 0.0, -0.03276392251404329, 3.085677581491367e+24, 1.1504153609630035, 1.2041105743447609, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 7
# Generation with parameters (1.7352391549462306e+33, 6.761341019032831e+32, 0.0, 0.0, -0.012835872029881354, 0.0, 0.0, 0.7257738039848967, 3.085677581491367e+24, 2.0585209071620274, 4.18923128697267, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7352391549462306e+33, 6.761341019032831e+32, 0.0, 0.0, -0.012835872029881354, 0.0, 0.0, 0.7257738039848967, 3.085677581491367e+24, 2.0585209071620274, 4.18923128697267, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 8
# Generation with parameters (2.5529326211899697e+33, 3.669070924211819e+32, 0.0, 0.0, -0.4095892387825662, 0.0, 0.0, 0.2426623470009595, 3.085677581491367e+24, 1.016937092094664, 1.3811772658839137, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5529326211899697e+33, 3.669070924211819e+32, 0.0, 0.0, -0.4095892387825662, 0.0, 0.0, 0.2426623470009595, 3.085677581491367e+24, 1.016937092094664, 1.3811772658839137, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 9
# Generation with parameters (2.5287957682619767e+33, 8.06432471536959e+32, 0.0, 0.0, -0.50469886038978, 0.0, 0.0, -0.5060146315833168, 3.085677581491367e+24, 0.48510051555375644, 0.9895982565491613, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5287957682619767e+33, 8.06432471536959e+32, 0.0, 0.0, -0.50469886038978, 0.0, 0.0, -0.5060146315833168, 3.085677581491367e+24, 0.48510051555375644, 0.9895982565491613, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 10
# Generation with parameters (2.4342481289778416e+33, 7.67797854594765e+32, 0.0, 0.0, 0.20316505739033963, 0.0, 0.0, 0.144238250269668, 3.085677581491367e+24, 2.2222988097686076, 4.150596120665958, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.4342481289778416e+33, 7.67797854594765e+32, 0.0, 0.0, 0.20316505739033963, 0.0, 0.0, 0.144238250269668, 3.085677581491367e+24, 2.2222988097686076, 4.150596120665958, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 11
# Generation with parameters (2.336009906050905e+33, 1.95020637016623e+33, 0.0, 0.0, -0.018525566382627985, 0.0, 0.0, -0.2317245308606957, 3.085677581491367e+24, 2.1924694298486327, 0.2838741959255479, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.336009906050905e+33, 1.95020637016623e+33, 0.0, 0.0, -0.018525566382627985, 0.0, 0.0, -0.2317245308606957, 3.085677581491367e+24, 2.1924694298486327, 0.2838741959255479, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 12
# Generation with parameters (1.7537350406704035e+33, 6.06403591581568e+32, 0.0, 0.0, -0.23604902484601276, 0.0, 0.0, -0.11307276931546895, 3.085677581491367e+24, 2.0736017237305, 5.441741825671834, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7537350406704035e+33, 6.06403591581568e+32, 0.0, 0.0, -0.23604902484601276, 0.0, 0.0, -0.11307276931546895, 3.085677581491367e+24, 2.0736017237305, 5.441741825671834, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 13
# Generation with parameters (4.273516294890806e+33, 1.0916480471530194e+33, 0.0, 0.0, 0.2021242599222383, 0.0, 0.0, 0.043794074743604215, 3.085677581491367e+24, 0.4685642306947896, 3.906483480534326, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.273516294890806e+33, 1.0916480471530194e+33, 0.0, 0.0, 0.2021242599222383, 0.0, 0.0, 0.043794074743604215, 3.085677581491367e+24, 0.4685642306947896, 3.906483480534326, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 14
# Generation with parameters (3.208888223787219e+33, 9.180289191843771e+32, 0.0, 0.0, 0.4834900764171804, 0.0, 0.0, 0.27282974551464895, 3.085677581491367e+24, 1.5952855792885574, 3.9061664220772228, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.208888223787219e+33, 9.180289191843771e+32, 0.0, 0.0, 0.4834900764171804, 0.0, 0.0, 0.27282974551464895, 3.085677581491367e+24, 1.5952855792885574, 3.9061664220772228, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 15
# Generation with parameters (2.767520255124595e+33, 4.5541980864172405e+32, 0.0, 0.0, 0.2961364907550823, 0.0, 0.0, 0.2825425830338544, 3.085677581491367e+24, 0.9244082373074205, 1.368393342045095, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.767520255124595e+33, 4.5541980864172405e+32, 0.0, 0.0, 0.2961364907550823, 0.0, 0.0, 0.2825425830338544, 3.085677581491367e+24, 0.9244082373074205, 1.368393342045095, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 16
# Running injection 17
# Running injection 18
# Generation with parameters (2.5425807207873884e+33, 1.6291613415048578e+33, 0.0, 0.0, 0.007612212646169847, 0.0, 0.0, 0.0011110716242886784, 3.085677581491367e+24, 0.5746247353619023, 2.259592331711494, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5425807207873884e+33, 1.6291613415048578e+33, 0.0, 0.0, 0.007612212646169847, 0.0, 0.0, 0.0011110716242886784, 3.085677581491367e+24, 0.5746247353619023, 2.259592331711494, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 19
# Generation with parameters (2.943203111969585e+33, 1.2808040825570673e+33, 0.0, 0.0, 0.40832198827290855, 0.0, 0.0, 0.16121951900656117, 3.085677581491367e+24, 1.9537909464720415, 1.761293694928951, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.943203111969585e+33, 1.2808040825570673e+33, 0.0, 0.0, 0.40832198827290855, 0.0, 0.0, 0.16121951900656117, 3.085677581491367e+24, 1.9537909464720415, 1.761293694928951, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 20
# Generation with parameters (5.388293388000078e+33, 8.634015065875804e+32, 0.0, 0.0, 0.35554704726200764, 0.0, 0.0, 0.050785397566833215, 3.085677581491367e+24, 0.6876254263201487, 4.088142259678322, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.388293388000078e+33, 8.634015065875804e+32, 0.0, 0.0, 0.35554704726200764, 0.0, 0.0, 0.050785397566833215, 3.085677581491367e+24, 0.6876254263201487, 4.088142259678322, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 21
# Generation with parameters (4.2796087813903964e+33, 8.100510919662717e+32, 0.0, 0.0, -0.06560933198900007, 0.0, 0.0, -0.09718042764699125, 3.085677581491367e+24, 1.4464338638037542, 5.1392355197943305, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.2796087813903964e+33, 8.100510919662717e+32, 0.0, 0.0, -0.06560933198900007, 0.0, 0.0, -0.09718042764699125, 3.085677581491367e+24, 1.4464338638037542, 5.1392355197943305, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 22
# Generation with parameters (4.054647973566598e+33, 1.2184928326714835e+33, 0.0, 0.0, -0.01251776727368222, 0.0, 0.0, -0.25854461563974795, 3.085677581491367e+24, 1.2163706433081585, 4.035030474449278, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.054647973566598e+33, 1.2184928326714835e+33, 0.0, 0.0, -0.01251776727368222, 0.0, 0.0, -0.25854461563974795, 3.085677581491367e+24, 1.2163706433081585, 4.035030474449278, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 23
# Generation with parameters (1.2106188988064302e+33, 7.933626980405782e+32, 0.0, 0.0, 0.8760185568930804, 0.0, 0.0, -0.5828253518854754, 3.085677581491367e+24, 0.6343394351841624, 4.796679779201603, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2106188988064302e+33, 7.933626980405782e+32, 0.0, 0.0, 0.8760185568930804, 0.0, 0.0, -0.5828253518854754, 3.085677581491367e+24, 0.6343394351841624, 4.796679779201603, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 24
# Generation with parameters (4.1145809100908035e+33, 7.588163057407943e+32, 0.0, 0.0, -0.13887881510226313, 0.0, 0.0, -0.09868348813194623, 3.085677581491367e+24, 1.7282658624542009, 5.042241955576262, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.1145809100908035e+33, 7.588163057407943e+32, 0.0, 0.0, -0.13887881510226313, 0.0, 0.0, -0.09868348813194623, 3.085677581491367e+24, 1.7282658624542009, 5.042241955576262, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 25
# Generation with parameters (2.2696791333994707e+33, 1.471169346565523e+33, 0.0, 0.0, -0.49866461670150164, 0.0, 0.0, 0.15038802479608693, 3.085677581491367e+24, 0.7732061440027117, 2.2597332158504204, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2696791333994707e+33, 1.471169346565523e+33, 0.0, 0.0, -0.49866461670150164, 0.0, 0.0, 0.15038802479608693, 3.085677581491367e+24, 0.7732061440027117, 2.2597332158504204, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 26
# Generation with parameters (4.942620756921331e+33, 8.64172204980865e+32, 0.0, 0.0, 0.6440984693855837, 0.0, 0.0, -0.1778428512253204, 3.085677581491367e+24, 1.4671596787934675, 3.270350330970799, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.942620756921331e+33, 8.64172204980865e+32, 0.0, 0.0, 0.6440984693855837, 0.0, 0.0, -0.1778428512253204, 3.085677581491367e+24, 1.4671596787934675, 3.270350330970799, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 27
# Generation with parameters (4.9773653635361234e+33, 8.075155036976027e+32, 0.0, 0.0, -0.16235643575757708, 0.0, 0.0, 0.055129683243992936, 3.085677581491367e+24, 1.7686243705885667, 1.3687572526315337, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.9773653635361234e+33, 8.075155036976027e+32, 0.0, 0.0, -0.16235643575757708, 0.0, 0.0, 0.055129683243992936, 3.085677581491367e+24, 1.7686243705885667, 1.3687572526315337, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 28
# Generation with parameters (4.332169667823352e+33, 1.0823080725045416e+33, 0.0, 0.0, 0.019426794573603422, 0.0, 0.0, 0.1514100400862589, 3.085677581491367e+24, 0.9826542119978312, 5.151900583157911, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.332169667823352e+33, 1.0823080725045416e+33, 0.0, 0.0, 0.019426794573603422, 0.0, 0.0, 0.1514100400862589, 3.085677581491367e+24, 0.9826542119978312, 5.151900583157911, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 29
# Generation with parameters (4.685812446861175e+33, 9.79441937340526e+32, 0.0, 0.0, -0.1370368004299374, 0.0, 0.0, -0.4717037631188766, 3.085677581491367e+24, 1.4229588480291477, 4.755271842635234, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.685812446861175e+33, 9.79441937340526e+32, 0.0, 0.0, -0.1370368004299374, 0.0, 0.0, -0.4717037631188766, 3.085677581491367e+24, 1.4229588480291477, 4.755271842635234, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 30
# Generation with parameters (3.6616428007639145e+33, 1.475973091455105e+33, 0.0, 0.0, 0.04221428851588274, 0.0, 0.0, 0.1844634940920034, 3.085677581491367e+24, 2.294934095113035, 5.98210885917868, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.6616428007639145e+33, 1.475973091455105e+33, 0.0, 0.0, 0.04221428851588274, 0.0, 0.0, 0.1844634940920034, 3.085677581491367e+24, 2.294934095113035, 5.98210885917868, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 31
# Generation with parameters (1.402012766390229e+33, 8.010199826145914e+32, 0.0, 0.0, -0.2616194353639884, 0.0, 0.0, 0.12801653887605471, 3.085677581491367e+24, 1.5352923404323098, 6.105571013069136, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.402012766390229e+33, 8.010199826145914e+32, 0.0, 0.0, -0.2616194353639884, 0.0, 0.0, 0.12801653887605471, 3.085677581491367e+24, 1.5352923404323098, 6.105571013069136, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 32
# Generation with parameters (2.2972319667779342e+33, 7.194181522457339e+32, 0.0, 0.0, 0.061753878295601604, 0.0, 0.0, -0.00546569447613566, 3.085677581491367e+24, 1.5161481813284834, 0.8598430172888597, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2972319667779342e+33, 7.194181522457339e+32, 0.0, 0.0, 0.061753878295601604, 0.0, 0.0, -0.00546569447613566, 3.085677581491367e+24, 1.5161481813284834, 0.8598430172888597, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 33
# Generation with parameters (5.539248472413551e+33, 8.711425784486261e+32, 0.0, 0.0, 0.09813813006621747, 0.0, 0.0, 0.17348746788767577, 3.085677581491367e+24, 2.3323478671835267, 1.7433922010744496, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.539248472413551e+33, 8.711425784486261e+32, 0.0, 0.0, 0.09813813006621747, 0.0, 0.0, 0.17348746788767577, 3.085677581491367e+24, 2.3323478671835267, 1.7433922010744496, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 34
# Generation with parameters (3.096025781342237e+33, 4.0729514330390696e+32, 0.0, 0.0, -0.24050984989964422, 0.0, 0.0, 0.20866835301878364, 3.085677581491367e+24, 0.8505001682317253, 1.3996930273784944, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.096025781342237e+33, 4.0729514330390696e+32, 0.0, 0.0, -0.24050984989964422, 0.0, 0.0, 0.20866835301878364, 3.085677581491367e+24, 0.8505001682317253, 1.3996930273784944, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 35
# Generation with parameters (1.174097311770227e+33, 3.2528432696543146e+32, 0.0, 0.0, 0.44565832784019255, 0.0, 0.0, -0.542618571440564, 3.085677581491367e+24, 2.7402804257923536, 1.3755130354873861, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.174097311770227e+33, 3.2528432696543146e+32, 0.0, 0.0, 0.44565832784019255, 0.0, 0.0, -0.542618571440564, 3.085677581491367e+24, 2.7402804257923536, 1.3755130354873861, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 36
# Generation with parameters (2.7337566635056715e+33, 1.099070807081252e+33, 0.0, 0.0, 0.35235069098429456, 0.0, 0.0, -0.21762458170249105, 3.085677581491367e+24, 2.1316773701368623, 3.772669381937003, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.7337566635056715e+33, 1.099070807081252e+33, 0.0, 0.0, 0.35235069098429456, 0.0, 0.0, -0.21762458170249105, 3.085677581491367e+24, 2.1316773701368623, 3.772669381937003, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 37
# Generation with parameters (2.7748082809404926e+33, 3.5575350784017656e+32, 0.0, 0.0, -0.5027036534464111, 0.0, 0.0, 0.2711528309823937, 3.085677581491367e+24, 1.3883770454108846, 3.1638910799092756, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.7748082809404926e+33, 3.5575350784017656e+32, 0.0, 0.0, -0.5027036534464111, 0.0, 0.0, 0.2711528309823937, 3.085677581491367e+24, 1.3883770454108846, 3.1638910799092756, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 38
# Generation with parameters (3.845224586462452e+33, 7.690033633848454e+32, 0.0, 0.0, 0.17931966441579908, 0.0, 0.0, 0.41737538840473176, 3.085677581491367e+24, 0.8772858169575157, 1.2527311289838283, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.845224586462452e+33, 7.690033633848454e+32, 0.0, 0.0, 0.17931966441579908, 0.0, 0.0, 0.41737538840473176, 3.085677581491367e+24, 0.8772858169575157, 1.2527311289838283, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 39
# Generation with parameters (5.1887388846627495e+33, 1.1104907644466248e+33, 0.0, 0.0, 0.7161961010678198, 0.0, 0.0, -0.7741879099116709, 3.085677581491367e+24, 2.1115843244121066, 2.437343816011575, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.1887388846627495e+33, 1.1104907644466248e+33, 0.0, 0.0, 0.7161961010678198, 0.0, 0.0, -0.7741879099116709, 3.085677581491367e+24, 2.1115843244121066, 2.437343816011575, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 40
# Generation with parameters (2.172684801501039e+33, 3.401440605527371e+32, 0.0, 0.0, 0.25194034104761553, 0.0, 0.0, 0.10048228815857972, 3.085677581491367e+24, 1.1203248618245927, 5.781315404401211, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.172684801501039e+33, 3.401440605527371e+32, 0.0, 0.0, 0.25194034104761553, 0.0, 0.0, 0.10048228815857972, 3.085677581491367e+24, 1.1203248618245927, 5.781315404401211, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 41
# Generation with parameters (1.5229518128219095e+33, 7.107740313931084e+32, 0.0, 0.0, -0.2023505424643293, 0.0, 0.0, 0.23206171372081102, 3.085677581491367e+24, 1.585105820794226, 5.649705412244267, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5229518128219095e+33, 7.107740313931084e+32, 0.0, 0.0, -0.2023505424643293, 0.0, 0.0, 0.23206171372081102, 3.085677581491367e+24, 1.585105820794226, 5.649705412244267, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 42
# Generation with parameters (1.4625548098754757e+33, 3.942281893179218e+32, 0.0, 0.0, 0.05882798514617301, 0.0, 0.0, 0.020582889175985216, 3.085677581491367e+24, 1.4541354186590654, 3.1866933493719336, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4625548098754757e+33, 3.942281893179218e+32, 0.0, 0.0, 0.05882798514617301, 0.0, 0.0, 0.020582889175985216, 3.085677581491367e+24, 1.4541354186590654, 3.1866933493719336, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 43
# Generation with parameters (2.3565555537056797e+33, 1.9331694965351456e+33, 0.0, 0.0, 0.1524481977951307, 0.0, 0.0, 0.47012059651982185, 3.085677581491367e+24, 1.1320925527991146, 6.024692329333931, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3565555537056797e+33, 1.9331694965351456e+33, 0.0, 0.0, 0.1524481977951307, 0.0, 0.0, 0.47012059651982185, 3.085677581491367e+24, 1.1320925527991146, 6.024692329333931, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 44
# Generation with parameters (1.9963610054009037e+33, 1.1355185146670798e+33, 0.0, 0.0, -0.024925319647790593, 0.0, 0.0, 0.0037054545951649143, 3.085677581491367e+24, 0.9090993100574046, 0.479220069954169, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.9963610054009037e+33, 1.1355185146670798e+33, 0.0, 0.0, -0.024925319647790593, 0.0, 0.0, 0.0037054545951649143, 3.085677581491367e+24, 0.9090993100574046, 0.479220069954169, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 45
# Generation with parameters (2.1952251286678743e+33, 9.012362659796512e+32, 0.0, 0.0, 0.16949304884204508, 0.0, 0.0, 0.010515055240485764, 3.085677581491367e+24, 1.9846497059286043, 2.4888031344291113, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.1952251286678743e+33, 9.012362659796512e+32, 0.0, 0.0, 0.16949304884204508, 0.0, 0.0, 0.010515055240485764, 3.085677581491367e+24, 1.9846497059286043, 2.4888031344291113, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 46
# Generation with parameters (2.4460586192063932e+33, 1.1542369942286203e+33, 0.0, 0.0, 0.2995916810824634, 0.0, 0.0, 0.10301759548217894, 3.085677581491367e+24, 2.759851122412791, 5.154173274920045, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.4460586192063932e+33, 1.1542369942286203e+33, 0.0, 0.0, 0.2995916810824634, 0.0, 0.0, 0.10301759548217894, 3.085677581491367e+24, 2.759851122412791, 5.154173274920045, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 47
# Generation with parameters (3.6331574681615236e+33, 1.0591551327907818e+33, 0.0, 0.0, -0.4433335510218972, 0.0, 0.0, 0.3093293086736938, 3.085677581491367e+24, 2.321484788244737, 5.067382192073094, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.6331574681615236e+33, 1.0591551327907818e+33, 0.0, 0.0, -0.4433335510218972, 0.0, 0.0, 0.3093293086736938, 3.085677581491367e+24, 2.321484788244737, 5.067382192073094, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 48
# Generation with parameters (1.8423211048451098e+33, 1.3667885312527573e+33, 0.0, 0.0, 0.023776438781841592, 0.0, 0.0, -0.01648268163997308, 3.085677581491367e+24, 1.35672272301438, 0.30527578829668456, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8423211048451098e+33, 1.3667885312527573e+33, 0.0, 0.0, 0.023776438781841592, 0.0, 0.0, -0.01648268163997308, 3.085677581491367e+24, 1.35672272301438, 0.30527578829668456, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 49
# Running injection 50
# Generation with parameters (4.4817314866946456e+33, 7.014389932353147e+32, 0.0, 0.0, -0.33046114808920435, 0.0, 0.0, 0.022098570063649615, 3.085677581491367e+24, 1.34093644445988, 3.257937786828447, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.4817314866946456e+33, 7.014389932353147e+32, 0.0, 0.0, -0.33046114808920435, 0.0, 0.0, 0.022098570063649615, 3.085677581491367e+24, 1.34093644445988, 3.257937786828447, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 51
# Generation with parameters (1.7028820658925107e+33, 7.934874461662961e+32, 0.0, 0.0, -0.1137708073885068, 0.0, 0.0, 0.11477007527984466, 3.085677581491367e+24, 0.814300937718836, 5.688374324346332, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7028820658925107e+33, 7.934874461662961e+32, 0.0, 0.0, -0.1137708073885068, 0.0, 0.0, 0.11477007527984466, 3.085677581491367e+24, 0.814300937718836, 5.688374324346332, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 52
# Generation with parameters (2.5265365469027792e+33, 1.8794931351913268e+33, 0.0, 0.0, -0.35757934092339255, 0.0, 0.0, -0.0026471852239244964, 3.085677581491367e+24, 2.177716047619804, 5.741725474870662, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5265365469027792e+33, 1.8794931351913268e+33, 0.0, 0.0, -0.35757934092339255, 0.0, 0.0, -0.0026471852239244964, 3.085677581491367e+24, 2.177716047619804, 5.741725474870662, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 53
# Generation with parameters (1.5078970443460618e+33, 1.2317231771922858e+33, 0.0, 0.0, 0.29263247157900407, 0.0, 0.0, 0.11060820186882546, 3.085677581491367e+24, 0.42400358631522095, 6.250725967143834, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5078970443460618e+33, 1.2317231771922858e+33, 0.0, 0.0, 0.29263247157900407, 0.0, 0.0, 0.11060820186882546, 3.085677581491367e+24, 0.42400358631522095, 6.250725967143834, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 54
# Generation with parameters (2.0228575553339228e+33, 3.7941517333841886e+32, 0.0, 0.0, -0.12881397660847702, 0.0, 0.0, 0.04152607161897593, 3.085677581491367e+24, 2.588644107853528, 1.8882045615554228, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0228575553339228e+33, 3.7941517333841886e+32, 0.0, 0.0, -0.12881397660847702, 0.0, 0.0, 0.04152607161897593, 3.085677581491367e+24, 2.588644107853528, 1.8882045615554228, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 55
# Generation with parameters (2.306914090539714e+33, 7.305404191927715e+32, 0.0, 0.0, -0.5295590710310218, 0.0, 0.0, -0.35656539349906724, 3.085677581491367e+24, 1.5810506256147303, 0.6013522153494675, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.306914090539714e+33, 7.305404191927715e+32, 0.0, 0.0, -0.5295590710310218, 0.0, 0.0, -0.35656539349906724, 3.085677581491367e+24, 1.5810506256147303, 0.6013522153494675, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 56
# Generation with parameters (1.8311246258038576e+33, 1.549227467353101e+33, 0.0, 0.0, -0.008780094927983725, 0.0, 0.0, -0.47895873962746727, 3.085677581491367e+24, 0.8278623303190806, 1.896106252302734, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8311246258038576e+33, 1.549227467353101e+33, 0.0, 0.0, -0.008780094927983725, 0.0, 0.0, -0.47895873962746727, 3.085677581491367e+24, 0.8278623303190806, 1.896106252302734, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 57
# Generation with parameters (3.696952263094644e+33, 7.321159053215293e+32, 0.0, 0.0, 0.7401513296852743, 0.0, 0.0, 0.19283406367939923, 3.085677581491367e+24, 0.9068045788321007, 3.9741957428547057, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.696952263094644e+33, 7.321159053215293e+32, 0.0, 0.0, 0.7401513296852743, 0.0, 0.0, 0.19283406367939923, 3.085677581491367e+24, 0.9068045788321007, 3.9741957428547057, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 58
# Generation with parameters (2.998129511978485e+33, 1.6858190612709308e+33, 0.0, 0.0, -0.6467212389701095, 0.0, 0.0, -0.14865726660024045, 3.085677581491367e+24, 2.06098536401203, 4.93736937707159, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.998129511978485e+33, 1.6858190612709308e+33, 0.0, 0.0, -0.6467212389701095, 0.0, 0.0, -0.14865726660024045, 3.085677581491367e+24, 2.06098536401203, 4.93736937707159, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 59
# Generation with parameters (3.5133303898206796e+33, 8.438543957076688e+32, 0.0, 0.0, 0.02810984790488482, 0.0, 0.0, 0.13112097090815186, 3.085677581491367e+24, 3.072235101486921, 3.754604456791214, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.5133303898206796e+33, 8.438543957076688e+32, 0.0, 0.0, 0.02810984790488482, 0.0, 0.0, 0.13112097090815186, 3.085677581491367e+24, 3.072235101486921, 3.754604456791214, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 60
# Generation with parameters (3.720011339897084e+33, 1.0463886394979376e+33, 0.0, 0.0, -0.5732068423676281, 0.0, 0.0, -0.5004395453031344, 3.085677581491367e+24, 0.8897080199655735, 6.225071366292807, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.720011339897084e+33, 1.0463886394979376e+33, 0.0, 0.0, -0.5732068423676281, 0.0, 0.0, -0.5004395453031344, 3.085677581491367e+24, 0.8897080199655735, 6.225071366292807, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 61
# Generation with parameters (1.4416786600156455e+33, 1.2507120732440616e+33, 0.0, 0.0, -0.0030091521304805055, 0.0, 0.0, -0.5918356934276241, 3.085677581491367e+24, 2.0054238422829083, 1.8737965583960061, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4416786600156455e+33, 1.2507120732440616e+33, 0.0, 0.0, -0.0030091521304805055, 0.0, 0.0, -0.5918356934276241, 3.085677581491367e+24, 2.0054238422829083, 1.8737965583960061, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 62
# Generation with parameters (2.3835700826678868e+33, 5.346198723182914e+32, 0.0, 0.0, -0.07823274819226517, 0.0, 0.0, -0.4583355155431211, 3.085677581491367e+24, 1.0578374841366343, 1.386703515057916, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3835700826678868e+33, 5.346198723182914e+32, 0.0, 0.0, -0.07823274819226517, 0.0, 0.0, -0.4583355155431211, 3.085677581491367e+24, 1.0578374841366343, 1.386703515057916, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 63
# Generation with parameters (5.424846506332857e+33, 9.822424973661705e+32, 0.0, 0.0, -0.3596055664398338, 0.0, 0.0, 0.5162366827393329, 3.085677581491367e+24, 2.6772750799966833, 0.735057756604159, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.424846506332857e+33, 9.822424973661705e+32, 0.0, 0.0, -0.3596055664398338, 0.0, 0.0, 0.5162366827393329, 3.085677581491367e+24, 2.6772750799966833, 0.735057756604159, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 64
# Generation with parameters (3.784367634268571e+33, 9.781544881830849e+32, 0.0, 0.0, -0.26060130013331423, 0.0, 0.0, 0.46315572904765184, 3.085677581491367e+24, 2.4466700776983954, 5.491729714917878, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.784367634268571e+33, 9.781544881830849e+32, 0.0, 0.0, -0.26060130013331423, 0.0, 0.0, 0.46315572904765184, 3.085677581491367e+24, 2.4466700776983954, 5.491729714917878, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 65
# Generation with parameters (2.5037787013747858e+33, 1.9269669545966002e+33, 0.0, 0.0, 0.06603223054840184, 0.0, 0.0, -0.16695526192017499, 3.085677581491367e+24, 1.7187659530029729, 4.217143296594984, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5037787013747858e+33, 1.9269669545966002e+33, 0.0, 0.0, 0.06603223054840184, 0.0, 0.0, -0.16695526192017499, 3.085677581491367e+24, 1.7187659530029729, 4.217143296594984, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 66
# Generation with parameters (2.3342401316305918e+33, 3.201782117023937e+32, 0.0, 0.0, 0.038155327008592636, 0.0, 0.0, 0.3218335379265712, 3.085677581491367e+24, 1.277157614569807, 4.7113986050199665, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3342401316305918e+33, 3.201782117023937e+32, 0.0, 0.0, 0.038155327008592636, 0.0, 0.0, 0.3218335379265712, 3.085677581491367e+24, 1.277157614569807, 4.7113986050199665, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 67
# Generation with parameters (3.0330742225299295e+33, 6.14337353465003e+32, 0.0, 0.0, -0.19285519617457095, 0.0, 0.0, 0.018984738915541182, 3.085677581491367e+24, 2.511272212504442, 4.252012368072951, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.0330742225299295e+33, 6.14337353465003e+32, 0.0, 0.0, -0.19285519617457095, 0.0, 0.0, 0.018984738915541182, 3.085677581491367e+24, 2.511272212504442, 4.252012368072951, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 68
# Generation with parameters (3.125339603139936e+33, 1.0156457926112487e+33, 0.0, 0.0, 0.0012124502539865023, 0.0, 0.0, 0.3410389491052573, 3.085677581491367e+24, 0.4256242053447044, 0.8598083864705659, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.125339603139936e+33, 1.0156457926112487e+33, 0.0, 0.0, 0.0012124502539865023, 0.0, 0.0, 0.3410389491052573, 3.085677581491367e+24, 0.4256242053447044, 0.8598083864705659, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 69
# Generation with parameters (1.4764406487797003e+33, 6.72223391998828e+32, 0.0, 0.0, -0.06021137986630834, 0.0, 0.0, -0.01923165041294938, 3.085677581491367e+24, 0.23910542115652303, 2.2369307215300007, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4764406487797003e+33, 6.72223391998828e+32, 0.0, 0.0, -0.06021137986630834, 0.0, 0.0, -0.01923165041294938, 3.085677581491367e+24, 0.23910542115652303, 2.2369307215300007, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 70
# Generation with parameters (4.3487130023034307e+33, 9.063673699025945e+32, 0.0, 0.0, -0.4059661639480586, 0.0, 0.0, 0.4155460809356464, 3.085677581491367e+24, 1.9288790013656276, 3.472197733613463, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# ...
# Warning: turning off multibanding for parameters (8.777686053401993e+32, 8.340866264348478e+32, 0.0, 0.0, 0.07323893758719324, 0.0, 0.0, 0.10044522148580246, 3.085677581491367e+24, 2.649485288735199, 0.6799410026546638, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 976
# Generation with parameters (3.998229964713608e+33, 1.2019866395192014e+33, 0.0, 0.0, 0.33862681152994734, 0.0, 0.0, -0.06405964499188684, 3.085677581491367e+24, 1.0367570995935926, 2.2674165708959193, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.998229964713608e+33, 1.2019866395192014e+33, 0.0, 0.0, 0.33862681152994734, 0.0, 0.0, -0.06405964499188684, 3.085677581491367e+24, 1.0367570995935926, 2.2674165708959193, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 977
# Generation with parameters (5.476621161279927e+33, 8.583836346416189e+32, 0.0, 0.0, -0.6919258539998501, 0.0, 0.0, 0.3295877652596166, 3.085677581491367e+24, 2.3324311706373733, 3.2298803403962837, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.476621161279927e+33, 8.583836346416189e+32, 0.0, 0.0, -0.6919258539998501, 0.0, 0.0, 0.3295877652596166, 3.085677581491367e+24, 2.3324311706373733, 3.2298803403962837, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 978
# Generation with parameters (4.928077749031363e+33, 9.440980452933065e+32, 0.0, 0.0, -0.05658233313690221, 0.0, 0.0, 0.7767339535442589, 3.085677581491367e+24, 0.723501660570867, 2.1243961082633023, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.928077749031363e+33, 9.440980452933065e+32, 0.0, 0.0, -0.05658233313690221, 0.0, 0.0, 0.7767339535442589, 3.085677581491367e+24, 0.723501660570867, 2.1243961082633023, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 979
# Generation with parameters (1.3448504677279533e+33, 1.2976279984858706e+33, 0.0, 0.0, 0.7970493243052275, 0.0, 0.0, -0.08562462745182811, 3.085677581491367e+24, 1.6336217819579772, 1.473826400470931, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3448504677279533e+33, 1.2976279984858706e+33, 0.0, 0.0, 0.7970493243052275, 0.0, 0.0, -0.08562462745182811, 3.085677581491367e+24, 1.6336217819579772, 1.473826400470931, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 980
# Generation with parameters (4.918110036532275e+33, 1.1408166276970675e+33, 0.0, 0.0, -0.04895864112551055, 0.0, 0.0, -0.30906934178409723, 3.085677581491367e+24, 1.2961402061498866, 4.533333192171758, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.918110036532275e+33, 1.1408166276970675e+33, 0.0, 0.0, -0.04895864112551055, 0.0, 0.0, -0.30906934178409723, 3.085677581491367e+24, 1.2961402061498866, 4.533333192171758, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 981
# Generation with parameters (1.5620470821356495e+33, 1.4039809758194028e+33, 0.0, 0.0, 0.20814655776914123, 0.0, 0.0, -0.0011164715931975104, 3.085677581491367e+24, 1.4776019445351234, 0.7477445154855171, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5620470821356495e+33, 1.4039809758194028e+33, 0.0, 0.0, 0.20814655776914123, 0.0, 0.0, -0.0011164715931975104, 3.085677581491367e+24, 1.4776019445351234, 0.7477445154855171, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 982
# Generation with parameters (1.2290453737104908e+33, 7.919081682563218e+32, 0.0, 0.0, -0.14532743676861476, 0.0, 0.0, 0.14271076126931315, 3.085677581491367e+24, 2.2884683451183987, 4.452362772209524, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2290453737104908e+33, 7.919081682563218e+32, 0.0, 0.0, -0.14532743676861476, 0.0, 0.0, 0.14271076126931315, 3.085677581491367e+24, 2.2884683451183987, 4.452362772209524, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 983
# Generation with parameters (5.0272114807642383e+33, 1.1005678206584985e+33, 0.0, 0.0, -0.020696368647391022, 0.0, 0.0, -0.19902087664523319, 3.085677581491367e+24, 2.0703385358551785, 4.009135913560912, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.0272114807642383e+33, 1.1005678206584985e+33, 0.0, 0.0, -0.020696368647391022, 0.0, 0.0, -0.19902087664523319, 3.085677581491367e+24, 2.0703385358551785, 4.009135913560912, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 984
# Generation with parameters (1.9110458191415112e+33, 1.278803072534214e+33, 0.0, 0.0, -0.018938304892839302, 0.0, 0.0, -0.4639591813587566, 3.085677581491367e+24, 2.47712849923499, 3.862434734060176, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.9110458191415112e+33, 1.278803072534214e+33, 0.0, 0.0, -0.018938304892839302, 0.0, 0.0, -0.4639591813587566, 3.085677581491367e+24, 2.47712849923499, 3.862434734060176, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 985
# Generation with parameters (1.442379210738271e+33, 5.855044085896308e+32, 0.0, 0.0, -0.05938520933687564, 0.0, 0.0, -0.18853539289900167, 3.085677581491367e+24, 1.884927400674108, 0.00800860092107098, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.442379210738271e+33, 5.855044085896308e+32, 0.0, 0.0, -0.05938520933687564, 0.0, 0.0, -0.18853539289900167, 3.085677581491367e+24, 1.884927400674108, 0.00800860092107098, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 986
# Generation with parameters (9.515189885234098e+32, 9.159921958983914e+32, 0.0, 0.0, -0.2432137779080857, 0.0, 0.0, 0.15470028985038084, 3.085677581491367e+24, 2.005944419184984, 2.7187316670507036, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.515189885234098e+32, 9.159921958983914e+32, 0.0, 0.0, -0.2432137779080857, 0.0, 0.0, 0.15470028985038084, 3.085677581491367e+24, 2.005944419184984, 2.7187316670507036, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 987
# Generation with parameters (8.93333833667262e+32, 8.575140067709936e+32, 0.0, 0.0, -0.24404151935093638, 0.0, 0.0, 0.11602368068972872, 3.085677581491367e+24, 2.3689635804821125, 4.904999667326259, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.93333833667262e+32, 8.575140067709936e+32, 0.0, 0.0, -0.24404151935093638, 0.0, 0.0, 0.11602368068972872, 3.085677581491367e+24, 2.3689635804821125, 4.904999667326259, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 988
# Generation with parameters (3.3032016461111626e+33, 1.512220770623333e+33, 0.0, 0.0, 0.23786318499034334, 0.0, 0.0, -0.10243935286950484, 3.085677581491367e+24, 1.6444050381409774, 4.8940791660475735, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.3032016461111626e+33, 1.512220770623333e+33, 0.0, 0.0, 0.23786318499034334, 0.0, 0.0, -0.10243935286950484, 3.085677581491367e+24, 1.6444050381409774, 4.8940791660475735, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 989
# Generation with parameters (2.129608162616503e+33, 1.986521071042518e+33, 0.0, 0.0, 0.04135835740250903, 0.0, 0.0, 0.023373104181156474, 3.085677581491367e+24, 0.7756619700458645, 4.108776758945187, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.129608162616503e+33, 1.986521071042518e+33, 0.0, 0.0, 0.04135835740250903, 0.0, 0.0, 0.023373104181156474, 3.085677581491367e+24, 0.7756619700458645, 4.108776758945187, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 990
# Generation with parameters (4.427561374467865e+33, 1.161790572593119e+33, 0.0, 0.0, 0.04621605395127309, 0.0, 0.0, -0.16508610791702255, 3.085677581491367e+24, 2.5273875461917283, 3.8214417113490757, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.427561374467865e+33, 1.161790572593119e+33, 0.0, 0.0, 0.04621605395127309, 0.0, 0.0, -0.16508610791702255, 3.085677581491367e+24, 2.5273875461917283, 3.8214417113490757, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 991
# Generation with parameters (2.0126410582140574e+33, 1.476834262195267e+33, 0.0, 0.0, 0.5165946941134053, 0.0, 0.0, -0.14083884269281896, 3.085677581491367e+24, 1.975375946675947, 1.8129936766710757, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0126410582140574e+33, 1.476834262195267e+33, 0.0, 0.0, 0.5165946941134053, 0.0, 0.0, -0.14083884269281896, 3.085677581491367e+24, 1.975375946675947, 1.8129936766710757, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 992
# Generation with parameters (1.0303300655684452e+33, 2.763767426143489e+32, 0.0, 0.0, -0.2655230610123818, 0.0, 0.0, -0.6639273983262095, 3.085677581491367e+24, 0.5083199096421495, 2.1477337390319238, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0303300655684452e+33, 2.763767426143489e+32, 0.0, 0.0, -0.2655230610123818, 0.0, 0.0, -0.6639273983262095, 3.085677581491367e+24, 0.5083199096421495, 2.1477337390319238, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 993
# Generation with parameters (3.6614862873859496e+33, 1.1486638805512073e+33, 0.0, 0.0, 0.06658033767299125, 0.0, 0.0, 0.05748968530881043, 3.085677581491367e+24, 0.8901970441183582, 2.984338393273543, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.6614862873859496e+33, 1.1486638805512073e+33, 0.0, 0.0, 0.06658033767299125, 0.0, 0.0, 0.05748968530881043, 3.085677581491367e+24, 0.8901970441183582, 2.984338393273543, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 994
# Generation with parameters (3.2754662167019896e+33, 9.836858515135082e+32, 0.0, 0.0, -0.09260875823024334, 0.0, 0.0, -0.021591855700724714, 3.085677581491367e+24, 2.394384449941029, 2.1153824645752737, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.2754662167019896e+33, 9.836858515135082e+32, 0.0, 0.0, -0.09260875823024334, 0.0, 0.0, -0.021591855700724714, 3.085677581491367e+24, 2.394384449941029, 2.1153824645752737, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 995
# Generation with parameters (3.4294157856991826e+33, 1.5577625536166872e+33, 0.0, 0.0, 0.3630793537240361, 0.0, 0.0, 0.7414007668756526, 3.085677581491367e+24, 0.7050746136026919, 4.179450803751613, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.4294157856991826e+33, 1.5577625536166872e+33, 0.0, 0.0, 0.3630793537240361, 0.0, 0.0, 0.7414007668756526, 3.085677581491367e+24, 0.7050746136026919, 4.179450803751613, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 996
# Generation with parameters (5.879297995210809e+33, 7.67232811035475e+32, 0.0, 0.0, -0.5672927117829769, 0.0, 0.0, 0.09714434590459171, 3.085677581491367e+24, 2.02397212771391, 2.0989562620920204, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.879297995210809e+33, 7.67232811035475e+32, 0.0, 0.0, -0.5672927117829769, 0.0, 0.0, 0.09714434590459171, 3.085677581491367e+24, 2.02397212771391, 2.0989562620920204, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 997
# Generation with parameters (1.2808971416563137e+33, 8.53750670570203e+32, 0.0, 0.0, -0.001133242338870723, 0.0, 0.0, 0.035174287623203286, 3.085677581491367e+24, 1.215209473590419, 4.125262697161487, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2808971416563137e+33, 8.53750670570203e+32, 0.0, 0.0, -0.001133242338870723, 0.0, 0.0, 0.035174287623203286, 3.085677581491367e+24, 1.215209473590419, 4.125262697161487, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 998
# Generation with parameters (5.187097854253049e+33, 1.0800637277826775e+33, 0.0, 0.0, 0.730267824105134, 0.0, 0.0, 0.0679757096443425, 3.085677581491367e+24, 2.5949233085409533, 3.6880383133848986, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.187097854253049e+33, 1.0800637277826775e+33, 0.0, 0.0, 0.730267824105134, 0.0, 0.0, 0.0679757096443425, 3.085677581491367e+24, 2.5949233085409533, 3.6880383133848986, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 999

# %%
import os
import pickle

from dingo.gw.inference.gw_samplers import GWSampler


os.makedirs("/scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100", exist_ok=True)

injection_files = sorted(os.listdir("/scratch/tpausch/test_data/imbh_T8_mass2/injections"))

for fname in injection_files[:100]:

    # --------------------------------------------------------
    # Load injection
    # --------------------------------------------------------

    with open(f"/scratch/tpausch/test_data/imbh_T8_mass2/injections/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    strain_data = payload["strain_data"]

    # --------------------------------------------------------
    # Run sampler
    # --------------------------------------------------------

    sampler = GWSampler(model=main_pm)

    sampler.context = strain_data

    sampler.run_sampler(
        num_samples=50_000,
        batch_size=10_000,
    )

    result = sampler.to_result()

    # --------------------------------------------------------
    # Store result
    # --------------------------------------------------------

    result_payload = {
        "theta_true": theta_true,
        "result": result,
    }

    outname = fname.replace("inj_", "result_")

    with open(f"/scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/{outname}", "wb") as f:
        pickle.dump(result_payload, f)

    print(f"Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/{outname}")
# Out:
# Running sampler to generate 50000 samples.
# Done. This took 1.3 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0000.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0001.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0002.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0003.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.9 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0004.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0005.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0006.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0007.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0008.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0009.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0010.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0011.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0012.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0013.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0014.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0015.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0016.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0017.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0018.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0019.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0020.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0021.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0022.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0023.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0024.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0025.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0026.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0027.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0028.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0029.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0030.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0031.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0032.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0033.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0034.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0035.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0036.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0037.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0038.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0039.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0040.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0041.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0042.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0043.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0044.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0045.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0046.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0047.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0048.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0049.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0050.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0051.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0052.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0053.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0054.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0055.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0056.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0057.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0058.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0059.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0060.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0061.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0062.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0063.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0064.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0065.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0066.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0067.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0068.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0069.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0070.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0071.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0072.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0073.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0074.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0075.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0076.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0077.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0078.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0079.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0080.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0081.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0082.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0083.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0084.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0085.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0086.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0087.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0088.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0089.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0090.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0091.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0092.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0093.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0094.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0095.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0096.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0097.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0098.pkl
# Running sampler to generate 50000 samples.
# Done. This took 0.8 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/result_0099.pkl

# %%
import os
import pickle
import numpy as np

true_cm = []
true_mr = []
mass_ratio_error = []
mass_ratio_std = []
chirp_mass_error = []
chirp_mass_std = []


result_files = sorted(os.listdir("/scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    result = payload["result"]

    posterior_samples = result.samples

    #q_samples = np.array(posterior_samples["mass_ratio"])

    # inference statistics
    #q_mean = np.mean(q_samples)
    #q_std = np.std(q_samples)
#
    #true_q = theta_true["mass_ratio"]

    cm_samples = np.array(posterior_samples["chirp_mass"])

    cm_mean = np.mean(cm_samples)
    cm_std = np.std(cm_samples)

    true_mr.append(theta_true["mass_ratio"])
    true_cm.append(theta_true["chirp_mass"])
    #mass_ratio_error.append(q_mean - true_q)
    #mass_ratio_std.append(q_std)
    chirp_mass_error.append(cm_mean - theta_true["chirp_mass"])
    chirp_mass_std.append(cm_std)

# %%
import matplotlib.pyplot as plt
import numpy as np

true_mr = np.array(true_mr)
true_cm = np.array(true_cm)




# ------------------------------------------------------------
# Error bars
# ------------------------------------------------------------

#plt.errorbar(
#    true_cm,
#    chirp_mass_error,
#    yerr=chirp_mass_std,
#    fmt="none",
#    capsize=4,
#    alpha=0.5,
#    color="gray",
#)

# ------------------------------------------------------------
# Colored scatter points
# ------------------------------------------------------------

sc = plt.scatter(
    true_cm,
    chirp_mass_error,
    #c=true_mr,
    #cmap="viridis",
    s=20,
    edgecolor="black",
    alpha=0.3
)

# ------------------------------------------------------------
# Reference line
# ------------------------------------------------------------

plt.axhline(0, linestyle="--", color="black")

# ------------------------------------------------------------
# Colorbar
# ------------------------------------------------------------

cbar = plt.colorbar(sc)
cbar.set_label("True mass ratio")

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel("True chirp mass")
plt.ylabel("Chirp mass inference error (inferred − true)")

plt.title("Chirp-mass inference error")

plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm_err = np.asarray(chirp_mass_error)

mean_error = np.mean(cm_err)          # signed average bias (over/under-estimation)
mean_abs_error = np.mean(np.abs(cm_err))  # average magnitude of deviation
rms_error = np.sqrt(np.mean(cm_err**2))   # RMS deviation, penalizes outliers more
std_error = np.std(cm_err)            # spread of the errors around their mean

print(f"Mean error (bias):      {mean_error:.3f}")
print(f"Mean absolute error:    {mean_abs_error:.3f}")
print(f"RMS error:              {rms_error:.3f}")
print(f"Std of error:           {std_error:.3f}")
# Out:
# Mean error (bias):      13.551
# Mean absolute error:    71.971
# RMS error:              114.911
# Std of error:           114.109

# %%
pp_values_chirp_mass = []
pp_values_mass_ratio = []

result_files = sorted(os.listdir("/scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/imbh_T8_mass2/results_epoch100/{fname}", "rb") as f:

        payload = pickle.load(f)

        theta_true = payload["theta_true"]
        result = payload["result"]

        posterior_samples = result.samples


        # ============================================================
        # Chirp mass PP value
        # ============================================================

        cm_samples = posterior_samples["chirp_mass"]

        pp_cm = np.mean(
            cm_samples < theta_true["chirp_mass"]
        )

        pp_values_chirp_mass.append(pp_cm)


        # ============================================================
        # Mass ratio PP value
        # ============================================================

        #q_samples = posterior_samples["mass_ratio"]
#
        #pp_q = np.mean(
        #    q_samples < theta_true["mass_ratio"]
        #)
#
        #pp_values_mass_ratio.append(pp_q)

# %%
import matplotlib.pyplot as plt


def plot_pp(pp_values, label):

    pp_values = np.array(pp_values)

    sorted_pp = np.sort(pp_values)

    n = len(sorted_pp)

    empirical_cdf = np.arange(1, n + 1) / n

    x = np.linspace(0, 1, 200)

    sigma = np.sqrt(x * (1 - x) / n)

    plt.figure(figsize=(6, 6))

    # Ideal calibration
    plt.plot(
        [0, 1],
        [0, 1],
        linestyle="--",
        label="Ideal calibration",
    )


    # Empirical PP curve
    plt.plot(
        sorted_pp,
        empirical_cdf,
        marker="o",
        label=label,
    )

    plt.xlabel("Credible level")
    plt.ylabel("Fraction of injections")

    plt.title(f"PP Plot: {label}")

    plt.xlim(0, 1)
    plt.ylim(0, 1)

    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
plot_pp(
    pp_values_chirp_mass,
    "chirp_mass",
)

#plot_pp(
#    pp_values_mass_ratio,
#    "mass_ratio",
#)
