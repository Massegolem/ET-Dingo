# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
import GWFish.modules as gw


os.environ["CUDA_VISIBLE_DEVICES"] = "3"  # use GPU 1

name="stage1_2"

waveform_model = 'IMRPhenomXPHM'
f_ref = 20.
detectors = ['ET']
network = gw.detection.Network(detector_ids = detectors, detection_SNR = (0., 8.))

# %% [markdown]
# ## Load Model

# %%
from dingo.core.posterior_models.build_model import build_model_from_kwargs
main_pm = build_model_from_kwargs(
    filename=f"/scratch/tpausch/models/{name}/model_100.pt",
    device="cuda",
    load_training_info=False,
)
# Out:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1230+gc9da5d765 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Putting posterior model to device cuda.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt(f"/scratch/tpausch/models/{name}/history.txt")
epochs   = data[:, 0]
train    = data[:, 1]
val      = data[:, 2]


plt.figure(figsize=(8, 5))
plt.plot(epochs, train, label="Train loss")
plt.plot(epochs, val,   label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("Log-likelihood")
plt.legend()
plt.title("Dingo training history")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Simulate injections

# %%
import dingo.gw.injection as injection
from dingo.gw.noise.asd_dataset import ASDDataset

# ============================================================
# Setup
# ============================================================

num_injections = 1000
out_dir = f"/scratch/tpausch/test_data/{name}/injections"
os.makedirs(out_dir, exist_ok=True)

np.random.seed(42)  # optional, for reproducibility

injection_generator = injection.Injection.from_posterior_model_metadata(
    main_pm.metadata
)

asd_fname = main_pm.metadata["train_settings"]["training"]["stage_0"]["asd_dataset_path"]
asd_dataset = ASDDataset(file_name=asd_fname)

injection_generator.asd = {
    k: v[0] for k, v in asd_dataset.asds.items()
}

# This is the combined intrinsic + extrinsic bilby PriorDict
# that the network was trained on
prior = injection_generator.prior
print(prior)

# ============================================================
# Draw and run injections
# ============================================================

for idx in range(num_injections):

    print(f"Running injection {idx}")

    theta = prior.sample()
    theta = {k: float(v) for k, v in theta.items()}  # cast numpy -> float

    strain_data = injection_generator.injection(theta)

    payload = {
        "theta_true": theta,
        "strain_data": strain_data,
    }

    fname = os.path.join(out_dir, f"inj_{idx:04d}.pkl")

    with open(fname, "wb") as f:
        pickle.dump(payload, f)
# Out:
# Setting spin_conversion_phase = 0.0. Using this value for the phase parameter for conversion to cartesian spins.
# Loading dataset from training_data/asds_ET_T8.hdf5.
# {'mass_1': Constraint(minimum=30.0, maximum=3000.0, name='mass_1', latex_label='$m_1$', unit=None), 'mass_2': Constraint(minimum=30.0, maximum=3000.0, name='mass_2', latex_label='$m_2$', unit=None), 'chirp_mass': bilby.gw.prior.UniformInComponentsChirpMass(minimum=50.0, maximum=1000.0, name='chirp_mass', latex_label='$\\mathcal{M}$', unit=None, boundary=None), 'mass_ratio': bilby.gw.prior.UniformInComponentsMassRatio(minimum=0.125, maximum=1.0, name='mass_ratio', latex_label='$q$', unit=None, boundary=None, equal_mass=False), 'phase': Uniform(minimum=0.0, maximum=6.283185307179586, name='phase', latex_label='$\\phi$', unit=None, boundary='periodic'), 'chi_1': bilby.gw.prior.AlignedSpin(a_prior=Uniform(minimum=0, maximum=0.9, name=None, latex_label=None, unit=None, boundary=None), z_prior=Uniform(minimum=-1, maximum=1, name=None, latex_label=None, unit=None, boundary=None), name='chi_1', latex_label='$\\chi_1$', unit=None, boundary=None, minimum=-0.9, maximum=0.9, num_interp=100000), 'chi_2': bilby.gw.prior.AlignedSpin(a_prior=Uniform(minimum=0, maximum=0.9, name=None, latex_label=None, unit=None, boundary=None), z_prior=Uniform(minimum=-1, maximum=1, name=None, latex_label=None, unit=None, boundary=None), name='chi_2', latex_label='$\\chi_2$', unit=None, boundary=None, minimum=-0.9, maximum=0.9, num_interp=100000), 'theta_jn': Sine(minimum=0.0, maximum=3.141592653589793, name='theta_jn', latex_label='$\\theta_{JN}$', unit=None, boundary=None), 'luminosity_distance': LogUniform(minimum=1000.0, maximum=100000.0, name='luminosity_distance', latex_label='$d_L$', unit=None, boundary=None), 'geocent_time': Uniform(minimum=-0.1, maximum=0.1, name='geocent_time', latex_label='$t_c$', unit=None, boundary=None), 'dec': Cosine(minimum=-1.5707963267948966, maximum=1.5707963267948966, name='dec', latex_label='$\\mathrm{DEC}$', unit=None, boundary=None), 'ra': Uniform(minimum=0.0, maximum=6.283185307179586, name='ra', latex_label='$\\mathrm{RA}$', unit=None, boundary='periodic'), 'psi': Uniform(minimum=0.0, maximum=3.141592653589793, name='psi', latex_label='$\\psi$', unit=None, boundary='periodic')}
# Running injection 0
# Generation with parameters (1.9842453119434618e+33, 3.10688643774059e+32, 0.0, 0.0, -0.2734517242800614, 0.0, 0.0, -0.013932564317080582, 3.085677581491367e+24, 1.9434773021030822, 4.757800668514039, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.9842453119434618e+33, 3.10688643774059e+32, 0.0, 0.0, -0.2734517242800614, 0.0, 0.0, -0.013932564317080582, 3.085677581491367e+24, 1.9434773021030822, 4.757800668514039, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1
# Generation with parameters (4.161345235741551e+33, 9.841283293271427e+32, 0.0, 0.0, -0.07433168839416542, 0.0, 0.0, -0.20915301457459834, 3.085677581491367e+24, 1.9984635239798887, 5.589348327825435, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.161345235741551e+33, 9.841283293271427e+32, 0.0, 0.0, -0.07433168839416542, 0.0, 0.0, -0.20915301457459834, 3.085677581491367e+24, 1.9984635239798887, 5.589348327825435, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 2
# Generation with parameters (2.746325745091858e+33, 1.5209868143311024e+33, 0.0, 0.0, 0.08927845057572792, 0.0, 0.0, -0.06021165499986398, 3.085677581491367e+24, 1.704360277619273, 3.553833325277522, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.746325745091858e+33, 1.5209868143311024e+33, 0.0, 0.0, 0.08927845057572792, 0.0, 0.0, -0.06021165499986398, 3.085677581491367e+24, 1.704360277619273, 3.553833325277522, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 3
# Generation with parameters (2.3621075965116945e+33, 1.689277248823817e+33, 0.0, 0.0, -0.5401635444085916, 0.0, 0.0, -0.49606794409539684, 3.085677581491367e+24, 0.2730500984394177, 5.661915116394519, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3621075965116945e+33, 1.689277248823817e+33, 0.0, 0.0, -0.5401635444085916, 0.0, 0.0, -0.49606794409539684, 3.085677581491367e+24, 0.2730500984394177, 5.661915116394519, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 4
# Generation with parameters (3.786724569141529e+33, 1.2227085559994388e+33, 0.0, 0.0, 0.18491571636058227, 0.0, 0.0, -0.5264241804128245, 3.085677581491367e+24, 1.3320957803705824, 2.274894303358061, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.786724569141529e+33, 1.2227085559994388e+33, 0.0, 0.0, 0.18491571636058227, 0.0, 0.0, -0.5264241804128245, 3.085677581491367e+24, 1.3320957803705824, 2.274894303358061, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 5
# Generation with parameters (2.5584355753416936e+33, 1.1829922003666242e+33, 0.0, 0.0, 0.07634194313632658, 0.0, 0.0, -0.4906750648759942, 3.085677581491367e+24, 1.476802860462345, 2.427113629900965, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5584355753416936e+33, 1.1829922003666242e+33, 0.0, 0.0, 0.07634194313632658, 0.0, 0.0, -0.4906750648759942, 3.085677581491367e+24, 1.476802860462345, 2.427113629900965, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 6
# Generation with parameters (2.297360983436216e+33, 9.312033799283008e+32, 0.0, 0.0, -0.013466734976156169, 0.0, 0.0, -0.4027113691997427, 3.085677581491367e+24, 1.8342832767447312, 3.0988574299265745, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.297360983436216e+33, 9.312033799283008e+32, 0.0, 0.0, -0.013466734976156169, 0.0, 0.0, -0.4027113691997427, 3.085677581491367e+24, 1.8342832767447312, 3.0988574299265745, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 7
# Generation with parameters (1.5354817401824697e+33, 1.4708024587472103e+33, 0.0, 0.0, -0.47696650812785113, 0.0, 0.0, 0.003523727628539931, 3.085677581491367e+24, 1.9342401066429635, 5.578902444866066, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5354817401824697e+33, 1.4708024587472103e+33, 0.0, 0.0, -0.47696650812785113, 0.0, 0.0, 0.003523727628539931, 3.085677581491367e+24, 1.9342401066429635, 5.578902444866066, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 8
# Generation with parameters (3.661944814274095e+33, 5.4962310433970406e+32, 0.0, 0.0, 0.28055550708229954, 0.0, 0.0, -0.6553065145465025, 3.085677581491367e+24, 1.1984546409771095, 1.455733608693588, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.661944814274095e+33, 5.4962310433970406e+32, 0.0, 0.0, 0.28055550708229954, 0.0, 0.0, -0.6553065145465025, 3.085677581491367e+24, 1.1984546409771095, 1.455733608693588, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 9
# Generation with parameters (1.7361832493131188e+33, 1.5058999377183322e+33, 0.0, 0.0, 0.10240406187022771, 0.0, 0.0, 0.24953291980466796, 3.085677581491367e+24, 0.1453594846138643, 1.8645535740372239, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7361832493131188e+33, 1.5058999377183322e+33, 0.0, 0.0, 0.10240406187022771, 0.0, 0.0, 0.24953291980466796, 3.085677581491367e+24, 0.1453594846138643, 1.8645535740372239, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 10
# Generation with parameters (2.938275628748838e+33, 8.705386286643983e+32, 0.0, 0.0, 0.6457469504744456, 0.0, 0.0, -0.416676377129639, 3.085677581491367e+24, 1.9592096378341157, 3.6356911657347837, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.938275628748838e+33, 8.705386286643983e+32, 0.0, 0.0, 0.6457469504744456, 0.0, 0.0, -0.416676377129639, 3.085677581491367e+24, 1.9592096378341157, 3.6356911657347837, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 11
# Generation with parameters (2.6666713239969457e+33, 1.1807065695154833e+33, 0.0, 0.0, 0.781185595173763, 0.0, 0.0, 0.09288550683105969, 3.085677581491367e+24, 1.7321651186453557, 0.5430614557386624, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.6666713239969457e+33, 1.1807065695154833e+33, 0.0, 0.0, 0.781185595173763, 0.0, 0.0, 0.09288550683105969, 3.085677581491367e+24, 1.7321651186453557, 0.5430614557386624, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 12
# Generation with parameters (2.1057401828172064e+33, 1.2492829363163606e+33, 0.0, 0.0, -0.4054629748888061, 0.0, 0.0, -0.05242459868935102, 3.085677581491367e+24, 0.7209902486946699, 3.4059151794996563, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.1057401828172064e+33, 1.2492829363163606e+33, 0.0, 0.0, -0.4054629748888061, 0.0, 0.0, -0.05242459868935102, 3.085677581491367e+24, 0.7209902486946699, 3.4059151794996563, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 13
# Generation with parameters (4.303391890533005e+33, 1.2220695661062738e+33, 0.0, 0.0, -0.3987239833481141, 0.0, 0.0, -0.39279124208410604, 3.085677581491367e+24, 1.1430893500866222, 5.721448169693367, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.303391890533005e+33, 1.2220695661062738e+33, 0.0, 0.0, -0.3987239833481141, 0.0, 0.0, -0.39279124208410604, 3.085677581491367e+24, 1.1430893500866222, 5.721448169693367, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 14
# Generation with parameters (4.143671652677718e+33, 7.010939089629291e+32, 0.0, 0.0, -0.5760892756343223, 0.0, 0.0, -0.23832395604343304, 3.085677581491367e+24, 1.4466905178324125, 4.692769885013651, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.143671652677718e+33, 7.010939089629291e+32, 0.0, 0.0, -0.5760892756343223, 0.0, 0.0, -0.23832395604343304, 3.085677581491367e+24, 1.4466905178324125, 4.692769885013651, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 15
# Generation with parameters (4.858740074740924e+33, 7.935495241259665e+32, 0.0, 0.0, 0.22010844765394033, 0.0, 0.0, -0.6013880001327292, 3.085677581491367e+24, 1.3755892206383151, 2.054674146666143, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.858740074740924e+33, 7.935495241259665e+32, 0.0, 0.0, 0.22010844765394033, 0.0, 0.0, -0.6013880001327292, 3.085677581491367e+24, 1.3755892206383151, 2.054674146666143, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 16
# Generation with parameters (2.1656863779344917e+33, 1.7494946632949117e+33, 0.0, 0.0, -0.08947855436811569, 0.0, 0.0, -0.8198022420415048, 3.085677581491367e+24, 2.3620023574106996, 2.0459623911282763, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.1656863779344917e+33, 1.7494946632949117e+33, 0.0, 0.0, -0.08947855436811569, 0.0, 0.0, -0.8198022420415048, 3.085677581491367e+24, 2.3620023574106996, 2.0459623911282763, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 17
# Generation with parameters (2.9323560076743937e+33, 1.472394552024526e+33, 0.0, 0.0, 0.3448359769544205, 0.0, 0.0, -0.4712707851573466, 3.085677581491367e+24, 2.152406623866565, 5.497070598780987, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.9323560076743937e+33, 1.472394552024526e+33, 0.0, 0.0, 0.3448359769544205, 0.0, 0.0, -0.4712707851573466, 3.085677581491367e+24, 2.152406623866565, 5.497070598780987, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 18
# Generation with parameters (2.6887460749633135e+33, 3.979258535294106e+32, 0.0, 0.0, -0.03037473518266515, 0.0, 0.0, 0.2631485099359987, 3.085677581491367e+24, 1.0758017472550758, 3.229897227042691, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.6887460749633135e+33, 3.979258535294106e+32, 0.0, 0.0, -0.03037473518266515, 0.0, 0.0, 0.2631485099359987, 3.085677581491367e+24, 1.0758017472550758, 3.229897227042691, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 19
# Generation with parameters (3.9201369542877676e+33, 1.0248532547056735e+33, 0.0, 0.0, -0.004853710267726035, 0.0, 0.0, 0.05847878540106298, 3.085677581491367e+24, 1.963523375111992, 5.312116035759779, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.9201369542877676e+33, 1.0248532547056735e+33, 0.0, 0.0, -0.004853710267726035, 0.0, 0.0, 0.05847878540106298, 3.085677581491367e+24, 1.963523375111992, 5.312116035759779, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 20
# Generation with parameters (4.7987202891886086e+33, 7.245896400372908e+32, 0.0, 0.0, -0.11313031927556617, 0.0, 0.0, 0.05727582019263157, 3.085677581491367e+24, 1.4012162441459384, 5.457058684647004, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.7987202891886086e+33, 7.245896400372908e+32, 0.0, 0.0, -0.11313031927556617, 0.0, 0.0, 0.05727582019263157, 3.085677581491367e+24, 1.4012162441459384, 5.457058684647004, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 21
# Generation with parameters (2.2829469349466734e+33, 1.6528553185272985e+33, 0.0, 0.0, 0.527809258551701, 0.0, 0.0, -0.2350880984088859, 3.085677581491367e+24, 1.1929753277666284, 3.198424520315683, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2829469349466734e+33, 1.6528553185272985e+33, 0.0, 0.0, 0.527809258551701, 0.0, 0.0, -0.2350880984088859, 3.085677581491367e+24, 1.1929753277666284, 3.198424520315683, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 22
# Generation with parameters (2.0231452742896786e+33, 1.398222680477957e+33, 0.0, 0.0, 0.24717324374228558, 0.0, 0.0, -0.3282766073426214, 3.085677581491367e+24, 2.8367593052763116, 1.1380220691368732, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0231452742896786e+33, 1.398222680477957e+33, 0.0, 0.0, 0.24717324374228558, 0.0, 0.0, -0.3282766073426214, 3.085677581491367e+24, 2.8367593052763116, 1.1380220691368732, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 23
# Generation with parameters (2.376204599852095e+33, 1.966391209134929e+33, 0.0, 0.0, 0.44123605705033686, 0.0, 0.0, 0.14915960740240217, 3.085677581491367e+24, 0.8955981510397931, 0.18279230938626045, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.376204599852095e+33, 1.966391209134929e+33, 0.0, 0.0, 0.44123605705033686, 0.0, 0.0, 0.14915960740240217, 3.085677581491367e+24, 0.8955981510397931, 0.18279230938626045, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 24
# Generation with parameters (1.4569664013503483e+33, 1.988244389052277e+32, 0.0, 0.0, -0.2950764036006874, 0.0, 0.0, 0.025558933307694962, 3.085677581491367e+24, 0.9840969571413725, 3.7905741306237273, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4569664013503483e+33, 1.988244389052277e+32, 0.0, 0.0, -0.2950764036006874, 0.0, 0.0, 0.025558933307694962, 3.085677581491367e+24, 0.9840969571413725, 3.7905741306237273, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 25
# Generation with parameters (3.636013300132936e+33, 7.013939744028793e+32, 0.0, 0.0, -0.2069899279877064, 0.0, 0.0, -0.30595652858026334, 3.085677581491367e+24, 2.2814759346205933, 6.135883077773368, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.636013300132936e+33, 7.013939744028793e+32, 0.0, 0.0, -0.2069899279877064, 0.0, 0.0, -0.30595652858026334, 3.085677581491367e+24, 2.2814759346205933, 6.135883077773368, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 26
# Generation with parameters (3.474312675316437e+33, 1.3300189537721097e+33, 0.0, 0.0, -0.33469517648363517, 0.0, 0.0, 0.09292446240426648, 3.085677581491367e+24, 1.6456640024498315, 4.164232676941594, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.474312675316437e+33, 1.3300189537721097e+33, 0.0, 0.0, -0.33469517648363517, 0.0, 0.0, 0.09292446240426648, 3.085677581491367e+24, 1.6456640024498315, 4.164232676941594, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 27
# Generation with parameters (1.511856561938684e+33, 1.3516200598149673e+33, 0.0, 0.0, 0.28134210889068695, 0.0, 0.0, 0.010246255345650206, 3.085677581491367e+24, 1.0256277924634565, 3.160284831118435, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.511856561938684e+33, 1.3516200598149673e+33, 0.0, 0.0, 0.28134210889068695, 0.0, 0.0, 0.010246255345650206, 3.085677581491367e+24, 1.0256277924634565, 3.160284831118435, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 28
# Generation with parameters (1.8108184048256182e+33, 6.492505198022698e+32, 0.0, 0.0, 0.35228826154413967, 0.0, 0.0, 0.05503169413977174, 3.085677581491367e+24, 2.5323814695557476, 5.654002281048195, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8108184048256182e+33, 6.492505198022698e+32, 0.0, 0.0, 0.35228826154413967, 0.0, 0.0, 0.05503169413977174, 3.085677581491367e+24, 2.5323814695557476, 5.654002281048195, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 29
# Generation with parameters (1.8773035295181983e+33, 1.8622572572205682e+33, 0.0, 0.0, -0.6453543891013709, 0.0, 0.0, 0.008991542928529836, 3.085677581491367e+24, 2.015275888625262, 2.529259535875418, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8773035295181983e+33, 1.8622572572205682e+33, 0.0, 0.0, -0.6453543891013709, 0.0, 0.0, 0.008991542928529836, 3.085677581491367e+24, 2.015275888625262, 2.529259535875418, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 30
# Generation with parameters (2.3815487042899675e+33, 5.245436990945425e+32, 0.0, 0.0, -0.4149577210502839, 0.0, 0.0, -0.08955804367415054, 3.085677581491367e+24, 0.8206521082029461, 1.5376522495265914, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3815487042899675e+33, 5.245436990945425e+32, 0.0, 0.0, -0.4149577210502839, 0.0, 0.0, -0.08955804367415054, 3.085677581491367e+24, 0.8206521082029461, 1.5376522495265914, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 31
# Generation with parameters (4.4070821927576964e+33, 1.150012599861548e+33, 0.0, 0.0, 0.24856168020546598, 0.0, 0.0, 0.5196558205854664, 3.085677581491367e+24, 2.179524344234459, 4.5526490824127785, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.4070821927576964e+33, 1.150012599861548e+33, 0.0, 0.0, 0.24856168020546598, 0.0, 0.0, 0.5196558205854664, 3.085677581491367e+24, 2.179524344234459, 4.5526490824127785, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 32
# Generation with parameters (1.0735993535187992e+33, 9.213312590640143e+32, 0.0, 0.0, -0.28401386684018054, 0.0, 0.0, 0.003056677698062282, 3.085677581491367e+24, 1.8449934427162615, 0.005614074017407897, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0735993535187992e+33, 9.213312590640143e+32, 0.0, 0.0, -0.28401386684018054, 0.0, 0.0, 0.003056677698062282, 3.085677581491367e+24, 1.8449934427162615, 0.005614074017407897, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 33
# Generation with parameters (2.0597849196006706e+33, 5.512625316932739e+32, 0.0, 0.0, -0.06807819399063668, 0.0, 0.0, 0.03173856900388189, 3.085677581491367e+24, 2.2306272280317487, 4.710289739175898, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0597849196006706e+33, 5.512625316932739e+32, 0.0, 0.0, -0.06807819399063668, 0.0, 0.0, 0.03173856900388189, 3.085677581491367e+24, 2.2306272280317487, 4.710289739175898, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 34
# Generation with parameters (2.813657334718704e+33, 1.85863118135181e+33, 0.0, 0.0, -0.03362006361471423, 0.0, 0.0, 0.31196684639332134, 3.085677581491367e+24, 2.484904393360226, 5.657874833510977, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.813657334718704e+33, 1.85863118135181e+33, 0.0, 0.0, -0.03362006361471423, 0.0, 0.0, 0.31196684639332134, 3.085677581491367e+24, 2.484904393360226, 5.657874833510977, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 35
# Running injection 36
# Generation with parameters (2.5586471485172427e+33, 1.1721538453909654e+33, 0.0, 0.0, 0.0007941030160959196, 0.0, 0.0, 0.2740306789660005, 3.085677581491367e+24, 0.5295832322372243, 0.682349937757857, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5586471485172427e+33, 1.1721538453909654e+33, 0.0, 0.0, 0.0007941030160959196, 0.0, 0.0, 0.2740306789660005, 3.085677581491367e+24, 0.5295832322372243, 0.682349937757857, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 37
# Generation with parameters (2.7421753246776964e+33, 3.7123202183813824e+32, 0.0, 0.0, 0.2057117349531913, 0.0, 0.0, 0.17606024499123177, 3.085677581491367e+24, 0.5921687157155888, 4.686206029003121, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.7421753246776964e+33, 3.7123202183813824e+32, 0.0, 0.0, 0.2057117349531913, 0.0, 0.0, 0.17606024499123177, 3.085677581491367e+24, 0.5921687157155888, 4.686206029003121, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 38
# Generation with parameters (1.9660827269145432e+33, 1.127248235619888e+33, 0.0, 0.0, -0.38199083353980245, 0.0, 0.0, -0.18073127148297144, 3.085677581491367e+24, 1.3666087228298396, 2.236031520606308, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.9660827269145432e+33, 1.127248235619888e+33, 0.0, 0.0, -0.38199083353980245, 0.0, 0.0, -0.18073127148297144, 3.085677581491367e+24, 1.3666087228298396, 2.236031520606308, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 39
# Generation with parameters (4.582782895965757e+33, 8.281070782129487e+32, 0.0, 0.0, 0.3801773087490871, 0.0, 0.0, 0.10936781405051495, 3.085677581491367e+24, 1.1364400091072264, 0.7782401116290405, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.582782895965757e+33, 8.281070782129487e+32, 0.0, 0.0, 0.3801773087490871, 0.0, 0.0, 0.10936781405051495, 3.085677581491367e+24, 1.1364400091072264, 0.7782401116290405, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 40
# Running injection 41
# Generation with parameters (3.1096343054275974e+33, 6.698398724101071e+32, 0.0, 0.0, -0.7346472707848847, 0.0, 0.0, -0.01563015535580864, 3.085677581491367e+24, 1.9677373977412296, 3.7648434736306506, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.1096343054275974e+33, 6.698398724101071e+32, 0.0, 0.0, -0.7346472707848847, 0.0, 0.0, -0.01563015535580864, 3.085677581491367e+24, 1.9677373977412296, 3.7648434736306506, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 42
# Generation with parameters (4.004748633060669e+33, 6.339412747552114e+32, 0.0, 0.0, 0.1568239940109682, 0.0, 0.0, 0.3720371731436845, 3.085677581491367e+24, 2.412364733351402, 4.323516973342202, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.004748633060669e+33, 6.339412747552114e+32, 0.0, 0.0, 0.1568239940109682, 0.0, 0.0, 0.3720371731436845, 3.085677581491367e+24, 2.412364733351402, 4.323516973342202, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 43
# Generation with parameters (9.041856218490737e+32, 8.562581697375816e+32, 0.0, 0.0, -0.5480216825684733, 0.0, 0.0, -0.2768391864241586, 3.085677581491367e+24, 1.5347868040943733, 1.5867242811837197, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.041856218490737e+32, 8.562581697375816e+32, 0.0, 0.0, -0.5480216825684733, 0.0, 0.0, -0.2768391864241586, 3.085677581491367e+24, 1.5347868040943733, 1.5867242811837197, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 44
# Generation with parameters (1.76541692667959e+33, 1.17214682563361e+33, 0.0, 0.0, 0.42907662167485683, 0.0, 0.0, -0.21237802737938083, 3.085677581491367e+24, 0.28777834777049943, 5.402383719208448, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.76541692667959e+33, 1.17214682563361e+33, 0.0, 0.0, 0.42907662167485683, 0.0, 0.0, -0.21237802737938083, 3.085677581491367e+24, 0.28777834777049943, 5.402383719208448, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 45
# Generation with parameters (4.8428845288517416e+33, 6.65790737802121e+32, 0.0, 0.0, 0.2255773143597127, 0.0, 0.0, -0.10969644836646368, 3.085677581491367e+24, 1.5288250747258214, 4.313490438578617, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.8428845288517416e+33, 6.65790737802121e+32, 0.0, 0.0, 0.2255773143597127, 0.0, 0.0, -0.10969644836646368, 3.085677581491367e+24, 1.5288250747258214, 4.313490438578617, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 46
# Generation with parameters (4.731476730048532e+33, 8.018540657567678e+32, 0.0, 0.0, 0.4408083906738668, 0.0, 0.0, -0.44415655746077176, 3.085677581491367e+24, 2.1791521004077987, 5.501790661489444, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.731476730048532e+33, 8.018540657567678e+32, 0.0, 0.0, 0.4408083906738668, 0.0, 0.0, -0.44415655746077176, 3.085677581491367e+24, 2.1791521004077987, 5.501790661489444, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 47
# Generation with parameters (2.0954885229245275e+33, 1.3622722240342512e+33, 0.0, 0.0, 0.6122843498275902, 0.0, 0.0, -0.346077085525366, 3.085677581491367e+24, 1.752467726412251, 5.6184472608754135, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0954885229245275e+33, 1.3622722240342512e+33, 0.0, 0.0, 0.6122843498275902, 0.0, 0.0, -0.346077085525366, 3.085677581491367e+24, 1.752467726412251, 5.6184472608754135, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 48
# Generation with parameters (4.087010191160611e+33, 7.927363846771015e+32, 0.0, 0.0, -0.2468633524580285, 0.0, 0.0, -0.029960035373381145, 3.085677581491367e+24, 2.9927834882976576, 6.271117095841008, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.087010191160611e+33, 7.927363846771015e+32, 0.0, 0.0, -0.2468633524580285, 0.0, 0.0, -0.029960035373381145, 3.085677581491367e+24, 2.9927834882976576, 6.271117095841008, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 49
# Generation with parameters (4.202176404662065e+33, 9.831078045498602e+32, 0.0, 0.0, 0.07936154250385014, 0.0, 0.0, 0.31428449236122113, 3.085677581491367e+24, 0.6465135933189832, 3.85136362995773, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.202176404662065e+33, 9.831078045498602e+32, 0.0, 0.0, 0.07936154250385014, 0.0, 0.0, 0.31428449236122113, 3.085677581491367e+24, 0.6465135933189832, 3.85136362995773, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 50
# Generation with parameters (4.089984864503037e+33, 1.0785766786333128e+33, 0.0, 0.0, -0.002880417570544353, 0.0, 0.0, -0.026647428256205023, 3.085677581491367e+24, 2.297678167047728, 6.085599222619319, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.089984864503037e+33, 1.0785766786333128e+33, 0.0, 0.0, -0.002880417570544353, 0.0, 0.0, -0.026647428256205023, 3.085677581491367e+24, 2.297678167047728, 6.085599222619319, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 51
# Generation with parameters (1.3289153931634043e+33, 5.80701342391532e+32, 0.0, 0.0, -0.04114722636734278, 0.0, 0.0, 0.4272215441879734, 3.085677581491367e+24, 2.0580075919252137, 0.09395427392737389, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3289153931634043e+33, 5.80701342391532e+32, 0.0, 0.0, -0.04114722636734278, 0.0, 0.0, 0.4272215441879734, 3.085677581491367e+24, 2.0580075919252137, 0.09395427392737389, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 52
# Generation with parameters (5.75749447151884e+33, 8.377471629333036e+32, 0.0, 0.0, 0.07648809878793036, 0.0, 0.0, -0.7541659686834986, 3.085677581491367e+24, 2.4164920244637633, 5.782792001546828, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.75749447151884e+33, 8.377471629333036e+32, 0.0, 0.0, 0.07648809878793036, 0.0, 0.0, -0.7541659686834986, 3.085677581491367e+24, 2.4164920244637633, 5.782792001546828, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 53
# Generation with parameters (2.1973303874472103e+33, 1.0697758141968024e+33, 0.0, 0.0, -0.32665563088987076, 0.0, 0.0, -0.053803826999524164, 3.085677581491367e+24, 1.9236048236483219, 4.431467170067947, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.1973303874472103e+33, 1.0697758141968024e+33, 0.0, 0.0, -0.32665563088987076, 0.0, 0.0, -0.053803826999524164, 3.085677581491367e+24, 1.9236048236483219, 4.431467170067947, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 54
# Generation with parameters (1.8465936138304312e+33, 1.4581975004917835e+33, 0.0, 0.0, 0.253913766150405, 0.0, 0.0, 0.5278971908196116, 3.085677581491367e+24, 1.4297467690398316, 0.4121856696652353, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8465936138304312e+33, 1.4581975004917835e+33, 0.0, 0.0, 0.253913766150405, 0.0, 0.0, 0.5278971908196116, 3.085677581491367e+24, 1.4297467690398316, 0.4121856696652353, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 55
# Generation with parameters (1.6925632527445754e+33, 1.5267479764495732e+33, 0.0, 0.0, 0.020862088818177617, 0.0, 0.0, -0.8375849955739406, 3.085677581491367e+24, 2.5569633413214894, 2.5568386419592444, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6925632527445754e+33, 1.5267479764495732e+33, 0.0, 0.0, 0.020862088818177617, 0.0, 0.0, -0.8375849955739406, 3.085677581491367e+24, 2.5569633413214894, 2.5568386419592444, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 56
# Generation with parameters (2.4061419438949493e+33, 4.889583655920695e+32, 0.0, 0.0, 0.044607209871101505, 0.0, 0.0, -0.12696211497434623, 3.085677581491367e+24, 0.5175705670508607, 0.15929935403276335, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.4061419438949493e+33, 4.889583655920695e+32, 0.0, 0.0, 0.044607209871101505, 0.0, 0.0, -0.12696211497434623, 3.085677581491367e+24, 0.5175705670508607, 0.15929935403276335, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 57
# Generation with parameters (4.518032034237703e+33, 1.1258496548579171e+33, 0.0, 0.0, -0.3163497589970143, 0.0, 0.0, -0.2192655799201913, 3.085677581491367e+24, 1.340288765817993, 0.45524017531007244, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.518032034237703e+33, 1.1258496548579171e+33, 0.0, 0.0, -0.3163497589970143, 0.0, 0.0, -0.2192655799201913, 3.085677581491367e+24, 1.340288765817993, 0.45524017531007244, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 58
# Generation with parameters (3.906635707503143e+33, 1.3981637711813153e+33, 0.0, 0.0, -0.6672722413898527, 0.0, 0.0, 0.19896912403643, 3.085677581491367e+24, 0.9239169425245819, 6.170248356108467, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.906635707503143e+33, 1.3981637711813153e+33, 0.0, 0.0, -0.6672722413898527, 0.0, 0.0, 0.19896912403643, 3.085677581491367e+24, 0.9239169425245819, 6.170248356108467, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 59
# Generation with parameters (3.218842739207451e+33, 1.46676451429102e+33, 0.0, 0.0, 0.7004544596167587, 0.0, 0.0, 0.06213402539462508, 3.085677581491367e+24, 1.5817966519001552, 4.978791925106354, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.218842739207451e+33, 1.46676451429102e+33, 0.0, 0.0, 0.7004544596167587, 0.0, 0.0, 0.06213402539462508, 3.085677581491367e+24, 1.5817966519001552, 4.978791925106354, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 60
# Generation with parameters (2.6272768762626875e+33, 9.012243748222959e+32, 0.0, 0.0, 0.1012164413911167, 0.0, 0.0, -0.11960339944284264, 3.085677581491367e+24, 1.9003836798626934, 0.3280821547607739, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.6272768762626875e+33, 9.012243748222959e+32, 0.0, 0.0, 0.1012164413911167, 0.0, 0.0, -0.11960339944284264, 3.085677581491367e+24, 1.9003836798626934, 0.3280821547607739, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 61
# Generation with parameters (3.6823456119282306e+33, 1.2765005146113276e+33, 0.0, 0.0, -0.5666818346421479, 0.0, 0.0, 0.019376418716828044, 3.085677581491367e+24, 0.8425709161449636, 5.594882648601007, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.6823456119282306e+33, 1.2765005146113276e+33, 0.0, 0.0, -0.5666818346421479, 0.0, 0.0, 0.019376418716828044, 3.085677581491367e+24, 0.8425709161449636, 5.594882648601007, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 62
# Generation with parameters (1.7970139932253738e+33, 1.1733778843356087e+33, 0.0, 0.0, 0.8287634697430564, 0.0, 0.0, -0.30527144883196516, 3.085677581491367e+24, 1.3337533404120696, 4.382736559710286, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7970139932253738e+33, 1.1733778843356087e+33, 0.0, 0.0, 0.8287634697430564, 0.0, 0.0, -0.30527144883196516, 3.085677581491367e+24, 1.3337533404120696, 4.382736559710286, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 63
# Running injection 64
# Generation with parameters (3.0304487203953796e+33, 1.4862255448472497e+33, 0.0, 0.0, -0.35256028347276486, 0.0, 0.0, -0.33770337529978117, 3.085677581491367e+24, 0.6194231337281727, 5.725112259693003, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.0304487203953796e+33, 1.4862255448472497e+33, 0.0, 0.0, -0.35256028347276486, 0.0, 0.0, -0.33770337529978117, 3.085677581491367e+24, 0.6194231337281727, 5.725112259693003, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 65
# Generation with parameters (2.1505805716972217e+33, 1.555686847716338e+33, 0.0, 0.0, 0.041029135276578955, 0.0, 0.0, -0.042970372190054874, 3.085677581491367e+24, 1.5104430662362356, 4.838363466820759, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.1505805716972217e+33, 1.555686847716338e+33, 0.0, 0.0, 0.041029135276578955, 0.0, 0.0, -0.042970372190054874, 3.085677581491367e+24, 1.5104430662362356, 4.838363466820759, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 66
# Generation with parameters (2.505064571959696e+33, 1.9988006979506802e+33, 0.0, 0.0, 0.8224351655779658, 0.0, 0.0, -0.7332640515815285, 3.085677581491367e+24, 2.5984049877473736, 1.3352048302583477, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.505064571959696e+33, 1.9988006979506802e+33, 0.0, 0.0, 0.8224351655779658, 0.0, 0.0, -0.7332640515815285, 3.085677581491367e+24, 2.5984049877473736, 1.3352048302583477, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 67
# Generation with parameters (6.354786494638002e+32, 5.3364250701915104e+32, 0.0, 0.0, -0.5138056501533936, 0.0, 0.0, 0.07519694262432355, 3.085677581491367e+24, 0.4658087109024609, 6.096433200228991, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.354786494638002e+32, 5.3364250701915104e+32, 0.0, 0.0, -0.5138056501533936, 0.0, 0.0, 0.07519694262432355, 3.085677581491367e+24, 0.4658087109024609, 6.096433200228991, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 68
# Running injection 69
# Generation with parameters (1.3757843400579952e+33, 1.1440012004389406e+33, 0.0, 0.0, 0.055763695897149794, 0.0, 0.0, -0.7258876134395214, 3.085677581491367e+24, 2.1529333759684723, 2.853246626574009, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3757843400579952e+33, 1.1440012004389406e+33, 0.0, 0.0, 0.055763695897149794, 0.0, 0.0, -0.7258876134395214, 3.085677581491367e+24, 2.1529333759684723, 2.853246626574009, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 70
# Generation with parameters (1.1784307237144703e+33, 4.464509864509192e+32, 0.0, 0.0, 0.34515295577800353, 0.0, 0.0, -0.2899048908562654, 3.085677581491367e+24, 1.5938140990689647, 4.378469325196504, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1784307237144703e+33, 4.464509864509192e+32, 0.0, 0.0, 0.34515295577800353, 0.0, 0.0, -0.2899048908562654, 3.085677581491367e+24, 1.5938140990689647, 4.378469325196504, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 71
# ...
# Warning: turning off multibanding for parameters (1.70200247697774e+33, 6.337712043030487e+32, 0.0, 0.0, -0.14003048724088474, 0.0, 0.0, -0.15273399427085513, 3.085677581491367e+24, 1.83991469459414, 2.5918144563308307, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 975
# Generation with parameters (2.5566940302481216e+33, 2.0309542444995235e+33, 0.0, 0.0, -0.2795739848819235, 0.0, 0.0, -0.06461627207350742, 3.085677581491367e+24, 1.1652413727911322, 0.7906699865419116, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5566940302481216e+33, 2.0309542444995235e+33, 0.0, 0.0, -0.2795739848819235, 0.0, 0.0, -0.06461627207350742, 3.085677581491367e+24, 1.1652413727911322, 0.7906699865419116, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 976
# Generation with parameters (5.343835251422456e+33, 8.66350636498165e+32, 0.0, 0.0, 0.4668295408077165, 0.0, 0.0, 0.5029742238391568, 3.085677581491367e+24, 2.151937127004619, 1.844593426202206, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.343835251422456e+33, 8.66350636498165e+32, 0.0, 0.0, 0.4668295408077165, 0.0, 0.0, 0.5029742238391568, 3.085677581491367e+24, 2.151937127004619, 1.844593426202206, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 977
# Generation with parameters (2.5940065625795048e+33, 1.7901519205214093e+33, 0.0, 0.0, 0.21654572636866176, 0.0, 0.0, 0.05419428783136028, 3.085677581491367e+24, 1.0184660030932848, 3.2750150271866993, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5940065625795048e+33, 1.7901519205214093e+33, 0.0, 0.0, 0.21654572636866176, 0.0, 0.0, 0.05419428783136028, 3.085677581491367e+24, 1.0184660030932848, 3.2750150271866993, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 978
# Generation with parameters (2.9657997671514417e+33, 1.4643613185914248e+33, 0.0, 0.0, -0.05064515588605125, 0.0, 0.0, -0.07751918006448053, 3.085677581491367e+24, 1.7083601400750383, 2.802285613635788, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.9657997671514417e+33, 1.4643613185914248e+33, 0.0, 0.0, -0.05064515588605125, 0.0, 0.0, -0.07751918006448053, 3.085677581491367e+24, 1.7083601400750383, 2.802285613635788, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 979
# Generation with parameters (3.4743463850385254e+33, 6.2508859457625625e+32, 0.0, 0.0, 0.06178564805937363, 0.0, 0.0, -0.43061132132309793, 3.085677581491367e+24, 1.020841264528509, 0.3893865263464525, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.4743463850385254e+33, 6.2508859457625625e+32, 0.0, 0.0, 0.06178564805937363, 0.0, 0.0, -0.43061132132309793, 3.085677581491367e+24, 1.020841264528509, 0.3893865263464525, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 980
# Generation with parameters (2.3372217861139204e+33, 1.3780930460340568e+33, 0.0, 0.0, -0.051042354744756595, 0.0, 0.0, -0.022131376184258745, 3.085677581491367e+24, 2.2100144546253135, 2.31947788563774, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3372217861139204e+33, 1.3780930460340568e+33, 0.0, 0.0, -0.051042354744756595, 0.0, 0.0, -0.022131376184258745, 3.085677581491367e+24, 2.2100144546253135, 2.31947788563774, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 981
# Generation with parameters (5.302840003098684e+33, 8.683068469662074e+32, 0.0, 0.0, -0.1345977759496919, 0.0, 0.0, -0.20928035333916667, 3.085677581491367e+24, 3.0687837917562804, 2.8039676097855826, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.302840003098684e+33, 8.683068469662074e+32, 0.0, 0.0, -0.1345977759496919, 0.0, 0.0, -0.20928035333916667, 3.085677581491367e+24, 3.0687837917562804, 2.8039676097855826, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 982
# Generation with parameters (1.8192425622470642e+33, 1.7061417216242088e+33, 0.0, 0.0, 0.19699674403185002, 0.0, 0.0, 0.1839985134836865, 3.085677581491367e+24, 1.0196987574229974, 2.456387034624686, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8192425622470642e+33, 1.7061417216242088e+33, 0.0, 0.0, 0.19699674403185002, 0.0, 0.0, 0.1839985134836865, 3.085677581491367e+24, 1.0196987574229974, 2.456387034624686, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 983
# Generation with parameters (1.6006976671878163e+33, 2.0770959076540956e+32, 0.0, 0.0, 0.10107556131311686, 0.0, 0.0, 0.1663516848099225, 3.085677581491367e+24, 1.5285667864566332, 3.371045682658156, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6006976671878163e+33, 2.0770959076540956e+32, 0.0, 0.0, 0.10107556131311686, 0.0, 0.0, 0.1663516848099225, 3.085677581491367e+24, 1.5285667864566332, 3.371045682658156, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 984
# Generation with parameters (2.2680780665857135e+33, 1.9986858884501591e+33, 0.0, 0.0, -0.7685621897585387, 0.0, 0.0, -0.00523919653053071, 3.085677581491367e+24, 2.5456102673577026, 3.511235706319292, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2680780665857135e+33, 1.9986858884501591e+33, 0.0, 0.0, -0.7685621897585387, 0.0, 0.0, -0.00523919653053071, 3.085677581491367e+24, 2.5456102673577026, 3.511235706319292, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 985
# Generation with parameters (2.1972389585942407e+33, 1.418128037602865e+33, 0.0, 0.0, -0.42547697348368596, 0.0, 0.0, -0.22499963934613723, 3.085677581491367e+24, 0.5372778297303636, 0.13447385392311734, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.1972389585942407e+33, 1.418128037602865e+33, 0.0, 0.0, -0.42547697348368596, 0.0, 0.0, -0.22499963934613723, 3.085677581491367e+24, 0.5372778297303636, 0.13447385392311734, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 986
# Generation with parameters (5.494131501506717e+33, 7.121178333105828e+32, 0.0, 0.0, -0.26688333189753705, 0.0, 0.0, 0.09037378603862833, 3.085677581491367e+24, 1.1050197424980868, 5.839278587747917, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.494131501506717e+33, 7.121178333105828e+32, 0.0, 0.0, -0.26688333189753705, 0.0, 0.0, 0.09037378603862833, 3.085677581491367e+24, 1.1050197424980868, 5.839278587747917, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 987
# Generation with parameters (1.756119910098605e+33, 1.3641666958407753e+33, 0.0, 0.0, 0.28064554983041823, 0.0, 0.0, 0.2992101356388518, 3.085677581491367e+24, 2.0703259498226223, 2.5926895150109046, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.756119910098605e+33, 1.3641666958407753e+33, 0.0, 0.0, 0.28064554983041823, 0.0, 0.0, 0.2992101356388518, 3.085677581491367e+24, 2.0703259498226223, 2.5926895150109046, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 988
# Generation with parameters (4.868435716283572e+33, 8.484229954697154e+32, 0.0, 0.0, 0.0021180734148703367, 0.0, 0.0, 0.4897069556680393, 3.085677581491367e+24, 1.9420563568771367, 0.46474807412450636, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.868435716283572e+33, 8.484229954697154e+32, 0.0, 0.0, 0.0021180734148703367, 0.0, 0.0, 0.4897069556680393, 3.085677581491367e+24, 1.9420563568771367, 0.46474807412450636, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 989
# Running injection 990
# Running injection 991
# Generation with parameters (4.848352275901261e+33, 1.1006108157706979e+33, 0.0, 0.0, 0.10494807355456044, 0.0, 0.0, -0.40047127479176386, 3.085677581491367e+24, 1.3628658529432482, 0.7183860525130745, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.848352275901261e+33, 1.1006108157706979e+33, 0.0, 0.0, 0.10494807355456044, 0.0, 0.0, -0.40047127479176386, 3.085677581491367e+24, 1.3628658529432482, 0.7183860525130745, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 992
# Generation with parameters (2.2163242558583746e+33, 1.3571448486905322e+33, 0.0, 0.0, 0.001948400841820197, 0.0, 0.0, 0.02290343409321317, 3.085677581491367e+24, 1.4028120177567798, 5.316437366256692, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2163242558583746e+33, 1.3571448486905322e+33, 0.0, 0.0, 0.001948400841820197, 0.0, 0.0, 0.02290343409321317, 3.085677581491367e+24, 1.4028120177567798, 5.316437366256692, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 993
# Generation with parameters (1.3732250340066696e+33, 1.338367735802872e+33, 0.0, 0.0, 0.16120782683493645, 0.0, 0.0, -0.003191484353316428, 3.085677581491367e+24, 2.0012813872479334, 3.0552322984190567, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3732250340066696e+33, 1.338367735802872e+33, 0.0, 0.0, 0.16120782683493645, 0.0, 0.0, -0.003191484353316428, 3.085677581491367e+24, 2.0012813872479334, 3.0552322984190567, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 994
# Generation with parameters (5.864512667023048e+33, 9.048304719503327e+32, 0.0, 0.0, -0.3435058807350553, 0.0, 0.0, 0.08003766610903779, 3.085677581491367e+24, 1.7835420221536142, 4.702192947960472, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.864512667023048e+33, 9.048304719503327e+32, 0.0, 0.0, -0.3435058807350553, 0.0, 0.0, 0.08003766610903779, 3.085677581491367e+24, 1.7835420221536142, 4.702192947960472, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 995
# Generation with parameters (4.6012903868285485e+33, 8.017544120158826e+32, 0.0, 0.0, 0.09929790293889568, 0.0, 0.0, -0.253879146768672, 3.085677581491367e+24, 2.139938020371473, 5.004781330692289, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.6012903868285485e+33, 8.017544120158826e+32, 0.0, 0.0, 0.09929790293889568, 0.0, 0.0, -0.253879146768672, 3.085677581491367e+24, 2.139938020371473, 5.004781330692289, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 996
# Generation with parameters (2.46587034066001e+33, 1.7664981337803318e+33, 0.0, 0.0, -0.18593044653504218, 0.0, 0.0, -0.4706676509446434, 3.085677581491367e+24, 2.0068521255759246, 1.9160794659517286, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.46587034066001e+33, 1.7664981337803318e+33, 0.0, 0.0, -0.18593044653504218, 0.0, 0.0, -0.4706676509446434, 3.085677581491367e+24, 2.0068521255759246, 1.9160794659517286, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 997
# Generation with parameters (4.352668266847131e+33, 6.2889407800641824e+32, 0.0, 0.0, 0.21492116586275195, 0.0, 0.0, -0.7248016335527062, 3.085677581491367e+24, 1.7950959484419893, 1.7119871362436316, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.352668266847131e+33, 6.2889407800641824e+32, 0.0, 0.0, 0.21492116586275195, 0.0, 0.0, -0.7248016335527062, 3.085677581491367e+24, 1.7950959484419893, 1.7119871362436316, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 998
# Generation with parameters (5.662889271948202e+33, 8.095644800939827e+32, 0.0, 0.0, -0.3536294805817393, 0.0, 0.0, -0.30346084218275177, 3.085677581491367e+24, 0.44884365217640676, 3.2406342949019473, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.662889271948202e+33, 8.095644800939827e+32, 0.0, 0.0, -0.3536294805817393, 0.0, 0.0, -0.30346084218275177, 3.085677581491367e+24, 0.44884365217640676, 3.2406342949019473, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 999
# Generation with parameters (2.784262649187301e+33, 8.643018527481922e+32, 0.0, 0.0, -0.8127105940752769, 0.0, 0.0, 0.012086666393214906, 3.085677581491367e+24, 2.3523476504901364, 1.5343239830581923, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.784262649187301e+33, 8.643018527481922e+32, 0.0, 0.0, -0.8127105940752769, 0.0, 0.0, 0.012086666393214906, 3.085677581491367e+24, 2.3523476504901364, 1.5343239830581923, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.

# %% [markdown]
# ## Infere parameters

# %%
#%%capture  
#avoids printing a lot of output to the notebook
import pandas as pd
from dingo.gw.inference.gw_samplers import GWSampler




os.makedirs(f"/scratch/tpausch/test_data/{name}/results", exist_ok=True)

injection_files = sorted(os.listdir(f"/scratch/tpausch/test_data/stage1/injections"))

#first 100 injections
for fname in injection_files:

    # --------------------------------------------------------
    # Load injection
    # --------------------------------------------------------

    with open(f"/scratch/tpausch/test_data/stage1/injections/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    strain_data = payload["strain_data"]

    # --------------------------------------------------------
    # Run sampler
    # --------------------------------------------------------

    sampler = GWSampler(model=main_pm)

    sampler.context = strain_data

    sampler.run_sampler(
        num_samples=50_000,
        batch_size=10_000,
    )

    result = sampler.to_result()



    # --------------------------------------------------------
    # calculate network SNR
    # --------------------------------------------------------
    parameters = pd.DataFrame(
        {key: np.array([np.asarray(val).item()]) for key, val in theta_true.items()}
    )
    snr_df = gw.utilities.get_snr(parameters, network, waveform_model, f_ref)
    network_snr = float(snr_df["network"].iloc[0])  # extract as plain float

    # --------------------------------------------------------
    # Store result
    # --------------------------------------------------------

    result_payload = {
        "theta_true": theta_true,
        "result": result,
        "network_snr": network_snr,
    }

    outname = fname.replace("inj_", "result_")

    with open(f"/scratch/tpausch/test_data/{name}/results/{outname}", "wb") as f:
        pickle.dump(result_payload, f)

    print(f"Saved /scratch/tpausch/test_data/{name}/results/{outname}")
# Out:
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0000.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0001.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0002.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0003.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0004.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0005.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0006.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0007.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0008.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0009.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0010.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0011.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0012.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0013.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0014.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0015.pkl
# Running sampler to generate 50000 samples.
# Done. This took 4.9 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0016.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0017.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0018.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0019.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0020.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0021.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0022.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0023.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0024.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0025.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0026.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0027.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0028.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0029.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0030.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0031.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0032.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0033.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0034.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0035.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0036.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0037.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0038.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.1 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0039.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0040.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.1 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0041.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0042.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0043.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0044.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0045.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0046.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0047.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0048.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0049.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0050.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0051.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0052.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0053.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.1 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0054.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.1 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0055.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.1 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0056.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.1 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0057.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0058.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0059.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0060.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0061.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.1 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0062.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0063.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.1 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0064.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0065.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.1 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0066.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0067.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0068.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.1 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0069.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.1 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0070.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0071.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.1 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0072.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0073.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0074.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.1 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0075.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.1 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# ...
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0403.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0404.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0405.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0406.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0407.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0408.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0409.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0410.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0411.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0412.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0413.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0414.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0415.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0416.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0417.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0418.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0419.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0420.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0421.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0422.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0423.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0424.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0425.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0426.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0427.pkl
# Running sampler to generate 50000 samples.
# Done. This took 5.0 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1_2/results/result_0428.pkl
# Running sampler to generate 50000 samples.

# %% [markdown]
# ## Calculate and plot chirp mass inference error

# %%
true_cm = []
true_mr = []
mass_ratio_error = []
mass_ratio_std = []
chirp_mass_error = []
chirp_mass_std = []


result_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/{name}/results/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    result = payload["result"]

    posterior_samples = result.samples

    #q_samples = np.array(posterior_samples["mass_ratio"])

    # inference statistics
    #q_mean = np.mean(q_samples)
    #q_std = np.std(q_samples)
#
    #true_q = theta_true["mass_ratio"]

    cm_samples = np.array(posterior_samples["chirp_mass"])

    cm_mean = np.mean(cm_samples)
    cm_std = np.std(cm_samples)

    true_mr.append(theta_true["mass_ratio"])
    true_cm.append(theta_true["chirp_mass"])
    #mass_ratio_error.append(q_mean - true_q)
    #mass_ratio_std.append(q_std)
    chirp_mass_error.append(cm_mean - theta_true["chirp_mass"])
    chirp_mass_std.append(cm_std)


true_mr = np.array(true_mr)
true_cm = np.array(true_cm)

# ------------------------------------------------------------
# Error bars
# ------------------------------------------------------------

#plt.errorbar(
#    true_cm,
#    chirp_mass_error,
#    yerr=chirp_mass_std,
#    fmt="none",
#    capsize=4,
#    alpha=0.5,
#    color="gray",
#)

# ------------------------------------------------------------
# Colored scatter points
# ------------------------------------------------------------

sc = plt.scatter(
    true_cm,
    chirp_mass_error,
    s=20,
    edgecolor="black",
    alpha=0.3
)

# ------------------------------------------------------------
# Reference line
# ------------------------------------------------------------

plt.axhline(0, linestyle="--", color="black")


# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel("True chirp mass")
plt.ylabel("Chirp mass inference error (inferred − true)")

plt.title("Chirp-mass inference error")

plt.grid(True)

plt.tight_layout()
plt.show()

cm_err = np.asarray(chirp_mass_error)

mean_error = np.mean(cm_err)          # signed average bias (over/under-estimation)
mean_abs_error = np.mean(np.abs(cm_err))  # average magnitude of deviation
rms_error = np.sqrt(np.mean(cm_err**2))   # RMS deviation, penalizes outliers more
std_error = np.std(cm_err)            # spread of the errors around their mean
p90_abs_error = np.percentile(np.abs(cm_err), 90)
p95_abs_error = np.percentile(np.abs(cm_err), 95)
p99_abs_error = np.percentile(np.abs(cm_err), 99)


print(f"Mean error (bias):      {mean_error:.3f}")
print(f"Mean absolute error:    {mean_abs_error:.3f}")
print(f"RMS error:              {rms_error:.3f}")
print(f"Std of error:           {std_error:.3f}")
print(f"90th percentile |error|: {p90_abs_error:.3f}")
print(f"95th percentile |error|: {p95_abs_error:.3f}")
print(f"99th percentile |error|: {p99_abs_error:.3f}")
# Out:
# Mean error (bias):      0.366
# Mean absolute error:    29.466
# RMS error:              55.995
# Std of error:           55.994
# 90th percentile |error|: 80.943
# 95th percentile |error|: 119.574
# 99th percentile |error|: 218.018

# %% [markdown]
# ## PP-plot

# %%
pp_values_chirp_mass = []
pp_values_mass_ratio = []

result_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/{name}/results/{fname}", "rb") as f:

        payload = pickle.load(f)

        theta_true = payload["theta_true"]
        result = payload["result"]

        posterior_samples = result.samples


        # ============================================================
        # Chirp mass PP value
        # ============================================================

        cm_samples = posterior_samples["chirp_mass"]

        pp_cm = np.mean(
            cm_samples < theta_true["chirp_mass"]
        )

        pp_values_chirp_mass.append(pp_cm)


        # ============================================================
        # Mass ratio PP value
        # ============================================================

        #q_samples = posterior_samples["mass_ratio"]
#
        #pp_q = np.mean(
        #    q_samples < theta_true["mass_ratio"]
        #)
#
        #pp_values_mass_ratio.append(pp_q)




def plot_pp(pp_values, label):

    pp_values = np.array(pp_values)

    sorted_pp = np.sort(pp_values)

    n = len(sorted_pp)

    empirical_cdf = np.arange(1, n + 1) / n

    x = np.linspace(0, 1, 200)

    sigma = np.sqrt(x * (1 - x) / n)

    plt.figure(figsize=(6, 6))

    # Ideal calibration
    plt.plot(
        [0, 1],
        [0, 1],
        linestyle="--",
        label="Ideal calibration",
    )


    # Empirical PP curve
    plt.plot(
        sorted_pp,
        empirical_cdf,
        marker="o",
        label=label,
    )

    plt.xlabel("Credible level")
    plt.ylabel("Fraction of injections")

    plt.title(f"PP Plot: {label}")

    plt.xlim(0, 1)
    plt.ylim(0, 1)

    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()


plot_pp(
    pp_values_chirp_mass,
    "chirp_mass",
)

#plot_pp(
#    pp_values_mass_ratio,
#    "mass_ratio",
#)

# %% [markdown]
# ## SNR analysis

# %%
snrs = []
ci90_widths = []
chirp_masses = []

result_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/{name}/results/{fname}", "rb") as f:

        payload = pickle.load(f)
    
    theta_true = payload["theta_true"]
    result = payload["result"]


    snr = payload["network_snr"]   # use "ET" instead if you want the single-detector value
   

    snrs.append(snr)

    samples = result.samples["chirp_mass"].to_numpy()  # adjust if result.samples is a DataFrame

    ci90 = np.percentile(samples, 95) - np.percentile(samples, 5)
    ci90_widths.append(ci90)
    chirp_masses.append(theta_true["chirp_mass"])

snrs = np.array(snrs)
ci90_widths = np.array(ci90_widths)
chirp_masses = np.array(chirp_masses)

frac_widths = ci90_widths / chirp_masses  # relative width, dimensionless

plt.figure(figsize=(6, 5))
sc = plt.scatter(snrs, ci90_widths, c=chirp_masses, cmap="viridis", alpha=0.6, s=15)
#sc = plt.scatter(snrs, frac_widths, c=chirp_masses, cmap="viridis", alpha=0.6, s=15)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Network SNR")
plt.ylabel("Chirp mass 90% CI width")
plt.colorbar(sc, label="Injected chirp mass [M$_\\odot$]")
plt.title("posterior width vs SNR")
plt.grid(True, which="both", alpha=0.3)
plt.tight_layout()
plt.show()


chirp_mass_error = np.array(chirp_mass_error)
mask = snrs < 10000.0

plt.figure(figsize=(10, 5))
sc = plt.scatter(
    snrs[mask],
    chirp_mass_error[mask],
    s=10,
    edgecolor="black",
    alpha=0.3
)

plt.axhline(0, linestyle="--", color="black")
plt.xlabel("SNR")
plt.ylabel("Chirp mass inference error (inferred − true)")
plt.title("Chirp-mass inference error")
plt.grid(True)
plt.tight_layout()
plt.show()




# --- Plot distribution ---
plt.figure(figsize=(6, 5))

# Histogram, normalized to a density so it represents "how likely each value is"
counts, bins, _ = plt.hist(
    snrs, bins=100, density=True, alpha=0.5, color="steelblue", edgecolor="k", label="Histogram"
)
plt.xlabel("Network SNR")
plt.ylabel("Probability density")
plt.title(f"Distribution of injected network SNR (n={len(snrs)})")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()


print(f"SNR stats: min={snrs.min():.2f}, max={snrs.max():.2f}, "
      f"median={np.median(snrs):.2f}, mean={snrs.mean():.2f}",
      f"snr99={np.percentile(np.abs(snrs), 99):.2f}")
# Out:
# SNR stats: min=1.49, max=5003.07, median=113.07, mean=316.66 snr99=2078.25
