# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
import GWFish.modules as gw


os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # use GPU 1

name="imbh_T8_mass2_3_z10"

waveform_model = 'IMRPhenomXPHM'
f_ref = 20.
detectors = ['ET']
network = gw.detection.Network(detector_ids = detectors, detection_SNR = (0., 8.))
# Out:
# /home/tpausch/.conda/envs/ET-DINGO/lib/python3.10/site-packages/lalsimulation/_lalsimulation_swig.py:8: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   import lal

# %% [markdown]
# ## Load Model

# %%
from dingo.core.posterior_models.build_model import build_model_from_kwargs
main_pm = build_model_from_kwargs(
    filename=f"/scratch/tpausch/models/{name}/model_latest.pt",
    device="cuda",
    load_training_info=False,
)
# Out:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Putting posterior model to device cuda.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt(f"/scratch/tpausch/models/{name}/history.txt")
epochs   = data[:, 0]
train    = data[:, 1]
val      = data[:, 2]


plt.figure(figsize=(8, 5))
plt.plot(epochs, train, label="Train loss")
plt.plot(epochs, val,   label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("Log-likelihood")
plt.legend()
plt.title("Dingo training history")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Simulate injections

# %%
import dingo.gw.injection as injection
from dingo.gw.noise.asd_dataset import ASDDataset

# ============================================================
# Setup
# ============================================================

num_injections = 1000
out_dir = f"/scratch/tpausch/test_data/{name}/injections"
os.makedirs(out_dir, exist_ok=True)

np.random.seed(42)  # optional, for reproducibility

injection_generator = injection.Injection.from_posterior_model_metadata(
    main_pm.metadata
)

asd_fname = main_pm.metadata["train_settings"]["training"]["stage_0"]["asd_dataset_path"]
asd_dataset = ASDDataset(file_name=asd_fname)

injection_generator.asd = {
    k: v[0] for k, v in asd_dataset.asds.items()
}

# This is the combined intrinsic + extrinsic bilby PriorDict
# that the network was trained on
prior = injection_generator.prior
print(prior)

# ============================================================
# Draw and run injections
# ============================================================

for idx in range(num_injections):

    print(f"Running injection {idx}")

    theta = prior.sample()
    theta = {k: float(v) for k, v in theta.items()}  # cast numpy -> float

    strain_data = injection_generator.injection(theta)

    payload = {
        "theta_true": theta,
        "strain_data": strain_data,
    }

    fname = os.path.join(out_dir, f"inj_{idx:04d}.pkl")

    with open(fname, "wb") as f:
        pickle.dump(payload, f)
# Out:
# Setting spin_conversion_phase = 0.0. Using this value for the phase parameter for conversion to cartesian spins.
# Loading dataset from training_data/asds_ET_T8.hdf5.
# {'mass_1': Constraint(minimum=30.0, maximum=3000.0, name='mass_1', latex_label='$m_1$', unit=None), 'mass_2': Constraint(minimum=30.0, maximum=3000.0, name='mass_2', latex_label='$m_2$', unit=None), 'chirp_mass': bilby.gw.prior.UniformInComponentsChirpMass(minimum=50.0, maximum=1000.0, name='chirp_mass', latex_label='$\\mathcal{M}$', unit=None, boundary=None), 'mass_ratio': bilby.gw.prior.UniformInComponentsMassRatio(minimum=0.125, maximum=1.0, name='mass_ratio', latex_label='$q$', unit=None, boundary=None, equal_mass=False), 'phase': Uniform(minimum=0.0, maximum=6.283185307179586, name='phase', latex_label='$\\phi$', unit=None, boundary='periodic'), 'chi_1': bilby.gw.prior.AlignedSpin(a_prior=Uniform(minimum=0, maximum=0.9, name=None, latex_label=None, unit=None, boundary=None), z_prior=Uniform(minimum=-1, maximum=1, name=None, latex_label=None, unit=None, boundary=None), name='chi_1', latex_label='$\\chi_1$', unit=None, boundary=None, minimum=-0.9, maximum=0.9, num_interp=100000), 'chi_2': bilby.gw.prior.AlignedSpin(a_prior=Uniform(minimum=0, maximum=0.9, name=None, latex_label=None, unit=None, boundary=None), z_prior=Uniform(minimum=-1, maximum=1, name=None, latex_label=None, unit=None, boundary=None), name='chi_2', latex_label='$\\chi_2$', unit=None, boundary=None, minimum=-0.9, maximum=0.9, num_interp=100000), 'theta_jn': Sine(minimum=0.0, maximum=3.141592653589793, name='theta_jn', latex_label='$\\theta_{JN}$', unit=None, boundary=None), 'luminosity_distance': LogUniform(minimum=1000.0, maximum=100000.0, name='luminosity_distance', latex_label='$d_L$', unit=None, boundary=None), 'geocent_time': Uniform(minimum=-0.1, maximum=0.1, name='geocent_time', latex_label='$t_c$', unit=None, boundary=None), 'dec': Cosine(minimum=-1.5707963267948966, maximum=1.5707963267948966, name='dec', latex_label='$\\mathrm{DEC}$', unit=None, boundary=None), 'ra': Uniform(minimum=0.0, maximum=6.283185307179586, name='ra', latex_label='$\\mathrm{RA}$', unit=None, boundary='periodic'), 'psi': Uniform(minimum=0.0, maximum=3.141592653589793, name='psi', latex_label='$\\psi$', unit=None, boundary='periodic')}
# Running injection 0
# Generation with parameters (4.6779129200803105e+33, 6.086602906606435e+32, 0.0, 0.0, -0.24370420933449455, 0.0, 0.0, -0.1082478774160846, 3.085677581491367e+24, 1.7786631005992053, 5.348097153853454, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.6779129200803105e+33, 6.086602906606435e+32, 0.0, 0.0, -0.24370420933449455, 0.0, 0.0, -0.1082478774160846, 3.085677581491367e+24, 1.7786631005992053, 5.348097153853454, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1
# Generation with parameters (2.0435993375065952e+33, 1.6148521373375656e+33, 0.0, 0.0, -0.020740226943219295, 0.0, 0.0, -0.46908430966613407, 3.085677581491367e+24, 0.9980679088139918, 5.277750602728448, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0435993375065952e+33, 1.6148521373375656e+33, 0.0, 0.0, -0.020740226943219295, 0.0, 0.0, -0.46908430966613407, 3.085677581491367e+24, 0.9980679088139918, 5.277750602728448, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 2
# Generation with parameters (2.087354826582398e+33, 2.0282578258659864e+33, 0.0, 0.0, 0.19409920970138098, 0.0, 0.0, -0.7994464591026452, 3.085677581491367e+24, 1.1651465757439834, 5.6021210456292385, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.087354826582398e+33, 2.0282578258659864e+33, 0.0, 0.0, 0.19409920970138098, 0.0, 0.0, -0.7994464591026452, 3.085677581491367e+24, 1.1651465757439834, 5.6021210456292385, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 3
# Generation with parameters (2.238625177744953e+33, 9.600862988720475e+32, 0.0, 0.0, -0.6288445217760653, 0.0, 0.0, 0.04804818267223975, 3.085677581491367e+24, 1.5797822536099497, 3.037777214965129, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.238625177744953e+33, 9.600862988720475e+32, 0.0, 0.0, -0.6288445217760653, 0.0, 0.0, 0.04804818267223975, 3.085677581491367e+24, 1.5797822536099497, 3.037777214965129, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 4
# Running injection 5
# Generation with parameters (1.2161077834088233e+33, 7.996648496539058e+32, 0.0, 0.0, 0.31428301336324643, 0.0, 0.0, -0.1122333161576602, 3.085677581491367e+24, 2.93242333272534, 5.962765154835488, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2161077834088233e+33, 7.996648496539058e+32, 0.0, 0.0, 0.31428301336324643, 0.0, 0.0, -0.1122333161576602, 3.085677581491367e+24, 2.93242333272534, 5.962765154835488, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 6
# Generation with parameters (9.363679390548091e+32, 7.909570746984011e+32, 0.0, 0.0, -0.18916604307991272, 0.0, 0.0, 0.12817917826334008, 3.085677581491367e+24, 1.8378417746159013, 2.0657549773407573, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.363679390548091e+32, 7.909570746984011e+32, 0.0, 0.0, -0.18916604307991272, 0.0, 0.0, 0.12817917826334008, 3.085677581491367e+24, 1.8378417746159013, 2.0657549773407573, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 7
# Generation with parameters (3.3748622384075863e+33, 1.5260498662092546e+33, 0.0, 0.0, 0.6168099928562397, 0.0, 0.0, 0.37786484677232046, 3.085677581491367e+24, 0.4854285173907527, 0.9225730379668936, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.3748622384075863e+33, 1.5260498662092546e+33, 0.0, 0.0, 0.6168099928562397, 0.0, 0.0, 0.37786484677232046, 3.085677581491367e+24, 0.4854285173907527, 0.9225730379668936, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 8
# Generation with parameters (1.602075701271173e+33, 1.601666978676958e+33, 0.0, 0.0, 0.028972482460314006, 0.0, 0.0, 0.023537669158292928, 3.085677581491367e+24, 0.9259037791904403, 2.4520073380101897, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.602075701271173e+33, 1.601666978676958e+33, 0.0, 0.0, 0.028972482460314006, 0.0, 0.0, 0.023537669158292928, 3.085677581491367e+24, 0.9259037791904403, 2.4520073380101897, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 9
# Generation with parameters (4.114405444354964e+33, 8.3147581946592e+32, 0.0, 0.0, -0.0027868726556348577, 0.0, 0.0, -0.06690374008280492, 3.085677581491367e+24, 1.1789748266238418, 2.2839400145198723, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.114405444354964e+33, 8.3147581946592e+32, 0.0, 0.0, -0.0027868726556348577, 0.0, 0.0, -0.06690374008280492, 3.085677581491367e+24, 1.1789748266238418, 2.2839400145198723, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 10
# Generation with parameters (2.8279166327710553e+33, 1.6466747927514037e+33, 0.0, 0.0, 0.2965671800676805, 0.0, 0.0, -0.2777205693782667, 3.085677581491367e+24, 0.29132369073477427, 0.1934812509021567, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.8279166327710553e+33, 1.6466747927514037e+33, 0.0, 0.0, 0.2965671800676805, 0.0, 0.0, -0.2777205693782667, 3.085677581491367e+24, 0.29132369073477427, 0.1934812509021567, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 11
# Generation with parameters (1.6264854182292864e+33, 4.5230586009713396e+32, 0.0, 0.0, -0.13564481589585625, 0.0, 0.0, 0.6060269480322199, 3.085677581491367e+24, 1.594975603502773, 2.206140808347903, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6264854182292864e+33, 4.5230586009713396e+32, 0.0, 0.0, -0.13564481589585625, 0.0, 0.0, 0.6060269480322199, 3.085677581491367e+24, 1.594975603502773, 2.206140808347903, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 12
# Generation with parameters (3.3535652960684017e+33, 1.141014336824154e+33, 0.0, 0.0, 0.01245999403473834, 0.0, 0.0, 0.38971631017036457, 3.085677581491367e+24, 1.8691336715196338, 2.1505838895429927, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.3535652960684017e+33, 1.141014336824154e+33, 0.0, 0.0, 0.01245999403473834, 0.0, 0.0, 0.38971631017036457, 3.085677581491367e+24, 1.8691336715196338, 2.1505838895429927, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 13
# Generation with parameters (2.87119441993849e+33, 7.555272408647844e+32, 0.0, 0.0, -0.13497028167338168, 0.0, 0.0, -0.11779084463026568, 3.085677581491367e+24, 2.6956116183840155, 2.6018833281102385, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.87119441993849e+33, 7.555272408647844e+32, 0.0, 0.0, -0.13497028167338168, 0.0, 0.0, -0.11779084463026568, 3.085677581491367e+24, 2.6956116183840155, 2.6018833281102385, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 14
# Generation with parameters (2.047299497827605e+33, 1.1903379318568315e+33, 0.0, 0.0, -0.13946093097119996, 0.0, 0.0, -0.300626303925087, 3.085677581491367e+24, 0.6189876480003935, 1.5662000693897569, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.047299497827605e+33, 1.1903379318568315e+33, 0.0, 0.0, -0.13946093097119996, 0.0, 0.0, -0.300626303925087, 3.085677581491367e+24, 0.6189876480003935, 1.5662000693897569, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 15
# Generation with parameters (4.4075546541391874e+33, 7.455842086528633e+32, 0.0, 0.0, 0.4632207406133669, 0.0, 0.0, -0.33247755437203297, 3.085677581491367e+24, 0.3582384738024779, 0.5846399044468772, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.4075546541391874e+33, 7.455842086528633e+32, 0.0, 0.0, 0.4632207406133669, 0.0, 0.0, -0.33247755437203297, 3.085677581491367e+24, 0.3582384738024779, 0.5846399044468772, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 16
# Generation with parameters (2.9653681214719236e+33, 8.186168489645282e+32, 0.0, 0.0, 0.05128669415344228, 0.0, 0.0, -0.10787863781792192, 3.085677581491367e+24, 1.901881108917698, 0.31154628267942636, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.9653681214719236e+33, 8.186168489645282e+32, 0.0, 0.0, 0.05128669415344228, 0.0, 0.0, -0.10787863781792192, 3.085677581491367e+24, 1.901881108917698, 0.31154628267942636, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 17
# Generation with parameters (3.138183463961479e+33, 1.2497228776764506e+33, 0.0, 0.0, -0.09409394351395475, 0.0, 0.0, -0.06503865199560266, 3.085677581491367e+24, 1.4466847976210966, 5.415063873657627, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.138183463961479e+33, 1.2497228776764506e+33, 0.0, 0.0, -0.09409394351395475, 0.0, 0.0, -0.06503865199560266, 3.085677581491367e+24, 1.4466847976210966, 5.415063873657627, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 18
# Generation with parameters (1.439640497874695e+33, 1.1075807822136527e+33, 0.0, 0.0, -0.31826184812347386, 0.0, 0.0, -0.07000779894039233, 3.085677581491367e+24, 0.7696743703851586, 4.159040637470598, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.439640497874695e+33, 1.1075807822136527e+33, 0.0, 0.0, -0.31826184812347386, 0.0, 0.0, -0.07000779894039233, 3.085677581491367e+24, 0.7696743703851586, 4.159040637470598, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 19
# Generation with parameters (2.6363354709017763e+33, 5.5062563235485434e+32, 0.0, 0.0, -0.7298694010028413, 0.0, 0.0, 0.08213765342252811, 3.085677581491367e+24, 1.3356928412827112, 0.7758690540713523, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.6363354709017763e+33, 5.5062563235485434e+32, 0.0, 0.0, -0.7298694010028413, 0.0, 0.0, 0.08213765342252811, 3.085677581491367e+24, 1.3356928412827112, 0.7758690540713523, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 20
# Generation with parameters (2.0720834824470408e+33, 3.0486386420052377e+32, 0.0, 0.0, -0.0408137509143779, 0.0, 0.0, -0.05733413704838611, 3.085677581491367e+24, 1.5660199087324334, 5.294104526344542, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0720834824470408e+33, 3.0486386420052377e+32, 0.0, 0.0, -0.0408137509143779, 0.0, 0.0, -0.05733413704838611, 3.085677581491367e+24, 1.5660199087324334, 5.294104526344542, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 21
# Generation with parameters (2.265903903290477e+33, 1.0193901104204136e+33, 0.0, 0.0, -0.18282138157071046, 0.0, 0.0, 0.1553887196206467, 3.085677581491367e+24, 1.2090705006997156, 1.8578443451148725, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.265903903290477e+33, 1.0193901104204136e+33, 0.0, 0.0, -0.18282138157071046, 0.0, 0.0, 0.1553887196206467, 3.085677581491367e+24, 1.2090705006997156, 1.8578443451148725, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 22
# Generation with parameters (2.6182148994716625e+33, 1.7122542856699183e+33, 0.0, 0.0, 0.3258643575816123, 0.0, 0.0, -0.24461186285768227, 3.085677581491367e+24, 1.2654436227714634, 2.4884058208606645, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.6182148994716625e+33, 1.7122542856699183e+33, 0.0, 0.0, 0.3258643575816123, 0.0, 0.0, -0.24461186285768227, 3.085677581491367e+24, 1.2654436227714634, 2.4884058208606645, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 23
# Generation with parameters (3.3667787769993466e+33, 6.4367565648782326e+32, 0.0, 0.0, -0.06893239864291986, 0.0, 0.0, -0.027569427473482008, 3.085677581491367e+24, 1.4709403155783032, 3.6779316749169118, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.3667787769993466e+33, 6.4367565648782326e+32, 0.0, 0.0, -0.06893239864291986, 0.0, 0.0, -0.027569427473482008, 3.085677581491367e+24, 1.4709403155783032, 3.6779316749169118, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 24
# Generation with parameters (8.75609161420245e+32, 4.862472003983785e+32, 0.0, 0.0, -0.1449145173417482, 0.0, 0.0, -0.3123616666440921, 3.085677581491367e+24, 1.098255594357798, 1.5979994505863926, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.75609161420245e+32, 4.862472003983785e+32, 0.0, 0.0, -0.1449145173417482, 0.0, 0.0, -0.3123616666440921, 3.085677581491367e+24, 1.098255594357798, 1.5979994505863926, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 25
# Generation with parameters (5.769776524501944e+33, 8.56476677945225e+32, 0.0, 0.0, 0.00010059507111677707, 0.0, 0.0, 0.19476112370572532, 3.085677581491367e+24, 2.6962852066516785, 1.9582198690453518, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.769776524501944e+33, 8.56476677945225e+32, 0.0, 0.0, 0.00010059507111677707, 0.0, 0.0, 0.19476112370572532, 3.085677581491367e+24, 2.6962852066516785, 1.9582198690453518, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 26
# Generation with parameters (3.033452103821703e+33, 7.06025283494405e+32, 0.0, 0.0, -0.05629213143487907, 0.0, 0.0, -0.6191867863307446, 3.085677581491367e+24, 0.9690077439729013, 4.879425918241881, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.033452103821703e+33, 7.06025283494405e+32, 0.0, 0.0, -0.05629213143487907, 0.0, 0.0, -0.6191867863307446, 3.085677581491367e+24, 0.9690077439729013, 4.879425918241881, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 27
# Generation with parameters (3.7797399863638025e+33, 1.0446302399051422e+33, 0.0, 0.0, -0.11590812232966455, 0.0, 0.0, 0.1485958028322856, 3.085677581491367e+24, 0.9565353124906405, 1.7915858275529826, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.7797399863638025e+33, 1.0446302399051422e+33, 0.0, 0.0, -0.11590812232966455, 0.0, 0.0, 0.1485958028322856, 3.085677581491367e+24, 0.9565353124906405, 1.7915858275529826, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 28
# Generation with parameters (3.7300776666685194e+33, 7.22862951445324e+32, 0.0, 0.0, 0.2067253800957167, 0.0, 0.0, -0.12063445634264205, 3.085677581491367e+24, 1.6636868610080036, 5.625519923433745, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.7300776666685194e+33, 7.22862951445324e+32, 0.0, 0.0, 0.2067253800957167, 0.0, 0.0, -0.12063445634264205, 3.085677581491367e+24, 1.6636868610080036, 5.625519923433745, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 29
# Generation with parameters (1.9239797162594934e+33, 9.765475287707265e+32, 0.0, 0.0, 0.5500901394261657, 0.0, 0.0, -0.3115042354180309, 3.085677581491367e+24, 0.8104290517846262, 4.847320732144919, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.9239797162594934e+33, 9.765475287707265e+32, 0.0, 0.0, 0.5500901394261657, 0.0, 0.0, -0.3115042354180309, 3.085677581491367e+24, 0.8104290517846262, 4.847320732144919, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 30
# Generation with parameters (1.413912850906831e+33, 5.922863596173346e+32, 0.0, 0.0, 0.6647938459967234, 0.0, 0.0, -0.0781288844359325, 3.085677581491367e+24, 2.6506355484600648, 4.5848716202599205, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.413912850906831e+33, 5.922863596173346e+32, 0.0, 0.0, 0.6647938459967234, 0.0, 0.0, -0.0781288844359325, 3.085677581491367e+24, 2.6506355484600648, 4.5848716202599205, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 31
# Generation with parameters (1.653110994157418e+33, 1.148772835054633e+33, 0.0, 0.0, 0.14643846784978612, 0.0, 0.0, 0.08207949520367182, 3.085677581491367e+24, 2.81125356383309, 3.7002459853989875, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.653110994157418e+33, 1.148772835054633e+33, 0.0, 0.0, 0.14643846784978612, 0.0, 0.0, 0.08207949520367182, 3.085677581491367e+24, 2.81125356383309, 3.7002459853989875, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 32
# Generation with parameters (2.7396586311491744e+33, 5.558496377291796e+32, 0.0, 0.0, 0.019715795775340834, 0.0, 0.0, 0.5840055818036273, 3.085677581491367e+24, 2.3211663768465227, 1.6054362468222878, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.7396586311491744e+33, 5.558496377291796e+32, 0.0, 0.0, 0.019715795775340834, 0.0, 0.0, 0.5840055818036273, 3.085677581491367e+24, 2.3211663768465227, 1.6054362468222878, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 33
# Generation with parameters (3.178300634350719e+33, 1.2430182299835109e+33, 0.0, 0.0, -0.35744364427888947, 0.0, 0.0, -0.33772615565340186, 3.085677581491367e+24, 0.7546210947306866, 3.2841132136519144, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.178300634350719e+33, 1.2430182299835109e+33, 0.0, 0.0, -0.35744364427888947, 0.0, 0.0, -0.33772615565340186, 3.085677581491367e+24, 0.7546210947306866, 3.2841132136519144, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 34
# Generation with parameters (3.633127256025101e+33, 6.680326063511808e+32, 0.0, 0.0, -0.009701078879598403, 0.0, 0.0, 0.064332584628744, 3.085677581491367e+24, 1.6846359109324935, 3.487605437825008, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.633127256025101e+33, 6.680326063511808e+32, 0.0, 0.0, -0.009701078879598403, 0.0, 0.0, 0.064332584628744, 3.085677581491367e+24, 1.6846359109324935, 3.487605437825008, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 35
# Generation with parameters (3.082594172518381e+33, 5.7379607355254354e+32, 0.0, 0.0, -0.32246696264416363, 0.0, 0.0, 0.20346277691473075, 3.085677581491367e+24, 1.9392655556111726, 3.8504514297587824, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.082594172518381e+33, 5.7379607355254354e+32, 0.0, 0.0, -0.32246696264416363, 0.0, 0.0, 0.20346277691473075, 3.085677581491367e+24, 1.9392655556111726, 3.8504514297587824, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 36
# Generation with parameters (5.268258392230703e+33, 9.382286938168993e+32, 0.0, 0.0, 0.00035513422707779174, 0.0, 0.0, -0.31360517388199904, 3.085677581491367e+24, 1.154586616800545, 1.565322584609837, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.268258392230703e+33, 9.382286938168993e+32, 0.0, 0.0, 0.00035513422707779174, 0.0, 0.0, -0.31360517388199904, 3.085677581491367e+24, 1.154586616800545, 1.565322584609837, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 37
# Generation with parameters (2.5144025788900492e+33, 5.954211548100986e+32, 0.0, 0.0, 0.1985360816171267, 0.0, 0.0, 0.08211608028157812, 3.085677581491367e+24, 2.1756153794511826, 5.3174458403389995, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5144025788900492e+33, 5.954211548100986e+32, 0.0, 0.0, 0.1985360816171267, 0.0, 0.0, 0.08211608028157812, 3.085677581491367e+24, 2.1756153794511826, 5.3174458403389995, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 38
# Generation with parameters (3.400347242540834e+33, 1.4988159976773344e+33, 0.0, 0.0, 0.583187281361477, 0.0, 0.0, 0.19354139826048888, 3.085677581491367e+24, 1.6645107192525141, 3.95742989831753, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.400347242540834e+33, 1.4988159976773344e+33, 0.0, 0.0, 0.583187281361477, 0.0, 0.0, 0.19354139826048888, 3.085677581491367e+24, 1.6645107192525141, 3.95742989831753, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 39
# Generation with parameters (3.997612309826752e+33, 7.260154021427383e+32, 0.0, 0.0, 0.1801725004597551, 0.0, 0.0, 0.021116077756235592, 3.085677581491367e+24, 2.5354603345426043, 2.9768503383749283, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.997612309826752e+33, 7.260154021427383e+32, 0.0, 0.0, 0.1801725004597551, 0.0, 0.0, 0.021116077756235592, 3.085677581491367e+24, 2.5354603345426043, 2.9768503383749283, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 40
# Generation with parameters (3.511545739613665e+33, 1.1074707155076705e+33, 0.0, 0.0, 0.7927522894549074, 0.0, 0.0, -0.34757745164325937, 3.085677581491367e+24, 2.384170270630672, 4.676899648512652, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.511545739613665e+33, 1.1074707155076705e+33, 0.0, 0.0, 0.7927522894549074, 0.0, 0.0, -0.34757745164325937, 3.085677581491367e+24, 2.384170270630672, 4.676899648512652, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 41
# Running injection 42
# Generation with parameters (3.890516577025726e+33, 1.1140657593744252e+33, 0.0, 0.0, 0.009242481338848729, 0.0, 0.0, -0.16478437475780275, 3.085677581491367e+24, 2.581301955102388, 5.449454165587397, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.890516577025726e+33, 1.1140657593744252e+33, 0.0, 0.0, 0.009242481338848729, 0.0, 0.0, -0.16478437475780275, 3.085677581491367e+24, 2.581301955102388, 5.449454165587397, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 43
# Generation with parameters (4.090461484118178e+33, 1.1036805220152483e+33, 0.0, 0.0, 0.13531678105939393, 0.0, 0.0, 0.7399320589984509, 3.085677581491367e+24, 1.0702313508331893, 3.3258407827183545, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.090461484118178e+33, 1.1036805220152483e+33, 0.0, 0.0, 0.13531678105939393, 0.0, 0.0, 0.7399320589984509, 3.085677581491367e+24, 1.0702313508331893, 3.3258407827183545, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 44
# Generation with parameters (3.195904891873672e+33, 7.230281635808576e+32, 0.0, 0.0, -0.15081856754574421, 0.0, 0.0, -0.689523644413249, 3.085677581491367e+24, 1.1409713402478248, 0.048039749409148846, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.195904891873672e+33, 7.230281635808576e+32, 0.0, 0.0, -0.15081856754574421, 0.0, 0.0, -0.689523644413249, 3.085677581491367e+24, 1.1409713402478248, 0.048039749409148846, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 45
# Generation with parameters (1.7154929802089986e+33, 1.0116953931705145e+33, 0.0, 0.0, -0.04243227825505537, 0.0, 0.0, -0.13673070190767764, 3.085677581491367e+24, 0.9746575491443082, 3.8029456148532126, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7154929802089986e+33, 1.0116953931705145e+33, 0.0, 0.0, -0.04243227825505537, 0.0, 0.0, -0.13673070190767764, 3.085677581491367e+24, 0.9746575491443082, 3.8029456148532126, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 46
# Generation with parameters (1.768432474067495e+33, 2.9792699321554113e+32, 0.0, 0.0, -0.09334713828459364, 0.0, 0.0, 0.08372904525715823, 3.085677581491367e+24, 1.3192460100759358, 3.3952537863888494, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.768432474067495e+33, 2.9792699321554113e+32, 0.0, 0.0, -0.09334713828459364, 0.0, 0.0, 0.08372904525715823, 3.085677581491367e+24, 1.3192460100759358, 3.3952537863888494, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 47
# Generation with parameters (2.195789657517282e+33, 1.647577709411395e+33, 0.0, 0.0, -0.016457140648881756, 0.0, 0.0, 0.4566009522543663, 3.085677581491367e+24, 2.1481282116551434, 5.2716105876064905, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.195789657517282e+33, 1.647577709411395e+33, 0.0, 0.0, -0.016457140648881756, 0.0, 0.0, 0.4566009522543663, 3.085677581491367e+24, 2.1481282116551434, 5.2716105876064905, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 48
# Generation with parameters (2.452885864341354e+33, 9.209397281857234e+32, 0.0, 0.0, 0.20722956204992396, 0.0, 0.0, 0.16318024316200175, 3.085677581491367e+24, 1.0505098872543304, 5.5684422596076715, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.452885864341354e+33, 9.209397281857234e+32, 0.0, 0.0, 0.20722956204992396, 0.0, 0.0, 0.16318024316200175, 3.085677581491367e+24, 1.0505098872543304, 5.5684422596076715, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 49
# Running injection 50
# Generation with parameters (1.4159379732869982e+33, 1.19679211574331e+33, 0.0, 0.0, -0.5963162098361557, 0.0, 0.0, 0.3926937768973883, 3.085677581491367e+24, 2.615795216534524, 2.0985610858755486, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4159379732869982e+33, 1.19679211574331e+33, 0.0, 0.0, -0.5963162098361557, 0.0, 0.0, 0.3926937768973883, 3.085677581491367e+24, 2.615795216534524, 2.0985610858755486, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 51
# Generation with parameters (4.0123966510616255e+33, 9.000279522557632e+32, 0.0, 0.0, -0.01672015985554982, 0.0, 0.0, -0.3488333711277054, 3.085677581491367e+24, 1.329096150055061, 4.598876072214155, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.0123966510616255e+33, 9.000279522557632e+32, 0.0, 0.0, -0.01672015985554982, 0.0, 0.0, -0.3488333711277054, 3.085677581491367e+24, 1.329096150055061, 4.598876072214155, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 52
# Generation with parameters (1.0076045958154529e+33, 7.283098923563134e+32, 0.0, 0.0, 0.532430849140469, 0.0, 0.0, 0.20572944193005352, 3.085677581491367e+24, 1.30944381994773, 1.8207775150688175, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0076045958154529e+33, 7.283098923563134e+32, 0.0, 0.0, 0.532430849140469, 0.0, 0.0, 0.20572944193005352, 3.085677581491367e+24, 1.30944381994773, 1.8207775150688175, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 53
# Generation with parameters (3.1648391032882827e+33, 7.405234802928361e+32, 0.0, 0.0, -0.03381498123110045, 0.0, 0.0, 0.14843959296286968, 3.085677581491367e+24, 1.3028060648387043, 0.7121733947396487, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.1648391032882827e+33, 7.405234802928361e+32, 0.0, 0.0, -0.03381498123110045, 0.0, 0.0, 0.14843959296286968, 3.085677581491367e+24, 1.3028060648387043, 0.7121733947396487, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 54
# Generation with parameters (1.7608119297207902e+33, 6.761985689783337e+32, 0.0, 0.0, -0.8280666691215407, 0.0, 0.0, 0.17786770922734765, 3.085677581491367e+24, 1.1634821196287592, 5.1954211060345, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7608119297207902e+33, 6.761985689783337e+32, 0.0, 0.0, -0.8280666691215407, 0.0, 0.0, 0.17786770922734765, 3.085677581491367e+24, 1.1634821196287592, 5.1954211060345, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 55
# Running injection 56
# Generation with parameters (3.406577396910963e+33, 1.44963912690318e+33, 0.0, 0.0, 0.1597186534149892, 0.0, 0.0, 0.3833145162210089, 3.085677581491367e+24, 1.8718893407271104, 5.8382637325508995, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.406577396910963e+33, 1.44963912690318e+33, 0.0, 0.0, 0.1597186534149892, 0.0, 0.0, 0.3833145162210089, 3.085677581491367e+24, 1.8718893407271104, 5.8382637325508995, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 57
# Generation with parameters (5.474731017916564e+33, 8.240917098818113e+32, 0.0, 0.0, -0.0772022016974045, 0.0, 0.0, 0.12880033866407442, 3.085677581491367e+24, 1.1085197997983556, 4.549230995568988, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.474731017916564e+33, 8.240917098818113e+32, 0.0, 0.0, -0.0772022016974045, 0.0, 0.0, 0.12880033866407442, 3.085677581491367e+24, 1.1085197997983556, 4.549230995568988, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 58
# Generation with parameters (1.0226279301397616e+33, 6.402941759428053e+32, 0.0, 0.0, 0.05108925487396793, 0.0, 0.0, -0.07130863967007729, 3.085677581491367e+24, 1.7601147602062042, 5.211923019853582, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0226279301397616e+33, 6.402941759428053e+32, 0.0, 0.0, 0.05108925487396793, 0.0, 0.0, -0.07130863967007729, 3.085677581491367e+24, 1.7601147602062042, 5.211923019853582, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 59
# Running injection 60
# Generation with parameters (4.927278601607164e+33, 9.319719444968307e+32, 0.0, 0.0, 0.5141066978309947, 0.0, 0.0, 0.16270724908058315, 3.085677581491367e+24, 1.4498099053829927, 2.7420221683479107, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.927278601607164e+33, 9.319719444968307e+32, 0.0, 0.0, 0.5141066978309947, 0.0, 0.0, 0.16270724908058315, 3.085677581491367e+24, 1.4498099053829927, 2.7420221683479107, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 61
# Generation with parameters (1.6292811790034052e+33, 3.585262269295393e+32, 0.0, 0.0, 0.0332395901435247, 0.0, 0.0, -0.0030653498859490374, 3.085677581491367e+24, 0.7672585521792711, 0.7019811611586393, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6292811790034052e+33, 3.585262269295393e+32, 0.0, 0.0, 0.0332395901435247, 0.0, 0.0, -0.0030653498859490374, 3.085677581491367e+24, 0.7672585521792711, 0.7019811611586393, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 62
# Generation with parameters (2.2066113140679508e+33, 7.189462729966421e+32, 0.0, 0.0, 0.5794562214098249, 0.0, 0.0, -0.098576987885384, 3.085677581491367e+24, 2.2421273854446606, 0.6775847135152875, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2066113140679508e+33, 7.189462729966421e+32, 0.0, 0.0, 0.5794562214098249, 0.0, 0.0, -0.098576987885384, 3.085677581491367e+24, 2.2421273854446606, 0.6775847135152875, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 63
# Generation with parameters (3.9958043011806127e+33, 1.325168259163753e+33, 0.0, 0.0, 0.33351210531543357, 0.0, 0.0, -0.002623020262176848, 3.085677581491367e+24, 0.03420199671813418, 0.3410396962031856, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.9958043011806127e+33, 1.325168259163753e+33, 0.0, 0.0, 0.33351210531543357, 0.0, 0.0, -0.002623020262176848, 3.085677581491367e+24, 0.03420199671813418, 0.3410396962031856, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 64
# Generation with parameters (3.340531346664128e+33, 1.3466754918960112e+33, 0.0, 0.0, 0.008792234597079, 0.0, 0.0, 0.5976367545531577, 3.085677581491367e+24, 1.2428443196186691, 3.402914745192353, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.340531346664128e+33, 1.3466754918960112e+33, 0.0, 0.0, 0.008792234597079, 0.0, 0.0, 0.5976367545531577, 3.085677581491367e+24, 1.2428443196186691, 3.402914745192353, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 65
# Generation with parameters (3.9301349304598903e+33, 1.0168061281808431e+33, 0.0, 0.0, 0.06937407634315586, 0.0, 0.0, -0.1555973731257046, 3.085677581491367e+24, 1.3720561809761522, 3.8785927778039913, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.9301349304598903e+33, 1.0168061281808431e+33, 0.0, 0.0, 0.06937407634315586, 0.0, 0.0, -0.1555973731257046, 3.085677581491367e+24, 1.3720561809761522, 3.8785927778039913, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 66
# Generation with parameters (2.0013535269774462e+33, 1.0176939514978666e+33, 0.0, 0.0, -0.05940343986783657, 0.0, 0.0, 0.08651318246478544, 3.085677581491367e+24, 0.2765078387490314, 5.686183850228013, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0013535269774462e+33, 1.0176939514978666e+33, 0.0, 0.0, -0.05940343986783657, 0.0, 0.0, 0.08651318246478544, 3.085677581491367e+24, 0.2765078387490314, 5.686183850228013, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 67
# Generation with parameters (1.7665971208601474e+33, 1.0811352031578465e+33, 0.0, 0.0, -0.33965271879065806, 0.0, 0.0, -0.02424415728268681, 3.085677581491367e+24, 1.794156820576973, 5.507745199532922, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7665971208601474e+33, 1.0811352031578465e+33, 0.0, 0.0, -0.33965271879065806, 0.0, 0.0, -0.02424415728268681, 3.085677581491367e+24, 1.794156820576973, 5.507745199532922, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 68
# Generation with parameters (1.2772549870457907e+33, 2.9229092628801798e+32, 0.0, 0.0, 0.10536427420425386, 0.0, 0.0, 0.140266997745302, 3.085677581491367e+24, 1.920295690518944, 3.419177741261492, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2772549870457907e+33, 2.9229092628801798e+32, 0.0, 0.0, 0.10536427420425386, 0.0, 0.0, 0.140266997745302, 3.085677581491367e+24, 1.920295690518944, 3.419177741261492, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 69
# Running injection 70
# Running injection 71
# Generation with parameters (3.3544820326063946e+33, 1.1091237469616995e+33, 0.0, 0.0, 0.0869651476202821, 0.0, 0.0, -0.17465217355327622, 3.085677581491367e+24, 1.6254972251140012, 0.30261747054904303, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.3544820326063946e+33, 1.1091237469616995e+33, 0.0, 0.0, 0.0869651476202821, 0.0, 0.0, -0.17465217355327622, 3.085677581491367e+24, 1.6254972251140012, 0.30261747054904303, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 72
# Generation with parameters (3.533163637634042e+33, 6.023885770928384e+32, 0.0, 0.0, -0.5612418201487018, 0.0, 0.0, 0.09379996570852012, 3.085677581491367e+24, 0.576133529852658, 1.4869268737015287, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.533163637634042e+33, 6.023885770928384e+32, 0.0, 0.0, -0.5612418201487018, 0.0, 0.0, 0.09379996570852012, 3.085677581491367e+24, 0.576133529852658, 1.4869268737015287, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 73
# Generation with parameters (3.897173307110277e+33, 7.099674751783801e+32, 0.0, 0.0, 0.011265107072433939, 0.0, 0.0, -0.667235784944552, 3.085677581491367e+24, 2.33678509680305, 2.369440087383276, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.897173307110277e+33, 7.099674751783801e+32, 0.0, 0.0, 0.011265107072433939, 0.0, 0.0, -0.667235784944552, 3.085677581491367e+24, 2.33678509680305, 2.369440087383276, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 74
# ...
# Running injection 973
# Generation with parameters (4.2499712515397285e+33, 1.2878275922666912e+33, 0.0, 0.0, -0.22811187428320043, 0.0, 0.0, -0.031673649015825416, 3.085677581491367e+24, 2.041427774895131, 5.2625479923732295, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.2499712515397285e+33, 1.2878275922666912e+33, 0.0, 0.0, -0.22811187428320043, 0.0, 0.0, -0.031673649015825416, 3.085677581491367e+24, 2.041427774895131, 5.2625479923732295, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 974
# Generation with parameters (2.811987961817325e+33, 1.8555112665177935e+33, 0.0, 0.0, -0.13950187774431613, 0.0, 0.0, -0.0030065027906626394, 3.085677581491367e+24, 0.5515798380380846, 2.635201869899116, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.811987961817325e+33, 1.8555112665177935e+33, 0.0, 0.0, -0.13950187774431613, 0.0, 0.0, -0.0030065027906626394, 3.085677581491367e+24, 0.5515798380380846, 2.635201869899116, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 975
# Generation with parameters (1.38775221292895e+33, 1.1833930496733308e+33, 0.0, 0.0, 0.05752955556492701, 0.0, 0.0, 0.10228747260882526, 3.085677581491367e+24, 1.5339007089841508, 2.432758396907765, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.38775221292895e+33, 1.1833930496733308e+33, 0.0, 0.0, 0.05752955556492701, 0.0, 0.0, 0.10228747260882526, 3.085677581491367e+24, 1.5339007089841508, 2.432758396907765, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 976
# Generation with parameters (5.429767005248724e+33, 8.738666961696985e+32, 0.0, 0.0, -0.22973575239212696, 0.0, 0.0, 0.19977095121679084, 3.085677581491367e+24, 1.5054019935906224, 5.05521447299548, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.429767005248724e+33, 8.738666961696985e+32, 0.0, 0.0, -0.22973575239212696, 0.0, 0.0, 0.19977095121679084, 3.085677581491367e+24, 1.5054019935906224, 5.05521447299548, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 977
# Generation with parameters (4.461209507603034e+33, 7.098594639849631e+32, 0.0, 0.0, 0.11932375777592305, 0.0, 0.0, 0.10023198191496398, 3.085677581491367e+24, 1.759420235347563, 3.572142352374481, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.461209507603034e+33, 7.098594639849631e+32, 0.0, 0.0, 0.11932375777592305, 0.0, 0.0, 0.10023198191496398, 3.085677581491367e+24, 1.759420235347563, 3.572142352374481, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 978
# Running injection 979
# Generation with parameters (1.6667683714860574e+33, 8.740922018875184e+32, 0.0, 0.0, 0.04505729219636163, 0.0, 0.0, 0.5766266692008297, 3.085677581491367e+24, 1.1484897492430064, 3.1706802867639476, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6667683714860574e+33, 8.740922018875184e+32, 0.0, 0.0, 0.04505729219636163, 0.0, 0.0, 0.5766266692008297, 3.085677581491367e+24, 1.1484897492430064, 3.1706802867639476, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 980
# Generation with parameters (1.953616786871249e+33, 9.026071585647518e+32, 0.0, 0.0, -0.01252568902852561, 0.0, 0.0, -0.002949180413916067, 3.085677581491367e+24, 0.7470407694304513, 4.009760100524413, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.953616786871249e+33, 9.026071585647518e+32, 0.0, 0.0, -0.01252568902852561, 0.0, 0.0, -0.002949180413916067, 3.085677581491367e+24, 0.7470407694304513, 4.009760100524413, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 981
# Generation with parameters (1.468037908692122e+33, 8.837854017756374e+32, 0.0, 0.0, -0.2758490457190649, 0.0, 0.0, -0.1928054921658927, 3.085677581491367e+24, 1.5225675267372023, 1.0596430871727835, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.468037908692122e+33, 8.837854017756374e+32, 0.0, 0.0, -0.2758490457190649, 0.0, 0.0, -0.1928054921658927, 3.085677581491367e+24, 1.5225675267372023, 1.0596430871727835, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 982
# Generation with parameters (2.6421313348059075e+33, 1.3512049011458584e+33, 0.0, 0.0, -0.0009761848480607461, 0.0, 0.0, 0.657287166790434, 3.085677581491367e+24, 2.295485638504639, 5.739285290707223, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.6421313348059075e+33, 1.3512049011458584e+33, 0.0, 0.0, -0.0009761848480607461, 0.0, 0.0, 0.657287166790434, 3.085677581491367e+24, 2.295485638504639, 5.739285290707223, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 983
# Generation with parameters (8.40549927474569e+32, 7.664191297961398e+32, 0.0, 0.0, -0.035530739315978305, 0.0, 0.0, -0.7805428419725179, 3.085677581491367e+24, 0.9342372227020833, 1.4916373542018575, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.40549927474569e+32, 7.664191297961398e+32, 0.0, 0.0, -0.035530739315978305, 0.0, 0.0, -0.7805428419725179, 3.085677581491367e+24, 0.9342372227020833, 1.4916373542018575, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 984
# Generation with parameters (2.3105319051842542e+33, 2.0349899409516568e+33, 0.0, 0.0, -0.2915597613101997, 0.0, 0.0, 0.09056955509648082, 3.085677581491367e+24, 1.9223305650050833, 0.09835309593824737, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3105319051842542e+33, 2.0349899409516568e+33, 0.0, 0.0, -0.2915597613101997, 0.0, 0.0, 0.09056955509648082, 3.085677581491367e+24, 1.9223305650050833, 0.09835309593824737, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 985
# Running injection 986
# Generation with parameters (4.5428676510696315e+33, 1.1853022981878815e+33, 0.0, 0.0, -0.2854715744457791, 0.0, 0.0, -0.07303203987108878, 3.085677581491367e+24, 1.1154707385237794, 5.164518419777233, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.5428676510696315e+33, 1.1853022981878815e+33, 0.0, 0.0, -0.2854715744457791, 0.0, 0.0, -0.07303203987108878, 3.085677581491367e+24, 1.1154707385237794, 5.164518419777233, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 987
# Generation with parameters (1.7555948047974197e+33, 1.0856240599972974e+33, 0.0, 0.0, -0.09264578658722532, 0.0, 0.0, 0.11683745194619978, 3.085677581491367e+24, 2.3954478299275563, 2.4274841880561295, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7555948047974197e+33, 1.0856240599972974e+33, 0.0, 0.0, -0.09264578658722532, 0.0, 0.0, 0.11683745194619978, 3.085677581491367e+24, 2.3954478299275563, 2.4274841880561295, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 988
# Generation with parameters (4.532494036658694e+33, 1.1969249440162044e+33, 0.0, 0.0, 0.009796075054046265, 0.0, 0.0, 0.011334034638513717, 3.085677581491367e+24, 2.6395455552611513, 3.756389395198195, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.532494036658694e+33, 1.1969249440162044e+33, 0.0, 0.0, 0.009796075054046265, 0.0, 0.0, 0.011334034638513717, 3.085677581491367e+24, 2.6395455552611513, 3.756389395198195, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 989
# Generation with parameters (1.4707884105536322e+33, 1.2329950675312167e+33, 0.0, 0.0, 0.27564966274270347, 0.0, 0.0, 0.252612507659488, 3.085677581491367e+24, 1.5906094900058163, 3.0703770284119636, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4707884105536322e+33, 1.2329950675312167e+33, 0.0, 0.0, 0.27564966274270347, 0.0, 0.0, 0.252612507659488, 3.085677581491367e+24, 1.5906094900058163, 3.0703770284119636, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 990
# Generation with parameters (2.1553902649973685e+33, 1.9155145456894e+33, 0.0, 0.0, 0.25120675857100144, 0.0, 0.0, 0.01622829324478594, 3.085677581491367e+24, 0.9825237731998562, 3.5662230340662795, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.1553902649973685e+33, 1.9155145456894e+33, 0.0, 0.0, 0.25120675857100144, 0.0, 0.0, 0.01622829324478594, 3.085677581491367e+24, 0.9825237731998562, 3.5662230340662795, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 991
# Generation with parameters (1.1899155377625162e+33, 7.661152524532682e+32, 0.0, 0.0, 0.13497148541957824, 0.0, 0.0, 0.0008555531559562518, 3.085677581491367e+24, 1.097758287693627, 2.676795683724679, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1899155377625162e+33, 7.661152524532682e+32, 0.0, 0.0, 0.13497148541957824, 0.0, 0.0, 0.0008555531559562518, 3.085677581491367e+24, 1.097758287693627, 2.676795683724679, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 992
# Running injection 993
# Generation with parameters (1.3766489214696187e+33, 5.725731184765038e+32, 0.0, 0.0, 0.15789796827964842, 0.0, 0.0, -0.015558812411832278, 3.085677581491367e+24, 2.68473402165733, 0.31423445139039735, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3766489214696187e+33, 5.725731184765038e+32, 0.0, 0.0, 0.15789796827964842, 0.0, 0.0, -0.015558812411832278, 3.085677581491367e+24, 2.68473402165733, 0.31423445139039735, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 994
# Generation with parameters (2.528174934429583e+33, 1.9459195773421303e+33, 0.0, 0.0, -0.2791380658837258, 0.0, 0.0, -0.13885050015716538, 3.085677581491367e+24, 1.8332867372758028, 0.03158273520124524, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.528174934429583e+33, 1.9459195773421303e+33, 0.0, 0.0, -0.2791380658837258, 0.0, 0.0, -0.13885050015716538, 3.085677581491367e+24, 1.8332867372758028, 0.03158273520124524, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 995
# Running injection 996
# Generation with parameters (3.5225425689664385e+33, 9.98316300673786e+32, 0.0, 0.0, 0.11851405067352008, 0.0, 0.0, -0.811992485238885, 3.085677581491367e+24, 1.1748647613393963, 3.428314220389499, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.5225425689664385e+33, 9.98316300673786e+32, 0.0, 0.0, 0.11851405067352008, 0.0, 0.0, -0.811992485238885, 3.085677581491367e+24, 1.1748647613393963, 3.428314220389499, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 997
# Generation with parameters (1.1349125150947558e+33, 8.299705648442174e+32, 0.0, 0.0, 0.04296066057869638, 0.0, 0.0, 0.5868701038498572, 3.085677581491367e+24, 1.4369099362911053, 3.4146786491471905, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1349125150947558e+33, 8.299705648442174e+32, 0.0, 0.0, 0.04296066057869638, 0.0, 0.0, 0.5868701038498572, 3.085677581491367e+24, 1.4369099362911053, 3.4146786491471905, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 998
# Generation with parameters (1.7160534730941917e+33, 4.861662264977322e+32, 0.0, 0.0, -0.47532810189344, 0.0, 0.0, -0.00955991551881235, 3.085677581491367e+24, 2.744940644365045, 5.614899434976748, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7160534730941917e+33, 4.861662264977322e+32, 0.0, 0.0, -0.47532810189344, 0.0, 0.0, -0.00955991551881235, 3.085677581491367e+24, 2.744940644365045, 5.614899434976748, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 999
# Generation with parameters (1.4838719528852057e+33, 1.0498261459422094e+33, 0.0, 0.0, 0.43660411158337337, 0.0, 0.0, 0.010564808834737698, 3.085677581491367e+24, 1.4655245887992059, 1.3628153373538479, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4838719528852057e+33, 1.0498261459422094e+33, 0.0, 0.0, 0.43660411158337337, 0.0, 0.0, 0.010564808834737698, 3.085677581491367e+24, 1.4655245887992059, 1.3628153373538479, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.

# %% [markdown]
# ## Infere parameters

# %%
# %%capture  
#avoids printing a lot of output to the notebook
import pandas as pd
from dingo.gw.inference.gw_samplers import GWSampler




os.makedirs(f"/scratch/tpausch/test_data/{name}/results", exist_ok=True)

injection_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/injections"))

for fname in injection_files:

    # --------------------------------------------------------
    # Load injection
    # --------------------------------------------------------

    with open(f"/scratch/tpausch/test_data/{name}/injections/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    strain_data = payload["strain_data"]

    # --------------------------------------------------------
    # Run sampler
    # --------------------------------------------------------

    sampler = GWSampler(model=main_pm)

    sampler.context = strain_data

    sampler.run_sampler(
        num_samples=50_000,
        batch_size=10_000,
    )

    result = sampler.to_result()



    # --------------------------------------------------------
    # calculate network SNR
    # --------------------------------------------------------
    parameters = pd.DataFrame(
        {key: np.array([np.asarray(val).item()]) for key, val in theta_true.items()}
    )
    snr_df = gw.utilities.get_snr(parameters, network, waveform_model, f_ref)
    network_snr = float(snr_df["network"].iloc[0])  # extract as plain float

    # --------------------------------------------------------
    # Store result
    # --------------------------------------------------------

    result_payload = {
        "theta_true": theta_true,
        "result": result,
        "network_snr": network_snr,
    }

    outname = fname.replace("inj_", "result_")

    with open(f"/scratch/tpausch/test_data/{name}/results/{outname}", "wb") as f:
        pickle.dump(result_payload, f)

    print(f"Saved /scratch/tpausch/test_data/{name}/results/{outname}")

# %% [markdown]
# ## Calculate and plot chirp mass inference error

# %%
true_cm = []
true_mr = []
mass_ratio_error = []
mass_ratio_std = []
chirp_mass_error = []
chirp_mass_std = []


result_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/{name}/results/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    result = payload["result"]

    posterior_samples = result.samples

    #q_samples = np.array(posterior_samples["mass_ratio"])

    # inference statistics
    #q_mean = np.mean(q_samples)
    #q_std = np.std(q_samples)
#
    #true_q = theta_true["mass_ratio"]

    cm_samples = np.array(posterior_samples["chirp_mass"])

    cm_mean = np.mean(cm_samples)
    cm_std = np.std(cm_samples)

    true_mr.append(theta_true["mass_ratio"])
    true_cm.append(theta_true["chirp_mass"])
    #mass_ratio_error.append(q_mean - true_q)
    #mass_ratio_std.append(q_std)
    chirp_mass_error.append(cm_mean - theta_true["chirp_mass"])
    chirp_mass_std.append(cm_std)


true_mr = np.array(true_mr)
true_cm = np.array(true_cm)

# ------------------------------------------------------------
# Error bars
# ------------------------------------------------------------

#plt.errorbar(
#    true_cm,
#    chirp_mass_error,
#    yerr=chirp_mass_std,
#    fmt="none",
#    capsize=4,
#    alpha=0.5,
#    color="gray",
#)

# ------------------------------------------------------------
# Colored scatter points
# ------------------------------------------------------------

sc = plt.scatter(
    true_cm,
    chirp_mass_error,
    s=20,
    edgecolor="black",
    alpha=0.3
)

# ------------------------------------------------------------
# Reference line
# ------------------------------------------------------------

plt.axhline(0, linestyle="--", color="black")


# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel("True chirp mass")
plt.ylabel("Chirp mass inference error (inferred − true)")

plt.title("Chirp-mass inference error")

plt.grid(True)

plt.tight_layout()
plt.show()

cm_err = np.asarray(chirp_mass_error)

mean_error = np.mean(cm_err)          # signed average bias (over/under-estimation)
mean_abs_error = np.mean(np.abs(cm_err))  # average magnitude of deviation
rms_error = np.sqrt(np.mean(cm_err**2))   # RMS deviation, penalizes outliers more
std_error = np.std(cm_err)            # spread of the errors around their mean
p90_abs_error = np.percentile(np.abs(cm_err), 90)
p99_abs_error = np.percentile(np.abs(cm_err), 99)


print(f"Mean error (bias):      {mean_error:.3f}")
print(f"Mean absolute error:    {mean_abs_error:.3f}")
print(f"RMS error:              {rms_error:.3f}")
print(f"Std of error:           {std_error:.3f}")
print(f"90th percentile |error|: {p90_abs_error:.3f}")
print(f"99th percentile |error|: {p99_abs_error:.3f}")
# Out:
# Mean error (bias):      3.327
# Mean absolute error:    41.745
# RMS error:              68.302
# Std of error:           68.221
# 90th percentile |error|: 107.699
# 99th percentile |error|: 243.464

# %% [markdown]
# ## PP-plot

# %%
pp_values_chirp_mass = []
pp_values_mass_ratio = []

result_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/{name}/results/{fname}", "rb") as f:

        payload = pickle.load(f)

        theta_true = payload["theta_true"]
        result = payload["result"]

        posterior_samples = result.samples


        # ============================================================
        # Chirp mass PP value
        # ============================================================

        cm_samples = posterior_samples["chirp_mass"]

        pp_cm = np.mean(
            cm_samples < theta_true["chirp_mass"]
        )

        pp_values_chirp_mass.append(pp_cm)


        # ============================================================
        # Mass ratio PP value
        # ============================================================

        #q_samples = posterior_samples["mass_ratio"]
#
        #pp_q = np.mean(
        #    q_samples < theta_true["mass_ratio"]
        #)
#
        #pp_values_mass_ratio.append(pp_q)




def plot_pp(pp_values, label):

    pp_values = np.array(pp_values)

    sorted_pp = np.sort(pp_values)

    n = len(sorted_pp)

    empirical_cdf = np.arange(1, n + 1) / n

    x = np.linspace(0, 1, 200)

    sigma = np.sqrt(x * (1 - x) / n)

    plt.figure(figsize=(6, 6))

    # Ideal calibration
    plt.plot(
        [0, 1],
        [0, 1],
        linestyle="--",
        label="Ideal calibration",
    )


    # Empirical PP curve
    plt.plot(
        sorted_pp,
        empirical_cdf,
        marker="o",
        label=label,
    )

    plt.xlabel("Credible level")
    plt.ylabel("Fraction of injections")

    plt.title(f"PP Plot: {label}")

    plt.xlim(0, 1)
    plt.ylim(0, 1)

    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()


plot_pp(
    pp_values_chirp_mass,
    "chirp_mass",
)

#plot_pp(
#    pp_values_mass_ratio,
#    "mass_ratio",
#)

# %% [markdown]
# ## SNR analysis

# %%
snrs = []
ci90_widths = []
chirp_masses = []

result_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/{name}/results/{fname}", "rb") as f:

        payload = pickle.load(f)
    
    theta_true = payload["theta_true"]
    result = payload["result"]


    snr = payload["network_snr"]   # use "ET" instead if you want the single-detector value
   

    snrs.append(snr)

    samples = result.samples["chirp_mass"].to_numpy()  # adjust if result.samples is a DataFrame

    ci90 = np.percentile(samples, 95) - np.percentile(samples, 5)
    ci90_widths.append(ci90)
    chirp_masses.append(theta_true["chirp_mass"])

snrs = np.array(snrs)
ci90_widths = np.array(ci90_widths)
chirp_masses = np.array(chirp_masses)

frac_widths = ci90_widths / chirp_masses  # relative width, dimensionless

plt.figure(figsize=(6, 5))
sc = plt.scatter(snrs, ci90_widths, c=chirp_masses, cmap="viridis", alpha=0.6, s=15)
#sc = plt.scatter(snrs, frac_widths, c=chirp_masses, cmap="viridis", alpha=0.6, s=15)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Network SNR")
plt.ylabel("Chirp mass 90% CI width")
plt.colorbar(sc, label="Injected chirp mass [M$_\\odot$]")
plt.title("posterior width vs SNR")
plt.grid(True, which="both", alpha=0.3)
plt.tight_layout()
plt.show()


chirp_mass_error = np.array(chirp_mass_error)
mask = snrs < 10000.0

plt.figure(figsize=(10, 5))
sc = plt.scatter(
    snrs[mask],
    chirp_mass_error[mask],
    s=10,
    edgecolor="black",
    alpha=0.3
)

plt.axhline(0, linestyle="--", color="black")
plt.xlabel("SNR")
plt.ylabel("Chirp mass inference error (inferred − true)")
plt.title("Chirp-mass inference error")
plt.grid(True)
plt.tight_layout()
plt.show()




# --- Plot distribution ---
plt.figure(figsize=(6, 5))

# Histogram, normalized to a density so it represents "how likely each value is"
counts, bins, _ = plt.hist(
    snrs, bins=100, density=True, alpha=0.5, color="steelblue", edgecolor="k", label="Histogram"
)
plt.xlabel("Network SNR")
plt.ylabel("Probability density")
plt.title(f"Distribution of injected network SNR (n={len(snrs)})")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()


print(f"SNR stats: min={snrs.min():.2f}, max={snrs.max():.2f}, "
      f"median={np.median(snrs):.2f}, mean={snrs.mean():.2f}",
      f"snr99={np.percentile(np.abs(snrs), 99):.2f}")
# Out:
# SNR stats: min=4.08, max=5401.84, median=118.13, mean=317.55 snr99=2513.65
