# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
import GWFish.modules as gw


os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # use GPU 1

name="stage1"

waveform_model = 'IMRPhenomXPHM'
f_ref = 20.
detectors = ['ET']
network = gw.detection.Network(detector_ids = detectors, detection_SNR = (0., 8.))
# Out:
# /home/tpausch/.conda/envs/ET-DINGO/lib/python3.10/site-packages/lalsimulation/_lalsimulation_swig.py:8: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   import lal

# %% [markdown]
# ## Load Model

# %%
from dingo.core.posterior_models.build_model import build_model_from_kwargs
main_pm = build_model_from_kwargs(
    filename=f"/scratch/tpausch/models/{name}/model_latest.pt",
    device="cuda",
    load_training_info=False,
)
# Out:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1230+gc9da5d765 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Putting posterior model to device cuda.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt(f"/scratch/tpausch/models/{name}/history.txt")
epochs   = data[:, 0]
train    = data[:, 1]
val      = data[:, 2]


plt.figure(figsize=(8, 5))
plt.plot(epochs, train, label="Train loss")
plt.plot(epochs, val,   label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("Log-likelihood")
plt.legend()
plt.title("Dingo training history")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 4 data = np.loadtxt(f"/scratch/tpausch/models/{name}/history.txt")
#       5 epochs   = data[:, 0]
#       6 train    = data[:, 1]
#
# File ~/.conda/envs/ET-DINGO/lib/python3.10/site-packages/numpy/lib/npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# File ~/.conda/envs/ET-DINGO/lib/python3.10/site-packages/numpy/lib/npyio.py:992, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     990     fname = os.fspath(fname)
#     991 if isinstance(fname, str):
# --> 992     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     993     if encoding is None:
#     994         encoding = getattr(fh, 'encoding', 'latin1')
#
# File ~/.conda/envs/ET-DINGO/lib/python3.10/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/.conda/envs/ET-DINGO/lib/python3.10/site-packages/numpy/lib/_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: /scratch/tpausch/models/stage1/history.txt not found.

# %% [markdown]
# ## Simulate injections

# %%
import dingo.gw.injection as injection
from dingo.gw.noise.asd_dataset import ASDDataset

# ============================================================
# Setup
# ============================================================

num_injections = 1000
out_dir = f"/scratch/tpausch/test_data/{name}/injections"
os.makedirs(out_dir, exist_ok=True)

np.random.seed(42)  # optional, for reproducibility

injection_generator = injection.Injection.from_posterior_model_metadata(
    main_pm.metadata
)

asd_fname = main_pm.metadata["train_settings"]["training"]["stage_0"]["asd_dataset_path"]
asd_dataset = ASDDataset(file_name=asd_fname)

injection_generator.asd = {
    k: v[0] for k, v in asd_dataset.asds.items()
}

# This is the combined intrinsic + extrinsic bilby PriorDict
# that the network was trained on
prior = injection_generator.prior
print(prior)

# ============================================================
# Draw and run injections
# ============================================================

for idx in range(num_injections):

    print(f"Running injection {idx}")

    theta = prior.sample()
    theta = {k: float(v) for k, v in theta.items()}  # cast numpy -> float

    strain_data = injection_generator.injection(theta)

    payload = {
        "theta_true": theta,
        "strain_data": strain_data,
    }

    fname = os.path.join(out_dir, f"inj_{idx:04d}.pkl")

    with open(fname, "wb") as f:
        pickle.dump(payload, f)
# Out:
# Setting spin_conversion_phase = 0.0. Using this value for the phase parameter for conversion to cartesian spins.
# Loading dataset from training_data/asds_ET_T8.hdf5.
# {'mass_1': Constraint(minimum=30.0, maximum=3000.0, name='mass_1', latex_label='$m_1$', unit=None), 'mass_2': Constraint(minimum=30.0, maximum=3000.0, name='mass_2', latex_label='$m_2$', unit=None), 'chirp_mass': bilby.gw.prior.UniformInComponentsChirpMass(minimum=50.0, maximum=1000.0, name='chirp_mass', latex_label='$\\mathcal{M}$', unit=None, boundary=None), 'mass_ratio': bilby.gw.prior.UniformInComponentsMassRatio(minimum=0.125, maximum=1.0, name='mass_ratio', latex_label='$q$', unit=None, boundary=None, equal_mass=False), 'phase': Uniform(minimum=0.0, maximum=6.283185307179586, name='phase', latex_label='$\\phi$', unit=None, boundary='periodic'), 'chi_1': bilby.gw.prior.AlignedSpin(a_prior=Uniform(minimum=0, maximum=0.9, name=None, latex_label=None, unit=None, boundary=None), z_prior=Uniform(minimum=-1, maximum=1, name=None, latex_label=None, unit=None, boundary=None), name='chi_1', latex_label='$\\chi_1$', unit=None, boundary=None, minimum=-0.9, maximum=0.9, num_interp=100000), 'chi_2': bilby.gw.prior.AlignedSpin(a_prior=Uniform(minimum=0, maximum=0.9, name=None, latex_label=None, unit=None, boundary=None), z_prior=Uniform(minimum=-1, maximum=1, name=None, latex_label=None, unit=None, boundary=None), name='chi_2', latex_label='$\\chi_2$', unit=None, boundary=None, minimum=-0.9, maximum=0.9, num_interp=100000), 'theta_jn': Sine(minimum=0.0, maximum=3.141592653589793, name='theta_jn', latex_label='$\\theta_{JN}$', unit=None, boundary=None), 'luminosity_distance': LogUniform(minimum=1000.0, maximum=100000.0, name='luminosity_distance', latex_label='$d_L$', unit=None, boundary=None), 'geocent_time': Uniform(minimum=-0.1, maximum=0.1, name='geocent_time', latex_label='$t_c$', unit=None, boundary=None), 'dec': Cosine(minimum=-1.5707963267948966, maximum=1.5707963267948966, name='dec', latex_label='$\\mathrm{DEC}$', unit=None, boundary=None), 'ra': Uniform(minimum=0.0, maximum=6.283185307179586, name='ra', latex_label='$\\mathrm{RA}$', unit=None, boundary='periodic'), 'psi': Uniform(minimum=0.0, maximum=3.141592653589793, name='psi', latex_label='$\\psi$', unit=None, boundary='periodic')}
# Running injection 0
# Generation with parameters (4.9625050076332194e+33, 7.277262870231076e+32, 0.0, 0.0, -0.15466749650489403, 0.0, 0.0, 0.2809144060099891, 3.085677581491367e+24, 2.161066884666597, 5.765358643204346, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.9625050076332194e+33, 7.277262870231076e+32, 0.0, 0.0, -0.15466749650489403, 0.0, 0.0, 0.2809144060099891, 3.085677581491367e+24, 2.161066884666597, 5.765358643204346, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1
# Generation with parameters (8.654923312984693e+32, 5.747078445755213e+32, 0.0, 0.0, 0.24436693335174123, 0.0, 0.0, -0.18671862786667104, 3.085677581491367e+24, 0.9761799796854166, 3.1876984946236187, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.654923312984693e+32, 5.747078445755213e+32, 0.0, 0.0, 0.24436693335174123, 0.0, 0.0, -0.18671862786667104, 3.085677581491367e+24, 0.9761799796854166, 3.1876984946236187, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 2
# Generation with parameters (4.397461915466158e+33, 1.2447995716805106e+33, 0.0, 0.0, 0.2313810012221563, 0.0, 0.0, -0.020005955689170338, 3.085677581491367e+24, 1.144518729751573, 2.7173104586317343, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.397461915466158e+33, 1.2447995716805106e+33, 0.0, 0.0, 0.2313810012221563, 0.0, 0.0, -0.020005955689170338, 3.085677581491367e+24, 1.144518729751573, 2.7173104586317343, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 3
# Generation with parameters (4.921691647629661e+33, 7.904063417074504e+32, 0.0, 0.0, 0.04383131575496499, 0.0, 0.0, 0.27151187495058304, 3.085677581491367e+24, 2.2761477695096786, 5.27085651403671, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.921691647629661e+33, 7.904063417074504e+32, 0.0, 0.0, 0.04383131575496499, 0.0, 0.0, 0.27151187495058304, 3.085677581491367e+24, 2.2761477695096786, 5.27085651403671, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 4
# Generation with parameters (9.725572663271406e+32, 9.387984856074421e+32, 0.0, 0.0, -0.47188675009452385, 0.0, 0.0, 0.028775002939981132, 3.085677581491367e+24, 1.8399786384268373, 2.794996539810859, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.725572663271406e+32, 9.387984856074421e+32, 0.0, 0.0, -0.47188675009452385, 0.0, 0.0, 0.028775002939981132, 3.085677581491367e+24, 1.8399786384268373, 2.794996539810859, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 5
# Generation with parameters (4.1375952011921546e+33, 1.0405599691099118e+33, 0.0, 0.0, 0.6456549172316906, 0.0, 0.0, 0.058714089294320405, 3.085677581491367e+24, 1.7396449991342973, 2.780841424589064, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.1375952011921546e+33, 1.0405599691099118e+33, 0.0, 0.0, 0.6456549172316906, 0.0, 0.0, 0.058714089294320405, 3.085677581491367e+24, 1.7396449991342973, 2.780841424589064, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 6
# Generation with parameters (1.9917417230541367e+33, 1.722009466445718e+33, 0.0, 0.0, -0.005356179485519315, 0.0, 0.0, 0.4501374058317461, 3.085677581491367e+24, 0.19692475990970829, 5.755746107540249, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.9917417230541367e+33, 1.722009466445718e+33, 0.0, 0.0, -0.005356179485519315, 0.0, 0.0, 0.4501374058317461, 3.085677581491367e+24, 0.19692475990970829, 5.755746107540249, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 7
# Generation with parameters (3.675787237177347e+33, 6.440079039343152e+32, 0.0, 0.0, 0.034294990859944516, 0.0, 0.0, 0.20538832110302163, 3.085677581491367e+24, 0.6542037710149486, 5.300564425632044, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.675787237177347e+33, 6.440079039343152e+32, 0.0, 0.0, 0.034294990859944516, 0.0, 0.0, 0.20538832110302163, 3.085677581491367e+24, 0.6542037710149486, 5.300564425632044, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 8
# Generation with parameters (1.973865950173646e+33, 6.788574201615404e+32, 0.0, 0.0, -0.27383942985030874, 0.0, 0.0, 0.38834455499576565, 3.085677581491367e+24, 2.6121774054953177, 0.42083354983930416, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.973865950173646e+33, 6.788574201615404e+32, 0.0, 0.0, -0.27383942985030874, 0.0, 0.0, 0.38834455499576565, 3.085677581491367e+24, 2.6121774054953177, 0.42083354983930416, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 9
# Generation with parameters (1.7847885377486965e+33, 7.14725469080633e+32, 0.0, 0.0, 0.03476923067060573, 0.0, 0.0, 0.22524399439885368, 3.085677581491367e+24, 1.4113842115749486, 0.9496819622754046, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7847885377486965e+33, 7.14725469080633e+32, 0.0, 0.0, 0.03476923067060573, 0.0, 0.0, 0.22524399439885368, 3.085677581491367e+24, 1.4113842115749486, 0.9496819622754046, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 10
# Generation with parameters (2.899870085146221e+33, 1.4229301608660275e+33, 0.0, 0.0, 0.6024730740490956, 0.0, 0.0, -0.3269655064851322, 3.085677581491367e+24, 1.8003979066775364, 0.4749107846001188, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.899870085146221e+33, 1.4229301608660275e+33, 0.0, 0.0, 0.6024730740490956, 0.0, 0.0, -0.3269655064851322, 3.085677581491367e+24, 1.8003979066775364, 0.4749107846001188, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 11
# Generation with parameters (1.5687074758105216e+33, 1.320873139825892e+33, 0.0, 0.0, -0.4024820962742816, 0.0, 0.0, -0.018481106685207423, 3.085677581491367e+24, 2.770895771910623, 4.285441259548594, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5687074758105216e+33, 1.320873139825892e+33, 0.0, 0.0, -0.4024820962742816, 0.0, 0.0, -0.018481106685207423, 3.085677581491367e+24, 2.770895771910623, 4.285441259548594, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 12
# Generation with parameters (1.934276763464504e+33, 1.6246163330623206e+33, 0.0, 0.0, 0.11265664297382788, 0.0, 0.0, -0.1545487150354078, 3.085677581491367e+24, 1.2131768163359844, 5.6546011637838065, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.934276763464504e+33, 1.6246163330623206e+33, 0.0, 0.0, 0.11265664297382788, 0.0, 0.0, -0.1545487150354078, 3.085677581491367e+24, 1.2131768163359844, 5.6546011637838065, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 13
# Generation with parameters (2.860949621911468e+33, 1.586403194427631e+33, 0.0, 0.0, 0.0455593320086577, 0.0, 0.0, 0.0447010058222568, 3.085677581491367e+24, 1.219205729647108, 0.5287988598868606, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.860949621911468e+33, 1.586403194427631e+33, 0.0, 0.0, 0.0455593320086577, 0.0, 0.0, 0.0447010058222568, 3.085677581491367e+24, 1.219205729647108, 0.5287988598868606, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 14
# Generation with parameters (4.379054472663831e+33, 5.7983818151685794e+32, 0.0, 0.0, -0.1845655518345657, 0.0, 0.0, 0.06270757612672824, 3.085677581491367e+24, 1.9301755418039148, 3.029172943017535, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.379054472663831e+33, 5.7983818151685794e+32, 0.0, 0.0, -0.1845655518345657, 0.0, 0.0, 0.06270757612672824, 3.085677581491367e+24, 1.9301755418039148, 3.029172943017535, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 15
# Generation with parameters (1.1574099497068226e+33, 9.872565400696678e+32, 0.0, 0.0, 0.21895816586126504, 0.0, 0.0, 0.025150584268464938, 3.085677581491367e+24, 1.75906910275706, 0.887334884921159, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1574099497068226e+33, 9.872565400696678e+32, 0.0, 0.0, 0.21895816586126504, 0.0, 0.0, 0.025150584268464938, 3.085677581491367e+24, 1.75906910275706, 0.887334884921159, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 16
# Generation with parameters (2.0731704344064128e+33, 5.194380621381433e+32, 0.0, 0.0, 0.47061378301102297, 0.0, 0.0, 0.08995844517856195, 3.085677581491367e+24, 1.2838721562829745, 0.37480902918813447, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0731704344064128e+33, 5.194380621381433e+32, 0.0, 0.0, 0.47061378301102297, 0.0, 0.0, 0.08995844517856195, 3.085677581491367e+24, 1.2838721562829745, 0.37480902918813447, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 17
# Generation with parameters (5.514135840698474e+33, 1.0474192079201457e+33, 0.0, 0.0, -0.2746132940973548, 0.0, 0.0, -0.12811543833268652, 3.085677581491367e+24, 2.2211665724863465, 3.06733008578113, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.514135840698474e+33, 1.0474192079201457e+33, 0.0, 0.0, -0.2746132940973548, 0.0, 0.0, -0.12811543833268652, 3.085677581491367e+24, 2.2211665724863465, 3.06733008578113, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 18
# Generation with parameters (3.2545624744518646e+33, 4.352989255053144e+32, 0.0, 0.0, -0.8028787752959358, 0.0, 0.0, 0.21430681013701336, 3.085677581491367e+24, 1.3556453066059295, 0.8984620173066687, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.2545624744518646e+33, 4.352989255053144e+32, 0.0, 0.0, -0.8028787752959358, 0.0, 0.0, 0.21430681013701336, 3.085677581491367e+24, 1.3556453066059295, 0.8984620173066687, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 19
# Generation with parameters (4.052182886046121e+33, 1.138217957195283e+33, 0.0, 0.0, -0.766206459870843, 0.0, 0.0, 0.16454099197288996, 3.085677581491367e+24, 0.8688484035170442, 4.805128813290053, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.052182886046121e+33, 1.138217957195283e+33, 0.0, 0.0, -0.766206459870843, 0.0, 0.0, 0.16454099197288996, 3.085677581491367e+24, 0.8688484035170442, 4.805128813290053, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 20
# Generation with parameters (2.527766951233526e+33, 1.8222526540942462e+33, 0.0, 0.0, 0.35904904887169486, 0.0, 0.0, 0.28435274791264287, 3.085677581491367e+24, 1.3699292006113666, 5.088949771461786, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.527766951233526e+33, 1.8222526540942462e+33, 0.0, 0.0, 0.35904904887169486, 0.0, 0.0, 0.28435274791264287, 3.085677581491367e+24, 1.3699292006113666, 5.088949771461786, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 21
# Generation with parameters (4.345476077179166e+33, 1.0494423667557603e+33, 0.0, 0.0, 0.0682806343627348, 0.0, 0.0, 0.16186757851813105, 3.085677581491367e+24, 1.0246217218802167, 2.28792144184695, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.345476077179166e+33, 1.0494423667557603e+33, 0.0, 0.0, 0.0682806343627348, 0.0, 0.0, 0.16186757851813105, 3.085677581491367e+24, 1.0246217218802167, 2.28792144184695, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 22
# Generation with parameters (2.2906657621208867e+33, 8.127749956829626e+32, 0.0, 0.0, -0.10873974961360232, 0.0, 0.0, 0.24256718314776812, 3.085677581491367e+24, 2.0385365999275735, 5.907274871723504, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2906657621208867e+33, 8.127749956829626e+32, 0.0, 0.0, -0.10873974961360232, 0.0, 0.0, 0.24256718314776812, 3.085677581491367e+24, 2.0385365999275735, 5.907274871723504, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 23
# Generation with parameters (5.104953805628359e+33, 1.1321132734824233e+33, 0.0, 0.0, 0.22806266125324717, 0.0, 0.0, 0.007651324441306834, 3.085677581491367e+24, 1.5739470860713713, 0.6382510130659228, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.104953805628359e+33, 1.1321132734824233e+33, 0.0, 0.0, 0.22806266125324717, 0.0, 0.0, 0.007651324441306834, 3.085677581491367e+24, 1.5739470860713713, 0.6382510130659228, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 24
# Generation with parameters (5.097277432377269e+33, 6.609651023289978e+32, 0.0, 0.0, -0.3699020179777245, 0.0, 0.0, -0.30111331865318824, 3.085677581491367e+24, 0.13713800849117633, 2.2342798064031277, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.097277432377269e+33, 6.609651023289978e+32, 0.0, 0.0, -0.3699020179777245, 0.0, 0.0, -0.30111331865318824, 3.085677581491367e+24, 0.13713800849117633, 2.2342798064031277, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 25
# Generation with parameters (5.945262457187239e+33, 8.844330698146085e+32, 0.0, 0.0, 0.14744173451948725, 0.0, 0.0, -0.06078447106318609, 3.085677581491367e+24, 1.8770101483631727, 1.9989260506208815, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.945262457187239e+33, 8.844330698146085e+32, 0.0, 0.0, 0.14744173451948725, 0.0, 0.0, -0.06078447106318609, 3.085677581491367e+24, 1.8770101483631727, 1.9989260506208815, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 26
# Generation with parameters (2.812454920403255e+33, 1.5689178347883065e+33, 0.0, 0.0, -0.04522182406535634, 0.0, 0.0, -0.17233029647649364, 3.085677581491367e+24, 1.8776343821005672, 2.8331120967390997, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.812454920403255e+33, 1.5689178347883065e+33, 0.0, 0.0, -0.04522182406535634, 0.0, 0.0, -0.17233029647649364, 3.085677581491367e+24, 1.8776343821005672, 2.8331120967390997, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 27
# Generation with parameters (1.7116189055662405e+33, 1.1987426432328373e+33, 0.0, 0.0, 0.47494470186714205, 0.0, 0.0, -0.6313916927975212, 3.085677581491367e+24, 0.7895880868661254, 5.863212253858093, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7116189055662405e+33, 1.1987426432328373e+33, 0.0, 0.0, 0.47494470186714205, 0.0, 0.0, -0.6313916927975212, 3.085677581491367e+24, 0.7895880868661254, 5.863212253858093, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 28
# Generation with parameters (1.628108290033147e+33, 8.147318631438481e+32, 0.0, 0.0, -0.05456640518125974, 0.0, 0.0, -0.20616827948022526, 3.085677581491367e+24, 1.5560391210864575, 1.0827337046139658, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.628108290033147e+33, 8.147318631438481e+32, 0.0, 0.0, -0.05456640518125974, 0.0, 0.0, -0.20616827948022526, 3.085677581491367e+24, 1.5560391210864575, 1.0827337046139658, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 29
# Generation with parameters (1.533426900297397e+33, 1.3837405701164573e+33, 0.0, 0.0, 0.04962566958078685, 0.0, 0.0, 0.15898872728198962, 3.085677581491367e+24, 2.7488073984769414, 0.8866636910331794, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.533426900297397e+33, 1.3837405701164573e+33, 0.0, 0.0, 0.04962566958078685, 0.0, 0.0, 0.15898872728198962, 3.085677581491367e+24, 2.7488073984769414, 0.8866636910331794, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 30
# Generation with parameters (1.3141735269675085e+33, 4.449323100987944e+32, 0.0, 0.0, -0.12740206778137217, 0.0, 0.0, 0.007609782911640346, 3.085677581491367e+24, 2.356014292374166, 3.999151779548025, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3141735269675085e+33, 4.449323100987944e+32, 0.0, 0.0, -0.12740206778137217, 0.0, 0.0, 0.007609782911640346, 3.085677581491367e+24, 2.356014292374166, 3.999151779548025, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 31
# Generation with parameters (1.94815133332796e+33, 4.899288804690912e+32, 0.0, 0.0, 0.3934680179729588, 0.0, 0.0, -0.06963649186103284, 3.085677581491367e+24, 1.9304063554710127, 5.81131124531281, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.94815133332796e+33, 4.899288804690912e+32, 0.0, 0.0, 0.3934680179729588, 0.0, 0.0, -0.06963649186103284, 3.085677581491367e+24, 1.9304063554710127, 5.81131124531281, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 32
# Generation with parameters (2.2409981914821295e+33, 2.0794453000740046e+33, 0.0, 0.0, 0.5555331208745946, 0.0, 0.0, 0.4937545744953508, 3.085677581491367e+24, 2.165055740036113, 0.20317041921671716, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2409981914821295e+33, 2.0794453000740046e+33, 0.0, 0.0, 0.5555331208745946, 0.0, 0.0, 0.4937545744953508, 3.085677581491367e+24, 2.165055740036113, 0.20317041921671716, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 33
# Generation with parameters (1.7854381249879868e+33, 4.456383080613061e+32, 0.0, 0.0, -0.11557838501194743, 0.0, 0.0, -0.5897505800729541, 3.085677581491367e+24, 2.752113719538876, 5.253433264119604, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7854381249879868e+33, 4.456383080613061e+32, 0.0, 0.0, -0.11557838501194743, 0.0, 0.0, -0.5897505800729541, 3.085677581491367e+24, 2.752113719538876, 5.253433264119604, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 34
# Generation with parameters (2.4700311971986627e+33, 1.915412987976937e+33, 0.0, 0.0, -0.06065597093156952, 0.0, 0.0, 0.18477608361881728, 3.085677581491367e+24, 0.8064831253909017, 3.6476873783289174, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.4700311971986627e+33, 1.915412987976937e+33, 0.0, 0.0, -0.06065597093156952, 0.0, 0.0, 0.18477608361881728, 3.085677581491367e+24, 0.8064831253909017, 3.6476873783289174, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 35
# Generation with parameters (1.4104492088670618e+33, 5.545747327641017e+32, 0.0, 0.0, 0.30198209193116143, 0.0, 0.0, 0.18878180892567922, 3.085677581491367e+24, 1.4525574797717475, 3.847177675517393, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4104492088670618e+33, 5.545747327641017e+32, 0.0, 0.0, 0.30198209193116143, 0.0, 0.0, 0.18878180892567922, 3.085677581491367e+24, 1.4525574797717475, 3.847177675517393, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 36
# Generation with parameters (1.7416349403682305e+33, 1.2876455669220629e+33, 0.0, 0.0, -0.031405242887854214, 0.0, 0.0, -0.4732898422983785, 3.085677581491367e+24, 1.5494764754298633, 3.1823533100135455, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7416349403682305e+33, 1.2876455669220629e+33, 0.0, 0.0, -0.031405242887854214, 0.0, 0.0, -0.4732898422983785, 3.085677581491367e+24, 1.5494764754298633, 3.1823533100135455, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 37
# Generation with parameters (1.8286927411275906e+33, 1.56842273629796e+33, 0.0, 0.0, -0.05905995667424317, 0.0, 0.0, 0.23010304366701323, 3.085677581491367e+24, 1.5985005313457687, 3.006745978803229, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8286927411275906e+33, 1.56842273629796e+33, 0.0, 0.0, -0.05905995667424317, 0.0, 0.0, 0.23010304366701323, 3.085677581491367e+24, 1.5985005313457687, 3.006745978803229, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 38
# Generation with parameters (3.0168052764040904e+33, 8.488424072122064e+32, 0.0, 0.0, -0.03161273775715088, 0.0, 0.0, -0.15095658187713373, 3.085677581491367e+24, 1.1350736409461533, 5.416519903476204, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.0168052764040904e+33, 8.488424072122064e+32, 0.0, 0.0, -0.03161273775715088, 0.0, 0.0, -0.15095658187713373, 3.085677581491367e+24, 1.1350736409461533, 5.416519903476204, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 39
# Generation with parameters (5.238836829725364e+33, 9.602269536282536e+32, 0.0, 0.0, 0.7228947787335327, 0.0, 0.0, -0.3479869638753624, 3.085677581491367e+24, 0.3528853136011772, 5.032168160780152, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.238836829725364e+33, 9.602269536282536e+32, 0.0, 0.0, 0.7228947787335327, 0.0, 0.0, -0.3479869638753624, 3.085677581491367e+24, 0.3528853136011772, 5.032168160780152, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 40
# Generation with parameters (4.1275354035035406e+33, 6.892204921290389e+32, 0.0, 0.0, 0.5883250543268098, 0.0, 0.0, -0.0653630933799951, 3.085677581491367e+24, 1.7719960460230015, 1.5929804353815555, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.1275354035035406e+33, 6.892204921290389e+32, 0.0, 0.0, 0.5883250543268098, 0.0, 0.0, -0.0653630933799951, 3.085677581491367e+24, 1.7719960460230015, 1.5929804353815555, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 41
# Generation with parameters (3.434910000381021e+33, 1.0879883502437419e+33, 0.0, 0.0, 0.011293900708492583, 0.0, 0.0, -0.004100052793992732, 3.085677581491367e+24, 2.153565297668034, 3.747127692809461, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.434910000381021e+33, 1.0879883502437419e+33, 0.0, 0.0, 0.011293900708492583, 0.0, 0.0, -0.004100052793992732, 3.085677581491367e+24, 2.153565297668034, 3.747127692809461, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 42
# Generation with parameters (1.7088604307611906e+33, 9.751759267814595e+32, 0.0, 0.0, -0.27361657092677233, 0.0, 0.0, -0.18164230686234542, 3.085677581491367e+24, 1.9853767317355449, 4.946773775534585, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7088604307611906e+33, 9.751759267814595e+32, 0.0, 0.0, -0.27361657092677233, 0.0, 0.0, -0.18164230686234542, 3.085677581491367e+24, 1.9853767317355449, 4.946773775534585, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 43
# Generation with parameters (5.531878999745899e+33, 7.990286750906499e+32, 0.0, 0.0, -0.17409535210391197, 0.0, 0.0, -0.04586364308799345, 3.085677581491367e+24, 2.525753674239287, 2.690815231321326, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.531878999745899e+33, 7.990286750906499e+32, 0.0, 0.0, -0.17409535210391197, 0.0, 0.0, -0.04586364308799345, 3.085677581491367e+24, 2.525753674239287, 2.690815231321326, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 44
# Generation with parameters (2.1317239319808864e+33, 1.6811260521704652e+33, 0.0, 0.0, 0.15922808013603124, 0.0, 0.0, -0.7421345685238544, 3.085677581491367e+24, 1.107371526063638, 1.5804925825626026, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.1317239319808864e+33, 1.6811260521704652e+33, 0.0, 0.0, 0.15922808013603124, 0.0, 0.0, -0.7421345685238544, 3.085677581491367e+24, 1.107371526063638, 1.5804925825626026, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 45
# Generation with parameters (3.438846669587791e+33, 1.1160666013555088e+33, 0.0, 0.0, -0.03217107449743636, 0.0, 0.0, -0.030835885973142758, 3.085677581491367e+24, 0.8926400186394752, 3.46906358745723, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.438846669587791e+33, 1.1160666013555088e+33, 0.0, 0.0, -0.03217107449743636, 0.0, 0.0, -0.030835885973142758, 3.085677581491367e+24, 0.8926400186394752, 3.46906358745723, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 46
# Generation with parameters (2.3510699943104345e+33, 1.7931641015535266e+33, 0.0, 0.0, 0.023495395403507233, 0.0, 0.0, -0.7444429901710687, 3.085677581491367e+24, 1.6679095746903054, 3.9190676150422807, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3510699943104345e+33, 1.7931641015535266e+33, 0.0, 0.0, 0.023495395403507233, 0.0, 0.0, -0.7444429901710687, 3.085677581491367e+24, 1.6679095746903054, 3.9190676150422807, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 47
# Generation with parameters (1.886074378657084e+33, 6.613931889717933e+32, 0.0, 0.0, 0.0007445886166545986, 0.0, 0.0, -0.026224521834392653, 3.085677581491367e+24, 1.4413119608988771, 5.376606905071621, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.886074378657084e+33, 6.613931889717933e+32, 0.0, 0.0, 0.0007445886166545986, 0.0, 0.0, -0.026224521834392653, 3.085677581491367e+24, 1.4413119608988771, 5.376606905071621, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 48
# Generation with parameters (2.828594756285371e+33, 1.1746747845324602e+33, 0.0, 0.0, 0.22939766306841064, 0.0, 0.0, 0.6061928833142302, 3.085677581491367e+24, 1.795452094071423, 1.5169246432209011, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.828594756285371e+33, 1.1746747845324602e+33, 0.0, 0.0, 0.22939766306841064, 0.0, 0.0, 0.6061928833142302, 3.085677581491367e+24, 1.795452094071423, 1.5169246432209011, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 49
# Generation with parameters (3.267941400004992e+33, 4.463038770694748e+32, 0.0, 0.0, 0.33271763515282227, 0.0, 0.0, 0.11123804894837569, 3.085677581491367e+24, 1.7207180127095956, 5.247312440881461, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.267941400004992e+33, 4.463038770694748e+32, 0.0, 0.0, 0.33271763515282227, 0.0, 0.0, 0.11123804894837569, 3.085677581491367e+24, 1.7207180127095956, 5.247312440881461, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 50
# Generation with parameters (2.024171442910063e+33, 3.8082344428679084e+32, 0.0, 0.0, 0.20793453470990952, 0.0, 0.0, -0.26925397136246204, 3.085677581491367e+24, 2.1131959266257487, 5.722824878316015, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.024171442910063e+33, 3.8082344428679084e+32, 0.0, 0.0, 0.20793453470990952, 0.0, 0.0, -0.26925397136246204, 3.085677581491367e+24, 2.1131959266257487, 5.722824878316015, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 51
# Running injection 52
# Generation with parameters (3.38134457266384e+33, 6.168620754620869e+32, 0.0, 0.0, -0.17111588480865883, 0.0, 0.0, 0.200960966958505, 3.085677581491367e+24, 1.4646675349385472, 2.038052807557317, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.38134457266384e+33, 6.168620754620869e+32, 0.0, 0.0, -0.17111588480865883, 0.0, 0.0, 0.200960966958505, 3.085677581491367e+24, 1.4646675349385472, 2.038052807557317, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 53
# Generation with parameters (2.2074872002288125e+33, 1.7062749162196765e+33, 0.0, 0.0, 0.5632669490744724, 0.0, 0.0, 0.43742144863508015, 3.085677581491367e+24, 1.2034750329174462, 2.428064210992521, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2074872002288125e+33, 1.7062749162196765e+33, 0.0, 0.0, 0.5632669490744724, 0.0, 0.0, 0.43742144863508015, 3.085677581491367e+24, 1.2034750329174462, 2.428064210992521, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 54
# Generation with parameters (3.0370482470203066e+33, 1.1381347196742606e+33, 0.0, 0.0, 0.5324505165953989, 0.0, 0.0, -0.3239247061643952, 3.085677581491367e+24, 2.0479210299179558, 5.663378939622968, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.0370482470203066e+33, 1.1381347196742606e+33, 0.0, 0.0, 0.5324505165953989, 0.0, 0.0, -0.3239247061643952, 3.085677581491367e+24, 2.0479210299179558, 5.663378939622968, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 55
# Generation with parameters (3.241786257703758e+33, 1.1890399160691371e+33, 0.0, 0.0, 0.10609498612797844, 0.0, 0.0, 0.4207743564175068, 3.085677581491367e+24, 1.6504068541490446, 4.015821794428194, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.241786257703758e+33, 1.1890399160691371e+33, 0.0, 0.0, 0.10609498612797844, 0.0, 0.0, 0.4207743564175068, 3.085677581491367e+24, 1.6504068541490446, 4.015821794428194, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 56
# Generation with parameters (3.5271283607864216e+33, 4.8283502061417956e+32, 0.0, 0.0, -0.054659607889240985, 0.0, 0.0, 0.6734396185230269, 3.085677581491367e+24, 2.4968430871523, 4.942446163364917, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.5271283607864216e+33, 4.8283502061417956e+32, 0.0, 0.0, -0.054659607889240985, 0.0, 0.0, 0.6734396185230269, 3.085677581491367e+24, 2.4968430871523, 4.942446163364917, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 57
# Generation with parameters (1.3577515117266265e+33, 1.0201736681531938e+33, 0.0, 0.0, 0.17640338103033015, 0.0, 0.0, -0.09934999632226585, 3.085677581491367e+24, 2.392366904319282, 5.3532835222397175, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3577515117266265e+33, 1.0201736681531938e+33, 0.0, 0.0, 0.17640338103033015, 0.0, 0.0, -0.09934999632226585, 3.085677581491367e+24, 2.392366904319282, 5.3532835222397175, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 58
# Generation with parameters (1.4966024283825387e+33, 1.471235869352637e+33, 0.0, 0.0, 0.24456830910772795, 0.0, 0.0, -0.20504282386592226, 3.085677581491367e+24, 2.5192297396082104, 2.8966281593113616, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4966024283825387e+33, 1.471235869352637e+33, 0.0, 0.0, 0.24456830910772795, 0.0, 0.0, -0.20504282386592226, 3.085677581491367e+24, 2.5192297396082104, 2.8966281593113616, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 59
# Generation with parameters (3.3208912660089954e+33, 1.1586528004921802e+33, 0.0, 0.0, -0.24534449316285686, 0.0, 0.0, 0.1014348826910248, 3.085677581491367e+24, 1.9173143091378753, 0.6592957899832179, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.3208912660089954e+33, 1.1586528004921802e+33, 0.0, 0.0, -0.24534449316285686, 0.0, 0.0, 0.1014348826910248, 3.085677581491367e+24, 1.9173143091378753, 0.6592957899832179, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 60
# Generation with parameters (1.660587859505537e+33, 1.1368784826436248e+33, 0.0, 0.0, 0.18428303594273265, 0.0, 0.0, 0.12918801306489697, 3.085677581491367e+24, 2.1336859585031704, 0.6760456259465527, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.660587859505537e+33, 1.1368784826436248e+33, 0.0, 0.0, 0.18428303594273265, 0.0, 0.0, 0.12918801306489697, 3.085677581491367e+24, 2.1336859585031704, 0.6760456259465527, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 61
# Generation with parameters (4.4623616652389866e+33, 7.243197557439743e+32, 0.0, 0.0, -0.02234629367766754, 0.0, 0.0, 0.004595455974582635, 3.085677581491367e+24, 1.8598780940761164, 0.7736052063342822, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.4623616652389866e+33, 7.243197557439743e+32, 0.0, 0.0, -0.02234629367766754, 0.0, 0.0, 0.004595455974582635, 3.085677581491367e+24, 1.8598780940761164, 0.7736052063342822, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 62
# Generation with parameters (1.50487093639035e+33, 1.0093980895954794e+33, 0.0, 0.0, 0.24874108650417726, 0.0, 0.0, -0.025968682934005893, 3.085677581491367e+24, 2.379122076707528, 4.713848743474107, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.50487093639035e+33, 1.0093980895954794e+33, 0.0, 0.0, 0.24874108650417726, 0.0, 0.0, -0.025968682934005893, 3.085677581491367e+24, 2.379122076707528, 4.713848743474107, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 63
# Generation with parameters (2.147944327309248e+33, 3.7973825328628154e+32, 0.0, 0.0, 0.09271595254244076, 0.0, 0.0, 0.0890155577697299, 3.085677581491367e+24, 0.8588007610798856, 4.7873414321998435, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.147944327309248e+33, 3.7973825328628154e+32, 0.0, 0.0, 0.09271595254244076, 0.0, 0.0, 0.0890155577697299, 3.085677581491367e+24, 0.8588007610798856, 4.7873414321998435, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 64
# Generation with parameters (1.681787203530549e+33, 1.6396450817349227e+33, 0.0, 0.0, 0.7964666436156147, 0.0, 0.0, 0.13639919040179352, 3.085677581491367e+24, 2.0075821879175226, 2.8759835316360483, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.681787203530549e+33, 1.6396450817349227e+33, 0.0, 0.0, 0.7964666436156147, 0.0, 0.0, 0.13639919040179352, 3.085677581491367e+24, 2.0075821879175226, 2.8759835316360483, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 65
# Generation with parameters (5.355832786400347e+33, 1.0515947230762462e+33, 0.0, 0.0, -0.12157973920674733, 0.0, 0.0, 0.24660607697719295, 3.085677581491367e+24, 0.9445350107806686, 6.072113060239852, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.355832786400347e+33, 1.0515947230762462e+33, 0.0, 0.0, -0.12157973920674733, 0.0, 0.0, 0.24660607697719295, 3.085677581491367e+24, 0.9445350107806686, 6.072113060239852, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 66
# Generation with parameters (2.6600661935396346e+33, 1.5117403822139196e+33, 0.0, 0.0, -0.0036003559770758898, 0.0, 0.0, -0.5983928377110382, 3.085677581491367e+24, 2.370341853963229, 1.0789407673468376, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.6600661935396346e+33, 1.5117403822139196e+33, 0.0, 0.0, -0.0036003559770758898, 0.0, 0.0, -0.5983928377110382, 3.085677581491367e+24, 2.370341853963229, 1.0789407673468376, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 67
# Generation with parameters (1.822834736503468e+33, 2.9312412588811937e+32, 0.0, 0.0, -0.05328913277928888, 0.0, 0.0, 0.16568351003294177, 3.085677581491367e+24, 2.3157754755655864, 0.1656156537558238, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.822834736503468e+33, 2.9312412588811937e+32, 0.0, 0.0, -0.05328913277928888, 0.0, 0.0, 0.16568351003294177, 3.085677581491367e+24, 2.3157754755655864, 0.1656156537558238, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 68
# Generation with parameters (3.3395844323457387e+33, 1.1916806466802674e+33, 0.0, 0.0, 0.7930611150369872, 0.0, 0.0, 0.3809723483882683, 3.085677581491367e+24, 1.630881222662243, 0.9704756182158143, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# ...
# Warning: turning off multibanding for parameters (2.5529492021784657e+33, 1.7944486575431628e+33, 0.0, 0.0, 0.05042949376518272, 0.0, 0.0, 0.0014540998400030963, 3.085677581491367e+24, 1.2292360723885105, 4.736868499743585, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 976
# Generation with parameters (2.9662235960174285e+33, 9.976620600154837e+32, 0.0, 0.0, -0.5881762872540026, 0.0, 0.0, -0.5057588184150226, 3.085677581491367e+24, 1.54005693522653, 5.751991128578073, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.9662235960174285e+33, 9.976620600154837e+32, 0.0, 0.0, -0.5881762872540026, 0.0, 0.0, -0.5057588184150226, 3.085677581491367e+24, 1.54005693522653, 5.751991128578073, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 977
# Generation with parameters (3.612380066665577e+33, 1.0384494378073742e+33, 0.0, 0.0, -0.40854913167626533, 0.0, 0.0, 0.4255928398856589, 3.085677581491367e+24, 2.194467101380234, 6.085302853019042, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.612380066665577e+33, 1.0384494378073742e+33, 0.0, 0.0, -0.40854913167626533, 0.0, 0.0, 0.4255928398856589, 3.085677581491367e+24, 2.194467101380234, 6.085302853019042, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 978
# Generation with parameters (1.4120904730551067e+33, 1.0290853944762617e+33, 0.0, 0.0, -0.34682339239, 0.0, 0.0, 0.0245616306891598, 3.085677581491367e+24, 1.601447980880208, 2.128240415965859, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4120904730551067e+33, 1.0290853944762617e+33, 0.0, 0.0, -0.34682339239, 0.0, 0.0, 0.0245616306891598, 3.085677581491367e+24, 1.601447980880208, 2.128240415965859, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 979
# Generation with parameters (2.46616341013433e+33, 1.2250433963790164e+33, 0.0, 0.0, 0.02528742557991081, 0.0, 0.0, -0.010697127588344662, 3.085677581491367e+24, 1.1551485580482947, 5.581997528580244, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.46616341013433e+33, 1.2250433963790164e+33, 0.0, 0.0, 0.02528742557991081, 0.0, 0.0, -0.010697127588344662, 3.085677581491367e+24, 1.1551485580482947, 5.581997528580244, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 980
# Generation with parameters (3.490539529105734e+33, 4.865826196502823e+32, 0.0, 0.0, -0.13419746154886572, 0.0, 0.0, -0.1278874308224306, 3.085677581491367e+24, 1.0585325413982098, 2.9618941559752607, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.490539529105734e+33, 4.865826196502823e+32, 0.0, 0.0, -0.13419746154886572, 0.0, 0.0, -0.1278874308224306, 3.085677581491367e+24, 1.0585325413982098, 2.9618941559752607, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 981
# Running injection 982
# Generation with parameters (1.3288688924434708e+33, 1.2422701805321914e+33, 0.0, 0.0, 0.8099978902611356, 0.0, 0.0, 0.2634421447687189, 3.085677581491367e+24, 1.724211645843437, 0.6524371244470354, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3288688924434708e+33, 1.2422701805321914e+33, 0.0, 0.0, 0.8099978902611356, 0.0, 0.0, 0.2634421447687189, 3.085677581491367e+24, 1.724211645843437, 0.6524371244470354, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 983
# Generation with parameters (4.219686116453747e+33, 9.018426911763333e+32, 0.0, 0.0, -0.16513544063744492, 0.0, 0.0, -0.009294905705694096, 3.085677581491367e+24, 0.6368275933522275, 2.3562482580868407, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.219686116453747e+33, 9.018426911763333e+32, 0.0, 0.0, -0.16513544063744492, 0.0, 0.0, -0.009294905705694096, 3.085677581491367e+24, 0.6368275933522275, 2.3562482580868407, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 984
# Generation with parameters (3.1169938080391247e+33, 6.026070127533487e+32, 0.0, 0.0, -0.012356535651539146, 0.0, 0.0, -0.38430698776138067, 3.085677581491367e+24, 1.4984577238932195, 4.6025319682037305, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.1169938080391247e+33, 6.026070127533487e+32, 0.0, 0.0, -0.012356535651539146, 0.0, 0.0, -0.38430698776138067, 3.085677581491367e+24, 1.4984577238932195, 4.6025319682037305, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 985
# Generation with parameters (2.3536029902976833e+33, 8.058198241224495e+32, 0.0, 0.0, 0.5478447163045649, 0.0, 0.0, -0.07848074725009967, 3.085677581491367e+24, 1.607916307962793, 0.7776387023198756, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3536029902976833e+33, 8.058198241224495e+32, 0.0, 0.0, 0.5478447163045649, 0.0, 0.0, -0.07848074725009967, 3.085677581491367e+24, 1.607916307962793, 0.7776387023198756, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 986
# Generation with parameters (5.0131540152427133e+33, 9.662628625621093e+32, 0.0, 0.0, 0.07358718984992164, 0.0, 0.0, 0.2162836200949368, 3.085677581491367e+24, 0.89355683201525, 1.0531858788116408, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.0131540152427133e+33, 9.662628625621093e+32, 0.0, 0.0, 0.07358718984992164, 0.0, 0.0, 0.2162836200949368, 3.085677581491367e+24, 0.89355683201525, 1.0531858788116408, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 987
# Generation with parameters (1.1940665390397104e+33, 4.026399047048323e+32, 0.0, 0.0, -0.8263365424329538, 0.0, 0.0, -0.14372536052278198, 3.085677581491367e+24, 2.0450863697660515, 6.0962389764028835, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1940665390397104e+33, 4.026399047048323e+32, 0.0, 0.0, -0.8263365424329538, 0.0, 0.0, -0.14372536052278198, 3.085677581491367e+24, 2.0450863697660515, 6.0962389764028835, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 988
# Generation with parameters (1.2250313420856769e+33, 5.6885371763018975e+32, 0.0, 0.0, -0.1155056678010189, 0.0, 0.0, -0.23698234329439122, 3.085677581491367e+24, 1.517434839936595, 3.420667024988038, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2250313420856769e+33, 5.6885371763018975e+32, 0.0, 0.0, -0.1155056678010189, 0.0, 0.0, -0.23698234329439122, 3.085677581491367e+24, 1.517434839936595, 3.420667024988038, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 989
# Generation with parameters (2.3490629303205545e+33, 1.1868174589229869e+33, 0.0, 0.0, 0.5353578317171952, 0.0, 0.0, 0.18795471641800618, 3.085677581491367e+24, 2.12326251934192, 6.172857438118676, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3490629303205545e+33, 1.1868174589229869e+33, 0.0, 0.0, 0.5353578317171952, 0.0, 0.0, 0.18795471641800618, 3.085677581491367e+24, 2.12326251934192, 6.172857438118676, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 990
# Generation with parameters (2.6732944202380884e+33, 1.2435940464048449e+33, 0.0, 0.0, 0.45712033653241, 0.0, 0.0, 0.10338691886043827, 3.085677581491367e+24, 0.5338751242437051, 4.839851569042476, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.6732944202380884e+33, 1.2435940464048449e+33, 0.0, 0.0, 0.45712033653241, 0.0, 0.0, 0.10338691886043827, 3.085677581491367e+24, 0.5338751242437051, 4.839851569042476, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 991
# Generation with parameters (4.0322098950677034e+33, 5.163958857572754e+32, 0.0, 0.0, 0.23111530949736822, 0.0, 0.0, 0.4694628399517051, 3.085677581491367e+24, 1.6176090075675265, 3.6135721658620445, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.0322098950677034e+33, 5.163958857572754e+32, 0.0, 0.0, 0.23111530949736822, 0.0, 0.0, 0.4694628399517051, 3.085677581491367e+24, 1.6176090075675265, 3.6135721658620445, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 992
# Generation with parameters (4.238038676117192e+33, 1.1032302901099318e+33, 0.0, 0.0, 0.14639783099197867, 0.0, 0.0, -0.19278539251985904, 3.085677581491367e+24, 0.773877449689067, 5.425110686664061, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.238038676117192e+33, 1.1032302901099318e+33, 0.0, 0.0, 0.14639783099197867, 0.0, 0.0, -0.19278539251985904, 3.085677581491367e+24, 0.773877449689067, 5.425110686664061, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 993
# Generation with parameters (5.451556513028699e+33, 1.0126738123840676e+33, 0.0, 0.0, -0.12756330925745937, 0.0, 0.0, -0.6610155349976626, 3.085677581491367e+24, 1.1668653327099912, 0.6118285686151016, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.451556513028699e+33, 1.0126738123840676e+33, 0.0, 0.0, -0.12756330925745937, 0.0, 0.0, -0.6610155349976626, 3.085677581491367e+24, 1.1668653327099912, 0.6118285686151016, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 994
# Generation with parameters (4.068542558916427e+33, 8.207441077241614e+32, 0.0, 0.0, 0.05479140119766886, 0.0, 0.0, -0.20991471691802996, 3.085677581491367e+24, 0.43813208125304176, 4.778507223102791, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.068542558916427e+33, 8.207441077241614e+32, 0.0, 0.0, 0.05479140119766886, 0.0, 0.0, -0.20991471691802996, 3.085677581491367e+24, 0.43813208125304176, 4.778507223102791, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 995
# Generation with parameters (4.0191688988684755e+33, 1.319342718769838e+33, 0.0, 0.0, -0.5038308927219204, 0.0, 0.0, -0.6365933217833333, 3.085677581491367e+24, 1.5960083016437574, 4.843445379993724, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.0191688988684755e+33, 1.319342718769838e+33, 0.0, 0.0, -0.5038308927219204, 0.0, 0.0, -0.6365933217833333, 3.085677581491367e+24, 1.5960083016437574, 4.843445379993724, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 996
# Generation with parameters (5.36743783804773e+33, 9.521180140010416e+32, 0.0, 0.0, -0.4685497220812737, 0.0, 0.0, -0.004667696610634515, 3.085677581491367e+24, 1.4328760334494477, 2.944336198827279, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.36743783804773e+33, 9.521180140010416e+32, 0.0, 0.0, -0.4685497220812737, 0.0, 0.0, -0.004667696610634515, 3.085677581491367e+24, 1.4328760334494477, 2.944336198827279, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 997
# Generation with parameters (1.0686958005800049e+33, 9.080080923130424e+32, 0.0, 0.0, 0.1670709497531228, 0.0, 0.0, 0.34778139900597693, 3.085677581491367e+24, 1.9555194644972815, 4.760644948503592, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0686958005800049e+33, 9.080080923130424e+32, 0.0, 0.0, 0.1670709497531228, 0.0, 0.0, 0.34778139900597693, 3.085677581491367e+24, 1.9555194644972815, 4.760644948503592, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 998
# Generation with parameters (4.7791672239732e+33, 6.000614488265877e+32, 0.0, 0.0, 0.4480397069408714, 0.0, 0.0, 0.2011018555458222, 3.085677581491367e+24, 0.4728095340188772, 0.8838715360012485, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.7791672239732e+33, 6.000614488265877e+32, 0.0, 0.0, 0.4480397069408714, 0.0, 0.0, 0.2011018555458222, 3.085677581491367e+24, 0.4728095340188772, 0.8838715360012485, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 999
# Generation with parameters (4.5488252224537506e+33, 1.0036492603226049e+33, 0.0, 0.0, -0.0730732773180252, 0.0, 0.0, 0.05390022581427499, 3.085677581491367e+24, 0.6346912063657282, 4.443536513825495, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.5488252224537506e+33, 1.0036492603226049e+33, 0.0, 0.0, -0.0730732773180252, 0.0, 0.0, 0.05390022581427499, 3.085677581491367e+24, 0.6346912063657282, 4.443536513825495, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.

# %% [markdown]
# ## Infere parameters

# %%
#%%capture  
#avoids printing a lot of output to the notebook
import pandas as pd
from dingo.gw.inference.gw_samplers import GWSampler




os.makedirs(f"/scratch/tpausch/test_data/{name}/results", exist_ok=True)

injection_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/injections"))

for fname in injection_files:

    # --------------------------------------------------------
    # Load injection
    # --------------------------------------------------------

    with open(f"/scratch/tpausch/test_data/{name}/injections/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    strain_data = payload["strain_data"]

    # --------------------------------------------------------
    # Run sampler
    # --------------------------------------------------------

    sampler = GWSampler(model=main_pm)

    sampler.context = strain_data

    sampler.run_sampler(
        num_samples=50_000,
        batch_size=10_000,
    )

    result = sampler.to_result()



    # --------------------------------------------------------
    # calculate network SNR
    # --------------------------------------------------------
    parameters = pd.DataFrame(
        {key: np.array([np.asarray(val).item()]) for key, val in theta_true.items()}
    )
    snr_df = gw.utilities.get_snr(parameters, network, waveform_model, f_ref)
    network_snr = float(snr_df["network"].iloc[0])  # extract as plain float

    # --------------------------------------------------------
    # Store result
    # --------------------------------------------------------

    result_payload = {
        "theta_true": theta_true,
        "result": result,
        "network_snr": network_snr,
    }

    outname = fname.replace("inj_", "result_")

    with open(f"/scratch/tpausch/test_data/{name}/results/{outname}", "wb") as f:
        pickle.dump(result_payload, f)

    print(f"Saved /scratch/tpausch/test_data/{name}/results/{outname}")
# Out:
# Running sampler to generate 50000 samples.
# Done. This took 2.6 s.
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0000.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0001.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.2 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0002.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0003.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0004.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0005.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0006.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0007.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0008.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0009.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0010.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0011.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0012.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0013.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0014.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0015.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0016.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0017.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0018.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0019.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0020.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0021.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0022.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0023.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0024.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0025.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0026.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0027.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0028.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0029.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0030.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0031.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0032.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0033.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0034.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0035.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0036.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0037.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0038.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0039.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0040.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0041.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0042.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0043.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0044.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0045.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0046.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0047.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0048.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0049.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0050.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0051.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0052.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0053.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0054.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0055.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0056.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0057.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0058.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0059.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0060.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0061.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0062.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0063.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0064.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0065.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0066.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0067.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0068.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0069.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0070.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0071.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0072.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0073.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.4 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0074.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0075.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# ...
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0974.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0975.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0976.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0977.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0978.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0979.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0980.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0981.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0982.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0983.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0984.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0985.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0986.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0987.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0988.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0989.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0990.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0991.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0992.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0993.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0994.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0995.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0996.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0997.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0998.pkl
# Running sampler to generate 50000 samples.
# Done. This took 2.3 s.
# WARNING:dingo.core.utils.backward_compatibility:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Saved /scratch/tpausch/test_data/stage1/results/result_0999.pkl

# %% [markdown]
# ## Calculate and plot chirp mass inference error

# %%
true_cm = []
true_mr = []
mass_ratio_error = []
mass_ratio_std = []
chirp_mass_error = []
chirp_mass_std = []


result_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/{name}/results/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    result = payload["result"]

    posterior_samples = result.samples

    #q_samples = np.array(posterior_samples["mass_ratio"])

    # inference statistics
    #q_mean = np.mean(q_samples)
    #q_std = np.std(q_samples)
#
    #true_q = theta_true["mass_ratio"]

    cm_samples = np.array(posterior_samples["chirp_mass"])

    cm_mean = np.mean(cm_samples)
    cm_std = np.std(cm_samples)

    true_mr.append(theta_true["mass_ratio"])
    true_cm.append(theta_true["chirp_mass"])
    #mass_ratio_error.append(q_mean - true_q)
    #mass_ratio_std.append(q_std)
    chirp_mass_error.append(cm_mean - theta_true["chirp_mass"])
    chirp_mass_std.append(cm_std)


true_mr = np.array(true_mr)
true_cm = np.array(true_cm)

# ------------------------------------------------------------
# Error bars
# ------------------------------------------------------------

#plt.errorbar(
#    true_cm,
#    chirp_mass_error,
#    yerr=chirp_mass_std,
#    fmt="none",
#    capsize=4,
#    alpha=0.5,
#    color="gray",
#)

# ------------------------------------------------------------
# Colored scatter points
# ------------------------------------------------------------

sc = plt.scatter(
    true_cm,
    chirp_mass_error,
    s=20,
    edgecolor="black",
    alpha=0.3
)

# ------------------------------------------------------------
# Reference line
# ------------------------------------------------------------

plt.axhline(0, linestyle="--", color="black")


# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel("True chirp mass")
plt.ylabel("Chirp mass inference error (inferred − true)")

plt.title("Chirp-mass inference error")

plt.grid(True)

plt.tight_layout()
plt.show()

cm_err = np.asarray(chirp_mass_error)

mean_error = np.mean(cm_err)          # signed average bias (over/under-estimation)
mean_abs_error = np.mean(np.abs(cm_err))  # average magnitude of deviation
rms_error = np.sqrt(np.mean(cm_err**2))   # RMS deviation, penalizes outliers more
std_error = np.std(cm_err)            # spread of the errors around their mean
p90_abs_error = np.percentile(np.abs(cm_err), 90)
p95_abs_error = np.percentile(np.abs(cm_err), 95)
p99_abs_error = np.percentile(np.abs(cm_err), 99)


print(f"Mean error (bias):      {mean_error:.3f}")
print(f"Mean absolute error:    {mean_abs_error:.3f}")
print(f"RMS error:              {rms_error:.3f}")
print(f"Std of error:           {std_error:.3f}")
print(f"90th percentile |error|: {p90_abs_error:.3f}")
print(f"95th percentile |error|: {p95_abs_error:.3f}")
print(f"99th percentile |error|: {p99_abs_error:.3f}")
# Out:
# Mean error (bias):      0.520
# Mean absolute error:    31.421
# RMS error:              58.735
# Std of error:           58.732
# 90th percentile |error|: 87.856
# 95th percentile |error|: 120.647
# 99th percentile |error|: 228.788

# %% [markdown]
# ## PP-plot

# %%
pp_values_chirp_mass = []
pp_values_mass_ratio = []

result_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/{name}/results/{fname}", "rb") as f:

        payload = pickle.load(f)

        theta_true = payload["theta_true"]
        result = payload["result"]

        posterior_samples = result.samples


        # ============================================================
        # Chirp mass PP value
        # ============================================================

        cm_samples = posterior_samples["chirp_mass"]

        pp_cm = np.mean(
            cm_samples < theta_true["chirp_mass"]
        )

        pp_values_chirp_mass.append(pp_cm)


        # ============================================================
        # Mass ratio PP value
        # ============================================================

        #q_samples = posterior_samples["mass_ratio"]
#
        #pp_q = np.mean(
        #    q_samples < theta_true["mass_ratio"]
        #)
#
        #pp_values_mass_ratio.append(pp_q)




def plot_pp(pp_values, label):

    pp_values = np.array(pp_values)

    sorted_pp = np.sort(pp_values)

    n = len(sorted_pp)

    empirical_cdf = np.arange(1, n + 1) / n

    x = np.linspace(0, 1, 200)

    sigma = np.sqrt(x * (1 - x) / n)

    plt.figure(figsize=(6, 6))

    # Ideal calibration
    plt.plot(
        [0, 1],
        [0, 1],
        linestyle="--",
        label="Ideal calibration",
    )


    # Empirical PP curve
    plt.plot(
        sorted_pp,
        empirical_cdf,
        marker="o",
        label=label,
    )

    plt.xlabel("Credible level")
    plt.ylabel("Fraction of injections")

    plt.title(f"PP Plot: {label}")

    plt.xlim(0, 1)
    plt.ylim(0, 1)

    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()


plot_pp(
    pp_values_chirp_mass,
    "chirp_mass",
)

#plot_pp(
#    pp_values_mass_ratio,
#    "mass_ratio",
#)

# %% [markdown]
# ## SNR analysis

# %%
snrs = []
ci90_widths = []
chirp_masses = []

result_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/{name}/results/{fname}", "rb") as f:

        payload = pickle.load(f)
    
    theta_true = payload["theta_true"]
    result = payload["result"]


    snr = payload["network_snr"]   # use "ET" instead if you want the single-detector value
   

    snrs.append(snr)

    samples = result.samples["chirp_mass"].to_numpy()  # adjust if result.samples is a DataFrame

    ci90 = np.percentile(samples, 95) - np.percentile(samples, 5)
    ci90_widths.append(ci90)
    chirp_masses.append(theta_true["chirp_mass"])

snrs = np.array(snrs)
ci90_widths = np.array(ci90_widths)
chirp_masses = np.array(chirp_masses)

frac_widths = ci90_widths / chirp_masses  # relative width, dimensionless

plt.figure(figsize=(6, 5))
sc = plt.scatter(snrs, ci90_widths, c=chirp_masses, cmap="viridis", alpha=0.6, s=15)
#sc = plt.scatter(snrs, frac_widths, c=chirp_masses, cmap="viridis", alpha=0.6, s=15)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Network SNR")
plt.ylabel("Chirp mass 90% CI width")
plt.colorbar(sc, label="Injected chirp mass [M$_\\odot$]")
plt.title("posterior width vs SNR")
plt.grid(True, which="both", alpha=0.3)
plt.tight_layout()
plt.show()


chirp_mass_error = np.array(chirp_mass_error)
mask = snrs < 10000.0

plt.figure(figsize=(10, 5))
sc = plt.scatter(
    snrs[mask],
    chirp_mass_error[mask],
    s=10,
    edgecolor="black",
    alpha=0.3
)

plt.axhline(0, linestyle="--", color="black")
plt.xlabel("SNR")
plt.ylabel("Chirp mass inference error (inferred − true)")
plt.title("Chirp-mass inference error")
plt.grid(True)
plt.tight_layout()
plt.show()




# --- Plot distribution ---
plt.figure(figsize=(6, 5))

# Histogram, normalized to a density so it represents "how likely each value is"
counts, bins, _ = plt.hist(
    snrs, bins=100, density=True, alpha=0.5, color="steelblue", edgecolor="k", label="Histogram"
)
plt.xlabel("Network SNR")
plt.ylabel("Probability density")
plt.title(f"Distribution of injected network SNR (n={len(snrs)})")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()


print(f"SNR stats: min={snrs.min():.2f}, max={snrs.max():.2f}, "
      f"median={np.median(snrs):.2f}, mean={snrs.mean():.2f}",
      f"snr99={np.percentile(np.abs(snrs), 99):.2f}")
# Out:
# SNR stats: min=1.49, max=5003.07, median=113.07, mean=316.66 snr99=2078.25
