# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
import GWFish.modules as gw


os.environ["CUDA_VISIBLE_DEVICES"] = "3"  # use GPU 1

name="170_420"

waveform_model = 'IMRPhenomXPHM'
f_ref = 20.
detectors = ['ET']
network = gw.detection.Network(detector_ids = detectors, detection_SNR = (0., 8.))
# Out:
# /home/tpausch/.conda/envs/ET-DINGO/lib/python3.10/site-packages/lalsimulation/_lalsimulation_swig.py:8: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   import lal

# %% [markdown]
# ## Load Model

# %%
from dingo.core.posterior_models.build_model import build_model_from_kwargs
main_pm = build_model_from_kwargs(
    filename=f"/scratch/tpausch/models/{name}/model_100.pt",
    device="cuda",
    load_training_info=False,
)
# Out:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1230+gc9da5d765 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Putting posterior model to device cuda.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt(f"/scratch/tpausch/models/{name}/history.txt")
epochs   = data[:, 0]
train    = data[:, 1]
val      = data[:, 2]


plt.figure(figsize=(8, 5))
plt.plot(epochs, train, label="Train loss")
plt.plot(epochs, val,   label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("Log-likelihood")
plt.legend()
plt.title("Dingo training history")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 4 data = np.loadtxt(f"/scratch/tpausch/models/{name}/history.txt")
#       5 epochs   = data[:, 0]
#       6 train    = data[:, 1]
#
# File ~/.conda/envs/ET-DINGO/lib/python3.10/site-packages/numpy/lib/npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# File ~/.conda/envs/ET-DINGO/lib/python3.10/site-packages/numpy/lib/npyio.py:992, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     990     fname = os.fspath(fname)
#     991 if isinstance(fname, str):
# --> 992     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     993     if encoding is None:
#     994         encoding = getattr(fh, 'encoding', 'latin1')
#
# File ~/.conda/envs/ET-DINGO/lib/python3.10/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/.conda/envs/ET-DINGO/lib/python3.10/site-packages/numpy/lib/_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: /scratch/tpausch/models/170_420/history.txt not found.

# %% [markdown]
# ## Simulate injections

# %%
import dingo.gw.injection as injection
from dingo.gw.noise.asd_dataset import ASDDataset

# ============================================================
# Setup
# ============================================================

num_injections = 1000
out_dir = f"/scratch/tpausch/test_data/{name}/injections"
os.makedirs(out_dir, exist_ok=True)

np.random.seed(42)  # optional, for reproducibility

injection_generator = injection.Injection.from_posterior_model_metadata(
    main_pm.metadata
)

asd_fname = main_pm.metadata["train_settings"]["training"]["stage_0"]["asd_dataset_path"]
asd_dataset = ASDDataset(file_name=asd_fname)

injection_generator.asd = {
    k: v[0] for k, v in asd_dataset.asds.items()
}

# This is the combined intrinsic + extrinsic bilby PriorDict
# that the network was trained on
prior = injection_generator.prior
print(prior)

# ============================================================
# Draw and run injections
# ============================================================

for idx in range(num_injections):

    print(f"Running injection {idx}")

    theta = prior.sample()
    theta = {k: float(v) for k, v in theta.items()}  # cast numpy -> float

    strain_data = injection_generator.injection(theta)

    payload = {
        "theta_true": theta,
        "strain_data": strain_data,
    }

    fname = os.path.join(out_dir, f"inj_{idx:04d}.pkl")

    with open(fname, "wb") as f:
        pickle.dump(payload, f)
# Out:
# Setting spin_conversion_phase = 0.0. Using this value for the phase parameter for conversion to cartesian spins.
# Loading dataset from training_data/asds_ET_T8.hdf5.
# {'mass_1': Constraint(minimum=50.0, maximum=1700.0, name='mass_1', latex_label='$m_1$', unit=None), 'mass_2': Constraint(minimum=50.0, maximum=1700.0, name='mass_2', latex_label='$m_2$', unit=None), 'chirp_mass': bilby.gw.prior.UniformInComponentsChirpMass(minimum=170.0, maximum=420.0, name='chirp_mass', latex_label='$\\mathcal{M}$', unit=None, boundary=None), 'mass_ratio': bilby.gw.prior.UniformInComponentsMassRatio(minimum=0.125, maximum=1.0, name='mass_ratio', latex_label='$q$', unit=None, boundary=None, equal_mass=False), 'phase': Uniform(minimum=0.0, maximum=6.283185307179586, name='phase', latex_label='$\\phi$', unit=None, boundary='periodic'), 'chi_1': bilby.gw.prior.AlignedSpin(a_prior=Uniform(minimum=0, maximum=0.9, name=None, latex_label=None, unit=None, boundary=None), z_prior=Uniform(minimum=-1, maximum=1, name=None, latex_label=None, unit=None, boundary=None), name='chi_1', latex_label='$\\chi_1$', unit=None, boundary=None, minimum=-0.9, maximum=0.9, num_interp=100000), 'chi_2': bilby.gw.prior.AlignedSpin(a_prior=Uniform(minimum=0, maximum=0.9, name=None, latex_label=None, unit=None, boundary=None), z_prior=Uniform(minimum=-1, maximum=1, name=None, latex_label=None, unit=None, boundary=None), name='chi_2', latex_label='$\\chi_2$', unit=None, boundary=None, minimum=-0.9, maximum=0.9, num_interp=100000), 'theta_jn': Sine(minimum=0.0, maximum=3.141592653589793, name='theta_jn', latex_label='$\\theta_{JN}$', unit=None, boundary=None), 'luminosity_distance': LogUniform(minimum=1000.0, maximum=100000.0, name='luminosity_distance', latex_label='$d_L$', unit=None, boundary=None), 'geocent_time': Uniform(minimum=-0.1, maximum=0.1, name='geocent_time', latex_label='$t_c$', unit=None, boundary=None), 'dec': Cosine(minimum=-1.5707963267948966, maximum=1.5707963267948966, name='dec', latex_label='$\\mathrm{DEC}$', unit=None, boundary=None), 'ra': Uniform(minimum=0.0, maximum=6.283185307179586, name='ra', latex_label='$\\mathrm{RA}$', unit=None, boundary='periodic'), 'psi': Uniform(minimum=0.0, maximum=3.141592653589793, name='psi', latex_label='$\\psi$', unit=None, boundary='periodic')}
# Running injection 0
# Generation with parameters (7.982586942652624e+32, 6.2200610032016884e+32, 0.0, 0.0, 0.07650187128955464, 0.0, 0.0, -0.7718159039217443, 3.085677581491367e+24, 1.0885202238089886, 0.140047006835794, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.982586942652624e+32, 6.2200610032016884e+32, 0.0, 0.0, 0.07650187128955464, 0.0, 0.0, -0.7718159039217443, 3.085677581491367e+24, 1.0885202238089886, 0.140047006835794, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1
# Generation with parameters (2.0826226655376212e+33, 4.8313743718204946e+32, 0.0, 0.0, -0.0646980752403404, 0.0, 0.0, 0.021936861426329845, 3.085677581491367e+24, 1.142578760339157, 0.355109901696368, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0826226655376212e+33, 4.8313743718204946e+32, 0.0, 0.0, -0.0646980752403404, 0.0, 0.0, 0.021936861426329845, 3.085677581491367e+24, 1.142578760339157, 0.355109901696368, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 2
# Running injection 3
# Generation with parameters (2.135922965226312e+33, 3.1684934511295244e+32, 0.0, 0.0, 0.0008337315859527875, 0.0, 0.0, -0.5351458726038999, 3.085677581491367e+24, 1.0909053500801087, 3.7695930872224785, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.135922965226312e+33, 3.1684934511295244e+32, 0.0, 0.0, 0.0008337315859527875, 0.0, 0.0, -0.5351458726038999, 3.085677581491367e+24, 1.0909053500801087, 3.7695930872224785, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 4
# Generation with parameters (1.492720024627685e+33, 2.923321624680104e+32, 0.0, 0.0, 0.31711227819995375, 0.0, 0.0, -0.017840251745766374, 3.085677581491367e+24, 2.1074944925301913, 5.683099909615034, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.492720024627685e+33, 2.923321624680104e+32, 0.0, 0.0, 0.31711227819995375, 0.0, 0.0, -0.017840251745766374, 3.085677581491367e+24, 2.1074944925301913, 5.683099909615034, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 5
# Generation with parameters (1.5652489819946615e+33, 2.6495440887986464e+32, 0.0, 0.0, 0.09493578404763293, 0.0, 0.0, -0.34785801379245673, 3.085677581491367e+24, 1.279391482852623, 6.04912531457655, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5652489819946615e+33, 2.6495440887986464e+32, 0.0, 0.0, 0.09493578404763293, 0.0, 0.0, -0.34785801379245673, 3.085677581491367e+24, 1.279391482852623, 6.04912531457655, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 6
# Generation with parameters (2.2715216634016462e+33, 3.841762557207056e+32, 0.0, 0.0, -0.03230483439125657, 0.0, 0.0, -0.13200266912682726, 3.085677581491367e+24, 2.0321807994815315, 3.3533990070276403, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2715216634016462e+33, 3.841762557207056e+32, 0.0, 0.0, -0.03230483439125657, 0.0, 0.0, -0.13200266912682726, 3.085677581491367e+24, 2.0321807994815315, 3.3533990070276403, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 7
# Generation with parameters (2.1464105512713336e+33, 4.491939009078059e+32, 0.0, 0.0, -0.22877324770579907, 0.0, 0.0, 0.26105005606790105, 3.085677581491367e+24, 0.6885561100510335, 2.056934303526882, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.1464105512713336e+33, 4.491939009078059e+32, 0.0, 0.0, -0.22877324770579907, 0.0, 0.0, 0.26105005606790105, 3.085677581491367e+24, 0.6885561100510335, 2.056934303526882, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 8
# Generation with parameters (1.458926666193967e+33, 5.405978341276496e+32, 0.0, 0.0, 0.26370900115111656, 0.0, 0.0, -0.7500768471894153, 3.085677581491367e+24, 2.49288871866357, 6.126273103524861, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.458926666193967e+33, 5.405978341276496e+32, 0.0, 0.0, 0.26370900115111656, 0.0, 0.0, -0.7500768471894153, 3.085677581491367e+24, 2.49288871866357, 6.126273103524861, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 9
# Generation with parameters (1.0681198612782128e+33, 4.005558915089014e+32, 0.0, 0.0, 0.6417514291185906, 0.0, 0.0, -0.07361377753791626, 3.085677581491367e+24, 2.8834889124987026, 0.11550448813651902, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0681198612782128e+33, 4.005558915089014e+32, 0.0, 0.0, 0.6417514291185906, 0.0, 0.0, -0.07361377753791626, 3.085677581491367e+24, 2.8834889124987026, 0.11550448813651902, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 10
# Generation with parameters (2.1765702423953603e+33, 4.2923460751644925e+32, 0.0, 0.0, -0.36012316662170496, 0.0, 0.0, 0.5418899211154853, 3.085677581491367e+24, 2.181396849236303, 5.598669305123438, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.1765702423953603e+33, 4.2923460751644925e+32, 0.0, 0.0, -0.36012316662170496, 0.0, 0.0, 0.5418899211154853, 3.085677581491367e+24, 2.181396849236303, 5.598669305123438, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 11
# Generation with parameters (1.391193485099061e+33, 2.5676080938063426e+32, 0.0, 0.0, 0.779894055850922, 0.0, 0.0, 0.5664249630284031, 3.085677581491367e+24, 2.4393430556771967, 1.0284171810862335, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.391193485099061e+33, 2.5676080938063426e+32, 0.0, 0.0, 0.779894055850922, 0.0, 0.0, 0.5664249630284031, 3.085677581491367e+24, 2.4393430556771967, 1.0284171810862335, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 12
# Running injection 13
# Generation with parameters (1.1080603231358067e+33, 7.36727706132909e+32, 0.0, 0.0, 0.026862858284163686, 0.0, 0.0, -0.5961512649633586, 3.085677581491367e+24, 0.7626188374858205, 5.748529920177598, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1080603231358067e+33, 7.36727706132909e+32, 0.0, 0.0, 0.026862858284163686, 0.0, 0.0, -0.5961512649633586, 3.085677581491367e+24, 0.7626188374858205, 5.748529920177598, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 14
# Running injection 15
# Generation with parameters (9.679017644308605e+32, 6.97722299763247e+32, 0.0, 0.0, -0.15793620919483026, 0.0, 0.0, -0.6471451271097887, 3.085677581491367e+24, 2.050971771280727, 0.21238030833017363, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.679017644308605e+32, 6.97722299763247e+32, 0.0, 0.0, -0.15793620919483026, 0.0, 0.0, -0.6471451271097887, 3.085677581491367e+24, 2.050971771280727, 0.21238030833017363, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 16
# Generation with parameters (1.3785586061053916e+33, 3.1847195875832012e+32, 0.0, 0.0, 0.0074773890337767575, 0.0, 0.0, -0.22398817279588118, 3.085677581491367e+24, 1.2498076231016029, 5.937565613609501, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3785586061053916e+33, 3.1847195875832012e+32, 0.0, 0.0, 0.0074773890337767575, 0.0, 0.0, -0.22398817279588118, 3.085677581491367e+24, 1.2498076231016029, 5.937565613609501, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 17
# Running injection 18
# Generation with parameters (1.528045113756054e+33, 3.961516545489612e+32, 0.0, 0.0, -0.38312816143519357, 0.0, 0.0, 0.7110766465644345, 3.085677581491367e+24, 1.7343638252352291, 5.184920210867864, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.528045113756054e+33, 3.961516545489612e+32, 0.0, 0.0, -0.38312816143519357, 0.0, 0.0, 0.7110766465644345, 3.085677581491367e+24, 1.7343638252352291, 5.184920210867864, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 19
# Running injection 20
# Running injection 21
# Generation with parameters (7.739462592773962e+32, 5.901573758317089e+32, 0.0, 0.0, 0.6036626605851259, 0.0, 0.0, 0.14681407522115114, 3.085677581491367e+24, 2.4917865111401083, 4.221666196888167, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.739462592773962e+32, 5.901573758317089e+32, 0.0, 0.0, 0.6036626605851259, 0.0, 0.0, 0.14681407522115114, 3.085677581491367e+24, 2.4917865111401083, 4.221666196888167, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 22
# Generation with parameters (2.3616539745811797e+33, 4.235208402771146e+32, 0.0, 0.0, 0.1379762719086629, 0.0, 0.0, -0.5083700787437094, 3.085677581491367e+24, 0.6124982901409148, 2.594844767207631, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3616539745811797e+33, 4.235208402771146e+32, 0.0, 0.0, 0.1379762719086629, 0.0, 0.0, -0.5083700787437094, 3.085677581491367e+24, 0.6124982901409148, 2.594844767207631, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 23
# Generation with parameters (1.230196990069324e+33, 6.2581086402940446e+32, 0.0, 0.0, 0.5338695221945041, 0.0, 0.0, 0.1291818432051917, 3.085677581491367e+24, 1.7606824644562518, 1.753586456585735, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.230196990069324e+33, 6.2581086402940446e+32, 0.0, 0.0, 0.5338695221945041, 0.0, 0.0, 0.1291818432051917, 3.085677581491367e+24, 1.7606824644562518, 1.753586456585735, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 24
# Generation with parameters (9.283952870055979e+32, 9.169744230379004e+32, 0.0, 0.0, 0.3372741925326016, 0.0, 0.0, -0.15035654535861265, 3.085677581491367e+24, 1.5935352089486299, 1.891785326449787, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.283952870055979e+32, 9.169744230379004e+32, 0.0, 0.0, 0.3372741925326016, 0.0, 0.0, -0.15035654535861265, 3.085677581491367e+24, 1.5935352089486299, 1.891785326449787, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 25
# Generation with parameters (8.681466632711431e+32, 7.420629759707183e+32, 0.0, 0.0, -0.008863241048195492, 0.0, 0.0, 0.0469786174164665, 3.085677581491367e+24, 2.2627610087976446, 2.283150118291983, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.681466632711431e+32, 7.420629759707183e+32, 0.0, 0.0, -0.008863241048195492, 0.0, 0.0, 0.0469786174164665, 3.085677581491367e+24, 2.2627610087976446, 2.283150118291983, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 26
# Generation with parameters (1.1384946178587471e+33, 5.580695745697305e+32, 0.0, 0.0, -0.5161824364443661, 0.0, 0.0, 0.7180724573608838, 3.085677581491367e+24, 1.0266003277512763, 5.855695306739489, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1384946178587471e+33, 5.580695745697305e+32, 0.0, 0.0, -0.5161824364443661, 0.0, 0.0, 0.7180724573608838, 3.085677581491367e+24, 1.0266003277512763, 5.855695306739489, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 27
# Running injection 28
# Running injection 29
# Generation with parameters (6.867001075386158e+32, 6.791480643641354e+32, 0.0, 0.0, -0.4176181262383519, 0.0, 0.0, -0.6571568445723457, 3.085677581491367e+24, 0.857685006354924, 1.4278123455231573, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.867001075386158e+32, 6.791480643641354e+32, 0.0, 0.0, -0.4176181262383519, 0.0, 0.0, -0.6571568445723457, 3.085677581491367e+24, 0.857685006354924, 1.4278123455231573, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 30
# Generation with parameters (1.3748673497585875e+33, 3.1680137064325057e+32, 0.0, 0.0, -0.09252873513556951, 0.0, 0.0, -0.18981757920364242, 3.085677581491367e+24, 1.2723497407002613, 0.462628997597603, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3748673497585875e+33, 3.1680137064325057e+32, 0.0, 0.0, -0.09252873513556951, 0.0, 0.0, -0.18981757920364242, 3.085677581491367e+24, 1.2723497407002613, 0.462628997597603, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 31
# Generation with parameters (2.780925431210031e+33, 3.4866703831555044e+32, 0.0, 0.0, 0.05654883608996748, 0.0, 0.0, 0.18038908424995756, 3.085677581491367e+24, 1.0818278667774388, 2.4627198142129165, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.780925431210031e+33, 3.4866703831555044e+32, 0.0, 0.0, 0.05654883608996748, 0.0, 0.0, 0.18038908424995756, 3.085677581491367e+24, 1.0818278667774388, 2.4627198142129165, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 32
# Generation with parameters (1.1639368890676469e+33, 7.559465407936425e+32, 0.0, 0.0, -0.6036229523333103, 0.0, 0.0, 0.19094171355445322, 3.085677581491367e+24, 2.597365751446732, 2.6271414769355714, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1639368890676469e+33, 7.559465407936425e+32, 0.0, 0.0, -0.6036229523333103, 0.0, 0.0, 0.19094171355445322, 3.085677581491367e+24, 2.597365751446732, 2.6271414769355714, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 33
# Generation with parameters (9.93791886968532e+32, 5.148431486709537e+32, 0.0, 0.0, 0.057265670344005454, 0.0, 0.0, 0.42954802254039676, 3.085677581491367e+24, 1.1736843746329761, 0.06468008630679926, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.93791886968532e+32, 5.148431486709537e+32, 0.0, 0.0, 0.057265670344005454, 0.0, 0.0, 0.42954802254039676, 3.085677581491367e+24, 1.1736843746329761, 0.06468008630679926, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 34
# Generation with parameters (1.829274691059431e+33, 4.3671166150988046e+32, 0.0, 0.0, 0.40442484338689116, 0.0, 0.0, 0.04689349083665838, 3.085677581491367e+24, 1.7419789779614203, 0.558537367043562, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.829274691059431e+33, 4.3671166150988046e+32, 0.0, 0.0, 0.40442484338689116, 0.0, 0.0, 0.04689349083665838, 3.085677581491367e+24, 1.7419789779614203, 0.558537367043562, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 35
# Generation with parameters (1.7288952130619777e+33, 3.0944364961571912e+32, 0.0, 0.0, -0.05919669931134398, 0.0, 0.0, -0.0005605849755136809, 3.085677581491367e+24, 1.9270858523687808, 5.963833930441351, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7288952130619777e+33, 3.0944364961571912e+32, 0.0, 0.0, -0.05919669931134398, 0.0, 0.0, -0.0005605849755136809, 3.085677581491367e+24, 1.9270858523687808, 5.963833930441351, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 36
# Generation with parameters (8.542234500241798e+32, 5.097339943896589e+32, 0.0, 0.0, 0.42207698768095975, 0.0, 0.0, 0.213422334729849, 3.085677581491367e+24, 0.773051128219663, 1.3682871744152203, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.542234500241798e+32, 5.097339943896589e+32, 0.0, 0.0, 0.42207698768095975, 0.0, 0.0, 0.213422334729849, 3.085677581491367e+24, 0.773051128219663, 1.3682871744152203, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 37
# Generation with parameters (1.7219704731086126e+33, 2.9739039009585156e+32, 0.0, 0.0, -0.20645771930497672, 0.0, 0.0, -0.7446699186875823, 3.085677581491367e+24, 2.372883996248409, 2.855284544142359, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7219704731086126e+33, 2.9739039009585156e+32, 0.0, 0.0, -0.20645771930497672, 0.0, 0.0, -0.7446699186875823, 3.085677581491367e+24, 2.372883996248409, 2.855284544142359, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 38
# Generation with parameters (1.3939431822910187e+33, 2.996294258357389e+32, 0.0, 0.0, 0.019408551464076624, 0.0, 0.0, 0.30256766211461295, 3.085677581491367e+24, 1.6308274463960877, 3.6047714778433653, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3939431822910187e+33, 2.996294258357389e+32, 0.0, 0.0, 0.019408551464076624, 0.0, 0.0, 0.30256766211461295, 3.085677581491367e+24, 1.6308274463960877, 3.6047714778433653, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 39
# Generation with parameters (1.1277781403954671e+33, 2.4838565897568732e+32, 0.0, 0.0, 0.2700798900680279, 0.0, 0.0, -0.15052210291868492, 3.085677581491367e+24, 2.936426917714706, 2.0672893198859947, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1277781403954671e+33, 2.4838565897568732e+32, 0.0, 0.0, 0.2700798900680279, 0.0, 0.0, -0.15052210291868492, 3.085677581491367e+24, 2.936426917714706, 2.0672893198859947, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 40
# Generation with parameters (7.212514561349652e+32, 7.20509115837246e+32, 0.0, 0.0, 0.028223032998432807, 0.0, 0.0, 0.12776753970875276, 3.085677581491367e+24, 1.8462557863502063, 4.415707431264956, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.212514561349652e+32, 7.20509115837246e+32, 0.0, 0.0, 0.028223032998432807, 0.0, 0.0, 0.12776753970875276, 3.085677581491367e+24, 1.8462557863502063, 4.415707431264956, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 41
# Generation with parameters (1.801079542126169e+33, 4.271198591455763e+32, 0.0, 0.0, -0.15273846756431203, 0.0, 0.0, -0.22064090799831168, 3.085677581491367e+24, 1.1894540705513332, 5.528259188435038, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.801079542126169e+33, 4.271198591455763e+32, 0.0, 0.0, -0.15273846756431203, 0.0, 0.0, -0.22064090799831168, 3.085677581491367e+24, 1.1894540705513332, 5.528259188435038, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 42
# Generation with parameters (2.0385005607722168e+33, 4.580209676784294e+32, 0.0, 0.0, 0.01627891030087803, 0.0, 0.0, 0.14949744418583344, 3.085677581491367e+24, 2.2315331110954286, 5.566187728250106, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0385005607722168e+33, 4.580209676784294e+32, 0.0, 0.0, 0.01627891030087803, 0.0, 0.0, 0.14949744418583344, 3.085677581491367e+24, 2.2315331110954286, 5.566187728250106, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 43
# Running injection 44
# Generation with parameters (1.3891158282336894e+33, 3.198534230067094e+32, 0.0, 0.0, 0.07372879799118101, 0.0, 0.0, 0.233160440307523, 3.085677581491367e+24, 0.31208922028079217, 4.020608061854771, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3891158282336894e+33, 3.198534230067094e+32, 0.0, 0.0, 0.07372879799118101, 0.0, 0.0, 0.233160440307523, 3.085677581491367e+24, 0.31208922028079217, 4.020608061854771, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 45
# Generation with parameters (1.5167800284944648e+33, 4.715201671352302e+32, 0.0, 0.0, -0.6495129339775603, 0.0, 0.0, -0.057028686199690155, 3.085677581491367e+24, 1.97090027746539, 2.0591520722235774, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5167800284944648e+33, 4.715201671352302e+32, 0.0, 0.0, -0.6495129339775603, 0.0, 0.0, -0.057028686199690155, 3.085677581491367e+24, 1.97090027746539, 2.0591520722235774, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 46
# Generation with parameters (1.2338200646119473e+33, 3.1605139241988176e+32, 0.0, 0.0, -0.18999036777080103, 0.0, 0.0, 0.16199643101147562, 3.085677581491367e+24, 2.2676243127085955, 2.928000100440285, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2338200646119473e+33, 3.1605139241988176e+32, 0.0, 0.0, -0.18999036777080103, 0.0, 0.0, 0.16199643101147562, 3.085677581491367e+24, 2.2676243127085955, 2.928000100440285, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 47
# Generation with parameters (1.0223881838464966e+33, 8.704502510696987e+32, 0.0, 0.0, -0.3918991945738586, 0.0, 0.0, 0.012082921999262784, 3.085677581491367e+24, 0.9285033935128596, 0.29072098020318093, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0223881838464966e+33, 8.704502510696987e+32, 0.0, 0.0, -0.3918991945738586, 0.0, 0.0, 0.012082921999262784, 3.085677581491367e+24, 0.9285033935128596, 0.29072098020318093, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 48
# Generation with parameters (1.6070364640522884e+33, 5.6803143450613295e+32, 0.0, 0.0, 0.1721855731589647, 0.0, 0.0, -0.031134943070736217, 3.085677581491367e+24, 0.6947885949158026, 0.19171260785790858, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6070364640522884e+33, 5.6803143450613295e+32, 0.0, 0.0, 0.1721855731589647, 0.0, 0.0, -0.031134943070736217, 3.085677581491367e+24, 0.6947885949158026, 0.19171260785790858, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 49
# Generation with parameters (1.4857726324279648e+33, 5.116753125804461e+32, 0.0, 0.0, 0.3622010749170651, 0.0, 0.0, 0.14182589037202414, 3.085677581491367e+24, 1.5599860321936703, 3.566424690879601, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4857726324279648e+33, 5.116753125804461e+32, 0.0, 0.0, 0.3622010749170651, 0.0, 0.0, 0.14182589037202414, 3.085677581491367e+24, 1.5599860321936703, 3.566424690879601, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 50
# Generation with parameters (1.1741662242654943e+33, 7.00175851226487e+32, 0.0, 0.0, 0.2268977784422257, 0.0, 0.0, 0.21750192485716374, 3.085677581491367e+24, 1.5972898546452405, 3.204803931149098, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1741662242654943e+33, 7.00175851226487e+32, 0.0, 0.0, 0.2268977784422257, 0.0, 0.0, 0.21750192485716374, 3.085677581491367e+24, 1.5972898546452405, 3.204803931149098, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 51
# Generation with parameters (9.924821878554872e+32, 7.256486207920231e+32, 0.0, 0.0, -0.14973895489766093, 0.0, 0.0, -0.5056417930030901, 3.085677581491367e+24, 1.858308455197848, 1.987491821753674, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.924821878554872e+32, 7.256486207920231e+32, 0.0, 0.0, -0.14973895489766093, 0.0, 0.0, -0.5056417930030901, 3.085677581491367e+24, 1.858308455197848, 1.987491821753674, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 52
# Running injection 53
# Generation with parameters (1.780918392101124e+33, 5.3723900507353845e+32, 0.0, 0.0, -0.0553506595809624, 0.0, 0.0, 0.7276485257777338, 3.085677581491367e+24, 2.425807590682288, 6.007751029428022, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.780918392101124e+33, 5.3723900507353845e+32, 0.0, 0.0, -0.0553506595809624, 0.0, 0.0, 0.7276485257777338, 3.085677581491367e+24, 2.425807590682288, 6.007751029428022, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 54
# Generation with parameters (2.61689492089745e+33, 3.3606348729108766e+32, 0.0, 0.0, -0.01713358109839987, 0.0, 0.0, 0.29142997721281605, 3.085677581491367e+24, 0.3353278736969275, 1.9369920923598607, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.61689492089745e+33, 3.3606348729108766e+32, 0.0, 0.0, -0.01713358109839987, 0.0, 0.0, 0.29142997721281605, 3.085677581491367e+24, 0.3353278736969275, 1.9369920923598607, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 55
# Generation with parameters (2.3333751877347466e+33, 4.047620023605621e+32, 0.0, 0.0, -0.12272573570524309, 0.0, 0.0, 0.13653122561490025, 3.085677581491367e+24, 1.851369854809436, 5.133351801013358, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3333751877347466e+33, 4.047620023605621e+32, 0.0, 0.0, -0.12272573570524309, 0.0, 0.0, 0.13653122561490025, 3.085677581491367e+24, 1.851369854809436, 5.133351801013358, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 56
# Generation with parameters (1.2687255412551635e+33, 3.0215952950076463e+32, 0.0, 0.0, 0.6418946524703102, 0.0, 0.0, 0.022938985968935236, 3.085677581491367e+24, 2.4390046012645636, 1.6975244368976077, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2687255412551635e+33, 3.0215952950076463e+32, 0.0, 0.0, 0.6418946524703102, 0.0, 0.0, 0.022938985968935236, 3.085677581491367e+24, 2.4390046012645636, 1.6975244368976077, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 57
# Generation with parameters (1.7783895823616225e+33, 3.975385944289675e+32, 0.0, 0.0, 0.09002195588771901, 0.0, 0.0, 0.008303456325365095, 3.085677581491367e+24, 1.295542230875042, 3.029910312816389, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7783895823616225e+33, 3.975385944289675e+32, 0.0, 0.0, 0.09002195588771901, 0.0, 0.0, 0.008303456325365095, 3.085677581491367e+24, 1.295542230875042, 3.029910312816389, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 58
# Generation with parameters (1.7924720018318076e+33, 3.982635886306903e+32, 0.0, 0.0, -0.23350547497153396, 0.0, 0.0, -0.1116700172702704, 3.085677581491367e+24, 1.1321692039396027, 4.546449752324225, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7924720018318076e+33, 3.982635886306903e+32, 0.0, 0.0, -0.23350547497153396, 0.0, 0.0, -0.1116700172702704, 3.085677581491367e+24, 1.1321692039396027, 4.546449752324225, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 59
# Generation with parameters (2.0021468381529744e+33, 2.9039744839281666e+32, 0.0, 0.0, -0.2076104932266517, 0.0, 0.0, -0.17402325699031446, 3.085677581491367e+24, 1.6734447542368094, 1.9755261841039273, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0021468381529744e+33, 2.9039744839281666e+32, 0.0, 0.0, -0.2076104932266517, 0.0, 0.0, -0.17402325699031446, 3.085677581491367e+24, 1.6734447542368094, 1.9755261841039273, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 60
# Generation with parameters (9.80697187186721e+32, 3.419545604685016e+32, 0.0, 0.0, -0.2923232896516794, 0.0, 0.0, 0.128974633551483, 3.085677581491367e+24, 0.36488593965085026, 5.423281516758647, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.80697187186721e+32, 3.419545604685016e+32, 0.0, 0.0, -0.2923232896516794, 0.0, 0.0, 0.128974633551483, 3.085677581491367e+24, 0.36488593965085026, 5.423281516758647, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 61
# Running injection 62
# Generation with parameters (8.96962387286801e+32, 6.127077204902255e+32, 0.0, 0.0, -0.22455770469985512, 0.0, 0.0, 0.13192643601458057, 3.085677581491367e+24, 1.0210661688978981, 2.3360408147626455, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.96962387286801e+32, 6.127077204902255e+32, 0.0, 0.0, -0.22455770469985512, 0.0, 0.0, 0.13192643601458057, 3.085677581491367e+24, 1.0210661688978981, 2.3360408147626455, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 63
# Generation with parameters (2.3496534225615676e+33, 3.77485199494014e+32, 0.0, 0.0, 0.420826962160232, 0.0, 0.0, -0.6441721845441959, 3.085677581491367e+24, 1.337306710550277, 1.0771834974915837, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3496534225615676e+33, 3.77485199494014e+32, 0.0, 0.0, 0.420826962160232, 0.0, 0.0, -0.6441721845441959, 3.085677581491367e+24, 1.337306710550277, 1.0771834974915837, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 64
# Generation with parameters (8.71562705634119e+32, 4.715377057716299e+32, 0.0, 0.0, 0.14587135066509865, 0.0, 0.0, -0.04297411005810734, 3.085677581491367e+24, 2.0546226042901603, 2.166821455258156, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.71562705634119e+32, 4.715377057716299e+32, 0.0, 0.0, 0.14587135066509865, 0.0, 0.0, -0.04297411005810734, 3.085677581491367e+24, 2.0546226042901603, 2.166821455258156, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 65
# Generation with parameters (1.364420271693402e+33, 3.748992327865351e+32, 0.0, 0.0, 0.25656923530892195, 0.0, 0.0, 0.32426466400644, 3.085677581491367e+24, 1.1098149588416948, 2.89872293645765, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.364420271693402e+33, 3.748992327865351e+32, 0.0, 0.0, 0.25656923530892195, 0.0, 0.0, 0.32426466400644, 3.085677581491367e+24, 1.1098149588416948, 2.89872293645765, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 66
# Generation with parameters (1.8320674791118729e+33, 3.803371160803329e+32, 0.0, 0.0, -0.07950851026913686, 0.0, 0.0, -0.283490743493023, 3.085677581491367e+24, 2.8200687295414855, 1.738060546122175, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8320674791118729e+33, 3.803371160803329e+32, 0.0, 0.0, -0.07950851026913686, 0.0, 0.0, -0.283490743493023, 3.085677581491367e+24, 2.8200687295414855, 1.738060546122175, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 67
# Generation with parameters (1.5841310116119104e+33, 3.412028518745886e+32, 0.0, 0.0, 0.06147492937904597, 0.0, 0.0, -0.14638244925208643, 3.085677581491367e+24, 1.0740633877724146, 6.281392635527051, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5841310116119104e+33, 3.412028518745886e+32, 0.0, 0.0, 0.06147492937904597, 0.0, 0.0, -0.14638244925208643, 3.085677581491367e+24, 1.0740633877724146, 6.281392635527051, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 68
# Generation with parameters (7.552375594879942e+32, 4.671674213798167e+32, 0.0, 0.0, -0.08791033134063438, 0.0, 0.0, 0.4504764151856787, 3.085677581491367e+24, 0.7318769993156288, 4.662959488981871, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (7.552375594879942e+32, 4.671674213798167e+32, 0.0, 0.0, -0.08791033134063438, 0.0, 0.0, 0.4504764151856787, 3.085677581491367e+24, 0.7318769993156288, 4.662959488981871, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 69
# Generation with parameters (1.978712242448443e+33, 4.571874218664236e+32, 0.0, 0.0, 0.07378214865539136, 0.0, 0.0, 0.05906974561908829, 3.085677581491367e+24, 2.820227373017285, 4.492327281561498, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.978712242448443e+33, 4.571874218664236e+32, 0.0, 0.0, 0.07378214865539136, 0.0, 0.0, 0.05906974561908829, 3.085677581491367e+24, 2.820227373017285, 4.492327281561498, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 70
# Generation with parameters (9.11378488348892e+32, 5.330606449297203e+32, 0.0, 0.0, 0.47832097647209565, 0.0, 0.0, -0.2324596192815362, 3.085677581491367e+24, 1.074868965238033, 4.0291092216556565, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.11378488348892e+32, 5.330606449297203e+32, 0.0, 0.0, 0.47832097647209565, 0.0, 0.0, -0.2324596192815362, 3.085677581491367e+24, 1.074868965238033, 4.0291092216556565, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 71
# Generation with parameters (1.7428322734801497e+33, 4.803818992946926e+32, 0.0, 0.0, -0.5570947858232136, 0.0, 0.0, -0.08983872365686946, 3.085677581491367e+24, 1.1739350751526043, 1.1910565870511385, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7428322734801497e+33, 4.803818992946926e+32, 0.0, 0.0, -0.5570947858232136, 0.0, 0.0, -0.08983872365686946, 3.085677581491367e+24, 1.1739350751526043, 1.1910565870511385, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 72
# Generation with parameters (1.528183352330283e+33, 3.22312304784439e+32, 0.0, 0.0, -0.3914025691400661, 0.0, 0.0, 0.009811182371487108, 3.085677581491367e+24, 1.6925227002263414, 0.8557016504386517, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.528183352330283e+33, 3.22312304784439e+32, 0.0, 0.0, -0.3914025691400661, 0.0, 0.0, 0.009811182371487108, 3.085677581491367e+24, 1.6925227002263414, 0.8557016504386517, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 73
# Generation with parameters (1.3206639689395894e+33, 7.101598744844162e+32, 0.0, 0.0, 0.08841193490713907, 0.0, 0.0, -0.2833314690149106, 3.085677581491367e+24, 2.1789684077702134, 1.0028655587437316, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3206639689395894e+33, 7.101598744844162e+32, 0.0, 0.0, 0.08841193490713907, 0.0, 0.0, -0.2833314690149106, 3.085677581491367e+24, 2.1789684077702134, 1.0028655587437316, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 74
# Generation with parameters (1.1416454272105543e+33, 7.547550100328574e+32, 0.0, 0.0, 0.36885305403266444, 0.0, 0.0, 0.01683529757651954, 3.085677581491367e+24, 1.2271225706889948, 4.267278400249332, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1416454272105543e+33, 7.547550100328574e+32, 0.0, 0.0, 0.36885305403266444, 0.0, 0.0, 0.01683529757651954, 3.085677581491367e+24, 1.2271225706889948, 4.267278400249332, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 75
# Generation with parameters (9.348937470069533e+32, 7.705813966247905e+32, 0.0, 0.0, 0.041185684391732834, 0.0, 0.0, 0.1351870239113955, 3.085677581491367e+24, 1.150442586142836, 2.350292695555131, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.348937470069533e+32, 7.705813966247905e+32, 0.0, 0.0, 0.041185684391732834, 0.0, 0.0, 0.1351870239113955, 3.085677581491367e+24, 1.150442586142836, 2.350292695555131, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 76
# Generation with parameters (1.443484260045664e+33, 4.687015319964124e+32, 0.0, 0.0, 0.5714401868221187, 0.0, 0.0, -0.17178611081546252, 3.085677581491367e+24, 1.4867174851404175, 3.6011835622690653, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.443484260045664e+33, 4.687015319964124e+32, 0.0, 0.0, 0.5714401868221187, 0.0, 0.0, -0.17178611081546252, 3.085677581491367e+24, 1.4867174851404175, 3.6011835622690653, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 77
# Generation with parameters (1.1626811620129165e+33, 7.299508757428405e+32, 0.0, 0.0, 0.4683946669199367, 0.0, 0.0, 0.39013265840925804, 3.085677581491367e+24, 0.8595042451026859, 5.911336341849551, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1626811620129165e+33, 7.299508757428405e+32, 0.0, 0.0, 0.4683946669199367, 0.0, 0.0, 0.39013265840925804, 3.085677581491367e+24, 0.8595042451026859, 5.911336341849551, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 78
# ...
# Running injection 968
# Generation with parameters (1.3838745654868661e+33, 6.207807471919716e+32, 0.0, 0.0, -0.03668236508205281, 0.0, 0.0, -0.13777968325664672, 3.085677581491367e+24, 2.1555610868481065, 5.722174268441612, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3838745654868661e+33, 6.207807471919716e+32, 0.0, 0.0, -0.03668236508205281, 0.0, 0.0, -0.13777968325664672, 3.085677581491367e+24, 2.1555610868481065, 5.722174268441612, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 969
# Generation with parameters (1.5324476736583447e+33, 3.1869976879372885e+32, 0.0, 0.0, 0.34175433278419215, 0.0, 0.0, 0.1734595837275694, 3.085677581491367e+24, 2.5511597973508495, 5.476525615189605, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5324476736583447e+33, 3.1869976879372885e+32, 0.0, 0.0, 0.34175433278419215, 0.0, 0.0, 0.1734595837275694, 3.085677581491367e+24, 2.5511597973508495, 5.476525615189605, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 970
# Running injection 971
# Running injection 972
# Running injection 973
# Generation with parameters (1.4163639222294497e+33, 5.333704665293493e+32, 0.0, 0.0, 0.32627939146156215, 0.0, 0.0, 0.2026394076404888, 3.085677581491367e+24, 2.3940818298984943, 4.137782498206068, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4163639222294497e+33, 5.333704665293493e+32, 0.0, 0.0, 0.32627939146156215, 0.0, 0.0, 0.2026394076404888, 3.085677581491367e+24, 2.3940818298984943, 4.137782498206068, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 974
# Generation with parameters (1.7943877090263988e+33, 5.422527461213723e+32, 0.0, 0.0, -0.6780097249603816, 0.0, 0.0, 0.08883721262758332, 3.085677581491367e+24, 0.5101456585232904, 2.050639965947637, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7943877090263988e+33, 5.422527461213723e+32, 0.0, 0.0, -0.6780097249603816, 0.0, 0.0, 0.08883721262758332, 3.085677581491367e+24, 0.5101456585232904, 2.050639965947637, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 975
# Generation with parameters (1.9498560803284707e+33, 4.724490065981135e+32, 0.0, 0.0, 0.07876539766771072, 0.0, 0.0, -0.21345963303669044, 3.085677581491367e+24, 1.6648749320942609, 0.10480465444530862, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.9498560803284707e+33, 4.724490065981135e+32, 0.0, 0.0, 0.07876539766771072, 0.0, 0.0, -0.21345963303669044, 3.085677581491367e+24, 1.6648749320942609, 0.10480465444530862, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 976
# Generation with parameters (1.8924570809197232e+33, 3.323615430275687e+32, 0.0, 0.0, 0.07727889436449786, 0.0, 0.0, 0.0325269914437873, 3.085677581491367e+24, 1.7221710167234305, 0.213723828074743, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8924570809197232e+33, 3.323615430275687e+32, 0.0, 0.0, 0.07727889436449786, 0.0, 0.0, 0.0325269914437873, 3.085677581491367e+24, 1.7221710167234305, 0.213723828074743, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 977
# Running injection 978
# Running injection 979
# Generation with parameters (8.433105386264258e+32, 7.989938433846395e+32, 0.0, 0.0, 0.03300818645443853, 0.0, 0.0, 0.2537144576111086, 3.085677581491367e+24, 2.3877685611725203, 4.886695544746133, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.433105386264258e+32, 7.989938433846395e+32, 0.0, 0.0, 0.03300818645443853, 0.0, 0.0, 0.2537144576111086, 3.085677581491367e+24, 2.3877685611725203, 4.886695544746133, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 980
# Generation with parameters (1.5096628141927558e+33, 5.306342488094627e+32, 0.0, 0.0, 0.3924336616679813, 0.0, 0.0, -0.034936011390892203, 3.085677581491367e+24, 1.8261526068757774, 3.651355652889123, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5096628141927558e+33, 5.306342488094627e+32, 0.0, 0.0, 0.3924336616679813, 0.0, 0.0, -0.034936011390892203, 3.085677581491367e+24, 1.8261526068757774, 3.651355652889123, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 981
# Running injection 982
# Running injection 983
# Generation with parameters (8.796036261417487e+32, 6.67876415098771e+32, 0.0, 0.0, 0.19687680216421682, 0.0, 0.0, -0.39270426977901823, 3.085677581491367e+24, 2.710831018761602, 2.601599668802095, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.796036261417487e+32, 6.67876415098771e+32, 0.0, 0.0, 0.19687680216421682, 0.0, 0.0, -0.39270426977901823, 3.085677581491367e+24, 2.710831018761602, 2.601599668802095, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 984
# Generation with parameters (1.335713253138364e+33, 2.819754226641713e+32, 0.0, 0.0, 0.035472145197459205, 0.0, 0.0, 0.11105272616765366, 3.085677581491367e+24, 0.05619865117174678, 3.5779475004057906, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.335713253138364e+33, 2.819754226641713e+32, 0.0, 0.0, 0.035472145197459205, 0.0, 0.0, 0.11105272616765366, 3.085677581491367e+24, 0.05619865117174678, 3.5779475004057906, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 985
# Running injection 986
# Generation with parameters (1.5793079462300692e+33, 4.0183479160018115e+32, 0.0, 0.0, 0.04687599911065343, 0.0, 0.0, -0.011151933337598277, 3.085677581491367e+24, 1.8160606378651776, 5.236923539598264, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5793079462300692e+33, 4.0183479160018115e+32, 0.0, 0.0, 0.04687599911065343, 0.0, 0.0, -0.011151933337598277, 3.085677581491367e+24, 1.8160606378651776, 5.236923539598264, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 987
# Generation with parameters (9.890309121114913e+32, 3.869314114729996e+32, 0.0, 0.0, -0.22444600268574458, 0.0, 0.0, -0.6345671918819578, 3.085677581491367e+24, 2.3359120899318673, 2.289562110459199, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.890309121114913e+32, 3.869314114729996e+32, 0.0, 0.0, -0.22444600268574458, 0.0, 0.0, -0.6345671918819578, 3.085677581491367e+24, 2.3359120899318673, 2.289562110459199, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 988
# Generation with parameters (1.5544703691011876e+33, 4.382138474821967e+32, 0.0, 0.0, -0.3498144821922786, 0.0, 0.0, 0.37249837701585825, 3.085677581491367e+24, 2.2162448056063186, 4.658512969873189, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5544703691011876e+33, 4.382138474821967e+32, 0.0, 0.0, -0.3498144821922786, 0.0, 0.0, 0.37249837701585825, 3.085677581491367e+24, 2.2162448056063186, 4.658512969873189, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 989
# Generation with parameters (6.851325886423347e+32, 5.373524598227319e+32, 0.0, 0.0, 0.0044784640090178, 0.0, 0.0, -0.14383910998993168, 3.085677581491367e+24, 0.8553452913022112, 3.7375541985696787, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.851325886423347e+32, 5.373524598227319e+32, 0.0, 0.0, 0.0044784640090178, 0.0, 0.0, -0.14383910998993168, 3.085677581491367e+24, 0.8553452913022112, 3.7375541985696787, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 990
# Generation with parameters (1.90075364161596e+33, 4.002916305365252e+32, 0.0, 0.0, 0.06864209639729764, 0.0, 0.0, 0.5736658797194267, 3.085677581491367e+24, 0.6794752816742312, 4.081363055538177, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.90075364161596e+33, 4.002916305365252e+32, 0.0, 0.0, 0.06864209639729764, 0.0, 0.0, 0.5736658797194267, 3.085677581491367e+24, 0.6794752816742312, 4.081363055538177, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 991
# Generation with parameters (1.079285313411599e+33, 3.302655403618e+32, 0.0, 0.0, 0.4535315122740578, 0.0, 0.0, 0.15024215649547118, 3.085677581491367e+24, 2.12878532528282, 1.7685680426026082, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.079285313411599e+33, 3.302655403618e+32, 0.0, 0.0, 0.4535315122740578, 0.0, 0.0, 0.15024215649547118, 3.085677581491367e+24, 2.12878532528282, 1.7685680426026082, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 992
# Running injection 993
# Generation with parameters (1.42935042817705e+33, 6.2311403330107925e+32, 0.0, 0.0, -0.03253308032130217, 0.0, 0.0, -0.659330772420721, 3.085677581491367e+24, 1.9375788265227654, 1.1219056784826509, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.42935042817705e+33, 6.2311403330107925e+32, 0.0, 0.0, -0.03253308032130217, 0.0, 0.0, -0.659330772420721, 3.085677581491367e+24, 1.9375788265227654, 1.1219056784826509, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 994
# Generation with parameters (1.4046738447204541e+33, 6.333729861570544e+32, 0.0, 0.0, 0.7591697855990202, 0.0, 0.0, 0.08115952135383164, 3.085677581491367e+24, 0.957488045182, 0.08928792003819327, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4046738447204541e+33, 6.333729861570544e+32, 0.0, 0.0, 0.7591697855990202, 0.0, 0.0, 0.08115952135383164, 3.085677581491367e+24, 0.957488045182, 0.08928792003819327, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 995
# Generation with parameters (1.6510757594935965e+33, 4.489622236871441e+32, 0.0, 0.0, -0.2527899304183535, 0.0, 0.0, -0.6286975916333162, 3.085677581491367e+24, 2.1152494870754888, 0.023334360958685362, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6510757594935965e+33, 4.489622236871441e+32, 0.0, 0.0, -0.2527899304183535, 0.0, 0.0, -0.6286975916333162, 3.085677581491367e+24, 2.1152494870754888, 0.023334360958685362, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 996
# Generation with parameters (1.001669975532309e+33, 7.699864948183777e+32, 0.0, 0.0, 0.05466640658440641, 0.0, 0.0, 0.0032849014115394434, 3.085677581491367e+24, 1.2494946239210165, 2.655879047901916, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.001669975532309e+33, 7.699864948183777e+32, 0.0, 0.0, 0.05466640658440641, 0.0, 0.0, 0.0032849014115394434, 3.085677581491367e+24, 1.2494946239210165, 2.655879047901916, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 997
# Generation with parameters (1.6329996404061355e+33, 5.656408464978924e+32, 0.0, 0.0, 0.2624887845269893, 0.0, 0.0, 0.13337978183862872, 3.085677581491367e+24, 1.2588196349360428, 4.256282737966145, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6329996404061355e+33, 5.656408464978924e+32, 0.0, 0.0, 0.2624887845269893, 0.0, 0.0, 0.13337978183862872, 3.085677581491367e+24, 1.2588196349360428, 4.256282737966145, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 998
# Generation with parameters (1.8274708558507202e+33, 4.663429415314625e+32, 0.0, 0.0, -0.3003694843119009, 0.0, 0.0, 0.0035770089100251473, 3.085677581491367e+24, 0.9458990610562267, 0.38944356478844516, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8274708558507202e+33, 4.663429415314625e+32, 0.0, 0.0, -0.3003694843119009, 0.0, 0.0, 0.0035770089100251473, 3.085677581491367e+24, 0.9458990610562267, 0.38944356478844516, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 999
# Generation with parameters (1.344490097611376e+33, 6.07429825686757e+32, 0.0, 0.0, -0.060800682586344905, 0.0, 0.0, -0.006256609486999262, 3.085677581491367e+24, 2.2363348453094187, 2.4176240905737494, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.344490097611376e+33, 6.07429825686757e+32, 0.0, 0.0, -0.060800682586344905, 0.0, 0.0, -0.006256609486999262, 3.085677581491367e+24, 2.2363348453094187, 2.4176240905737494, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.

# %% [markdown]
# ## Infere parameters

# %%
# %%capture  
#avoids printing a lot of output to the notebook
import pandas as pd
from dingo.gw.inference.gw_samplers import GWSampler




os.makedirs(f"/scratch/tpausch/test_data/{name}/results", exist_ok=True)

injection_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/injections"))

for fname in injection_files[:100]:  # only run the first 10 injections for testing

    # --------------------------------------------------------
    # Load injection
    # --------------------------------------------------------

    with open(f"/scratch/tpausch/test_data/{name}/injections/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    strain_data = payload["strain_data"]

    # --------------------------------------------------------
    # Run sampler
    # --------------------------------------------------------

    sampler = GWSampler(model=main_pm)

    sampler.context = strain_data

    sampler.run_sampler(
        num_samples=50_000,
        batch_size=10_000,
    )

    result = sampler.to_result()



    # --------------------------------------------------------
    # calculate network SNR
    # --------------------------------------------------------
    parameters = pd.DataFrame(
        {key: np.array([np.asarray(val).item()]) for key, val in theta_true.items()}
    )
    snr_df = gw.utilities.get_snr(parameters, network, waveform_model, f_ref)
    network_snr = float(snr_df["network"].iloc[0])  # extract as plain float

    # --------------------------------------------------------
    # Store result
    # --------------------------------------------------------

    result_payload = {
        "theta_true": theta_true,
        "result": result,
        "network_snr": network_snr,
    }

    outname = fname.replace("inj_", "result_")

    with open(f"/scratch/tpausch/test_data/{name}/results/{outname}", "wb") as f:
        pickle.dump(result_payload, f)

    print(f"Saved /scratch/tpausch/test_data/{name}/results/{outname}")

# %% [markdown]
# ## Calculate and plot chirp mass inference error

# %%
true_cm = []
true_mr = []
mass_ratio_error = []
mass_ratio_std = []
chirp_mass_error = []
chirp_mass_std = []


result_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/{name}/results/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    result = payload["result"]

    posterior_samples = result.samples

    #q_samples = np.array(posterior_samples["mass_ratio"])

    # inference statistics
    #q_mean = np.mean(q_samples)
    #q_std = np.std(q_samples)
#
    #true_q = theta_true["mass_ratio"]

    cm_samples = np.array(posterior_samples["chirp_mass"])

    cm_mean = np.mean(cm_samples)
    cm_std = np.std(cm_samples)

    true_mr.append(theta_true["mass_ratio"])
    true_cm.append(theta_true["chirp_mass"])
    #mass_ratio_error.append(q_mean - true_q)
    #mass_ratio_std.append(q_std)
    chirp_mass_error.append(cm_mean - theta_true["chirp_mass"])
    chirp_mass_std.append(cm_std)


true_mr = np.array(true_mr)
true_cm = np.array(true_cm)

# ------------------------------------------------------------
# Error bars
# ------------------------------------------------------------

#plt.errorbar(
#    true_cm,
#    chirp_mass_error,
#    yerr=chirp_mass_std,
#    fmt="none",
#    capsize=4,
#    alpha=0.5,
#    color="gray",
#)

# ------------------------------------------------------------
# Colored scatter points
# ------------------------------------------------------------

sc = plt.scatter(
    true_cm,
    chirp_mass_error,
    s=20,
    edgecolor="black",
    alpha=0.3
)

# ------------------------------------------------------------
# Reference line
# ------------------------------------------------------------

plt.axhline(0, linestyle="--", color="black")


# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel("True chirp mass")
plt.ylabel("Chirp mass inference error (inferred − true)")

plt.title("Chirp-mass inference error")

plt.grid(True)

plt.tight_layout()
plt.show()

cm_err = np.asarray(chirp_mass_error)

mean_error = np.mean(cm_err)          # signed average bias (over/under-estimation)
mean_abs_error = np.mean(np.abs(cm_err))  # average magnitude of deviation
rms_error = np.sqrt(np.mean(cm_err**2))   # RMS deviation, penalizes outliers more
std_error = np.std(cm_err)            # spread of the errors around their mean
p90_abs_error = np.percentile(np.abs(cm_err), 90)
p95_abs_error = np.percentile(np.abs(cm_err), 95)
p99_abs_error = np.percentile(np.abs(cm_err), 99)


print(f"Mean error (bias):      {mean_error:.3f}")
print(f"Mean absolute error:    {mean_abs_error:.3f}")
print(f"RMS error:              {rms_error:.3f}")
print(f"Std of error:           {std_error:.3f}")
print(f"90th percentile |error|: {p90_abs_error:.3f}")
print(f"95th percentile |error|: {p95_abs_error:.3f}")
print(f"99th percentile |error|: {p99_abs_error:.3f}")
# Out:
# Mean error (bias):      0.187
# Mean absolute error:    13.312
# RMS error:              22.830
# Std of error:           22.829
# 90th percentile |error|: 37.780
# 95th percentile |error|: 55.473
# 99th percentile |error|: 85.030

# %% [markdown]
# ## PP-plot

# %%
pp_values_chirp_mass = []
pp_values_mass_ratio = []

result_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/{name}/results/{fname}", "rb") as f:

        payload = pickle.load(f)

        theta_true = payload["theta_true"]
        result = payload["result"]

        posterior_samples = result.samples


        # ============================================================
        # Chirp mass PP value
        # ============================================================

        cm_samples = posterior_samples["chirp_mass"]

        pp_cm = np.mean(
            cm_samples < theta_true["chirp_mass"]
        )

        pp_values_chirp_mass.append(pp_cm)


        # ============================================================
        # Mass ratio PP value
        # ============================================================

        #q_samples = posterior_samples["mass_ratio"]
#
        #pp_q = np.mean(
        #    q_samples < theta_true["mass_ratio"]
        #)
#
        #pp_values_mass_ratio.append(pp_q)




def plot_pp(pp_values, label):

    pp_values = np.array(pp_values)

    sorted_pp = np.sort(pp_values)

    n = len(sorted_pp)

    empirical_cdf = np.arange(1, n + 1) / n

    x = np.linspace(0, 1, 200)

    sigma = np.sqrt(x * (1 - x) / n)

    plt.figure(figsize=(6, 6))

    # Ideal calibration
    plt.plot(
        [0, 1],
        [0, 1],
        linestyle="--",
        label="Ideal calibration",
    )


    # Empirical PP curve
    plt.plot(
        sorted_pp,
        empirical_cdf,
        marker="o",
        label=label,
    )

    plt.xlabel("Credible level")
    plt.ylabel("Fraction of injections")

    plt.title(f"PP Plot: {label}")

    plt.xlim(0, 1)
    plt.ylim(0, 1)

    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()


plot_pp(
    pp_values_chirp_mass,
    "chirp_mass",
)

#plot_pp(
#    pp_values_mass_ratio,
#    "mass_ratio",
#)

# %% [markdown]
# ## SNR analysis

# %%
snrs = []
ci90_widths = []
chirp_masses = []

result_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/{name}/results/{fname}", "rb") as f:

        payload = pickle.load(f)
    
    theta_true = payload["theta_true"]
    result = payload["result"]


    snr = payload["network_snr"]   # use "ET" instead if you want the single-detector value
   

    snrs.append(snr)

    samples = result.samples["chirp_mass"].to_numpy()  # adjust if result.samples is a DataFrame

    ci90 = np.percentile(samples, 95) - np.percentile(samples, 5)
    ci90_widths.append(ci90)
    chirp_masses.append(theta_true["chirp_mass"])

snrs = np.array(snrs)
ci90_widths = np.array(ci90_widths)
chirp_masses = np.array(chirp_masses)

frac_widths = ci90_widths / chirp_masses  # relative width, dimensionless

plt.figure(figsize=(6, 5))
sc = plt.scatter(snrs, ci90_widths, c=chirp_masses, cmap="viridis", alpha=0.6, s=15)
#sc = plt.scatter(snrs, frac_widths, c=chirp_masses, cmap="viridis", alpha=0.6, s=15)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Network SNR")
plt.ylabel("Chirp mass 90% CI width")
plt.colorbar(sc, label="Injected chirp mass [M$_\\odot$]")
plt.title("posterior width vs SNR")
plt.grid(True, which="both", alpha=0.3)
plt.tight_layout()
plt.show()


chirp_mass_error = np.array(chirp_mass_error)
mask = snrs < 100.0

plt.figure(figsize=(10, 5))
sc = plt.scatter(
    snrs[mask],
    chirp_mass_error[mask],
    s=10,
    edgecolor="black",
    alpha=0.3
)

plt.axhline(0, linestyle="--", color="black")
plt.xlabel("SNR")
plt.ylabel("Chirp mass inference error (inferred − true)")
plt.title("Chirp-mass inference error")
plt.grid(True)
plt.tight_layout()
plt.show()




# --- Plot distribution ---
plt.figure(figsize=(6, 5))

# Histogram, normalized to a density so it represents "how likely each value is"
counts, bins, _ = plt.hist(
    snrs, bins=100, density=True, alpha=0.5, color="steelblue", edgecolor="k", label="Histogram"
)
plt.xlabel("Network SNR")
plt.ylabel("Probability density")
plt.title(f"Distribution of injected network SNR (n={len(snrs)})")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()


print(f"SNR stats: min={snrs.min():.2f}, max={snrs.max():.2f}, "
      f"median={np.median(snrs):.2f}, mean={snrs.mean():.2f}",
      f"snr99={np.percentile(np.abs(snrs), 99):.2f}")
# Out:
# SNR stats: min=0.23, max=4798.27, median=122.72, mean=292.31 snr99=1955.50
