# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
import GWFish.modules as gw


os.environ["CUDA_VISIBLE_DEVICES"] = "3"  # use GPU 1

name="170_420"

waveform_model = 'IMRPhenomXPHM'
f_ref = 20.
detectors = ['ET']
network = gw.detection.Network(detector_ids = detectors, detection_SNR = (0., 8.))

# %% [markdown]
# ## Load Model

# %%
from dingo.core.posterior_models.build_model import build_model_from_kwargs
main_pm = build_model_from_kwargs(
    filename=f"/scratch/tpausch/models/{name}/model_100.pt",
    device="cuda",
    load_training_info=False,
)
# Out:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1174+g45666b754 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Putting posterior model to device cuda.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt(f"/scratch/tpausch/models/{name}/history.txt")
epochs   = data[:, 0]
train    = data[:, 1]
val      = data[:, 2]


plt.figure(figsize=(8, 5))
plt.plot(epochs, train, label="Train loss")
plt.plot(epochs, val,   label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("Log-likelihood")
plt.legend()
plt.title("Dingo training history")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Simulate injections

# %%
import dingo.gw.injection as injection
from dingo.gw.noise.asd_dataset import ASDDataset

# ============================================================
# Setup
# ============================================================

num_injections = 1000
out_dir = f"/scratch/tpausch/test_data/{name}/injections"
os.makedirs(out_dir, exist_ok=True)

np.random.seed(42)  # optional, for reproducibility

injection_generator = injection.Injection.from_posterior_model_metadata(
    main_pm.metadata
)

asd_fname = main_pm.metadata["train_settings"]["training"]["stage_0"]["asd_dataset_path"]
asd_dataset = ASDDataset(file_name=asd_fname)

injection_generator.asd = {
    k: v[0] for k, v in asd_dataset.asds.items()
}

# This is the combined intrinsic + extrinsic bilby PriorDict
# that the network was trained on
prior = injection_generator.prior
print(prior)

# ============================================================
# Draw and run injections
# ============================================================

for idx in range(num_injections):

    print(f"Running injection {idx}")

    theta = prior.sample()
    theta = {k: float(v) for k, v in theta.items()}  # cast numpy -> float

    strain_data = injection_generator.injection(theta)

    payload = {
        "theta_true": theta,
        "strain_data": strain_data,
    }

    fname = os.path.join(out_dir, f"inj_{idx:04d}.pkl")

    with open(fname, "wb") as f:
        pickle.dump(payload, f)
# Out:
# Setting spin_conversion_phase = 0.0. Using this value for the phase parameter for conversion to cartesian spins.
# Loading dataset from training_data/asds_ET_T8.hdf5.
# {'mass_1': Constraint(minimum=30.0, maximum=3000.0, name='mass_1', latex_label='$m_1$', unit=None), 'mass_2': Constraint(minimum=30.0, maximum=3000.0, name='mass_2', latex_label='$m_2$', unit=None), 'chirp_mass': bilby.gw.prior.UniformInComponentsChirpMass(minimum=50.0, maximum=1000.0, name='chirp_mass', latex_label='$\\mathcal{M}$', unit=None, boundary=None), 'mass_ratio': bilby.gw.prior.UniformInComponentsMassRatio(minimum=0.125, maximum=1.0, name='mass_ratio', latex_label='$q$', unit=None, boundary=None, equal_mass=False), 'phase': Uniform(minimum=0.0, maximum=6.283185307179586, name='phase', latex_label='$\\phi$', unit=None, boundary='periodic'), 'chi_1': bilby.gw.prior.AlignedSpin(a_prior=Uniform(minimum=0, maximum=0.9, name=None, latex_label=None, unit=None, boundary=None), z_prior=Uniform(minimum=-1, maximum=1, name=None, latex_label=None, unit=None, boundary=None), name='chi_1', latex_label='$\\chi_1$', unit=None, boundary=None, minimum=-0.9, maximum=0.9, num_interp=100000), 'chi_2': bilby.gw.prior.AlignedSpin(a_prior=Uniform(minimum=0, maximum=0.9, name=None, latex_label=None, unit=None, boundary=None), z_prior=Uniform(minimum=-1, maximum=1, name=None, latex_label=None, unit=None, boundary=None), name='chi_2', latex_label='$\\chi_2$', unit=None, boundary=None, minimum=-0.9, maximum=0.9, num_interp=100000), 'theta_jn': Sine(minimum=0.0, maximum=3.141592653589793, name='theta_jn', latex_label='$\\theta_{JN}$', unit=None, boundary=None), 'luminosity_distance': LogUniform(minimum=1000.0, maximum=100000.0, name='luminosity_distance', latex_label='$d_L$', unit=None, boundary=None), 'geocent_time': Uniform(minimum=-0.1, maximum=0.1, name='geocent_time', latex_label='$t_c$', unit=None, boundary=None), 'dec': Cosine(minimum=-1.5707963267948966, maximum=1.5707963267948966, name='dec', latex_label='$\\mathrm{DEC}$', unit=None, boundary=None), 'ra': Uniform(minimum=0.0, maximum=6.283185307179586, name='ra', latex_label='$\\mathrm{RA}$', unit=None, boundary='periodic'), 'psi': Uniform(minimum=0.0, maximum=3.141592653589793, name='psi', latex_label='$\\psi$', unit=None, boundary='periodic')}
# Running injection 0
# Generation with parameters (1.9983654641522335e+33, 5.800578510353907e+32, 0.0, 0.0, -0.011035904007676641, 0.0, 0.0, 0.03148494131502296, 3.085677581491367e+24, 2.418302843966261, 6.097870087818012, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.9983654641522335e+33, 5.800578510353907e+32, 0.0, 0.0, -0.011035904007676641, 0.0, 0.0, 0.03148494131502296, 3.085677581491367e+24, 2.418302843966261, 6.097870087818012, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1
# Generation with parameters (3.2321606917351023e+33, 1.5295346191868864e+33, 0.0, 0.0, 0.23799375470077985, 0.0, 0.0, 0.1878765974491143, 3.085677581491367e+24, 2.1367413681463097, 5.097600841709094, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.2321606917351023e+33, 1.5295346191868864e+33, 0.0, 0.0, 0.23799375470077985, 0.0, 0.0, 0.1878765974491143, 3.085677581491367e+24, 2.1367413681463097, 5.097600841709094, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 2
# Generation with parameters (2.871025105738939e+33, 1.0781087456212077e+33, 0.0, 0.0, -0.13135015201633585, 0.0, 0.0, -0.4310518734099092, 3.085677581491367e+24, 0.5923919470782426, 3.106831600628836, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.871025105738939e+33, 1.0781087456212077e+33, 0.0, 0.0, -0.13135015201633585, 0.0, 0.0, -0.4310518734099092, 3.085677581491367e+24, 0.5923919470782426, 3.106831600628836, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 3
# Running injection 4
# Generation with parameters (1.027725776432546e+33, 6.985950091601844e+32, 0.0, 0.0, 0.6568427560444433, 0.0, 0.0, -0.4499053136498063, 3.085677581491367e+24, 0.7726422111548559, 3.0708360225167604, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.027725776432546e+33, 6.985950091601844e+32, 0.0, 0.0, 0.6568427560444433, 0.0, 0.0, -0.4499053136498063, 3.085677581491367e+24, 0.7726422111548559, 3.0708360225167604, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 5
# Generation with parameters (3.1980562906020177e+33, 1.1084173064306093e+33, 0.0, 0.0, -0.15821721034358172, 0.0, 0.0, -0.2534693424387606, 3.085677581491367e+24, 1.558845191581074, 4.915505644396763, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.1980562906020177e+33, 1.1084173064306093e+33, 0.0, 0.0, -0.15821721034358172, 0.0, 0.0, -0.2534693424387606, 3.085677581491367e+24, 1.558845191581074, 4.915505644396763, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 6
# Generation with parameters (1.5392759134867273e+33, 1.3405981871020738e+33, 0.0, 0.0, -0.23620861518440986, 0.0, 0.0, 0.045242377229813176, 3.085677581491367e+24, 1.57804914936174, 4.1841544101238295, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5392759134867273e+33, 1.3405981871020738e+33, 0.0, 0.0, -0.23620861518440986, 0.0, 0.0, 0.045242377229813176, 3.085677581491367e+24, 1.57804914936174, 4.1841544101238295, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 7
# Generation with parameters (3.568676963202837e+33, 1.432269047707161e+33, 0.0, 0.0, -0.33564962762662653, 0.0, 0.0, 0.010909401702977082, 3.085677581491367e+24, 1.0806927396881456, 3.6905662533148194, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.568676963202837e+33, 1.432269047707161e+33, 0.0, 0.0, -0.33564962762662653, 0.0, 0.0, 0.010909401702977082, 3.085677581491367e+24, 1.0806927396881456, 3.6905662533148194, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 8
# Generation with parameters (3.0887594960518193e+33, 6.62757967988572e+32, 0.0, 0.0, 0.018198981877965394, 0.0, 0.0, 0.329948688987655, 3.085677581491367e+24, 2.863667784398148, 3.730075626412195, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.0887594960518193e+33, 6.62757967988572e+32, 0.0, 0.0, 0.018198981877965394, 0.0, 0.0, 0.329948688987655, 3.085677581491367e+24, 2.863667784398148, 3.730075626412195, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 9
# Generation with parameters (2.916383728262835e+33, 1.3212796147122112e+33, 0.0, 0.0, -0.3636564939467374, 0.0, 0.0, -0.1614542501053533, 3.085677581491367e+24, 1.1463520699827159, 0.5367365564531114, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.916383728262835e+33, 1.3212796147122112e+33, 0.0, 0.0, -0.3636564939467374, 0.0, 0.0, -0.1614542501053533, 3.085677581491367e+24, 1.1463520699827159, 0.5367365564531114, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 10
# Generation with parameters (3.3312826637459786e+33, 8.929858952393283e+32, 0.0, 0.0, 0.3389990843389158, 0.0, 0.0, -0.15048436275787172, 3.085677581491367e+24, 2.3766764142299417, 0.4456803094468332, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.3312826637459786e+33, 8.929858952393283e+32, 0.0, 0.0, 0.3389990843389158, 0.0, 0.0, -0.15048436275787172, 3.085677581491367e+24, 2.3766764142299417, 0.4456803094468332, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 11
# Generation with parameters (4.5226807844953544e+33, 6.694170073143355e+32, 0.0, 0.0, -0.31095387697131355, 0.0, 0.0, -0.4866038918534751, 3.085677581491367e+24, 2.3461532091517254, 3.0423442401082186, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.5226807844953544e+33, 6.694170073143355e+32, 0.0, 0.0, -0.31095387697131355, 0.0, 0.0, -0.4866038918534751, 3.085677581491367e+24, 2.3461532091517254, 3.0423442401082186, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 12
# Generation with parameters (5.525247920239488e+33, 8.023672037772078e+32, 0.0, 0.0, -0.014821294269048832, 0.0, 0.0, -0.04718983880299801, 3.085677581491367e+24, 1.2026202208194907, 4.761385757010752, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.525247920239488e+33, 8.023672037772078e+32, 0.0, 0.0, -0.014821294269048832, 0.0, 0.0, -0.04718983880299801, 3.085677581491367e+24, 1.2026202208194907, 4.761385757010752, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 13
# Running injection 14
# Generation with parameters (4.74267968445805e+33, 8.29817774553302e+32, 0.0, 0.0, -0.2467470060754417, 0.0, 0.0, -0.05049831366299196, 3.085677581491367e+24, 1.3184599658634342, 0.007424245161185542, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.74267968445805e+33, 8.29817774553302e+32, 0.0, 0.0, -0.2467470060754417, 0.0, 0.0, -0.05049831366299196, 3.085677581491367e+24, 1.3184599658634342, 0.007424245161185542, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 15
# Generation with parameters (1.4662139221923384e+33, 1.0449498109088759e+33, 0.0, 0.0, 0.009308498565593923, 0.0, 0.0, 0.0016590611350116452, 3.085677581491367e+24, 0.76529325472439, 6.0161052133592925, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4662139221923384e+33, 1.0449498109088759e+33, 0.0, 0.0, 0.009308498565593923, 0.0, 0.0, 0.0016590611350116452, 3.085677581491367e+24, 0.76529325472439, 6.0161052133592925, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 16
# Generation with parameters (4.959909924219595e+33, 6.657231171878712e+32, 0.0, 0.0, 0.6195753058789089, 0.0, 0.0, -0.18593996793989606, 3.085677581491367e+24, 2.2393146238235353, 2.7615239679927512, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.959909924219595e+33, 6.657231171878712e+32, 0.0, 0.0, 0.6195753058789089, 0.0, 0.0, -0.18593996793989606, 3.085677581491367e+24, 2.2393146238235353, 2.7615239679927512, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 17
# Generation with parameters (2.699200974522845e+33, 1.6153453456548832e+33, 0.0, 0.0, 0.0943881631653874, 0.0, 0.0, 0.45412605531168915, 3.085677581491367e+24, 1.515640577974422, 1.6825145229478333, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.699200974522845e+33, 1.6153453456548832e+33, 0.0, 0.0, 0.0943881631653874, 0.0, 0.0, 0.45412605531168915, 3.085677581491367e+24, 1.515640577974422, 1.6825145229478333, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 18
# Generation with parameters (4.4577278630426765e+33, 1.1280561739742776e+33, 0.0, 0.0, -0.036742125231270836, 0.0, 0.0, -0.2404676285656923, 3.085677581491367e+24, 0.26903403269521303, 0.5610307551889796, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.4577278630426765e+33, 1.1280561739742776e+33, 0.0, 0.0, -0.036742125231270836, 0.0, 0.0, -0.2404676285656923, 3.085677581491367e+24, 0.26903403269521303, 0.5610307551889796, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 19
# Generation with parameters (4.176418147768627e+33, 8.576659291049927e+32, 0.0, 0.0, -0.03378116388318862, 0.0, 0.0, 0.20650722731803112, 3.085677581491367e+24, 1.7244152482596924, 5.784317397140726, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.176418147768627e+33, 8.576659291049927e+32, 0.0, 0.0, -0.03378116388318862, 0.0, 0.0, 0.20650722731803112, 3.085677581491367e+24, 1.7244152482596924, 5.784317397140726, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 20
# Generation with parameters (2.694560327023779e+33, 5.523507838962304e+32, 0.0, 0.0, -0.044386723236047636, 0.0, 0.0, -0.5151806433982693, 3.085677581491367e+24, 2.531802852214136, 2.1319137514506004, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.694560327023779e+33, 5.523507838962304e+32, 0.0, 0.0, -0.044386723236047636, 0.0, 0.0, -0.5151806433982693, 3.085677581491367e+24, 2.531802852214136, 2.1319137514506004, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 21
# Generation with parameters (2.672216396625583e+33, 7.730237360838378e+32, 0.0, 0.0, 0.00614455646483777, 0.0, 0.0, 0.2146825208639313, 3.085677581491367e+24, 2.3579547794212945, 2.5758551179727083, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.672216396625583e+33, 7.730237360838378e+32, 0.0, 0.0, 0.00614455646483777, 0.0, 0.0, 0.2146825208639313, 3.085677581491367e+24, 2.3579547794212945, 2.5758551179727083, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 22
# Generation with parameters (2.474915153577573e+33, 1.6742001794250737e+33, 0.0, 0.0, -0.199196104884754, 0.0, 0.0, -0.25206331409279115, 3.085677581491367e+24, 1.489196465743514, 3.379219954039458, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.474915153577573e+33, 1.6742001794250737e+33, 0.0, 0.0, -0.199196104884754, 0.0, 0.0, -0.25206331409279115, 3.085677581491367e+24, 1.489196465743514, 3.379219954039458, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 23
# Generation with parameters (5.716240136167878e+33, 9.007214070047652e+32, 0.0, 0.0, 0.14830212865409456, 0.0, 0.0, -0.2100204406111348, 3.085677581491367e+24, 1.5700016413643396, 1.95845606136034, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.716240136167878e+33, 9.007214070047652e+32, 0.0, 0.0, 0.14830212865409456, 0.0, 0.0, -0.2100204406111348, 3.085677581491367e+24, 1.5700016413643396, 1.95845606136034, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 24
# Generation with parameters (1.8318330347631547e+33, 1.6930200022738134e+33, 0.0, 0.0, 0.08562290094817651, 0.0, 0.0, 0.34429330520328455, 3.085677581491367e+24, 2.127150984990733, 3.4734686228571765, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8318330347631547e+33, 1.6930200022738134e+33, 0.0, 0.0, 0.08562290094817651, 0.0, 0.0, 0.34429330520328455, 3.085677581491367e+24, 2.127150984990733, 3.4734686228571765, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 25
# Generation with parameters (3.908792320740682e+33, 1.2702402280398802e+33, 0.0, 0.0, 0.6949105583681643, 0.0, 0.0, -0.1986601324972134, 3.085677581491367e+24, 0.9259923604194482, 1.0239569361044485, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.908792320740682e+33, 1.2702402280398802e+33, 0.0, 0.0, 0.6949105583681643, 0.0, 0.0, -0.1986601324972134, 3.085677581491367e+24, 0.9259923604194482, 1.0239569361044485, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 26
# Generation with parameters (2.608752469955338e+33, 1.7068828907189656e+33, 0.0, 0.0, 0.2438843999418911, 0.0, 0.0, 0.04082900349332205, 3.085677581491367e+24, 1.5995618606663924, 0.5678468613443316, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.608752469955338e+33, 1.7068828907189656e+33, 0.0, 0.0, 0.2438843999418911, 0.0, 0.0, 0.04082900349332205, 3.085677581491367e+24, 1.5995618606663924, 0.5678468613443316, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 27
# Generation with parameters (3.355272313025808e+33, 5.555760503826927e+32, 0.0, 0.0, 0.005593165729206473, 0.0, 0.0, 0.004729093451816151, 3.085677581491367e+24, 2.847245542412067, 2.001603145275487, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.355272313025808e+33, 5.555760503826927e+32, 0.0, 0.0, 0.005593165729206473, 0.0, 0.0, 0.004729093451816151, 3.085677581491367e+24, 2.847245542412067, 2.001603145275487, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 28
# Generation with parameters (4.432959872305358e+33, 1.2250353083450936e+33, 0.0, 0.0, -0.23506946299197784, 0.0, 0.0, -0.04900217721401731, 3.085677581491367e+24, 0.9177101057642009, 2.0506277303616476, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.432959872305358e+33, 1.2250353083450936e+33, 0.0, 0.0, -0.23506946299197784, 0.0, 0.0, -0.04900217721401731, 3.085677581491367e+24, 0.9177101057642009, 2.0506277303616476, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 29
# Generation with parameters (1.737818385481411e+33, 1.1110699468411238e+33, 0.0, 0.0, 0.027088871490153252, 0.0, 0.0, -0.023331829356776676, 3.085677581491367e+24, 0.9400679080542617, 4.062670269011894, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.737818385481411e+33, 1.1110699468411238e+33, 0.0, 0.0, 0.027088871490153252, 0.0, 0.0, -0.023331829356776676, 3.085677581491367e+24, 0.9400679080542617, 4.062670269011894, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 30
# Generation with parameters (1.7050204219987546e+33, 4.639714161191217e+32, 0.0, 0.0, 0.006865957155798997, 0.0, 0.0, -0.11271337593895323, 3.085677581491367e+24, 0.21781990592849337, 5.080414572215558, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7050204219987546e+33, 4.639714161191217e+32, 0.0, 0.0, 0.006865957155798997, 0.0, 0.0, -0.11271337593895323, 3.085677581491367e+24, 0.21781990592849337, 5.080414572215558, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 31
# Generation with parameters (2.351061480796973e+33, 1.1744712399003746e+33, 0.0, 0.0, -0.4930108958992039, 0.0, 0.0, 0.10127750549555385, 3.085677581491367e+24, 1.0317492764860046, 1.7512717346508555, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.351061480796973e+33, 1.1744712399003746e+33, 0.0, 0.0, -0.4930108958992039, 0.0, 0.0, 0.10127750549555385, 3.085677581491367e+24, 1.0317492764860046, 1.7512717346508555, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 32
# Generation with parameters (2.4419560179278865e+33, 4.64593884804501e+32, 0.0, 0.0, 0.21912163210119934, 0.0, 0.0, 0.17605948858903925, 3.085677581491367e+24, 0.7333357249346387, 5.064121365122652, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.4419560179278865e+33, 4.64593884804501e+32, 0.0, 0.0, 0.21912163210119934, 0.0, 0.0, 0.17605948858903925, 3.085677581491367e+24, 0.7333357249346387, 5.064121365122652, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 33
# Generation with parameters (2.5025656798161806e+33, 1.4990978479319216e+33, 0.0, 0.0, 0.012797887122824415, 0.0, 0.0, -0.7229352294273942, 3.085677581491367e+24, 2.272409588504267, 5.228359410489426, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5025656798161806e+33, 1.4990978479319216e+33, 0.0, 0.0, 0.012797887122824415, 0.0, 0.0, -0.7229352294273942, 3.085677581491367e+24, 2.272409588504267, 5.228359410489426, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 34
# Generation with parameters (2.4110866738992896e+33, 9.031430072595628e+32, 0.0, 0.0, -0.8381403197060157, 0.0, 0.0, 0.380954710701512, 3.085677581491367e+24, 1.6616778855986236, 0.4828130866907515, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.4110866738992896e+33, 9.031430072595628e+32, 0.0, 0.0, -0.8381403197060157, 0.0, 0.0, 0.380954710701512, 3.085677581491367e+24, 1.6616778855986236, 0.4828130866907515, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 35
# Generation with parameters (1.6844089167182977e+33, 1.1751992635525504e+33, 0.0, 0.0, 0.5086445270626002, 0.0, 0.0, 0.29902488210771366, 3.085677581491367e+24, 1.7768153534619462, 3.0995879179008976, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6844089167182977e+33, 1.1751992635525504e+33, 0.0, 0.0, 0.5086445270626002, 0.0, 0.0, 0.29902488210771366, 3.085677581491367e+24, 1.7768153534619462, 3.0995879179008976, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 36
# Generation with parameters (3.3608598575491366e+33, 9.168516417972571e+32, 0.0, 0.0, 0.015924446842601355, 0.0, 0.0, 0.15533781716566988, 3.085677581491367e+24, 2.3069770400396754, 2.2911926307382515, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.3608598575491366e+33, 9.168516417972571e+32, 0.0, 0.0, 0.015924446842601355, 0.0, 0.0, 0.15533781716566988, 3.085677581491367e+24, 2.3069770400396754, 2.2911926307382515, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 37
# Generation with parameters (2.691994612083091e+33, 3.517590041464294e+32, 0.0, 0.0, 0.06089670983340007, 0.0, 0.0, -0.06779027608686168, 3.085677581491367e+24, 0.8903055964867514, 1.7278541832050929, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.691994612083091e+33, 3.517590041464294e+32, 0.0, 0.0, 0.06089670983340007, 0.0, 0.0, -0.06779027608686168, 3.085677581491367e+24, 0.8903055964867514, 1.7278541832050929, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 38
# Generation with parameters (3.3531811702753863e+33, 1.330629812307321e+33, 0.0, 0.0, -0.50550287347844, 0.0, 0.0, -0.24115802044800122, 3.085677581491367e+24, 2.2132144849235207, 3.8902629671176037, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.3531811702753863e+33, 1.330629812307321e+33, 0.0, 0.0, -0.50550287347844, 0.0, 0.0, -0.24115802044800122, 3.085677581491367e+24, 2.2132144849235207, 3.8902629671176037, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 39
# Generation with parameters (5.880101617384729e+33, 7.750506885601145e+32, 0.0, 0.0, 0.020255177500518716, 0.0, 0.0, -0.013460770568501715, 3.085677581491367e+24, 1.6452020850096132, 6.05337467689345, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.880101617384729e+33, 7.750506885601145e+32, 0.0, 0.0, 0.020255177500518716, 0.0, 0.0, -0.013460770568501715, 3.085677581491367e+24, 1.6452020850096132, 6.05337467689345, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 40
# Generation with parameters (1.2470817964207752e+33, 5.152345426953636e+32, 0.0, 0.0, 0.252004338361883, 0.0, 0.0, 0.07809482377069601, 3.085677581491367e+24, 1.3961533673248847, 4.578039067856841, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2470817964207752e+33, 5.152345426953636e+32, 0.0, 0.0, 0.252004338361883, 0.0, 0.0, 0.07809482377069601, 3.085677581491367e+24, 1.3961533673248847, 4.578039067856841, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 41
# Generation with parameters (1.737347562285374e+33, 9.934776388644055e+32, 0.0, 0.0, -0.08728023499702547, 0.0, 0.0, -0.039582809160161235, 3.085677581491367e+24, 1.0449376558219272, 6.063282147565828, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.737347562285374e+33, 9.934776388644055e+32, 0.0, 0.0, -0.08728023499702547, 0.0, 0.0, -0.039582809160161235, 3.085677581491367e+24, 1.0449376558219272, 6.063282147565828, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 42
# Generation with parameters (3.34565069131249e+33, 8.078569132478957e+32, 0.0, 0.0, -0.4366063302842048, 0.0, 0.0, -0.04819517515426518, 3.085677581491367e+24, 1.7194299894742426, 4.6270435660268285, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.34565069131249e+33, 8.078569132478957e+32, 0.0, 0.0, -0.4366063302842048, 0.0, 0.0, -0.04819517515426518, 3.085677581491367e+24, 1.7194299894742426, 4.6270435660268285, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 43
# Generation with parameters (1.9491832638542993e+33, 1.7918380215157026e+33, 0.0, 0.0, -0.1095233908992353, 0.0, 0.0, -0.37547871067415756, 3.085677581491367e+24, 0.6706701765386806, 4.412906937100678, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.9491832638542993e+33, 1.7918380215157026e+33, 0.0, 0.0, -0.1095233908992353, 0.0, 0.0, -0.37547871067415756, 3.085677581491367e+24, 0.6706701765386806, 4.412906937100678, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 44
# Generation with parameters (2.2169942381075677e+33, 1.9978140376220588e+33, 0.0, 0.0, -0.12247891447037104, 0.0, 0.0, 0.10264019621484856, 3.085677581491367e+24, 1.207979643453761, 3.462297606659612, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2169942381075677e+33, 1.9978140376220588e+33, 0.0, 0.0, -0.12247891447037104, 0.0, 0.0, 0.10264019621484856, 3.085677581491367e+24, 1.207979643453761, 3.462297606659612, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 45
# Generation with parameters (4.7796504906389034e+33, 8.591819713221917e+32, 0.0, 0.0, -0.49278914338004626, 0.0, 0.0, 0.22548047602027102, 3.085677581491367e+24, 1.0228480390639951, 4.083468598366618, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.7796504906389034e+33, 8.591819713221917e+32, 0.0, 0.0, -0.49278914338004626, 0.0, 0.0, 0.22548047602027102, 3.085677581491367e+24, 1.0228480390639951, 4.083468598366618, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 46
# Generation with parameters (4.5009666786446196e+33, 1.2190861770276885e+33, 0.0, 0.0, 0.0032576717694653133, 0.0, 0.0, 0.567196312291539, 3.085677581491367e+24, 1.629240486251652, 4.675717033208675, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.5009666786446196e+33, 1.2190861770276885e+33, 0.0, 0.0, 0.0032576717694653133, 0.0, 0.0, 0.567196312291539, 3.085677581491367e+24, 1.629240486251652, 4.675717033208675, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 47
# Generation with parameters (3.100931119211527e+33, 6.775138967078636e+32, 0.0, 0.0, -0.6989372048470116, 0.0, 0.0, -0.058775058828582395, 3.085677581491367e+24, 1.9757698774973966, 3.0134018894566945, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.100931119211527e+33, 6.775138967078636e+32, 0.0, 0.0, -0.6989372048470116, 0.0, 0.0, -0.058775058828582395, 3.085677581491367e+24, 1.9757698774973966, 3.0134018894566945, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 48
# Generation with parameters (1.938744368722741e+33, 1.902259446865482e+33, 0.0, 0.0, -0.4976926460746841, 0.0, 0.0, 0.08722991772259847, 3.085677581491367e+24, 1.119468030121135, 1.1743549606053483, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.938744368722741e+33, 1.902259446865482e+33, 0.0, 0.0, -0.4976926460746841, 0.0, 0.0, 0.08722991772259847, 3.085677581491367e+24, 1.119468030121135, 1.1743549606053483, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 49
# Generation with parameters (4.508285810146504e+33, 6.3889198623789335e+32, 0.0, 0.0, -0.02473136281266447, 0.0, 0.0, 0.7311295554484819, 3.085677581491367e+24, 2.0845857084148376, 0.8032312174462821, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.508285810146504e+33, 6.3889198623789335e+32, 0.0, 0.0, -0.02473136281266447, 0.0, 0.0, 0.7311295554484819, 3.085677581491367e+24, 2.0845857084148376, 0.8032312174462821, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 50
# Generation with parameters (1.2202815787513801e+33, 9.191595454555689e+32, 0.0, 0.0, 0.197171716200419, 0.0, 0.0, -0.20495782413071856, 3.085677581491367e+24, 2.3905699068558848, 0.20942770861777854, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2202815787513801e+33, 9.191595454555689e+32, 0.0, 0.0, 0.197171716200419, 0.0, 0.0, -0.20495782413071856, 3.085677581491367e+24, 2.3905699068558848, 0.20942770861777854, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 51
# Generation with parameters (3.788585353606117e+33, 1.2687026014958213e+33, 0.0, 0.0, -0.3808091899958715, 0.0, 0.0, -0.7528642962610498, 3.085677581491367e+24, 0.8574935293939713, 2.4492102643203815, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.788585353606117e+33, 1.2687026014958213e+33, 0.0, 0.0, -0.3808091899958715, 0.0, 0.0, -0.7528642962610498, 3.085677581491367e+24, 0.8574935293939713, 2.4492102643203815, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 52
# Generation with parameters (1.987127065000241e+33, 4.37154653788966e+32, 0.0, 0.0, 0.28664417808982867, 0.0, 0.0, 0.5561774652037813, 3.085677581491367e+24, 0.8712474968880861, 4.312134680606552, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.987127065000241e+33, 4.37154653788966e+32, 0.0, 0.0, 0.28664417808982867, 0.0, 0.0, 0.5561774652037813, 3.085677581491367e+24, 0.8712474968880861, 4.312134680606552, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 53
# Generation with parameters (3.9773504573351836e+33, 8.754451219954467e+32, 0.0, 0.0, -0.0013154776111658638, 0.0, 0.0, -0.040339116942385934, 3.085677581491367e+24, 0.9715496127647921, 1.2013765554188858, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.9773504573351836e+33, 8.754451219954467e+32, 0.0, 0.0, -0.0013154776111658638, 0.0, 0.0, -0.040339116942385934, 3.085677581491367e+24, 0.9715496127647921, 1.2013765554188858, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 54
# Generation with parameters (2.2884612984581772e+33, 1.0746594589414696e+33, 0.0, 0.0, -0.01996387216533421, 0.0, 0.0, 0.21548021541498708, 3.085677581491367e+24, 0.7089837283153608, 5.970499625131324, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2884612984581772e+33, 1.0746594589414696e+33, 0.0, 0.0, -0.01996387216533421, 0.0, 0.0, 0.21548021541498708, 3.085677581491367e+24, 0.7089837283153608, 5.970499625131324, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 55
# Generation with parameters (1.7510322058611415e+33, 6.138554697967171e+32, 0.0, 0.0, -0.4012520048734115, 0.0, 0.0, 0.1773187284588741, 3.085677581491367e+24, 0.5229246011655075, 5.476179774495939, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7510322058611415e+33, 6.138554697967171e+32, 0.0, 0.0, -0.4012520048734115, 0.0, 0.0, 0.1773187284588741, 3.085677581491367e+24, 0.5229246011655075, 5.476179774495939, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 56
# Generation with parameters (1.393303771830512e+33, 5.4444237223897404e+32, 0.0, 0.0, -0.7850557213105792, 0.0, 0.0, 0.05115085880143265, 3.085677581491367e+24, 1.8531380143116039, 4.127270364795019, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.393303771830512e+33, 5.4444237223897404e+32, 0.0, 0.0, -0.7850557213105792, 0.0, 0.0, 0.05115085880143265, 3.085677581491367e+24, 1.8531380143116039, 4.127270364795019, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 57
# Generation with parameters (1.8392853298358535e+33, 1.5991986419743443e+33, 0.0, 0.0, 0.34535790207855416, 0.0, 0.0, 0.03496800284113664, 3.085677581491367e+24, 1.3895070552328004, 3.5452624650514037, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8392853298358535e+33, 1.5991986419743443e+33, 0.0, 0.0, 0.34535790207855416, 0.0, 0.0, 0.03496800284113664, 3.085677581491367e+24, 1.3895070552328004, 3.5452624650514037, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 58
# Generation with parameters (1.1927515348360648e+33, 6.516948113910866e+32, 0.0, 0.0, -0.11714058411537191, 0.0, 0.0, -0.12898686804586273, 3.085677581491367e+24, 1.2023619485503745, 2.0649869325755277, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1927515348360648e+33, 6.516948113910866e+32, 0.0, 0.0, -0.11714058411537191, 0.0, 0.0, -0.12898686804586273, 3.085677581491367e+24, 1.2023619485503745, 2.0649869325755277, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 59
# Generation with parameters (3.7390291116467054e+33, 9.160204435519093e+32, 0.0, 0.0, -0.01067449508551179, 0.0, 0.0, 0.44949954390708413, 3.085677581491367e+24, 0.1982378521743682, 3.7589842666380635, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.7390291116467054e+33, 9.160204435519093e+32, 0.0, 0.0, -0.01067449508551179, 0.0, 0.0, 0.44949954390708413, 3.085677581491367e+24, 0.1982378521743682, 3.7589842666380635, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 60
# Generation with parameters (1.220951419920645e+33, 5.528673376396222e+32, 0.0, 0.0, -0.0748130143231116, 0.0, 0.0, -0.5799919471260901, 3.085677581491367e+24, 1.5088127241965044, 3.149885674238656, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.220951419920645e+33, 5.528673376396222e+32, 0.0, 0.0, -0.0748130143231116, 0.0, 0.0, -0.5799919471260901, 3.085677581491367e+24, 1.5088127241965044, 3.149885674238656, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 61
# Generation with parameters (2.562690037355548e+33, 1.6580366984065423e+33, 0.0, 0.0, -0.34624859484657616, 0.0, 0.0, -0.026152562748240397, 3.085677581491367e+24, 1.009021807183498, 1.8871936573886294, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.562690037355548e+33, 1.6580366984065423e+33, 0.0, 0.0, -0.34624859484657616, 0.0, 0.0, -0.026152562748240397, 3.085677581491367e+24, 1.009021807183498, 1.8871936573886294, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 62
# Generation with parameters (1.3591304986697717e+33, 2.434088952920937e+32, 0.0, 0.0, -0.012266993291700874, 0.0, 0.0, 0.06215215798988685, 3.085677581491367e+24, 2.835709318152202, 4.826420494506528, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3591304986697717e+33, 2.434088952920937e+32, 0.0, 0.0, -0.012266993291700874, 0.0, 0.0, 0.06215215798988685, 3.085677581491367e+24, 2.835709318152202, 4.826420494506528, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 63
# Generation with parameters (1.4419022847636354e+33, 8.527930868711263e+32, 0.0, 0.0, -0.6102351210907774, 0.0, 0.0, 0.6254938566507197, 3.085677581491367e+24, 1.3620347581933656, 0.3933945220287942, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4419022847636354e+33, 8.527930868711263e+32, 0.0, 0.0, -0.6102351210907774, 0.0, 0.0, 0.6254938566507197, 3.085677581491367e+24, 1.3620347581933656, 0.3933945220287942, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 64
# Generation with parameters (2.2568397522727802e+33, 1.8991488160605577e+33, 0.0, 0.0, 0.0599679567039904, 0.0, 0.0, 0.22800442329876772, 3.085677581491367e+24, 0.7633889818217668, 1.3192358648476237, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2568397522727802e+33, 1.8991488160605577e+33, 0.0, 0.0, 0.0599679567039904, 0.0, 0.0, 0.22800442329876772, 3.085677581491367e+24, 0.7633889818217668, 1.3192358648476237, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 65
# Generation with parameters (2.2089979329927395e+33, 2.1286419772461253e+33, 0.0, 0.0, 0.02409687971422475, 0.0, 0.0, -0.2322342010935942, 3.085677581491367e+24, 2.2719672128767603, 0.8284191014596859, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2089979329927395e+33, 2.1286419772461253e+33, 0.0, 0.0, 0.02409687971422475, 0.0, 0.0, -0.2322342010935942, 3.085677581491367e+24, 2.2719672128767603, 0.8284191014596859, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 66
# Generation with parameters (2.1085815627838873e+33, 1.735493169959557e+33, 0.0, 0.0, 0.4278420481501636, 0.0, 0.0, -0.6377273144446941, 3.085677581491367e+24, 1.4563997517919793, 0.8326126832718336, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.1085815627838873e+33, 1.735493169959557e+33, 0.0, 0.0, 0.4278420481501636, 0.0, 0.0, -0.6377273144446941, 3.085677581491367e+24, 1.4563997517919793, 0.8326126832718336, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 67
# Running injection 68
# Generation with parameters (3.217331528117803e+33, 8.934626353150065e+32, 0.0, 0.0, -0.09794403997541683, 0.0, 0.0, -0.639883919646773, 3.085677581491367e+24, 2.1406969655327748, 4.947008028860961, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.217331528117803e+33, 8.934626353150065e+32, 0.0, 0.0, -0.09794403997541683, 0.0, 0.0, -0.639883919646773, 3.085677581491367e+24, 2.1406969655327748, 4.947008028860961, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 69
# Generation with parameters (1.602544040353178e+33, 4.5546432516404796e+32, 0.0, 0.0, -0.020949806262202737, 0.0, 0.0, -0.25874098952486985, 3.085677581491367e+24, 1.1019558341958713, 0.9231776601770671, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.602544040353178e+33, 4.5546432516404796e+32, 0.0, 0.0, -0.020949806262202737, 0.0, 0.0, -0.25874098952486985, 3.085677581491367e+24, 1.1019558341958713, 0.9231776601770671, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 70
# ...
# Warning: turning off multibanding for parameters (1.4391565248743585e+33, 1.851926268855856e+32, 0.0, 0.0, 0.5918662655007277, 0.0, 0.0, 0.01090179470965477, 3.085677581491367e+24, 2.0092715122720475, 4.3107598075154, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 976
# Generation with parameters (2.491405459215272e+33, 1.7297071272751767e+33, 0.0, 0.0, -0.6378627619391506, 0.0, 0.0, -0.5979709838216708, 3.085677581491367e+24, 1.4173711317382987, 4.756399554873044, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.491405459215272e+33, 1.7297071272751767e+33, 0.0, 0.0, -0.6378627619391506, 0.0, 0.0, -0.5979709838216708, 3.085677581491367e+24, 1.4173711317382987, 4.756399554873044, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 977
# Generation with parameters (5.0995336246118214e+33, 1.0515868933733931e+33, 0.0, 0.0, -0.012922365959213002, 0.0, 0.0, -0.03403162422713874, 3.085677581491367e+24, 2.4216816093928824, 1.5257668835086853, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.0995336246118214e+33, 1.0515868933733931e+33, 0.0, 0.0, -0.012922365959213002, 0.0, 0.0, -0.03403162422713874, 3.085677581491367e+24, 2.4216816093928824, 1.5257668835086853, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 978
# Generation with parameters (2.2814151189032575e+33, 8.356436073348799e+32, 0.0, 0.0, 0.11672719914824294, 0.0, 0.0, -0.1937418393374097, 3.085677581491367e+24, 2.1073951678357403, 3.033364853866441, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.2814151189032575e+33, 8.356436073348799e+32, 0.0, 0.0, 0.11672719914824294, 0.0, 0.0, -0.1937418393374097, 3.085677581491367e+24, 2.1073951678357403, 3.033364853866441, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 979
# Generation with parameters (4.2315608148749635e+33, 1.0610638374463596e+33, 0.0, 0.0, 0.04746750713102698, 0.0, 0.0, -0.16266777765443258, 3.085677581491367e+24, 1.1091097482228498, 2.4908812161113794, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.2315608148749635e+33, 1.0610638374463596e+33, 0.0, 0.0, 0.04746750713102698, 0.0, 0.0, -0.16266777765443258, 3.085677581491367e+24, 1.1091097482228498, 2.4908812161113794, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 980
# Generation with parameters (4.2767459604448745e+33, 1.2884019223717592e+33, 0.0, 0.0, 0.16994130217194772, 0.0, 0.0, 0.32313361022946907, 3.085677581491367e+24, 0.5983969065692378, 5.907203056457628, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.2767459604448745e+33, 1.2884019223717592e+33, 0.0, 0.0, 0.16994130217194772, 0.0, 0.0, 0.32313361022946907, 3.085677581491367e+24, 0.5983969065692378, 5.907203056457628, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 981
# Generation with parameters (3.6173115146175833e+33, 8.617311499793857e+32, 0.0, 0.0, 0.23314585561995024, 0.0, 0.0, -0.25666868417904876, 3.085677581491367e+24, 2.306892776151657, 2.7264165894773593, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.6173115146175833e+33, 8.617311499793857e+32, 0.0, 0.0, 0.23314585561995024, 0.0, 0.0, -0.25666868417904876, 3.085677581491367e+24, 2.306892776151657, 2.7264165894773593, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 982
# Generation with parameters (1.934360402301308e+33, 5.280343517560842e+32, 0.0, 0.0, -0.3076422441335189, 0.0, 0.0, 0.7250770492726943, 3.085677581491367e+24, 1.7831495009962215, 1.3162541339619247, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.934360402301308e+33, 5.280343517560842e+32, 0.0, 0.0, -0.3076422441335189, 0.0, 0.0, 0.7250770492726943, 3.085677581491367e+24, 1.7831495009962215, 1.3162541339619247, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 983
# Generation with parameters (4.103369275186816e+33, 8.88025502480962e+32, 0.0, 0.0, -0.5288156905558321, 0.0, 0.0, 0.5474403381313393, 3.085677581491367e+24, 1.3550421376354465, 3.762181706982421, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.103369275186816e+33, 8.88025502480962e+32, 0.0, 0.0, -0.5288156905558321, 0.0, 0.0, 0.5474403381313393, 3.085677581491367e+24, 1.3550421376354465, 3.762181706982421, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 984
# Generation with parameters (4.5152025904436314e+33, 6.858147783081868e+32, 0.0, 0.0, 0.29173696736600535, 0.0, 0.0, 0.3390877593051824, 3.085677581491367e+24, 1.3585675827904178, 4.690285856803245, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.5152025904436314e+33, 6.858147783081868e+32, 0.0, 0.0, 0.29173696736600535, 0.0, 0.0, 0.3390877593051824, 3.085677581491367e+24, 1.3585675827904178, 4.690285856803245, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 985
# Generation with parameters (3.623550841607169e+33, 7.86898728251786e+32, 0.0, 0.0, -0.32408126919840385, 0.0, 0.0, 0.19342022327326297, 3.085677581491367e+24, 1.4805287983889794, 1.2574736987242374, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.623550841607169e+33, 7.86898728251786e+32, 0.0, 0.0, -0.32408126919840385, 0.0, 0.0, 0.19342022327326297, 3.085677581491367e+24, 1.4805287983889794, 1.2574736987242374, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 986
# Generation with parameters (4.868005282186438e+33, 1.0911031206704086e+33, 0.0, 0.0, -0.34017946317824266, 0.0, 0.0, -0.0014635871917835555, 3.085677581491367e+24, 0.7203383021189509, 4.961837257936599, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.868005282186438e+33, 1.0911031206704086e+33, 0.0, 0.0, -0.34017946317824266, 0.0, 0.0, -0.0014635871917835555, 3.085677581491367e+24, 0.7203383021189509, 4.961837257936599, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 987
# Generation with parameters (4.267564715368626e+33, 1.2860968044459259e+33, 0.0, 0.0, 0.11124218141163837, 0.0, 0.0, -0.1275630580555072, 3.085677581491367e+24, 1.017729751247191, 3.3863364000244336, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.267564715368626e+33, 1.2860968044459259e+33, 0.0, 0.0, 0.11124218141163837, 0.0, 0.0, -0.1275630580555072, 3.085677581491367e+24, 1.017729751247191, 3.3863364000244336, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 988
# Generation with parameters (4.173023856956907e+33, 7.275087138719007e+32, 0.0, 0.0, 0.18006774811225795, 0.0, 0.0, -0.056692876421160214, 3.085677581491367e+24, 2.0434145849425485, 5.971450663383446, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.173023856956907e+33, 7.275087138719007e+32, 0.0, 0.0, 0.18006774811225795, 0.0, 0.0, -0.056692876421160214, 3.085677581491367e+24, 2.0434145849425485, 5.971450663383446, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 989
# Generation with parameters (1.549130958397652e+33, 2.6634394856244388e+32, 0.0, 0.0, 0.1426262233864329, 0.0, 0.0, 0.04896107758240607, 3.085677581491367e+24, 0.5310196556911527, 0.5451712102395176, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.549130958397652e+33, 2.6634394856244388e+32, 0.0, 0.0, 0.1426262233864329, 0.0, 0.0, 0.04896107758240607, 3.085677581491367e+24, 0.5310196556911527, 0.5451712102395176, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 990
# Generation with parameters (5.909281896403762e+33, 7.769286648007753e+32, 0.0, 0.0, 0.18462067287567135, 0.0, 0.0, 0.14815027059867433, 3.085677581491367e+24, 0.8523002380927093, 1.8674725239829488, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.909281896403762e+33, 7.769286648007753e+32, 0.0, 0.0, 0.18462067287567135, 0.0, 0.0, 0.14815027059867433, 3.085677581491367e+24, 0.8523002380927093, 1.8674725239829488, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 991
# Generation with parameters (5.644692401054023e+33, 7.43753780854463e+32, 0.0, 0.0, 0.3151354373842644, 0.0, 0.0, -0.3142460577956865, 3.085677581491367e+24, 1.3567472481535239, 3.433300941572271, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.644692401054023e+33, 7.43753780854463e+32, 0.0, 0.0, 0.3151354373842644, 0.0, 0.0, -0.3142460577956865, 3.085677581491367e+24, 1.3567472481535239, 3.433300941572271, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 992
# Generation with parameters (2.771516602460476e+33, 5.918561586025465e+32, 0.0, 0.0, 0.00019071929550504996, 0.0, 0.0, 0.36218724162570076, 3.085677581491367e+24, 1.185683939491169, 1.416063356556863, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.771516602460476e+33, 5.918561586025465e+32, 0.0, 0.0, 0.00019071929550504996, 0.0, 0.0, 0.36218724162570076, 3.085677581491367e+24, 1.185683939491169, 1.416063356556863, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 993
# Generation with parameters (3.356593504263089e+33, 8.420852738415587e+32, 0.0, 0.0, 0.4359837407269342, 0.0, 0.0, 0.0673541304010597, 3.085677581491367e+24, 1.850227188070104, 0.3768858315370692, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.356593504263089e+33, 8.420852738415587e+32, 0.0, 0.0, 0.4359837407269342, 0.0, 0.0, 0.0673541304010597, 3.085677581491367e+24, 1.850227188070104, 0.3768858315370692, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 994
# Generation with parameters (4.9937252016961584e+33, 9.638350947659537e+32, 0.0, 0.0, 0.001107009699194314, 0.0, 0.0, -0.16213054316315695, 3.085677581491367e+24, 1.1571735825319598, 0.564139854982891, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.9937252016961584e+33, 9.638350947659537e+32, 0.0, 0.0, 0.001107009699194314, 0.0, 0.0, -0.16213054316315695, 3.085677581491367e+24, 1.1571735825319598, 0.564139854982891, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 995
# Generation with parameters (4.567160196827627e+33, 1.0624152801349897e+33, 0.0, 0.0, 0.012868993888377445, 0.0, 0.0, 0.1219916671599814, 3.085677581491367e+24, 1.7293782539018243, 3.7697388461446604, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (4.567160196827627e+33, 1.0624152801349897e+33, 0.0, 0.0, 0.012868993888377445, 0.0, 0.0, 0.1219916671599814, 3.085677581491367e+24, 1.7293782539018243, 3.7697388461446604, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 996
# Generation with parameters (2.7312149750810877e+33, 1.1239485541224866e+33, 0.0, 0.0, -0.1380786952812096, 0.0, 0.0, -0.31106104818144, 3.085677581491367e+24, 2.1841510166770073, 1.779602302171602, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.7312149750810877e+33, 1.1239485541224866e+33, 0.0, 0.0, -0.1380786952812096, 0.0, 0.0, -0.31106104818144, 3.085677581491367e+24, 2.1841510166770073, 1.779602302171602, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 997
# Running injection 998
# Generation with parameters (3.192641913190964e+33, 1.6568012787967398e+33, 0.0, 0.0, -0.7663797090520695, 0.0, 0.0, -0.2688349734061426, 3.085677581491367e+24, 1.882925992692409, 4.146109359700276, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (3.192641913190964e+33, 1.6568012787967398e+33, 0.0, 0.0, -0.7663797090520695, 0.0, 0.0, -0.2688349734061426, 3.085677581491367e+24, 1.882925992692409, 4.146109359700276, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 999
# Generation with parameters (1.6429192452617613e+33, 1.0122096867737942e+33, 0.0, 0.0, -0.7071369257766696, 0.0, 0.0, -0.04670621548919027, 3.085677581491367e+24, 0.7326822135256852, 2.813821212079879, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6429192452617613e+33, 1.0122096867737942e+33, 0.0, 0.0, -0.7071369257766696, 0.0, 0.0, -0.04670621548919027, 3.085677581491367e+24, 0.7326822135256852, 2.813821212079879, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.

# %% [markdown]
# ## Infere parameters

# %%
# %%capture  
#avoids printing a lot of output to the notebook
import pandas as pd
from dingo.gw.inference.gw_samplers import GWSampler




os.makedirs(f"/scratch/tpausch/test_data/{name}/results", exist_ok=True)

injection_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/injections"))

for fname in injection_files:

    # --------------------------------------------------------
    # Load injection
    # --------------------------------------------------------

    with open(f"/scratch/tpausch/test_data/{name}/injections/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    strain_data = payload["strain_data"]

    # --------------------------------------------------------
    # Run sampler
    # --------------------------------------------------------

    sampler = GWSampler(model=main_pm)

    sampler.context = strain_data

    sampler.run_sampler(
        num_samples=50_000,
        batch_size=10_000,
    )

    result = sampler.to_result()



    # --------------------------------------------------------
    # calculate network SNR
    # --------------------------------------------------------
    parameters = pd.DataFrame(
        {key: np.array([np.asarray(val).item()]) for key, val in theta_true.items()}
    )
    snr_df = gw.utilities.get_snr(parameters, network, waveform_model, f_ref)
    network_snr = float(snr_df["network"].iloc[0])  # extract as plain float

    # --------------------------------------------------------
    # Store result
    # --------------------------------------------------------

    result_payload = {
        "theta_true": theta_true,
        "result": result,
        "network_snr": network_snr,
    }

    outname = fname.replace("inj_", "result_")

    with open(f"/scratch/tpausch/test_data/{name}/results/{outname}", "wb") as f:
        pickle.dump(result_payload, f)

    print(f"Saved /scratch/tpausch/test_data/{name}/results/{outname}")

# %% [markdown]
# ## Calculate and plot chirp mass inference error

# %%
true_cm = []
true_mr = []
mass_ratio_error = []
mass_ratio_std = []
chirp_mass_error = []
chirp_mass_std = []


result_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/{name}/results/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    result = payload["result"]

    posterior_samples = result.samples

    #q_samples = np.array(posterior_samples["mass_ratio"])

    # inference statistics
    #q_mean = np.mean(q_samples)
    #q_std = np.std(q_samples)
#
    #true_q = theta_true["mass_ratio"]

    cm_samples = np.array(posterior_samples["chirp_mass"])

    cm_mean = np.mean(cm_samples)
    cm_std = np.std(cm_samples)

    true_mr.append(theta_true["mass_ratio"])
    true_cm.append(theta_true["chirp_mass"])
    #mass_ratio_error.append(q_mean - true_q)
    #mass_ratio_std.append(q_std)
    chirp_mass_error.append(cm_mean - theta_true["chirp_mass"])
    chirp_mass_std.append(cm_std)


true_mr = np.array(true_mr)
true_cm = np.array(true_cm)

# ------------------------------------------------------------
# Error bars
# ------------------------------------------------------------

#plt.errorbar(
#    true_cm,
#    chirp_mass_error,
#    yerr=chirp_mass_std,
#    fmt="none",
#    capsize=4,
#    alpha=0.5,
#    color="gray",
#)

# ------------------------------------------------------------
# Colored scatter points
# ------------------------------------------------------------

sc = plt.scatter(
    true_cm,
    chirp_mass_error,
    s=20,
    edgecolor="black",
    alpha=0.3
)

# ------------------------------------------------------------
# Reference line
# ------------------------------------------------------------

plt.axhline(0, linestyle="--", color="black")


# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel("True chirp mass")
plt.ylabel("Chirp mass inference error (inferred − true)")

plt.title("Chirp-mass inference error")

plt.grid(True)

plt.tight_layout()
plt.show()

cm_err = np.asarray(chirp_mass_error)

mean_error = np.mean(cm_err)          # signed average bias (over/under-estimation)
mean_abs_error = np.mean(np.abs(cm_err))  # average magnitude of deviation
rms_error = np.sqrt(np.mean(cm_err**2))   # RMS deviation, penalizes outliers more
std_error = np.std(cm_err)            # spread of the errors around their mean
p90_abs_error = np.percentile(np.abs(cm_err), 90)
p99_abs_error = np.percentile(np.abs(cm_err), 99)


print(f"Mean error (bias):      {mean_error:.3f}")
print(f"Mean absolute error:    {mean_abs_error:.3f}")
print(f"RMS error:              {rms_error:.3f}")
print(f"Std of error:           {std_error:.3f}")
print(f"90th percentile |error|: {p90_abs_error:.3f}")
print(f"99th percentile |error|: {p99_abs_error:.3f}")
# Out:
# Mean error (bias):      -4.000
# Mean absolute error:    37.649
# RMS error:              69.861
# Std of error:           69.746
# 90th percentile |error|: 98.623
# 99th percentile |error|: 275.785

# %% [markdown]
# ## PP-plot

# %%
pp_values_chirp_mass = []
pp_values_mass_ratio = []

result_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/{name}/results/{fname}", "rb") as f:

        payload = pickle.load(f)

        theta_true = payload["theta_true"]
        result = payload["result"]

        posterior_samples = result.samples


        # ============================================================
        # Chirp mass PP value
        # ============================================================

        cm_samples = posterior_samples["chirp_mass"]

        pp_cm = np.mean(
            cm_samples < theta_true["chirp_mass"]
        )

        pp_values_chirp_mass.append(pp_cm)


        # ============================================================
        # Mass ratio PP value
        # ============================================================

        #q_samples = posterior_samples["mass_ratio"]
#
        #pp_q = np.mean(
        #    q_samples < theta_true["mass_ratio"]
        #)
#
        #pp_values_mass_ratio.append(pp_q)




def plot_pp(pp_values, label):

    pp_values = np.array(pp_values)

    sorted_pp = np.sort(pp_values)

    n = len(sorted_pp)

    empirical_cdf = np.arange(1, n + 1) / n

    x = np.linspace(0, 1, 200)

    sigma = np.sqrt(x * (1 - x) / n)

    plt.figure(figsize=(6, 6))

    # Ideal calibration
    plt.plot(
        [0, 1],
        [0, 1],
        linestyle="--",
        label="Ideal calibration",
    )


    # Empirical PP curve
    plt.plot(
        sorted_pp,
        empirical_cdf,
        marker="o",
        label=label,
    )

    plt.xlabel("Credible level")
    plt.ylabel("Fraction of injections")

    plt.title(f"PP Plot: {label}")

    plt.xlim(0, 1)
    plt.ylim(0, 1)

    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()


plot_pp(
    pp_values_chirp_mass,
    "chirp_mass",
)

#plot_pp(
#    pp_values_mass_ratio,
#    "mass_ratio",
#)

# %% [markdown]
# ## SNR analysis

# %%
snrs = []
ci90_widths = []
chirp_masses = []

result_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/{name}/results/{fname}", "rb") as f:

        payload = pickle.load(f)
    
    theta_true = payload["theta_true"]
    result = payload["result"]


    snr = payload["network_snr"]   # use "ET" instead if you want the single-detector value
   

    snrs.append(snr)

    samples = result.samples["chirp_mass"].to_numpy()  # adjust if result.samples is a DataFrame

    ci90 = np.percentile(samples, 95) - np.percentile(samples, 5)
    ci90_widths.append(ci90)
    chirp_masses.append(theta_true["chirp_mass"])

snrs = np.array(snrs)
ci90_widths = np.array(ci90_widths)
chirp_masses = np.array(chirp_masses)

frac_widths = ci90_widths / chirp_masses  # relative width, dimensionless

plt.figure(figsize=(6, 5))
sc = plt.scatter(snrs, ci90_widths, c=chirp_masses, cmap="viridis", alpha=0.6, s=15)
#sc = plt.scatter(snrs, frac_widths, c=chirp_masses, cmap="viridis", alpha=0.6, s=15)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Network SNR")
plt.ylabel("Chirp mass 90% CI width")
plt.colorbar(sc, label="Injected chirp mass [M$_\\odot$]")
plt.title("posterior width vs SNR")
plt.grid(True, which="both", alpha=0.3)
plt.tight_layout()
plt.show()


chirp_mass_error = np.array(chirp_mass_error)
mask = snrs < 100.0

plt.figure(figsize=(10, 5))
sc = plt.scatter(
    snrs[mask],
    chirp_mass_error[mask],
    s=10,
    edgecolor="black",
    alpha=0.3
)

plt.axhline(0, linestyle="--", color="black")
plt.xlabel("SNR")
plt.ylabel("Chirp mass inference error (inferred − true)")
plt.title("Chirp-mass inference error")
plt.grid(True)
plt.tight_layout()
plt.show()




# --- Plot distribution ---
plt.figure(figsize=(6, 5))

# Histogram, normalized to a density so it represents "how likely each value is"
counts, bins, _ = plt.hist(
    snrs, bins=100, density=True, alpha=0.5, color="steelblue", edgecolor="k", label="Histogram"
)
plt.xlabel("Network SNR")
plt.ylabel("Probability density")
plt.title(f"Distribution of injected network SNR (n={len(snrs)})")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()


print(f"SNR stats: min={snrs.min():.2f}, max={snrs.max():.2f}, "
      f"median={np.median(snrs):.2f}, mean={snrs.mean():.2f}",
      f"snr99={np.percentile(np.abs(snrs), 99):.2f}")
# Out:
# SNR stats: min=0.23, max=4798.27, median=122.72, mean=292.31 snr99=1955.50
