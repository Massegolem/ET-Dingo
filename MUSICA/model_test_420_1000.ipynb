# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
import GWFish.modules as gw


os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # use GPU 1

name="170_420"

waveform_model = 'IMRPhenomXPHM'
f_ref = 20.
detectors = ['ET']
network = gw.detection.Network(detector_ids = detectors, detection_SNR = (0., 8.))
# Out:
# /home/tpausch/.conda/envs/ET-DINGO/lib/python3.10/site-packages/lalsimulation/_lalsimulation_swig.py:8: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   import lal

# %% [markdown]
# ## Load Model

# %%
from dingo.core.posterior_models.build_model import build_model_from_kwargs
main_pm = build_model_from_kwargs(
    filename=f"/scratch/tpausch/models/{name}/model_100.pt",
    device="cuda",
    load_training_info=False,
)
# Out:
# ========
# WARNING!
#
# This object was created using Dingo version 0.1.dev1230+gc9da5d765 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
# Putting posterior model to device cuda.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt(f"/scratch/tpausch/models/{name}/history.txt")
epochs   = data[:, 0]
train    = data[:, 1]
val      = data[:, 2]


plt.figure(figsize=(8, 5))
plt.plot(epochs, train, label="Train loss")
plt.plot(epochs, val,   label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("Log-likelihood")
plt.legend()
plt.title("Dingo training history")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 4 data = np.loadtxt(f"/scratch/tpausch/models/{name}/history.txt")
#       5 epochs   = data[:, 0]
#       6 train    = data[:, 1]
#
# File ~/.conda/envs/ET-DINGO/lib/python3.10/site-packages/numpy/lib/npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# File ~/.conda/envs/ET-DINGO/lib/python3.10/site-packages/numpy/lib/npyio.py:992, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     990     fname = os.fspath(fname)
#     991 if isinstance(fname, str):
# --> 992     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     993     if encoding is None:
#     994         encoding = getattr(fh, 'encoding', 'latin1')
#
# File ~/.conda/envs/ET-DINGO/lib/python3.10/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/.conda/envs/ET-DINGO/lib/python3.10/site-packages/numpy/lib/_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: /scratch/tpausch/models/170_420/history.txt not found.

# %% [markdown]
# ## Simulate injections

# %%
import dingo.gw.injection as injection
from dingo.gw.noise.asd_dataset import ASDDataset

# ============================================================
# Setup
# ============================================================

num_injections = 1000
out_dir = f"/scratch/tpausch/test_data/{name}/injections"
os.makedirs(out_dir, exist_ok=True)

np.random.seed(42)  # optional, for reproducibility

injection_generator = injection.Injection.from_posterior_model_metadata(
    main_pm.metadata
)

asd_fname = main_pm.metadata["train_settings"]["training"]["stage_0"]["asd_dataset_path"]
asd_dataset = ASDDataset(file_name=asd_fname)

injection_generator.asd = {
    k: v[0] for k, v in asd_dataset.asds.items()
}

# This is the combined intrinsic + extrinsic bilby PriorDict
# that the network was trained on
prior = injection_generator.prior
print(prior)

# ============================================================
# Draw and run injections
# ============================================================

for idx in range(num_injections):

    print(f"Running injection {idx}")

    theta = prior.sample()
    theta = {k: float(v) for k, v in theta.items()}  # cast numpy -> float

    strain_data = injection_generator.injection(theta)

    payload = {
        "theta_true": theta,
        "strain_data": strain_data,
    }

    fname = os.path.join(out_dir, f"inj_{idx:04d}.pkl")

    with open(fname, "wb") as f:
        pickle.dump(payload, f)
# Out:
# Setting spin_conversion_phase = 0.0. Using this value for the phase parameter for conversion to cartesian spins.
# Loading dataset from training_data/asds_ET_T8.hdf5.
# {'mass_1': Constraint(minimum=50.0, maximum=1700.0, name='mass_1', latex_label='$m_1$', unit=None), 'mass_2': Constraint(minimum=50.0, maximum=1700.0, name='mass_2', latex_label='$m_2$', unit=None), 'chirp_mass': bilby.gw.prior.UniformInComponentsChirpMass(minimum=170.0, maximum=420.0, name='chirp_mass', latex_label='$\\mathcal{M}$', unit=None, boundary=None), 'mass_ratio': bilby.gw.prior.UniformInComponentsMassRatio(minimum=0.125, maximum=1.0, name='mass_ratio', latex_label='$q$', unit=None, boundary=None, equal_mass=False), 'phase': Uniform(minimum=0.0, maximum=6.283185307179586, name='phase', latex_label='$\\phi$', unit=None, boundary='periodic'), 'chi_1': bilby.gw.prior.AlignedSpin(a_prior=Uniform(minimum=0, maximum=0.9, name=None, latex_label=None, unit=None, boundary=None), z_prior=Uniform(minimum=-1, maximum=1, name=None, latex_label=None, unit=None, boundary=None), name='chi_1', latex_label='$\\chi_1$', unit=None, boundary=None, minimum=-0.9, maximum=0.9, num_interp=100000), 'chi_2': bilby.gw.prior.AlignedSpin(a_prior=Uniform(minimum=0, maximum=0.9, name=None, latex_label=None, unit=None, boundary=None), z_prior=Uniform(minimum=-1, maximum=1, name=None, latex_label=None, unit=None, boundary=None), name='chi_2', latex_label='$\\chi_2$', unit=None, boundary=None, minimum=-0.9, maximum=0.9, num_interp=100000), 'theta_jn': Sine(minimum=0.0, maximum=3.141592653589793, name='theta_jn', latex_label='$\\theta_{JN}$', unit=None, boundary=None), 'luminosity_distance': LogUniform(minimum=1000.0, maximum=100000.0, name='luminosity_distance', latex_label='$d_L$', unit=None, boundary=None), 'geocent_time': Uniform(minimum=-0.1, maximum=0.1, name='geocent_time', latex_label='$t_c$', unit=None, boundary=None), 'dec': Cosine(minimum=-1.5707963267948966, maximum=1.5707963267948966, name='dec', latex_label='$\\mathrm{DEC}$', unit=None, boundary=None), 'ra': Uniform(minimum=0.0, maximum=6.283185307179586, name='ra', latex_label='$\\mathrm{RA}$', unit=None, boundary='periodic'), 'psi': Uniform(minimum=0.0, maximum=3.141592653589793, name='psi', latex_label='$\\psi$', unit=None, boundary='periodic')}
# Running injection 0
# Generation with parameters (1.472101463097507e+33, 5.561159191282206e+32, 0.0, 0.0, 0.12403495504202253, 0.0, 0.0, -0.61039717123613, 3.085677581491367e+24, 0.3461036304617448, 3.171447039210956, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.472101463097507e+33, 5.561159191282206e+32, 0.0, 0.0, 0.12403495504202253, 0.0, 0.0, -0.61039717123613, 3.085677581491367e+24, 0.3461036304617448, 3.171447039210956, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 1
# Running injection 2
# Generation with parameters (1.479352507432719e+33, 5.1600264195240755e+32, 0.0, 0.0, 0.22513307727535037, 0.0, 0.0, 0.08517297481756152, 3.085677581491367e+24, 2.1041476559515857, 5.442994816781839, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.479352507432719e+33, 5.1600264195240755e+32, 0.0, 0.0, 0.22513307727535037, 0.0, 0.0, 0.08517297481756152, 3.085677581491367e+24, 2.1041476559515857, 5.442994816781839, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 3
# Generation with parameters (1.6787641934167353e+33, 3.0084184905709546e+32, 0.0, 0.0, -0.1425526163057811, 0.0, 0.0, 0.001622410202874808, 3.085677581491367e+24, 1.1418469226444863, 2.1993395814688914, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6787641934167353e+33, 3.0084184905709546e+32, 0.0, 0.0, -0.1425526163057811, 0.0, 0.0, 0.001622410202874808, 3.085677581491367e+24, 1.1418469226444863, 2.1993395814688914, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 4
# Generation with parameters (1.2864916430151603e+33, 6.739251056919051e+32, 0.0, 0.0, -0.0016210443305385526, 0.0, 0.0, 0.4776999707376392, 3.085677581491367e+24, 0.8016228650810496, 1.1139794496865314, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2864916430151603e+33, 6.739251056919051e+32, 0.0, 0.0, -0.0016210443305385526, 0.0, 0.0, 0.4776999707376392, 3.085677581491367e+24, 0.8016228650810496, 1.1139794496865314, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 5
# Generation with parameters (1.1134820882662714e+33, 5.919186894144507e+32, 0.0, 0.0, 0.08146238988439705, 0.0, 0.0, -0.034394001105835154, 3.085677581491367e+24, 1.2131200679397844, 2.8909682744617347, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1134820882662714e+33, 5.919186894144507e+32, 0.0, 0.0, 0.08146238988439705, 0.0, 0.0, -0.034394001105835154, 3.085677581491367e+24, 1.2131200679397844, 2.8909682744617347, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 6
# Generation with parameters (1.8467458286530818e+33, 2.6806859344129617e+32, 0.0, 0.0, -0.0005052107805479216, 0.0, 0.0, 0.09477099972364876, 3.085677581491367e+24, 2.485627924856685, 4.510937674178626, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8467458286530818e+33, 2.6806859344129617e+32, 0.0, 0.0, -0.0005052107805479216, 0.0, 0.0, 0.09477099972364876, 3.085677581491367e+24, 2.485627924856685, 4.510937674178626, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 7
# Generation with parameters (9.943305698919475e+32, 8.675651517487199e+32, 0.0, 0.0, -0.189604619726231, 0.0, 0.0, -0.11708677052775401, 3.085677581491367e+24, 1.9806255472052154, 0.7833769387454869, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.943305698919475e+32, 8.675651517487199e+32, 0.0, 0.0, -0.189604619726231, 0.0, 0.0, -0.11708677052775401, 3.085677581491367e+24, 1.9806255472052154, 0.7833769387454869, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 8
# Generation with parameters (2.289341693872386e+33, 3.309325826307129e+32, 0.0, 0.0, 0.5967859197776849, 0.0, 0.0, -0.26975406534884444, 3.085677581491367e+24, 1.3919973476586367, 3.250484232840472, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.289341693872386e+33, 3.309325826307129e+32, 0.0, 0.0, 0.5967859197776849, 0.0, 0.0, -0.26975406534884444, 3.085677581491367e+24, 1.3919973476586367, 3.250484232840472, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 9
# Generation with parameters (6.71647534061313e+32, 6.470460556918579e+32, 0.0, 0.0, 0.6771858054314671, 0.0, 0.0, -0.10718819381040853, 3.085677581491367e+24, 0.5822263320409518, 2.525979446166014, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (6.71647534061313e+32, 6.470460556918579e+32, 0.0, 0.0, 0.6771858054314671, 0.0, 0.0, -0.10718819381040853, 3.085677581491367e+24, 0.5822263320409518, 2.525979446166014, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 10
# Generation with parameters (1.0964648772539748e+33, 6.072342910968092e+32, 0.0, 0.0, 0.1822609958103896, 0.0, 0.0, -0.04377263903984994, 3.085677581491367e+24, 1.3202996710313233, 3.574753871239691, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0964648772539748e+33, 6.072342910968092e+32, 0.0, 0.0, 0.1822609958103896, 0.0, 0.0, -0.04377263903984994, 3.085677581491367e+24, 1.3202996710313233, 3.574753871239691, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 11
# Generation with parameters (1.1201101101828423e+33, 2.3247461161360002e+32, 0.0, 0.0, 0.4681962232408056, 0.0, 0.0, 0.15392292917685804, 3.085677581491367e+24, 2.1678770720280327, 1.68905131030608, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1201101101828423e+33, 2.3247461161360002e+32, 0.0, 0.0, 0.4681962232408056, 0.0, 0.0, 0.15392292917685804, 3.085677581491367e+24, 2.1678770720280327, 1.68905131030608, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 12
# Generation with parameters (1.9547128850823568e+33, 4.6183761885140915e+32, 0.0, 0.0, 0.10199305633524475, 0.0, 0.0, 0.3277722260673244, 3.085677581491367e+24, 0.6141258352496864, 1.8194044507708749, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.9547128850823568e+33, 4.6183761885140915e+32, 0.0, 0.0, 0.10199305633524475, 0.0, 0.0, 0.3277722260673244, 3.085677581491367e+24, 0.6141258352496864, 1.8194044507708749, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 13
# Running injection 14
# Generation with parameters (1.732323260160656e+33, 5.621939308748405e+32, 0.0, 0.0, 0.13489309193503346, 0.0, 0.0, 0.3523099629740724, 3.085677581491367e+24, 2.5823658762018216, 3.4104941550809382, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.732323260160656e+33, 5.621939308748405e+32, 0.0, 0.0, 0.13489309193503346, 0.0, 0.0, 0.3523099629740724, 3.085677581491367e+24, 2.5823658762018216, 3.4104941550809382, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 15
# Running injection 16
# Generation with parameters (1.4989529982600443e+33, 5.826002879334152e+32, 0.0, 0.0, -0.6328352629900664, 0.0, 0.0, 0.0037261726790546908, 3.085677581491367e+24, 1.8706263393659972, 4.53245013598786, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4989529982600443e+33, 5.826002879334152e+32, 0.0, 0.0, -0.6328352629900664, 0.0, 0.0, 0.0037261726790546908, 3.085677581491367e+24, 1.8706263393659972, 4.53245013598786, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 17
# Generation with parameters (9.05098869206702e+32, 5.7245883323988894e+32, 0.0, 0.0, 0.37199292354145336, 0.0, 0.0, -0.08492327661737319, 3.085677581491367e+24, 2.510342227085131, 1.2918342820792295, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.05098869206702e+32, 5.7245883323988894e+32, 0.0, 0.0, 0.37199292354145336, 0.0, 0.0, -0.08492327661737319, 3.085677581491367e+24, 2.510342227085131, 1.2918342820792295, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 18
# Running injection 19
# Generation with parameters (9.31305701153374e+32, 8.736875960695543e+32, 0.0, 0.0, 0.03658077194838403, 0.0, 0.0, 0.07604714432321785, 3.085677581491367e+24, 0.7960504769263745, 0.9619202380354662, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.31305701153374e+32, 8.736875960695543e+32, 0.0, 0.0, 0.03658077194838403, 0.0, 0.0, 0.07604714432321785, 3.085677581491367e+24, 0.7960504769263745, 0.9619202380354662, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 20
# Generation with parameters (1.6738395058378807e+33, 3.606685504636023e+32, 0.0, 0.0, 0.252426307580193, 0.0, 0.0, -0.34149849624738693, 3.085677581491367e+24, 1.1935982453170044, 4.45477020059737, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6738395058378807e+33, 3.606685504636023e+32, 0.0, 0.0, 0.252426307580193, 0.0, 0.0, -0.34149849624738693, 3.085677581491367e+24, 1.1935982453170044, 4.45477020059737, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 21
# Generation with parameters (8.662582457696249e+32, 7.551275924560348e+32, 0.0, 0.0, 0.0809464594852981, 0.0, 0.0, 0.1677441636450661, 3.085677581491367e+24, 2.7537890134943743, 3.609573773131682, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.662582457696249e+32, 7.551275924560348e+32, 0.0, 0.0, 0.0809464594852981, 0.0, 0.0, 0.1677441636450661, 3.085677581491367e+24, 2.7537890134943743, 3.609573773131682, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 22
# Running injection 23
# Generation with parameters (1.5545062195539527e+33, 4.52002280279427e+32, 0.0, 0.0, 0.030380174190513875, 0.0, 0.0, 0.04660258923331201, 3.085677581491367e+24, 2.0749715486954194, 5.187033302098831, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5545062195539527e+33, 4.52002280279427e+32, 0.0, 0.0, 0.030380174190513875, 0.0, 0.0, 0.04660258923331201, 3.085677581491367e+24, 2.0749715486954194, 5.187033302098831, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 24
# Generation with parameters (1.1215129579366884e+33, 4.727251572217968e+32, 0.0, 0.0, 0.22136163211585605, 0.0, 0.0, -0.06282762138688253, 3.085677581491367e+24, 1.1134265579703515, 0.14840588600944724, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1215129579366884e+33, 4.727251572217968e+32, 0.0, 0.0, 0.22136163211585605, 0.0, 0.0, -0.06282762138688253, 3.085677581491367e+24, 1.1134265579703515, 0.14840588600944724, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 25
# Generation with parameters (1.2626356978024453e+33, 4.871005279465281e+32, 0.0, 0.0, 0.10422833232446697, 0.0, 0.0, 0.1273503303614723, 3.085677581491367e+24, 0.5213254954040483, 2.4974364719016733, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.2626356978024453e+33, 4.871005279465281e+32, 0.0, 0.0, 0.10422833232446697, 0.0, 0.0, 0.1273503303614723, 3.085677581491367e+24, 0.5213254954040483, 2.4974364719016733, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 26
# Running injection 27
# Running injection 28
# Generation with parameters (2.330992268317706e+33, 3.7382305852965354e+32, 0.0, 0.0, 0.007104528855554892, 0.0, 0.0, -0.24207063078263705, 3.085677581491367e+24, 0.46305695529158436, 0.4916554730999248, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.330992268317706e+33, 3.7382305852965354e+32, 0.0, 0.0, 0.007104528855554892, 0.0, 0.0, -0.24207063078263705, 3.085677581491367e+24, 0.46305695529158436, 0.4916554730999248, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 29
# Generation with parameters (1.214580883100343e+33, 6.461724544436066e+32, 0.0, 0.0, -0.212740073027159, 0.0, 0.0, -0.029049199469759156, 3.085677581491367e+24, 1.221806236546304, 3.7162227037391746, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.214580883100343e+33, 6.461724544436066e+32, 0.0, 0.0, -0.212740073027159, 0.0, 0.0, -0.029049199469759156, 3.085677581491367e+24, 1.221806236546304, 3.7162227037391746, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 30
# Generation with parameters (1.756142828555477e+33, 4.024555225897585e+32, 0.0, 0.0, -0.7945617554525662, 0.0, 0.0, -0.11232131231869853, 3.085677581491367e+24, 1.4775909668732046, 2.7523116509510728, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.756142828555477e+33, 4.024555225897585e+32, 0.0, 0.0, -0.7945617554525662, 0.0, 0.0, -0.11232131231869853, 3.085677581491367e+24, 1.4775909668732046, 2.7523116509510728, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 31
# Generation with parameters (1.0668730947731379e+33, 3.347734692883189e+32, 0.0, 0.0, 0.2194229200491349, 0.0, 0.0, -0.08434159927988692, 3.085677581491367e+24, 1.3127114238944348, 4.623986791868033, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0668730947731379e+33, 3.347734692883189e+32, 0.0, 0.0, 0.2194229200491349, 0.0, 0.0, -0.08434159927988692, 3.085677581491367e+24, 1.3127114238944348, 4.623986791868033, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 32
# Generation with parameters (2.596370904163979e+33, 3.441219756174282e+32, 0.0, 0.0, -0.016852569395580927, 0.0, 0.0, 0.6568805960384092, 3.085677581491367e+24, 1.2583436893264526, 4.40403856654733, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.596370904163979e+33, 3.441219756174282e+32, 0.0, 0.0, -0.016852569395580927, 0.0, 0.0, 0.6568805960384092, 3.085677581491367e+24, 1.2583436893264526, 4.40403856654733, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 33
# Generation with parameters (2.3541112507992442e+33, 3.5491271251468696e+32, 0.0, 0.0, 0.10447698105892599, 0.0, 0.0, 0.16896331351813998, 3.085677581491367e+24, 1.578098334831181, 0.8129847632653697, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.3541112507992442e+33, 3.5491271251468696e+32, 0.0, 0.0, 0.10447698105892599, 0.0, 0.0, 0.16896331351813998, 3.085677581491367e+24, 1.578098334831181, 0.8129847632653697, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 34
# Generation with parameters (9.383917672557867e+32, 4.5248945277254706e+32, 0.0, 0.0, 0.5184843517613758, 0.0, 0.0, 0.020050649683606377, 3.085677581491367e+24, 1.4421785170810122, 1.577851806128365, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.383917672557867e+32, 4.5248945277254706e+32, 0.0, 0.0, 0.5184843517613758, 0.0, 0.0, 0.020050649683606377, 3.085677581491367e+24, 1.4421785170810122, 1.577851806128365, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 35
# Generation with parameters (8.315674620656088e+32, 4.319190364034279e+32, 0.0, 0.0, -0.14237377122966866, 0.0, 0.0, -0.09884283063202255, 3.085677581491367e+24, 0.45975896190600163, 4.327574639265833, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.315674620656088e+32, 4.319190364034279e+32, 0.0, 0.0, -0.14237377122966866, 0.0, 0.0, -0.09884283063202255, 3.085677581491367e+24, 0.45975896190600163, 4.327574639265833, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 36
# Generation with parameters (2.5961217055624845e+33, 4.095043825048716e+32, 0.0, 0.0, -0.03907370305804919, 0.0, 0.0, -0.18410340395390046, 3.085677581491367e+24, 1.1811280120555778, 2.383044389677556, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5961217055624845e+33, 4.095043825048716e+32, 0.0, 0.0, -0.03907370305804919, 0.0, 0.0, -0.18410340395390046, 3.085677581491367e+24, 1.1811280120555778, 2.383044389677556, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 37
# Generation with parameters (1.452878808692681e+33, 4.149414256735095e+32, 0.0, 0.0, -0.2699199150104314, 0.0, 0.0, 0.02293101660065116, 3.085677581491367e+24, 0.5496362130307919, 0.5507664506139653, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.452878808692681e+33, 4.149414256735095e+32, 0.0, 0.0, -0.2699199150104314, 0.0, 0.0, 0.02293101660065116, 3.085677581491367e+24, 0.5496362130307919, 0.5507664506139653, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 38
# Generation with parameters (2.725631664847577e+33, 3.534377648949493e+32, 0.0, 0.0, -0.0017414693052626882, 0.0, 0.0, 0.33040647566791026, 3.085677581491367e+24, 2.281365476114663, 4.723153511759554, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.725631664847577e+33, 3.534377648949493e+32, 0.0, 0.0, -0.0017414693052626882, 0.0, 0.0, 0.33040647566791026, 3.085677581491367e+24, 2.281365476114663, 4.723153511759554, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 39
# Running injection 40
# Generation with parameters (9.814627818015136e+32, 9.271433305093322e+32, 0.0, 0.0, -0.026021878815625024, 0.0, 0.0, -0.10060897884306673, 3.085677581491367e+24, 2.3639610283211177, 5.717126357927575, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.814627818015136e+32, 9.271433305093322e+32, 0.0, 0.0, -0.026021878815625024, 0.0, 0.0, -0.10060897884306673, 3.085677581491367e+24, 2.3639610283211177, 5.717126357927575, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 41
# Generation with parameters (2.183857883803146e+33, 4.6905616221452096e+32, 0.0, 0.0, -0.24532159475088092, 0.0, 0.0, -0.0613555980946329, 3.085677581491367e+24, 2.488830432529408, 4.332956620141273, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.183857883803146e+33, 4.6905616221452096e+32, 0.0, 0.0, -0.24532159475088092, 0.0, 0.0, -0.0613555980946329, 3.085677581491367e+24, 2.488830432529408, 4.332956620141273, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 42
# Running injection 43
# Generation with parameters (1.0326747478022327e+33, 5.507770588925501e+32, 0.0, 0.0, 0.19047695306934612, 0.0, 0.0, -0.0005706985152575333, 3.085677581491367e+24, 0.35563254706298675, 0.7750869341852369, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0326747478022327e+33, 5.507770588925501e+32, 0.0, 0.0, 0.19047695306934612, 0.0, 0.0, -0.0005706985152575333, 3.085677581491367e+24, 0.35563254706298675, 0.7750869341852369, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 44
# Generation with parameters (1.4691676493281427e+33, 3.0980116869113535e+32, 0.0, 0.0, -0.14435434955537568, 0.0, 0.0, -0.49126583023058285, 3.085677581491367e+24, 0.31883470727792584, 3.479490653087096, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4691676493281427e+33, 3.0980116869113535e+32, 0.0, 0.0, -0.14435434955537568, 0.0, 0.0, -0.49126583023058285, 3.085677581491367e+24, 0.31883470727792584, 3.479490653087096, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 45
# Generation with parameters (2.459306486286604e+33, 3.8449914826084486e+32, 0.0, 0.0, -0.46594526527324814, 0.0, 0.0, -0.2838617654871591, 3.085677581491367e+24, 2.5708447100301717, 6.199960112859842, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.459306486286604e+33, 3.8449914826084486e+32, 0.0, 0.0, -0.46594526527324814, 0.0, 0.0, -0.2838617654871591, 3.085677581491367e+24, 2.5708447100301717, 6.199960112859842, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 46
# Generation with parameters (1.6738762309624725e+33, 2.3402609486770433e+32, 0.0, 0.0, -0.020878749288844364, 0.0, 0.0, -0.5527105713471682, 3.085677581491367e+24, 0.8479993253383089, 6.1542969835360095, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.6738762309624725e+33, 2.3402609486770433e+32, 0.0, 0.0, -0.020878749288844364, 0.0, 0.0, -0.5527105713471682, 3.085677581491367e+24, 0.8479993253383089, 6.1542969835360095, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 47
# Running injection 48
# Generation with parameters (1.7028554958870754e+33, 5.414444428662917e+32, 0.0, 0.0, 0.047901091859245896, 0.0, 0.0, 0.3505063307431968, 3.085677581491367e+24, 2.7878384808933068, 4.383031011322213, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7028554958870754e+33, 5.414444428662917e+32, 0.0, 0.0, 0.047901091859245896, 0.0, 0.0, 0.3505063307431968, 3.085677581491367e+24, 2.7878384808933068, 4.383031011322213, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 49
# Generation with parameters (1.404689340273274e+33, 2.2302133121557075e+32, 0.0, 0.0, -0.34241817074952796, 0.0, 0.0, 0.028290891456206946, 3.085677581491367e+24, 0.7900681045382335, 3.6253308720823116, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.404689340273274e+33, 2.2302133121557075e+32, 0.0, 0.0, -0.34241817074952796, 0.0, 0.0, 0.028290891456206946, 3.085677581491367e+24, 0.7900681045382335, 3.6253308720823116, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 50
# Running injection 51
# Generation with parameters (1.4108475907888582e+33, 5.176377496578613e+32, 0.0, 0.0, 0.026719365683513904, 0.0, 0.0, -0.028487424717861594, 3.085677581491367e+24, 2.243125384372816, 5.988341633437312, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4108475907888582e+33, 5.176377496578613e+32, 0.0, 0.0, 0.026719365683513904, 0.0, 0.0, -0.028487424717861594, 3.085677581491367e+24, 2.243125384372816, 5.988341633437312, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 52
# Running injection 53
# Running injection 54
# Running injection 55
# Generation with parameters (1.98007770534918e+33, 4.354661561526616e+32, 0.0, 0.0, -0.12105183530286483, 0.0, 0.0, 0.045790988511504975, 3.085677581491367e+24, 0.3368259410242626, 5.025881123040721, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.98007770534918e+33, 4.354661561526616e+32, 0.0, 0.0, -0.12105183530286483, 0.0, 0.0, 0.045790988511504975, 3.085677581491367e+24, 0.3368259410242626, 5.025881123040721, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 56
# Generation with parameters (1.1755070814545914e+33, 6.679604021830223e+32, 0.0, 0.0, 0.0811736171409486, 0.0, 0.0, 0.46914506423585683, 3.085677581491367e+24, 0.9771408238664603, 3.498535547516693, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1755070814545914e+33, 6.679604021830223e+32, 0.0, 0.0, 0.0811736171409486, 0.0, 0.0, 0.46914506423585683, 3.085677581491367e+24, 0.9771408238664603, 3.498535547516693, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 57
# Running injection 58
# Generation with parameters (1.356034355992828e+33, 6.834119688397537e+32, 0.0, 0.0, 0.29663886009740625, 0.0, 0.0, 0.36313504686178144, 3.085677581491367e+24, 2.5316444466917054, 0.7228185315805695, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.356034355992828e+33, 6.834119688397537e+32, 0.0, 0.0, 0.29663886009740625, 0.0, 0.0, 0.36313504686178144, 3.085677581491367e+24, 2.5316444466917054, 0.7228185315805695, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 59
# Generation with parameters (2.1988779845224573e+33, 4.6277139027292376e+32, 0.0, 0.0, -0.3339512594989912, 0.0, 0.0, 0.025768477654389457, 3.085677581491367e+24, 2.7105549728019787, 5.9971897757547135, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.1988779845224573e+33, 4.6277139027292376e+32, 0.0, 0.0, -0.3339512594989912, 0.0, 0.0, 0.025768477654389457, 3.085677581491367e+24, 2.7105549728019787, 5.9971897757547135, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 60
# Running injection 61
# Generation with parameters (2.0083926626852348e+33, 4.022918691612958e+32, 0.0, 0.0, 0.22624827319021937, 0.0, 0.0, 0.42783822207811006, 3.085677581491367e+24, 1.5260171059500571, 4.3993417200283, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0083926626852348e+33, 4.022918691612958e+32, 0.0, 0.0, 0.22624827319021937, 0.0, 0.0, 0.42783822207811006, 3.085677581491367e+24, 1.5260171059500571, 4.3993417200283, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 62
# Generation with parameters (9.92508310352566e+32, 2.9967619250571927e+32, 0.0, 0.0, 0.0009346154259051917, 0.0, 0.0, -0.7052905680935714, 3.085677581491367e+24, 2.5123383691169696, 1.6255649460250408, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.92508310352566e+32, 2.9967619250571927e+32, 0.0, 0.0, 0.0009346154259051917, 0.0, 0.0, -0.7052905680935714, 3.085677581491367e+24, 2.5123383691169696, 1.6255649460250408, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 63
# Generation with parameters (1.5568210774145367e+33, 5.1598531855082235e+32, 0.0, 0.0, -0.14475651296449116, 0.0, 0.0, 0.48528617028604476, 3.085677581491367e+24, 1.5892461940293099, 4.85649272304304, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5568210774145367e+33, 5.1598531855082235e+32, 0.0, 0.0, -0.14475651296449116, 0.0, 0.0, 0.48528617028604476, 3.085677581491367e+24, 1.5892461940293099, 4.85649272304304, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 64
# Generation with parameters (1.1139035653870928e+33, 7.640409642664803e+32, 0.0, 0.0, 0.3140744237221691, 0.0, 0.0, -0.11711983276773633, 3.085677581491367e+24, 0.3618521522362633, 3.521982352893458, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1139035653870928e+33, 7.640409642664803e+32, 0.0, 0.0, 0.3140744237221691, 0.0, 0.0, -0.11711983276773633, 3.085677581491367e+24, 0.3618521522362633, 3.521982352893458, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 65
# Generation with parameters (1.546817468766998e+33, 4.038000836995816e+32, 0.0, 0.0, -0.13186469354484373, 0.0, 0.0, 0.1032727998366067, 3.085677581491367e+24, 0.9537679688738916, 1.4122975839955771, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.546817468766998e+33, 4.038000836995816e+32, 0.0, 0.0, -0.13186469354484373, 0.0, 0.0, 0.1032727998366067, 3.085677581491367e+24, 0.9537679688738916, 1.4122975839955771, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 66
# Generation with parameters (1.8105033859873208e+33, 4.987444209352362e+32, 0.0, 0.0, -0.17188084805817327, 0.0, 0.0, 0.16205381802264182, 3.085677581491367e+24, 2.6286560602622924, 1.3914181288642506, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8105033859873208e+33, 4.987444209352362e+32, 0.0, 0.0, -0.17188084805817327, 0.0, 0.0, 0.16205381802264182, 3.085677581491367e+24, 2.6286560602622924, 1.3914181288642506, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 67
# Generation with parameters (9.620790069285253e+32, 9.446849786184945e+32, 0.0, 0.0, 0.4342322646820332, 0.0, 0.0, -0.0150651146704427, 3.085677581491367e+24, 1.7666107941627336, 3.9345489416154216, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.620790069285253e+32, 9.446849786184945e+32, 0.0, 0.0, 0.4342322646820332, 0.0, 0.0, -0.0150651146704427, 3.085677581491367e+24, 1.7666107941627336, 3.9345489416154216, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 68
# Generation with parameters (1.9369699252202317e+33, 3.255680016319445e+32, 0.0, 0.0, 0.3900651208568476, 0.0, 0.0, -0.06741481698881177, 3.085677581491367e+24, 0.5727888345445613, 3.0952470085572314, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.9369699252202317e+33, 3.255680016319445e+32, 0.0, 0.0, 0.3900651208568476, 0.0, 0.0, -0.06741481698881177, 3.085677581491367e+24, 0.5727888345445613, 3.0952470085572314, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 69
# Generation with parameters (1.408961427455853e+33, 3.4033689515442635e+32, 0.0, 0.0, -0.0855107303584391, 0.0, 0.0, 0.040058316412904506, 3.085677581491367e+24, 2.611330930011362, 2.8071506459246796, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.408961427455853e+33, 3.4033689515442635e+32, 0.0, 0.0, -0.0855107303584391, 0.0, 0.0, 0.040058316412904506, 3.085677581491367e+24, 2.611330930011362, 2.8071506459246796, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 70
# Generation with parameters (1.7922612311912687e+33, 3.2526038668657146e+32, 0.0, 0.0, -0.0640788747462295, 0.0, 0.0, -0.0010495176060248174, 3.085677581491367e+24, 0.9989858525351331, 0.21993117594650813, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7922612311912687e+33, 3.2526038668657146e+32, 0.0, 0.0, -0.0640788747462295, 0.0, 0.0, -0.0010495176060248174, 3.085677581491367e+24, 0.9989858525351331, 0.21993117594650813, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 71
# Generation with parameters (1.5088961862288553e+33, 3.912998033996042e+32, 0.0, 0.0, 0.8043436787069448, 0.0, 0.0, -0.17052415121693196, 3.085677581491367e+24, 2.064583777288348, 4.605483870418012, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5088961862288553e+33, 3.912998033996042e+32, 0.0, 0.0, 0.8043436787069448, 0.0, 0.0, -0.17052415121693196, 3.085677581491367e+24, 2.064583777288348, 4.605483870418012, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 72
# Running injection 73
# Generation with parameters (1.839379673663119e+33, 2.6758873413829922e+32, 0.0, 0.0, -0.05830860878056208, 0.0, 0.0, 0.08326752492834964, 3.085677581491367e+24, 0.6688069812530055, 0.682005721636133, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.839379673663119e+33, 2.6758873413829922e+32, 0.0, 0.0, -0.05830860878056208, 0.0, 0.0, 0.08326752492834964, 3.085677581491367e+24, 0.6688069812530055, 0.682005721636133, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 74
# Running injection 75
# Running injection 76
# Generation with parameters (9.331157796801041e+32, 5.7482045535370936e+32, 0.0, 0.0, 0.618128484344887, 0.0, 0.0, 0.007487360481032954, 3.085677581491367e+24, 1.4131175412027919, 1.8492266694178265, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.331157796801041e+32, 5.7482045535370936e+32, 0.0, 0.0, 0.618128484344887, 0.0, 0.0, 0.007487360481032954, 3.085677581491367e+24, 1.4131175412027919, 1.8492266694178265, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 77
# Generation with parameters (1.4666797507936582e+33, 3.885465381647088e+32, 0.0, 0.0, 0.2785913875761074, 0.0, 0.0, 0.6958495005099833, 3.085677581491367e+24, 1.6826756446140845, 0.06848847355202699, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4666797507936582e+33, 3.885465381647088e+32, 0.0, 0.0, 0.2785913875761074, 0.0, 0.0, 0.6958495005099833, 3.085677581491367e+24, 1.6826756446140845, 0.06848847355202699, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 78
# Generation with parameters (1.570455445980889e+33, 3.2484337872588414e+32, 0.0, 0.0, -0.4705958812111001, 0.0, 0.0, 0.01339764373130723, 3.085677581491367e+24, 0.629170922362008, 4.514574099327185, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.570455445980889e+33, 3.2484337872588414e+32, 0.0, 0.0, -0.4705958812111001, 0.0, 0.0, 0.01339764373130723, 3.085677581491367e+24, 0.629170922362008, 4.514574099327185, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 79
# Running injection 80
# Generation with parameters (2.0032347924767903e+33, 3.1615039121998835e+32, 0.0, 0.0, -0.022132759427496165, 0.0, 0.0, -0.0033348899246083592, 3.085677581491367e+24, 0.8828392439173676, 0.14354196231145974, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0032347924767903e+33, 3.1615039121998835e+32, 0.0, 0.0, -0.022132759427496165, 0.0, 0.0, -0.0033348899246083592, 3.085677581491367e+24, 0.8828392439173676, 0.14354196231145974, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 81
# Generation with parameters (5.982266756631878e+32, 5.973734605070936e+32, 0.0, 0.0, -0.42264425742999145, 0.0, 0.0, 0.17133464764807613, 3.085677581491367e+24, 0.25558581468488833, 5.574703519307748, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (5.982266756631878e+32, 5.973734605070936e+32, 0.0, 0.0, -0.42264425742999145, 0.0, 0.0, 0.17133464764807613, 3.085677581491367e+24, 0.25558581468488833, 5.574703519307748, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 82
# Generation with parameters (1.0935405529482506e+33, 5.90309574591567e+32, 0.0, 0.0, -0.07008725796460497, 0.0, 0.0, -0.11648877859278282, 3.085677581491367e+24, 0.18644404770548098, 1.7898950749142002, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0935405529482506e+33, 5.90309574591567e+32, 0.0, 0.0, -0.07008725796460497, 0.0, 0.0, -0.11648877859278282, 3.085677581491367e+24, 0.18644404770548098, 1.7898950749142002, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 83
# Generation with parameters (2.265688380441866e+33, 3.174434837583088e+32, 0.0, 0.0, -0.006830212483560786, 0.0, 0.0, 0.013096649252919907, 3.085677581491367e+24, 2.2675724925507805, 0.213004938338949, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.265688380441866e+33, 3.174434837583088e+32, 0.0, 0.0, -0.006830212483560786, 0.0, 0.0, 0.013096649252919907, 3.085677581491367e+24, 2.2675724925507805, 0.213004938338949, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 84
# Generation with parameters (1.7875749195972042e+33, 3.0748510755303345e+32, 0.0, 0.0, 0.5070127828681334, 0.0, 0.0, -0.15939027544757658, 3.085677581491367e+24, 2.164785618661555, 3.0567272035310658, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7875749195972042e+33, 3.0748510755303345e+32, 0.0, 0.0, 0.5070127828681334, 0.0, 0.0, -0.15939027544757658, 3.085677581491367e+24, 2.164785618661555, 3.0567272035310658, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 85
# Running injection 86
# Generation with parameters (1.5766851179960883e+33, 4.446631285394813e+32, 0.0, 0.0, 0.1945643222494214, 0.0, 0.0, 0.4854266711547538, 3.085677581491367e+24, 1.6162510413945728, 2.087791754109288, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.5766851179960883e+33, 4.446631285394813e+32, 0.0, 0.0, 0.1945643222494214, 0.0, 0.0, 0.4854266711547538, 3.085677581491367e+24, 1.6162510413945728, 2.087791754109288, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 87
# Generation with parameters (1.8926557475794238e+33, 4.485379443020169e+32, 0.0, 0.0, 0.769302340384723, 0.0, 0.0, 0.12101249693724007, 3.085677581491367e+24, 1.9450389154047216, 0.5699127889831754, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# ...
# Running injection 968
# Generation with parameters (1.8353046614828066e+33, 3.707876726159189e+32, 0.0, 0.0, -0.5057550586665246, 0.0, 0.0, -0.6681138036760079, 3.085677581491367e+24, 1.5736192289046198, 4.499046051639918, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8353046614828066e+33, 3.707876726159189e+32, 0.0, 0.0, -0.5057550586665246, 0.0, 0.0, -0.6681138036760079, 3.085677581491367e+24, 1.5736192289046198, 4.499046051639918, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 969
# Generation with parameters (2.0064595818193664e+33, 4.921431248180672e+32, 0.0, 0.0, -0.29386051967075744, 0.0, 0.0, 0.053814844861946216, 3.085677581491367e+24, 2.0351282570894043, 0.23240676225547707, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.0064595818193664e+33, 4.921431248180672e+32, 0.0, 0.0, -0.29386051967075744, 0.0, 0.0, 0.053814844861946216, 3.085677581491367e+24, 2.0351282570894043, 0.23240676225547707, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 970
# Running injection 971
# Generation with parameters (2.02843219901114e+33, 2.9015833522642004e+32, 0.0, 0.0, -0.26864452110509796, 0.0, 0.0, -0.2726511964450491, 3.085677581491367e+24, 2.157202141612477, 2.775031473729415, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.02843219901114e+33, 2.9015833522642004e+32, 0.0, 0.0, -0.26864452110509796, 0.0, 0.0, -0.2726511964450491, 3.085677581491367e+24, 2.157202141612477, 2.775031473729415, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 972
# Running injection 973
# Generation with parameters (8.37923057941127e+32, 4.6988933761720655e+32, 0.0, 0.0, 0.10854717683726257, 0.0, 0.0, -0.14213197609538414, 3.085677581491367e+24, 2.1013664785415083, 2.3374418128719894, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.37923057941127e+32, 4.6988933761720655e+32, 0.0, 0.0, 0.10854717683726257, 0.0, 0.0, -0.14213197609538414, 3.085677581491367e+24, 2.1013664785415083, 2.3374418128719894, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 974
# Generation with parameters (1.0866180461852129e+33, 3.16059610965175e+32, 0.0, 0.0, 0.32282925427284476, 0.0, 0.0, 0.002321863679490931, 3.085677581491367e+24, 0.819673631238932, 5.266886255576747, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.0866180461852129e+33, 3.16059610965175e+32, 0.0, 0.0, 0.32282925427284476, 0.0, 0.0, 0.002321863679490931, 3.085677581491367e+24, 0.819673631238932, 5.266886255576747, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 975
# Generation with parameters (2.543866869146981e+33, 3.7151157061011676e+32, 0.0, 0.0, 0.06232705843001195, 0.0, 0.0, 0.5871970287468652, 3.085677581491367e+24, 1.3854444253613658, 3.675151514323769, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.543866869146981e+33, 3.7151157061011676e+32, 0.0, 0.0, 0.06232705843001195, 0.0, 0.0, 0.5871970287468652, 3.085677581491367e+24, 1.3854444253613658, 3.675151514323769, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 976
# Running injection 977
# Generation with parameters (8.72762863603953e+32, 7.73008936256714e+32, 0.0, 0.0, -0.025952039204239188, 0.0, 0.0, 0.2836917459252603, 3.085677581491367e+24, 2.3346565020969545, 4.135296300109191, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.72762863603953e+32, 7.73008936256714e+32, 0.0, 0.0, -0.025952039204239188, 0.0, 0.0, 0.2836917459252603, 3.085677581491367e+24, 2.3346565020969545, 4.135296300109191, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 978
# Running injection 979
# Running injection 980
# Generation with parameters (9.745047702218785e+32, 7.905550176178019e+32, 0.0, 0.0, 0.0015671995556056785, 0.0, 0.0, -0.04726493162410686, 3.085677581491367e+24, 2.378276466971863, 0.20094883281488352, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (9.745047702218785e+32, 7.905550176178019e+32, 0.0, 0.0, 0.0015671995556056785, 0.0, 0.0, -0.04726493162410686, 3.085677581491367e+24, 2.378276466971863, 0.20094883281488352, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 981
# Generation with parameters (1.8382791961571347e+33, 4.106095349044368e+32, 0.0, 0.0, 0.016497814312704934, 0.0, 0.0, -0.04584045258300176, 3.085677581491367e+24, 2.090250910413029, 3.7796476373468004, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8382791961571347e+33, 4.106095349044368e+32, 0.0, 0.0, 0.016497814312704934, 0.0, 0.0, -0.04584045258300176, 3.085677581491367e+24, 2.090250910413029, 3.7796476373468004, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 982
# Running injection 983
# Generation with parameters (1.8818899786800262e+33, 2.6439959580491844e+32, 0.0, 0.0, 0.09488629944715078, 0.0, 0.0, 0.14524367074557296, 3.085677581491367e+24, 1.2262634262395198, 3.4260348817089215, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8818899786800262e+33, 2.6439959580491844e+32, 0.0, 0.0, 0.09488629944715078, 0.0, 0.0, 0.14524367074557296, 3.085677581491367e+24, 1.2262634262395198, 3.4260348817089215, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 984
# Generation with parameters (2.1255811796059512e+33, 3.61645543034407e+32, 0.0, 0.0, -0.1584146292767169, 0.0, 0.0, -0.049189040388100874, 3.085677581491367e+24, 1.4006704137226995, 3.741918997914139, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.1255811796059512e+33, 3.61645543034407e+32, 0.0, 0.0, -0.1584146292767169, 0.0, 0.0, -0.049189040388100874, 3.085677581491367e+24, 1.4006704137226995, 3.741918997914139, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 985
# Generation with parameters (8.37164852078601e+32, 7.594071962351822e+32, 0.0, 0.0, 0.035829713418267066, 0.0, 0.0, -0.29642761670122747, 3.085677581491367e+24, 0.9109728942640347, 4.597042332947446, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.37164852078601e+32, 7.594071962351822e+32, 0.0, 0.0, 0.035829713418267066, 0.0, 0.0, -0.29642761670122747, 3.085677581491367e+24, 0.9109728942640347, 4.597042332947446, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 986
# Running injection 987
# Generation with parameters (1.7596926232202085e+33, 2.342257997154639e+32, 0.0, 0.0, -0.03389321331204387, 0.0, 0.0, 0.07399670013184584, 3.085677581491367e+24, 0.610989107171764, 4.414483843212936, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7596926232202085e+33, 2.342257997154639e+32, 0.0, 0.0, -0.03389321331204387, 0.0, 0.0, 0.07399670013184584, 3.085677581491367e+24, 0.610989107171764, 4.414483843212936, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 988
# Generation with parameters (1.4045713346294358e+33, 2.7261593029633888e+32, 0.0, 0.0, -0.049213470642197825, 0.0, 0.0, -0.044272996747516107, 3.085677581491367e+24, 2.201588536975008, 2.3167736861773083, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4045713346294358e+33, 2.7261593029633888e+32, 0.0, 0.0, -0.049213470642197825, 0.0, 0.0, -0.044272996747516107, 3.085677581491367e+24, 2.201588536975008, 2.3167736861773083, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 989
# Running injection 990
# Generation with parameters (2.5010469621704532e+33, 3.644322618462359e+32, 0.0, 0.0, -0.20774905680310232, 0.0, 0.0, -0.6229066252858444, 3.085677581491367e+24, 1.6073058846773371, 2.5543819678378132, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.5010469621704532e+33, 3.644322618462359e+32, 0.0, 0.0, -0.20774905680310232, 0.0, 0.0, -0.6229066252858444, 3.085677581491367e+24, 1.6073058846773371, 2.5543819678378132, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 991
# Generation with parameters (2.1418594638610413e+33, 3.580705451564019e+32, 0.0, 0.0, 0.00498486800845011, 0.0, 0.0, 0.5659591684451571, 3.085677581491367e+24, 1.0550169690102638, 4.647470718904427, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (2.1418594638610413e+33, 3.580705451564019e+32, 0.0, 0.0, 0.00498486800845011, 0.0, 0.0, 0.5659591684451571, 3.085677581491367e+24, 1.0550169690102638, 4.647470718904427, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 992
# Generation with parameters (1.1462833706209364e+33, 6.011228127233866e+32, 0.0, 0.0, -0.0511809072705436, 0.0, 0.0, 0.2747397470154513, 3.085677581491367e+24, 1.8946363353017275, 0.5214674617307022, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.1462833706209364e+33, 6.011228127233866e+32, 0.0, 0.0, -0.0511809072705436, 0.0, 0.0, 0.2747397470154513, 3.085677581491367e+24, 1.8946363353017275, 0.5214674617307022, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 993
# Generation with parameters (1.557450798756538e+33, 3.296131568715747e+32, 0.0, 0.0, -0.8098197848342701, 0.0, 0.0, 0.026640433990151167, 3.085677581491367e+24, 0.9557423046091647, 4.230147376967659, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.557450798756538e+33, 3.296131568715747e+32, 0.0, 0.0, -0.8098197848342701, 0.0, 0.0, 0.026640433990151167, 3.085677581491367e+24, 0.9557423046091647, 4.230147376967659, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 994
# Generation with parameters (1.4732936080359075e+33, 5.5822622923976776e+32, 0.0, 0.0, -0.4408036187607989, 0.0, 0.0, -0.3820616280863168, 3.085677581491367e+24, 1.808304857027988, 4.345837179140212, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.4732936080359075e+33, 5.5822622923976776e+32, 0.0, 0.0, -0.4408036187607989, 0.0, 0.0, -0.3820616280863168, 3.085677581491367e+24, 1.808304857027988, 4.345837179140212, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 995
# Generation with parameters (8.597964876602468e+32, 5.1767924196007716e+32, 0.0, 0.0, 0.1594828961708027, 0.0, 0.0, 0.21053205031248567, 3.085677581491367e+24, 2.6254349997336917, 0.0766339823314004, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (8.597964876602468e+32, 5.1767924196007716e+32, 0.0, 0.0, 0.1594828961708027, 0.0, 0.0, 0.21053205031248567, 3.085677581491367e+24, 2.6254349997336917, 0.0766339823314004, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 996
# Generation with parameters (1.7708152314667464e+33, 2.553583135816639e+32, 0.0, 0.0, -0.15322916824298777, 0.0, 0.0, 0.025306517488770625, 3.085677581491367e+24, 1.8998516189204482, 2.9612423973934767, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.7708152314667464e+33, 2.553583135816639e+32, 0.0, 0.0, -0.15322916824298777, 0.0, 0.0, 0.025306517488770625, 3.085677581491367e+24, 1.8998516189204482, 2.9612423973934767, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 997
# Running injection 998
# Generation with parameters (1.3691660798928696e+33, 2.7681482631476315e+32, 0.0, 0.0, 0.018685850367130493, 0.0, 0.0, -0.030546973862106155, 3.085677581491367e+24, 1.0267471129961172, 3.4232183322031284, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.3691660798928696e+33, 2.7681482631476315e+32, 0.0, 0.0, 0.018685850367130493, 0.0, 0.0, -0.030546973862106155, 3.085677581491367e+24, 1.0267471129961172, 3.4232183322031284, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.
# Running injection 999
# Generation with parameters (1.8770207104771536e+33, 4.3476715216387304e+32, 0.0, 0.0, 0.0007734860690286834, 0.0, 0.0, -0.05473000465346336, 3.085677581491367e+24, 1.6127948537266306, 1.8944250498978608, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically unstable due to multibanding, turn off multibanding.
# Warning: turning off multibanding for parameters (1.8770207104771536e+33, 4.3476715216387304e+32, 0.0, 0.0, 0.0007734860690286834, 0.0, 0.0, -0.05473000465346336, 3.085677581491367e+24, 1.6127948537266306, 1.8944250498978608, 0.0, 0.0, 0.0, 0.125, 6.0, 256.0, 20.0, None, 101) likely numerically might not have fixed it, check manually.

# %% [markdown]
# ## Infere parameters

# %%
# %%capture  
#avoids printing a lot of output to the notebook
import pandas as pd
from dingo.gw.inference.gw_samplers import GWSampler




os.makedirs(f"/scratch/tpausch/test_data/{name}/results", exist_ok=True)

injection_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/injections"))

for fname in injection_files[:100]:  # only run the first 10 injections for testing

    # --------------------------------------------------------
    # Load injection
    # --------------------------------------------------------

    with open(f"/scratch/tpausch/test_data/{name}/injections/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    strain_data = payload["strain_data"]

    # --------------------------------------------------------
    # Run sampler
    # --------------------------------------------------------

    sampler = GWSampler(model=main_pm)

    sampler.context = strain_data

    sampler.run_sampler(
        num_samples=50_000,
        batch_size=10_000,
    )

    result = sampler.to_result()



    # --------------------------------------------------------
    # calculate network SNR
    # --------------------------------------------------------
    parameters = pd.DataFrame(
        {key: np.array([np.asarray(val).item()]) for key, val in theta_true.items()}
    )
    snr_df = gw.utilities.get_snr(parameters, network, waveform_model, f_ref)
    network_snr = float(snr_df["network"].iloc[0])  # extract as plain float

    # --------------------------------------------------------
    # Store result
    # --------------------------------------------------------

    result_payload = {
        "theta_true": theta_true,
        "result": result,
        "network_snr": network_snr,
    }

    outname = fname.replace("inj_", "result_")

    with open(f"/scratch/tpausch/test_data/{name}/results/{outname}", "wb") as f:
        pickle.dump(result_payload, f)

    print(f"Saved /scratch/tpausch/test_data/{name}/results/{outname}")

# %% [markdown]
# ## Calculate and plot chirp mass inference error

# %%
true_cm = []
true_mr = []
mass_ratio_error = []
mass_ratio_std = []
chirp_mass_error = []
chirp_mass_std = []


result_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/{name}/results/{fname}", "rb") as f:
        payload = pickle.load(f)

    theta_true = payload["theta_true"]
    result = payload["result"]

    posterior_samples = result.samples

    #q_samples = np.array(posterior_samples["mass_ratio"])

    # inference statistics
    #q_mean = np.mean(q_samples)
    #q_std = np.std(q_samples)
#
    #true_q = theta_true["mass_ratio"]

    cm_samples = np.array(posterior_samples["chirp_mass"])

    cm_mean = np.mean(cm_samples)
    cm_std = np.std(cm_samples)

    true_mr.append(theta_true["mass_ratio"])
    true_cm.append(theta_true["chirp_mass"])
    #mass_ratio_error.append(q_mean - true_q)
    #mass_ratio_std.append(q_std)
    chirp_mass_error.append(cm_mean - theta_true["chirp_mass"])
    chirp_mass_std.append(cm_std)


true_mr = np.array(true_mr)
true_cm = np.array(true_cm)

# ------------------------------------------------------------
# Error bars
# ------------------------------------------------------------

#plt.errorbar(
#    true_cm,
#    chirp_mass_error,
#    yerr=chirp_mass_std,
#    fmt="none",
#    capsize=4,
#    alpha=0.5,
#    color="gray",
#)

# ------------------------------------------------------------
# Colored scatter points
# ------------------------------------------------------------

sc = plt.scatter(
    true_cm,
    chirp_mass_error,
    s=20,
    edgecolor="black",
    alpha=0.3
)

# ------------------------------------------------------------
# Reference line
# ------------------------------------------------------------

plt.axhline(0, linestyle="--", color="black")


# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel("True chirp mass")
plt.ylabel("Chirp mass inference error (inferred − true)")

plt.title("Chirp-mass inference error")

plt.grid(True)

plt.tight_layout()
plt.show()

cm_err = np.asarray(chirp_mass_error)

mean_error = np.mean(cm_err)          # signed average bias (over/under-estimation)
mean_abs_error = np.mean(np.abs(cm_err))  # average magnitude of deviation
rms_error = np.sqrt(np.mean(cm_err**2))   # RMS deviation, penalizes outliers more
std_error = np.std(cm_err)            # spread of the errors around their mean
p90_abs_error = np.percentile(np.abs(cm_err), 90)
p95_abs_error = np.percentile(np.abs(cm_err), 95)
p99_abs_error = np.percentile(np.abs(cm_err), 99)


print(f"Mean error (bias):      {mean_error:.3f}")
print(f"Mean absolute error:    {mean_abs_error:.3f}")
print(f"RMS error:              {rms_error:.3f}")
print(f"Std of error:           {std_error:.3f}")
print(f"90th percentile |error|: {p90_abs_error:.3f}")
print(f"95th percentile |error|: {p95_abs_error:.3f}")
print(f"99th percentile |error|: {p99_abs_error:.3f}")
# Out:
# Mean error (bias):      0.313
# Mean absolute error:    13.410
# RMS error:              22.960
# Std of error:           22.958
# 90th percentile |error|: 37.407
# 95th percentile |error|: 56.261
# 99th percentile |error|: 84.504

# %% [markdown]
# ## PP-plot

# %%
pp_values_chirp_mass = []
pp_values_mass_ratio = []

result_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/{name}/results/{fname}", "rb") as f:

        payload = pickle.load(f)

        theta_true = payload["theta_true"]
        result = payload["result"]

        posterior_samples = result.samples


        # ============================================================
        # Chirp mass PP value
        # ============================================================

        cm_samples = posterior_samples["chirp_mass"]

        pp_cm = np.mean(
            cm_samples < theta_true["chirp_mass"]
        )

        pp_values_chirp_mass.append(pp_cm)


        # ============================================================
        # Mass ratio PP value
        # ============================================================

        #q_samples = posterior_samples["mass_ratio"]
#
        #pp_q = np.mean(
        #    q_samples < theta_true["mass_ratio"]
        #)
#
        #pp_values_mass_ratio.append(pp_q)




def plot_pp(pp_values, label):

    pp_values = np.array(pp_values)

    sorted_pp = np.sort(pp_values)

    n = len(sorted_pp)

    empirical_cdf = np.arange(1, n + 1) / n

    x = np.linspace(0, 1, 200)

    sigma = np.sqrt(x * (1 - x) / n)

    plt.figure(figsize=(6, 6))

    # Ideal calibration
    plt.plot(
        [0, 1],
        [0, 1],
        linestyle="--",
        label="Ideal calibration",
    )


    # Empirical PP curve
    plt.plot(
        sorted_pp,
        empirical_cdf,
        marker="o",
        label=label,
    )

    plt.xlabel("Credible level")
    plt.ylabel("Fraction of injections")

    plt.title(f"PP Plot: {label}")

    plt.xlim(0, 1)
    plt.ylim(0, 1)

    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()


plot_pp(
    pp_values_chirp_mass,
    "chirp_mass",
)

#plot_pp(
#    pp_values_mass_ratio,
#    "mass_ratio",
#)

# %% [markdown]
# ## SNR analysis

# %%
snrs = []
ci90_widths = []
chirp_masses = []

result_files = sorted(os.listdir(f"/scratch/tpausch/test_data/{name}/results"))

for fname in result_files:

    with open(f"/scratch/tpausch/test_data/{name}/results/{fname}", "rb") as f:

        payload = pickle.load(f)
    
    theta_true = payload["theta_true"]
    result = payload["result"]


    snr = payload["network_snr"]   # use "ET" instead if you want the single-detector value
   

    snrs.append(snr)

    samples = result.samples["chirp_mass"].to_numpy()  # adjust if result.samples is a DataFrame

    ci90 = np.percentile(samples, 95) - np.percentile(samples, 5)
    ci90_widths.append(ci90)
    chirp_masses.append(theta_true["chirp_mass"])

snrs = np.array(snrs)
ci90_widths = np.array(ci90_widths)
chirp_masses = np.array(chirp_masses)

frac_widths = ci90_widths / chirp_masses  # relative width, dimensionless

plt.figure(figsize=(6, 5))
sc = plt.scatter(snrs, ci90_widths, c=chirp_masses, cmap="viridis", alpha=0.6, s=15)
#sc = plt.scatter(snrs, frac_widths, c=chirp_masses, cmap="viridis", alpha=0.6, s=15)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Network SNR")
plt.ylabel("Chirp mass 90% CI width")
plt.colorbar(sc, label="Injected chirp mass [M$_\\odot$]")
plt.title("posterior width vs SNR")
plt.grid(True, which="both", alpha=0.3)
plt.tight_layout()
plt.show()


chirp_mass_error = np.array(chirp_mass_error)
mask = snrs < 100.0

plt.figure(figsize=(10, 5))
sc = plt.scatter(
    snrs[mask],
    chirp_mass_error[mask],
    s=10,
    edgecolor="black",
    alpha=0.3
)

plt.axhline(0, linestyle="--", color="black")
plt.xlabel("SNR")
plt.ylabel("Chirp mass inference error (inferred − true)")
plt.title("Chirp-mass inference error")
plt.grid(True)
plt.tight_layout()
plt.show()




# --- Plot distribution ---
plt.figure(figsize=(6, 5))

# Histogram, normalized to a density so it represents "how likely each value is"
counts, bins, _ = plt.hist(
    snrs, bins=100, density=True, alpha=0.5, color="steelblue", edgecolor="k", label="Histogram"
)
plt.xlabel("Network SNR")
plt.ylabel("Probability density")
plt.title(f"Distribution of injected network SNR (n={len(snrs)})")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()


print(f"SNR stats: min={snrs.min():.2f}, max={snrs.max():.2f}, "
      f"median={np.median(snrs):.2f}, mean={snrs.mean():.2f}",
      f"snr99={np.percentile(np.abs(snrs), 99):.2f}")
# Out:
# SNR stats: min=0.23, max=4798.27, median=122.72, mean=292.31 snr99=1955.50
